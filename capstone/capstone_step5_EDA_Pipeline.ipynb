# %% [markdown]
# # Section 20.6.5 of Machine Learning Bootcamp : Capstone Step 5, Data Wrangling and EDA
#
# Here I will focus on my chosen dataset for the capstone project, using Exploratory Data Analysis methods and Data Wrangling techniques to prepare and better undersnat the data. The prior step of the capstone had me find a similar project, but there it appears all the data was already wrangled and cleaned (for the most part) by whoever is responsible for managing the city's data. Also the writers of the paper seem to have received quite a bit of guidance about how to create the features used in their model, so here I will have to determine all that myself.

# %% [markdown]
# # Step 1: imports, option sets and data loading

# %%
import numpy as np
import pandas as pd
from datetime import datetime as dt

from numpy.lib.recfunctions import drop_fields
from sqlalchemy import create_engine, text
import seaborn as sns
import matplotlib.pyplot as plt
import os
import configparser
import joblib

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, ParameterSampler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score
from scipy.stats import uniform

from sklearn.neighbors import BallTree # for finding nearest geographical neighbors

pd.options.display.max_columns = 999

print(f"NumPy version: {np.__version__}")

# sets up the current date for later calculations
CURRENT_DATE = pd.Timestamp(2024,12,31)
CURRENT_DATE
# Out:
# NumPy version: 2.2.1
# Timestamp('2024-12-31 00:00:00')

# %% [markdown]
# ## CSV Dataset: Idle wells at risk of fees or penalties in California
# <p>To recap, in 2021, new legislation was passed in California that escalates the fines oil & gas operators must pay if they have not tested their idle wells according to the law. There is now a dramatic escalation of fees based on a schedule of the age of the well, and the duration of idleness.<br></p>
#
# <p><b>Problem statement:</b> Given that not all the data is available to accurately determine the specific status of a well, I think we can using machine learning to assess the companies exposure to the risk: i.e. have they been addressing their idle well burden by plugging & abandoning their idle well fleets, or are they "kicking the can down the road", and postponing until max pain arrives.<br></p>
#
# <p><b>Hypothesis:</b> I think the larger companies (Chevron, Aera, SPR, CRC) are likely addressing their own idle well situations in a way to avoid onerous fees, and potentially damaging optics of not following the law. However, I suspect there a large number of smaller privately owned companies that have not kept up with their liabilities, and either don't have the cash flow to take care of it, or are hoping to fly under the radar for a bit longer.</p>
#
# <p><b>Data set:</b> the state publishes its view of the list of all wells in the state (241,912 data points, each of which represents a physical well), with currently known status and original drill (SPUD) date, so we know the age of the well, and the state's view of the status, which they have likely calculated based on the monthly production reports the operators are legally bound to send them. I have heard annecdotally it can take the state up to 2 years to update the well status, so there's some room here for machine learning to predict a trend by operator.</p>
#
# **Files:**
#     - master well listing: downloaded from state's website (filesize 55MB): <a href='https://gis.conservation.ca.gov/portal/home/item.html?id=0d30c4d9ac8f4f84a53a145e7d68eb6b'>linked here</a> and added to my git repo here: <a href='source_data/CALGEM AllWells_20241113.csv'>CALGEM AllWells_20241113.csv</a>
#     - production/injection data files: use this link and then search for "BAK" files to get the database backups by year from 2019-current. https://wellstar-public.conservation.ca.gov/General/PublicDownloads/Index
#     - older database files are available here: https://filerequest.conservation.ca.gov/?q=pre-2018_data_format

# %%
# joined 2 datasets together already in Excel, the all well list, and the idle list

# load candidate data file 1 and take a peek
# will take some work to get the data loaded with proper datatypes, and dates set correctly
# I'll use the API as the index as it should be unique, and is the well's identifier if any other data gets joined later.
well_list_datatypes = {
    'API':str,
    'LeaseName':str,
    'WellNumber':str,
    'WellDesign':str,
    'WellStatus':str,
    'WellType':str,
    'WellTypeLa':str,
    'OperatorCo':str,
    'OperatorNa':str,
    'FieldName':str,
    'AreaName':str,
    'Place':str,
    'District':str,
    'CountyName':str,
    'Section':int,
    'Township':str,
    'Range':str,
    'BaseMeridi':str,
    'Latitude':np.float64,
    'Longitude':np.float64,
    'GISSource':str,
    'isConfiden':str,
    'isDirectio':str,
    'inHPZ':str,
    'WellSymbol':str,
    'YearsIdle':np.float32,
    'IsLTIW':str,
    'UnsatAbandon':str
}

parse_date_list = ['SpudDate', 'IdleDate']
# CALGEM AllWells_20241113.csv
well_list_df = pd.read_csv('source_data/CALGEM AllWells_20241113.csv', dtype=well_list_datatypes, parse_dates=parse_date_list, date_format='%m/%d/%Y', skipinitialspace=True)
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                       NaN
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N 2001-08-14  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N 1993-01-05  Potentially Not Within HPZ
# 241911          N          N 1982-07-27  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon
# 0          IdleDG 1901-01-01  123.000000    Yes           No
# 1          IdleDG 2015-08-01    8.416667    Yes           No
# 2          IdleDG 2015-08-01    8.416667    Yes           No
# 3          IdleDG 2011-06-01   12.583333    Yes           No
# 4        ActiveDG        NaT         NaN    NaN          NaN
# ...           ...        ...         ...    ...          ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN
# 241908  PluggedDH        NaT         NaN    NaN          NaN
# 241909  PluggedDG        NaT         NaN    NaN          NaN
# 241910  PluggedDH        NaT         NaN    NaN          NaN
# 241911  PluggedDH        NaT         NaN    NaN          NaN
#
# [241912 rows x 30 columns]

# %% [markdown]
# ## SQL Data: Loading well numbers and last production dates for merging

# %%
# After inserting a new well/year row into "wells". use "mycursor.lastrowid" or "connection.insert_id()" to get the Last inserted ID for the monthly_well_volumes table
prod_dates_df = pd.DataFrame()
pickle_file_name = "last_prod_date.pkl"

if os.path.exists(pickle_file_name) :
    print("Reading existing well start and end dates pickle...")
    prod_dates_df = pd.read_pickle(pickle_file_name)
else:
    print("Reading last prod data from SQL...")
    mysql_dbname = "doggr"
    mysql_well_tablename ='wells_test'
    mysql_mv_tablename = 'monthly_well_volume_test'

    cfg = configparser.ConfigParser()
    cfg.read('mysql_creds.ini')
    mysql_cfg = cfg['mysql']

    mysql_user = mysql_cfg['mysql_user']
    mysql_password = mysql_cfg['mysql_password']
    mysql_host = mysql_cfg['mysql_host']

    # Connect to the mysql server to load the data
    # SQLAlchemy uses a database driver to connect, in this case I'll use mysql-connector-python
    conn_str = f"mysql+mysqlconnector://{mysql_user}:{mysql_password}@{mysql_host}/{mysql_dbname}"
    engine = create_engine(conn_str, echo=True)

    # This finds the last production or injection by API number
    sql_query = '''
    WITH volumes AS (
        SELECT
            api_no,
            prod_inj_date,
            COALESCE(oil_prod_vol_bbl,0)+COALESCE(gas_prod_vol_mcf,0)+COALESCE(water_prod_vol_bbl,0)+COALESCE(gas_inj_vol_mcf,0)+COALESCE(water_inj_vol_bbl,0)+COALESCE(stm_inj_vol_bbl,0) as volume
        FROM doggr.monthly_well_volume
        WHERE prod_inj_date is not null
        AND (COALESCE(oil_prod_vol_bbl,0)+COALESCE(gas_prod_vol_mcf,0)+COALESCE(water_prod_vol_bbl,0)+COALESCE(gas_inj_vol_mcf,0)+COALESCE(water_inj_vol_bbl,0)+COALESCE(stm_inj_vol_bbl,0)) > 0
    )
    SELECT
        left(api_no,10) as api_10,
        min(case when volume > 0 or volume is not null then prod_inj_date else null end) as first_date,
        max(case when volume > 0 or volume is not null then prod_inj_date else null end) as last_date
    FROM
        volumes
    GROUP BY left(api_no,10)
    ORDER BY left(api_no,10)
    '''

    with engine.begin() as conn:
        result = conn.execute(text(sql_query))
        # Get the well_id list by api_key
        prod_dates_df = pd.DataFrame(result.fetchall(), columns=result.keys())

    # MYSQL provides the Date in format '%Y-%m-%d', maybe it's an ISO default, not sure
    # NOTE: there is no native Pandas 'date' object, so to do date-based math later, we need to keep the column type 'datetime64[ns]'
    prod_dates_df['first_date'] = pd.to_datetime(prod_dates_df['first_date'], format='%Y-%m-%d').astype('datetime64[ns]')
    prod_dates_df['last_date'] = pd.to_datetime(prod_dates_df['last_date'], format='%Y-%m-%d').astype('datetime64[ns]')

    # save it to a local file, the SQL takes ~ 5 minutes to run
    # protocol=4 ensures backwards compatibility to whatever AWS is using still (NumPy version: 1.26.4 ffs)
    prod_dates_df.to_pickle(pickle_file_name, protocol=4)

prod_dates_df
# Out:
# Reading existing well start and end dates pickle...
#             api_10 first_date  last_date
# 0       0400100001 1977-01-31 2019-12-31
# 1       0400120004 1977-01-31 2022-01-31
# 2       0400120005 1977-01-31 1989-12-31
# 3       0400120008 1977-01-31 2014-06-30
# 4       0400120009 1977-01-31 2020-11-30
# ...            ...        ...        ...
# 153305  0428321583 1983-05-31 1992-08-31
# 153306  0428321584 1983-08-31 1990-07-31
# 153307  0428321585 1983-11-30 1992-08-31
# 153308  0428321586 1984-03-31 1992-08-31
# 153309  0429520060 1977-01-31 1988-09-30
#
# [153310 rows x 3 columns]

# %%
prod_dates_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153310 entries, 0 to 153309
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   api_10      153310 non-null  object
#  1   first_date  153310 non-null  datetime64[ns]
#  2   last_date   153310 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Basic Data Checks for missing and bad outliers
# 1 well is missing FieldName, which is really important later, so fixing it here

# %%
# looks like 1 null FieldName, replace with the generic 'Any Field' designation
well_list_df.fillna({'FieldName':'Any Field'}, inplace=True)

# %% [markdown]
# There are 8 wells with SPUD Date of `1801-01-01`, which is a placeholder. I'll set these to NULL and impute.

# %%
well_list_df.value_counts('SpudDate').sort_index().head(15)
# Out:
# SpudDate
# 1801-01-01    8
# 1867-08-01    1
# 1882-03-25    1
# 1885-04-09    1
# 1886-02-12    1
# 1886-04-14    1
# 1886-05-31    1
# 1887-01-01    3
# 1887-01-21    1
# 1887-03-25    1
# 1887-04-15    1
# 1887-07-18    1
# 1887-08-02    1
# 1887-08-13    1
# 1887-08-18    1
# Name: count, dtype: int64

# %%
well_list_df[well_list_df['SpudDate'] == pd.Timestamp(1801,1,1)]
# Out:
#                API             LeaseName WellNumber                WellDesign  \
# 132290  0402922369             Producers        8-B             Producers 8-B
# 157456  0403061290   Santiago Creek Unit       G-12  Santiago Creek Unit G-12
# 157457  0403061347   Santiago Creek Unit       G-13  Santiago Creek Unit G-13
# 157520  0403062014   Santiago Creek Unit       H-12  Santiago Creek Unit H-12
# 157521  0403062013   Santiago Creek Unit       H-13  Santiago Creek Unit H-13
# 197867  0403713276  Rancho San Francisco         96   Rancho San Francisco 96
# 197935  0403712621  Rancho San Francisco          2    Rancho San Francisco 2
# 197965  0403712858  Rancho San Francisco         45   Rancho San Francisco 45
#
#        WellStatus WellType WellTypeLa OperatorCo  \
# 132290    Plugged       OG  Oil & Gas      C5640
# 157456   Canceled       OG  Oil & Gas      H5200
# 157457   Canceled       OG  Oil & Gas      H5200
# 157520   Canceled       OG  Oil & Gas      H5200
# 157521   Canceled       OG  Oil & Gas      H5200
# 197867       Idle       OG  Oil & Gas      C0885
# 197935    Plugged       OG  Oil & Gas      C0885
# 197965    Plugged       OG  Oil & Gas      C0885
#
#                                          OperatorNa        FieldName  \
# 132290                          Chevron U.S.A. Inc.       Kern River
# 157456               Holmes Western Oil Corporation    Midway-Sunset
# 157457               Holmes Western Oil Corporation    Midway-Sunset
# 157520               Holmes Western Oil Corporation    Midway-Sunset
# 157521               Holmes Western Oil Corporation    Midway-Sunset
# 197867  California Resources Production Corporation  Newhall-Potrero
# 197935  California Resources Production Corporation  Newhall-Potrero
# 197965  California Resources Production Corporation  Newhall-Potrero
#
#         AreaName               Place  District   CountyName  Section Township  \
# 132290  Any Area         Kern County    Inland         Kern       36      28S
# 157456  Any Area         Kern County    Inland         Kern       21      11N
# 157457  Any Area         Kern County    Inland         Kern       21      11N
# 157520  Any Area         Kern County    Inland         Kern       21      11N
# 157521  Any Area         Kern County    Inland         Kern       21      11N
# 197867  Any Area  Los Angeles County  Northern  Los Angeles       25      04N
# 197935  Any Area  Los Angeles County  Northern  Los Angeles       26      04N
# 197965  Any Area  Los Angeles County  Northern  Los Angeles       27      04N
#
#        Range BaseMeridi   Latitude   Longitude     GISSource isConfiden  \
# 132290   27E         MD  35.444439 -119.012604  Well Summary          N
# 157456   23W         SB  35.031590 -119.340668  Well Summary          N
# 157457   23W         SB  35.031960 -119.341469  Well Summary          N
# 157520   23W         SB  35.031502 -119.340668  Well Summary          N
# 157521   23W         SB  35.031956 -119.341621  Well Summary          N
# 197867   17W         SB  34.392723 -118.618317  Well Summary          N
# 197935   17W         SB  34.395340 -118.635216  Well Summary          N
# 197965   17W         SB  34.406058 -118.649324  Well Summary          N
#
#        isDirectio   SpudDate           inHPZ  WellSymbol IdleDate  YearsIdle  \
# 132290          N 1801-01-01    Verified HPZ   PluggedOG      NaT        NaN
# 157456          N 1801-01-01  Not Within HPZ  CanceledOG      NaT        NaN
# 157457          N 1801-01-01  Not Within HPZ  CanceledOG      NaT        NaN
# 157520          N 1801-01-01  Not Within HPZ  CanceledOG      NaT        NaN
# 157521          N 1801-01-01  Not Within HPZ  CanceledOG      NaT        NaN
# 197867          N 1801-01-01  Not Within HPZ      IdleOG      NaT        NaN
# 197935          N 1801-01-01  Not Within HPZ   PluggedOG      NaT        NaN
# 197965          N 1801-01-01  Not Within HPZ   PluggedOG      NaT        NaN
#
#        IsLTIW UnsatAbandon
# 132290    NaN          NaN
# 157456    NaN          NaN
# 157457    NaN          NaN
# 157520    NaN          NaN
# 157521    NaN          NaN
# 197867    NaN          NaN
# 197935    NaN          NaN
# 197965    NaN          NaN

# %%
well_list_df.loc[well_list_df['SpudDate'] == pd.Timestamp(1801,1,1), 'SpudDate'] = None
assert(len(well_list_df[well_list_df['SpudDate'] == pd.Timestamp(1801,1,1)])==0 )

# %%
# There aren't any duplicate rows in the data set so far, but confirm it:
assert(well_list_df.duplicated().sum()==0)

# %% [markdown]
# ## Basic feature engineering to get some helper columns set up to assist with EDA
#  Year columns for the date columns
#  Naive Last Production year, which will be Idle Year - Years Idle - 2 for rows where that's populated
#  (naive because there's a complexity that I'll deal with later in the Imputation section)

# %%
well_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241912 entries, 0 to 241911
# Data columns (total 30 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   API           241912 non-null  object
#  1   LeaseName     241912 non-null  object
#  2   WellNumber    241567 non-null  object
#  3   WellDesign    241779 non-null  object
#  4   WellStatus    241912 non-null  object
#  5   WellType      241912 non-null  object
#  6   WellTypeLa    241912 non-null  object
#  7   OperatorCo    241912 non-null  object
#  8   OperatorNa    241912 non-null  object
#  9   FieldName     241912 non-null  object
#  10  AreaName      240458 non-null  object
#  11  Place         241895 non-null  object
#  12  District      241912 non-null  object
#  13  CountyName    241912 non-null  object
#  14  Section       241912 non-null  int64
#  15  Township      241912 non-null  object
#  16  Range         241912 non-null  object
#  17  BaseMeridi    241912 non-null  object
#  18  Latitude      241912 non-null  float64
#  19  Longitude     241912 non-null  float64
#  20  GISSource     241912 non-null  object
#  21  isConfiden    241912 non-null  object
#  22  isDirectio    241912 non-null  object
#  23  SpudDate      80832 non-null   datetime64[ns]
#  24  inHPZ         241912 non-null  object
#  25  WellSymbol    241912 non-null  object
#  26  IdleDate      29910 non-null   datetime64[ns]
#  27  YearsIdle     29910 non-null   float32
#  28  IsLTIW        29910 non-null   object
#  29  UnsatAbandon  29910 non-null   object
# dtypes: datetime64[ns](2), float32(1), float64(2), int64(1), object(24)
# memory usage: 54.4+ MB

# %%
well_list_df.describe()
# Out:
#              Section       Latitude      Longitude  \
# count  241912.000000  241912.000000  241912.000000
# mean       18.972134      35.314957    -119.462110
# min         1.000000      32.537811    -124.363670
# 25%         9.000000      35.077979    -119.735008
# 50%        19.000000      35.366459    -119.566372
# 75%        29.000000      35.485517    -118.990685
# max        36.000000      41.812958    -114.572904
# std        11.030148       1.003615       0.851529
#
#                             SpudDate                       IdleDate  \
# count                          80832                          29910
# mean   1990-01-12 20:29:55.724465536  2007-04-30 06:49:19.438314752
# min              1867-08-01 00:00:00            1900-01-01 00:00:00
# 25%              1972-02-13 12:00:00            2005-10-01 00:00:00
# 50%              1997-10-17 00:00:00            2016-06-01 00:00:00
# 75%              2012-06-15 00:00:00            2020-10-01 00:00:00
# max              2026-03-26 00:00:00            2024-01-01 00:00:00
# std                              NaN                            NaN
#
#           YearsIdle
# count  29910.000000
# mean      16.671970
# min        0.000000
# 25%        3.250000
# 50%        7.583333
# 75%       18.250000
# max      124.000000
# std       24.304653

# %%
# What percentage of the 39k idle wells, how many are missing the SPUD date?
well_list_df.isna().sum()
# Out:
# API                  0
# LeaseName            0
# WellNumber         345
# WellDesign         133
# WellStatus           0
# WellType             0
# WellTypeLa           0
# OperatorCo           0
# OperatorNa           0
# FieldName            0
# AreaName          1454
# Place               17
# District             0
# CountyName           0
# Section              0
# Township             0
# Range                0
# BaseMeridi           0
# Latitude             0
# Longitude            0
# GISSource            0
# isConfiden           0
# isDirectio           0
# SpudDate        161080
# inHPZ                0
# WellSymbol           0
# IdleDate        212002
# YearsIdle       212002
# IsLTIW          212002
# UnsatAbandon    212002
# dtype: int64

# %%
# create a flag to exclude the fields that are already fully abandoned; I'll be mostly ignoring these later
well_list_df['FieldAbd'] = [True if "(ABD)" in str(x) else False for x in well_list_df['FieldName']]

# Check : Row 50 should be False (not ABD) and Row 51 should be True (is ABD)
well_list_df.iloc[50:52]
# Out:
#            API             LeaseName WellNumber                  WellDesign  \
# 50  0402100015  ROCO-Afton Community      66-34  ROCO-Afton Community 66-34
# 51  0402120107              Glassgow     10-Jan               Glassgow 1-10
#
#    WellStatus WellType WellTypeLa OperatorCo               OperatorNa  \
# 50    Plugged       DH   Dry Hole      A4550  Arco Western Energy Co.
# 51    Plugged       DG    Dry Gas      S3100   Shell Western E&P Inc.
#
#                   FieldName  AreaName         Place  District CountyName  \
# 50                Afton Gas      Main  Glenn County  Northern      Glenn
# 51  Afton, South, Gas (ABD)  Any Area  Glenn County  Northern      Glenn
#
#     Section Township Range BaseMeridi   Latitude   Longitude GISSource  \
# 50       34      19N   01W         MD  39.454037 -121.954735       hud
# 51       10      18N   01W         MD  39.424908 -121.965179       hud
#
#    isConfiden isDirectio   SpudDate                       inHPZ WellSymbol  \
# 50          N          N 1962-06-10  Potentially Not Within HPZ  PluggedDH
# 51          N          Y 1977-05-31             Potentially HPZ  PluggedDG
#
#    IdleDate  YearsIdle IsLTIW UnsatAbandon  FieldAbd
# 50      NaT        NaN    NaN          NaN     False
# 51      NaT        NaN    NaN          NaN      True

# %%
# add year column, it should speed up calculations and won't affect accuracy of the results
# note: could use .dt.year.astype('Int64') to return an integer, and use 'Int64' instead of
#   just int because basic int can't handle NaN but the median function below will
#   return a float anyway, so just leave it as a float
#
well_list_df['SpudYear'] = well_list_df['SpudDate'].dt.year
well_list_df['IdleYear'] = well_list_df['IdleDate'].dt.year
#well_list_df.drop(columns=['api_10_x','last_date_x','api_10_y','last_date_y'], inplace=True)
#well_list_df['LastProdYear'] = well_list_df['IdleYear'] - well_list_df['YearsIdle'] - 2

# %% [markdown]
# ## Check for SPUD Dates > First Prod dates and correct as needed

# %%
well_list_df = pd.merge(well_list_df, prod_dates_df, how='left', left_on='API', right_on='api_10')
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N 2001-08-14  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N 1993-01-05  Potentially Not Within HPZ
# 241911          N          N 1982-07-27  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date
# 0            NaN    1901.0         NaN        NaT        NaT
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31
# ...          ...       ...         ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28
# 241908    2001.0       NaN         NaN        NaT        NaT
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31
# 241910    1993.0       NaN         NaN        NaT        NaT
# 241911    1982.0       NaN         NaN        NaT        NaT
#
# [241912 rows x 36 columns]

# %%
well_list_df[~well_list_df['last_date'].isna()]
# Out:
#                API                 LeaseName WellNumber  \
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# 7       0402100017         Afton Community 2          1
# ...            ...                       ...        ...
# 241904  0411320457               Arow-Knaggs          2
# 241905  0411320530            Knaggs-Wallace          3
# 241906  0411320779            Knaggs-Wallace          4
# 241907  0411320572            Knaggs-Wallace          5
# 241909  0411320667  Reclamation District 108          1
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# 7              Afton Community 2 1    Plugged       DG    Dry Gas      V1150
# ...                            ...        ...      ...        ...        ...
# 241904               Arow-Knaggs 2    Plugged       DG    Dry Gas      A4550
# 241905            Knaggs-Wallace 3    Plugged       DG    Dry Gas      P0325
# 241906            Knaggs-Wallace 4    Plugged       DG    Dry Gas      P0325
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
#
#                                   OperatorNa                 FieldName  \
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# 7                                Venoco, LLC                 Afton Gas
# ...                                      ...                       ...
# 241904               Arco Western Energy Co.          Zamora Gas (ABD)
# 241905  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241906  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# 7           Main  Glenn County  Northern      Glenn       34      19N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241904  Any Area   Yolo County  Northern       Yolo       10      11N   01E
# 241905  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241906  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude GISSource isConfiden isDirectio  \
# 1              MD  39.440640 -121.951889       GPS          N          N
# 2              MD  39.447174 -121.961273       GPS          N          N
# 3              MD  39.443230 -121.951042       GPS          N          N
# 4              MD  39.449158 -121.946289       GPS          N          N
# 7              MD  39.460217 -121.953537       hud          N          N
# ...           ...        ...         ...       ...        ...        ...
# 241904         MD  38.819450 -121.844765       hud          N          N
# 241905         MD  38.808781 -121.824226       hud          N          N
# 241906         MD  38.817829 -121.830810       hud          N          N
# 241907         MD  38.812370 -121.812614       hud          N          N
# 241909         MD  38.840790 -121.838989       hud          N          N
#
#          SpudDate                       inHPZ WellSymbol   IdleDate  \
# 1      1999-12-07              Not Within HPZ     IdleDG 2015-08-01
# 2      2000-05-13            Uncertainty Area     IdleDG 2015-08-01
# 3      2002-11-06              Not Within HPZ     IdleDG 2011-06-01
# 4      1988-02-17              Not Within HPZ   ActiveDG        NaT
# 7      1945-04-14             Potentially HPZ  PluggedDG        NaT
# ...           ...                         ...        ...        ...
# 241904 1977-08-05  Potentially Not Within HPZ  PluggedDG        NaT
# 241905 1979-03-24  Potentially Not Within HPZ  PluggedDG        NaT
# 241906 1984-02-21  Potentially Not Within HPZ  PluggedDG        NaT
# 241907 1979-12-12  Potentially Not Within HPZ  PluggedDG        NaT
# 241909 1981-09-17  Potentially Not Within HPZ  PluggedDG        NaT
#
#         YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  IdleYear  \
# 1        8.416667    Yes           No     False    1999.0    2015.0
# 2        8.416667    Yes           No     False    2000.0    2015.0
# 3       12.583333    Yes           No     False    2002.0    2011.0
# 4             NaN    NaN          NaN     False    1988.0       NaN
# 7             NaN    NaN          NaN     False    1945.0       NaN
# ...           ...    ...          ...       ...       ...       ...
# 241904        NaN    NaN          NaN      True    1977.0       NaN
# 241905        NaN    NaN          NaN      True    1979.0       NaN
# 241906        NaN    NaN          NaN      True    1984.0       NaN
# 241907        NaN    NaN          NaN      True    1979.0       NaN
# 241909        NaN    NaN          NaN      True    1981.0       NaN
#
#             api_10 first_date  last_date
# 1       0402120723 2000-04-30 2013-07-31
# 2       0402120734 2000-06-30 2013-07-31
# 3       0402120815 2004-10-31 2009-05-31
# 4       0402120521 1988-06-30 2023-08-31
# 7       0402100017 1977-09-30 1995-05-31
# ...            ...        ...        ...
# 241904  0411320457 1978-09-30 1981-02-28
# 241905  0411320530 1980-04-30 1981-09-30
# 241906  0411320779 1984-10-31 1992-10-31
# 241907  0411320572 1981-07-31 1982-02-28
# 241909  0411320667 1985-02-28 1985-10-31
#
# [151584 rows x 36 columns]

# %%
well_list_df['ProdYears'] = round((well_list_df['last_date'] - well_list_df['SpudDate']).dt.days/365.25, 2)
well_list_df[well_list_df['ProdYears']<0]
# Out:
#                API                              LeaseName WellNumber  \
# 287     0403700722                                 Porter         35
# 16075   0407920819                                  Maino   17-6 SPL
# 17207   0402956422                               Shamrock         68
# 20174   0403040327                            Unspecified   530C2-35
# 20239   0403027796                            Unspecified   533A3-35
# ...            ...                                    ...        ...
# 238988  0403701489                                    NWU       72-3
# 239104  0403721984                                    NWU       79-9
# 239303  0403703267        Lease by The Port of Long Beach      E130D
# 240072  0403704421  Lease by Tidelands Oil Production Co.    UP278RA
# 240367  0403723555  Lease by Tidelands Oil Production Co.     UP905B
#
#                   WellDesign WellStatus WellType   WellTypeLa OperatorCo  \
# 287                Porter 35    Plugged       GS  Gas Storage      S4700
# 16075         Maino 17-6 SPL    Plugged       OG    Oil & Gas      S2641
# 17207            Shamrock 68    Plugged       OG    Oil & Gas      C5640
# 20174   Unspecified 530C2-35    Plugged       WF   Waterflood      A0610
# 20239   Unspecified 533A3-35    Plugged       OG    Oil & Gas      A0610
# ...                      ...        ...      ...          ...        ...
# 238988              NWU 72-3    Plugged       OG    Oil & Gas      W0325
# 239104              NWU 79-9    Plugged       OG    Oil & Gas      W0325
# 239303                 E130D    Plugged       OG    Oil & Gas      P4015
# 240072               UP278RA    Plugged       OG    Oil & Gas      T2975
# 240367                UP905B    Plugged       OG    Oil & Gas      T2975
#
#                                     OperatorNa          FieldName  \
# 287            Southern California Gas Company       Aliso Canyon
# 16075   Sentinel Peak Resources California LLC      Arroyo Grande
# 17207                      Chevron U.S.A. Inc.  Belgian Anticline
# 20174                          Aera Energy LLC    Belridge, North
# 20239                          Aera Energy LLC    Belridge, North
# ...                                        ...                ...
# 238988                        Warren E&P, Inc.         Wilmington
# 239104                        Warren E&P, Inc.         Wilmington
# 239303                  The Port of Long Beach         Wilmington
# 240072            Tidelands Oil Production Co.         Wilmington
# 240367            Tidelands Oil Production Co.         Wilmington
#
#                 AreaName                   Place  District       CountyName  \
# 287             Any Area      Los Angeles County  Northern      Los Angeles
# 16075              Tiber  San Luis Obispo County  Northern  San Luis Obispo
# 17207               Main             Kern County    Inland             Kern
# 20174           Any Area             Kern County    Inland             Kern
# 20239           Any Area             Kern County    Inland             Kern
# ...                  ...                     ...       ...              ...
# 238988    Fault Block IV              Long Beach  Southern      Los Angeles
# 239104    Fault Block IV             Los Angeles  Southern      Los Angeles
# 239303    Fault Block IV     Long Beach Offshore  Southern      Los Angeles
# 240072     Fault Block I             Los Angeles  Southern      Los Angeles
# 240367  Fault Block II-A             Los Angeles  Southern      Los Angeles
#
#         Section Township Range BaseMeridi   Latitude   Longitude  \
# 287          28      03N   16W         SB  34.311604 -118.555931
# 16075        31      31S   13E         MD  35.181938 -120.616157
# 17207        19      30S   22E         MD  35.296673 -119.647629
# 20174        35      27S   20E         MD  35.536293 -119.784561
# 20239        35      27S   20E         MD  35.533894 -119.780357
# ...         ...      ...   ...        ...        ...         ...
# 238988       35      04S   13W         SB  33.784157 -118.219673
# 239104       34      04S   13W         SB  33.787242 -118.226069
# 239303        3      05S   13W         SB  33.764351 -118.222839
# 240072        4      05S   13W         SB  33.771713 -118.247414
# 240367        4      05S   13W         SB  33.767487 -118.241661
#
#            GISSource isConfiden isDirectio   SpudDate           inHPZ  \
# 287     Well Summary          N          Y 2018-04-30  Not Within HPZ
# 16075   Well Summary          N          N 2018-03-26    Verified HPZ
# 17207   Well Summary          N          N 2008-01-22  Not Within HPZ
# 20174   Well Summary          N          N 2015-08-06  Not Within HPZ
# 20239   Well Summary          N          Y 2015-08-14  Not Within HPZ
# ...              ...        ...        ...        ...             ...
# 238988  Well Summary          N          Y 2018-03-02    Verified HPZ
# 239104  Well Summary          N          Y 2022-04-18    Verified HPZ
# 239303  Well Summary          N          Y 2012-08-14  Not Within HPZ
# 240072  Well Summary          N          Y 2018-07-18    Verified HPZ
# 240367  Well Summary          N          Y 2017-09-14    Verified HPZ
#
#        WellSymbol   IdleDate  YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 287     PluggedGS        NaT        NaN    NaN          NaN     False
# 16075   PluggedOG        NaT        NaN    NaN          NaN     False
# 17207   PluggedOG        NaT        NaN    NaN          NaN     False
# 20174   PluggedWF        NaT        NaN    NaN          NaN     False
# 20239   PluggedOG        NaT        NaN    NaN          NaN     False
# ...           ...        ...        ...    ...          ...       ...
# 238988  PluggedOG 2016-10-01       7.25     No          Yes     False
# 239104  PluggedOG        NaT        NaN    NaN          NaN     False
# 239303  PluggedOG        NaT        NaN    NaN          NaN     False
# 240072  PluggedOG        NaT        NaN    NaN          NaN     False
# 240367  PluggedOG        NaT        NaN    NaN          NaN     False
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 287       2018.0       NaN  0403700722 1977-01-31 2016-03-01      -2.16
# 16075     2018.0       NaN  0407920819 2000-07-31 2017-01-01      -1.23
# 17207     2008.0       NaN  0402956422 1978-04-30 1988-07-31     -19.48
# 20174     2015.0       NaN  0403040327 2010-05-31 2015-03-01      -0.43
# 20239     2015.0       NaN  0403027796 2005-08-31 2014-01-31      -1.53
# ...          ...       ...         ...        ...        ...        ...
# 238988    2018.0    2016.0  0403701489 1977-01-31 2014-07-31      -3.59
# 239104    2022.0       NaN  0403721984 1979-09-30 2008-12-31     -13.30
# 239303    2012.0       NaN  0403703267 1977-01-31 2012-07-31      -0.04
# 240072    2018.0       NaN  0403704421 1977-01-31 2002-07-31     -15.96
# 240367    2017.0       NaN  0403723555 1989-04-30 2002-05-31     -15.29
#
# [291 rows x 37 columns]

# %%
# Example: Row 56021, API 0405906822 has production from 1977 to 1980, and then was apparently idle. This list has a SPUD date of 2022, which is clearly wrong... it may have been P&A'ed in 2022, not sure how to tell yet
well_list_df.loc[56021]
# Out:
# API                      0405906822
# LeaseName                    Orange
# WellNumber                       20
# WellDesign                Orange 20
# WellStatus                  Plugged
# WellType                         OG
# WellTypeLa                Oil & Gas
# OperatorCo                    B6136
# OperatorNa        Bridge Energy LLC
# FieldName               Brea-Olinda
# AreaName                   Any Area
# Place                 Orange County
# District                   Southern
# CountyName                   Orange
# Section                           2
# Township                        03S
# Range                           10W
# BaseMeridi                       SB
# Latitude                  33.944733
# Longitude               -117.894676
# GISSource              Well Summary
# isConfiden                        N
# isDirectio                        Y
# SpudDate        2022-11-03 00:00:00
# inHPZ                  Verified HPZ
# WellSymbol                PluggedOG
# IdleDate                        NaT
# YearsIdle                       NaN
# IsLTIW                          NaN
# UnsatAbandon                    NaN
# FieldAbd                      False
# SpudYear                     2022.0
# IdleYear                        NaN
# api_10                   0405906822
# first_date      1977-01-31 00:00:00
# last_date       1980-12-31 00:00:00
# ProdYears                    -41.84
# Name: 56021, dtype: object

# %%
# Set the SPUD date to the first_date if it's greater than the first_date (a lot of typos and bad data in the regulatory dataset)
# NOTE: So Pandas WHERE clause does a funny thing, where it only returns the other value if the conditional is False
well_list_df['SpudDate'] = well_list_df['SpudDate'].where(well_list_df['first_date'] > well_list_df['SpudDate'], well_list_df['first_date'])

# Where SpudDate == first_date, and it's 1/1/1977, then set SpudDate to NULL for later imputation
well_list_df['SpudDate'] = well_list_df['SpudDate'].where(well_list_df['SpudDate'] != pd.Timestamp(1977,1,31), None)
well_list_df[well_list_df['ProdYears']<0]
# Out:
#                API                              LeaseName WellNumber  \
# 287     0403700722                                 Porter         35
# 16075   0407920819                                  Maino   17-6 SPL
# 17207   0402956422                               Shamrock         68
# 20174   0403040327                            Unspecified   530C2-35
# 20239   0403027796                            Unspecified   533A3-35
# ...            ...                                    ...        ...
# 238988  0403701489                                    NWU       72-3
# 239104  0403721984                                    NWU       79-9
# 239303  0403703267        Lease by The Port of Long Beach      E130D
# 240072  0403704421  Lease by Tidelands Oil Production Co.    UP278RA
# 240367  0403723555  Lease by Tidelands Oil Production Co.     UP905B
#
#                   WellDesign WellStatus WellType   WellTypeLa OperatorCo  \
# 287                Porter 35    Plugged       GS  Gas Storage      S4700
# 16075         Maino 17-6 SPL    Plugged       OG    Oil & Gas      S2641
# 17207            Shamrock 68    Plugged       OG    Oil & Gas      C5640
# 20174   Unspecified 530C2-35    Plugged       WF   Waterflood      A0610
# 20239   Unspecified 533A3-35    Plugged       OG    Oil & Gas      A0610
# ...                      ...        ...      ...          ...        ...
# 238988              NWU 72-3    Plugged       OG    Oil & Gas      W0325
# 239104              NWU 79-9    Plugged       OG    Oil & Gas      W0325
# 239303                 E130D    Plugged       OG    Oil & Gas      P4015
# 240072               UP278RA    Plugged       OG    Oil & Gas      T2975
# 240367                UP905B    Plugged       OG    Oil & Gas      T2975
#
#                                     OperatorNa          FieldName  \
# 287            Southern California Gas Company       Aliso Canyon
# 16075   Sentinel Peak Resources California LLC      Arroyo Grande
# 17207                      Chevron U.S.A. Inc.  Belgian Anticline
# 20174                          Aera Energy LLC    Belridge, North
# 20239                          Aera Energy LLC    Belridge, North
# ...                                        ...                ...
# 238988                        Warren E&P, Inc.         Wilmington
# 239104                        Warren E&P, Inc.         Wilmington
# 239303                  The Port of Long Beach         Wilmington
# 240072            Tidelands Oil Production Co.         Wilmington
# 240367            Tidelands Oil Production Co.         Wilmington
#
#                 AreaName                   Place  District       CountyName  \
# 287             Any Area      Los Angeles County  Northern      Los Angeles
# 16075              Tiber  San Luis Obispo County  Northern  San Luis Obispo
# 17207               Main             Kern County    Inland             Kern
# 20174           Any Area             Kern County    Inland             Kern
# 20239           Any Area             Kern County    Inland             Kern
# ...                  ...                     ...       ...              ...
# 238988    Fault Block IV              Long Beach  Southern      Los Angeles
# 239104    Fault Block IV             Los Angeles  Southern      Los Angeles
# 239303    Fault Block IV     Long Beach Offshore  Southern      Los Angeles
# 240072     Fault Block I             Los Angeles  Southern      Los Angeles
# 240367  Fault Block II-A             Los Angeles  Southern      Los Angeles
#
#         Section Township Range BaseMeridi   Latitude   Longitude  \
# 287          28      03N   16W         SB  34.311604 -118.555931
# 16075        31      31S   13E         MD  35.181938 -120.616157
# 17207        19      30S   22E         MD  35.296673 -119.647629
# 20174        35      27S   20E         MD  35.536293 -119.784561
# 20239        35      27S   20E         MD  35.533894 -119.780357
# ...         ...      ...   ...        ...        ...         ...
# 238988       35      04S   13W         SB  33.784157 -118.219673
# 239104       34      04S   13W         SB  33.787242 -118.226069
# 239303        3      05S   13W         SB  33.764351 -118.222839
# 240072        4      05S   13W         SB  33.771713 -118.247414
# 240367        4      05S   13W         SB  33.767487 -118.241661
#
#            GISSource isConfiden isDirectio   SpudDate           inHPZ  \
# 287     Well Summary          N          Y        NaT  Not Within HPZ
# 16075   Well Summary          N          N 2000-07-31    Verified HPZ
# 17207   Well Summary          N          N 1978-04-30  Not Within HPZ
# 20174   Well Summary          N          N 2010-05-31  Not Within HPZ
# 20239   Well Summary          N          Y 2005-08-31  Not Within HPZ
# ...              ...        ...        ...        ...             ...
# 238988  Well Summary          N          Y        NaT    Verified HPZ
# 239104  Well Summary          N          Y 1979-09-30    Verified HPZ
# 239303  Well Summary          N          Y        NaT  Not Within HPZ
# 240072  Well Summary          N          Y        NaT    Verified HPZ
# 240367  Well Summary          N          Y 1989-04-30    Verified HPZ
#
#        WellSymbol   IdleDate  YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 287     PluggedGS        NaT        NaN    NaN          NaN     False
# 16075   PluggedOG        NaT        NaN    NaN          NaN     False
# 17207   PluggedOG        NaT        NaN    NaN          NaN     False
# 20174   PluggedWF        NaT        NaN    NaN          NaN     False
# 20239   PluggedOG        NaT        NaN    NaN          NaN     False
# ...           ...        ...        ...    ...          ...       ...
# 238988  PluggedOG 2016-10-01       7.25     No          Yes     False
# 239104  PluggedOG        NaT        NaN    NaN          NaN     False
# 239303  PluggedOG        NaT        NaN    NaN          NaN     False
# 240072  PluggedOG        NaT        NaN    NaN          NaN     False
# 240367  PluggedOG        NaT        NaN    NaN          NaN     False
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 287       2018.0       NaN  0403700722 1977-01-31 2016-03-01      -2.16
# 16075     2018.0       NaN  0407920819 2000-07-31 2017-01-01      -1.23
# 17207     2008.0       NaN  0402956422 1978-04-30 1988-07-31     -19.48
# 20174     2015.0       NaN  0403040327 2010-05-31 2015-03-01      -0.43
# 20239     2015.0       NaN  0403027796 2005-08-31 2014-01-31      -1.53
# ...          ...       ...         ...        ...        ...        ...
# 238988    2018.0    2016.0  0403701489 1977-01-31 2014-07-31      -3.59
# 239104    2022.0       NaN  0403721984 1979-09-30 2008-12-31     -13.30
# 239303    2012.0       NaN  0403703267 1977-01-31 2012-07-31      -0.04
# 240072    2018.0       NaN  0403704421 1977-01-31 2002-07-31     -15.96
# 240367    2017.0       NaN  0403723555 1989-04-30 2002-05-31     -15.29
#
# [291 rows x 37 columns]

# %%
# Then set any first_date == SpudDate to SpudDate + 1 month
well_list_df['SpudDate'] = well_list_df['SpudDate'].where(well_list_df['first_date'] != well_list_df['SpudDate'], well_list_df['SpudDate'] +  pd.DateOffset(months=-1))
well_list_df[well_list_df['ProdYears']<0]
# Out:
#                API                              LeaseName WellNumber  \
# 287     0403700722                                 Porter         35
# 16075   0407920819                                  Maino   17-6 SPL
# 17207   0402956422                               Shamrock         68
# 20174   0403040327                            Unspecified   530C2-35
# 20239   0403027796                            Unspecified   533A3-35
# ...            ...                                    ...        ...
# 238988  0403701489                                    NWU       72-3
# 239104  0403721984                                    NWU       79-9
# 239303  0403703267        Lease by The Port of Long Beach      E130D
# 240072  0403704421  Lease by Tidelands Oil Production Co.    UP278RA
# 240367  0403723555  Lease by Tidelands Oil Production Co.     UP905B
#
#                   WellDesign WellStatus WellType   WellTypeLa OperatorCo  \
# 287                Porter 35    Plugged       GS  Gas Storage      S4700
# 16075         Maino 17-6 SPL    Plugged       OG    Oil & Gas      S2641
# 17207            Shamrock 68    Plugged       OG    Oil & Gas      C5640
# 20174   Unspecified 530C2-35    Plugged       WF   Waterflood      A0610
# 20239   Unspecified 533A3-35    Plugged       OG    Oil & Gas      A0610
# ...                      ...        ...      ...          ...        ...
# 238988              NWU 72-3    Plugged       OG    Oil & Gas      W0325
# 239104              NWU 79-9    Plugged       OG    Oil & Gas      W0325
# 239303                 E130D    Plugged       OG    Oil & Gas      P4015
# 240072               UP278RA    Plugged       OG    Oil & Gas      T2975
# 240367                UP905B    Plugged       OG    Oil & Gas      T2975
#
#                                     OperatorNa          FieldName  \
# 287            Southern California Gas Company       Aliso Canyon
# 16075   Sentinel Peak Resources California LLC      Arroyo Grande
# 17207                      Chevron U.S.A. Inc.  Belgian Anticline
# 20174                          Aera Energy LLC    Belridge, North
# 20239                          Aera Energy LLC    Belridge, North
# ...                                        ...                ...
# 238988                        Warren E&P, Inc.         Wilmington
# 239104                        Warren E&P, Inc.         Wilmington
# 239303                  The Port of Long Beach         Wilmington
# 240072            Tidelands Oil Production Co.         Wilmington
# 240367            Tidelands Oil Production Co.         Wilmington
#
#                 AreaName                   Place  District       CountyName  \
# 287             Any Area      Los Angeles County  Northern      Los Angeles
# 16075              Tiber  San Luis Obispo County  Northern  San Luis Obispo
# 17207               Main             Kern County    Inland             Kern
# 20174           Any Area             Kern County    Inland             Kern
# 20239           Any Area             Kern County    Inland             Kern
# ...                  ...                     ...       ...              ...
# 238988    Fault Block IV              Long Beach  Southern      Los Angeles
# 239104    Fault Block IV             Los Angeles  Southern      Los Angeles
# 239303    Fault Block IV     Long Beach Offshore  Southern      Los Angeles
# 240072     Fault Block I             Los Angeles  Southern      Los Angeles
# 240367  Fault Block II-A             Los Angeles  Southern      Los Angeles
#
#         Section Township Range BaseMeridi   Latitude   Longitude  \
# 287          28      03N   16W         SB  34.311604 -118.555931
# 16075        31      31S   13E         MD  35.181938 -120.616157
# 17207        19      30S   22E         MD  35.296673 -119.647629
# 20174        35      27S   20E         MD  35.536293 -119.784561
# 20239        35      27S   20E         MD  35.533894 -119.780357
# ...         ...      ...   ...        ...        ...         ...
# 238988       35      04S   13W         SB  33.784157 -118.219673
# 239104       34      04S   13W         SB  33.787242 -118.226069
# 239303        3      05S   13W         SB  33.764351 -118.222839
# 240072        4      05S   13W         SB  33.771713 -118.247414
# 240367        4      05S   13W         SB  33.767487 -118.241661
#
#            GISSource isConfiden isDirectio   SpudDate           inHPZ  \
# 287     Well Summary          N          Y        NaT  Not Within HPZ
# 16075   Well Summary          N          N 2000-06-30    Verified HPZ
# 17207   Well Summary          N          N 1978-03-30  Not Within HPZ
# 20174   Well Summary          N          N 2010-04-30  Not Within HPZ
# 20239   Well Summary          N          Y 2005-07-31  Not Within HPZ
# ...              ...        ...        ...        ...             ...
# 238988  Well Summary          N          Y        NaT    Verified HPZ
# 239104  Well Summary          N          Y 1979-08-30    Verified HPZ
# 239303  Well Summary          N          Y        NaT  Not Within HPZ
# 240072  Well Summary          N          Y        NaT    Verified HPZ
# 240367  Well Summary          N          Y 1989-03-30    Verified HPZ
#
#        WellSymbol   IdleDate  YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 287     PluggedGS        NaT        NaN    NaN          NaN     False
# 16075   PluggedOG        NaT        NaN    NaN          NaN     False
# 17207   PluggedOG        NaT        NaN    NaN          NaN     False
# 20174   PluggedWF        NaT        NaN    NaN          NaN     False
# 20239   PluggedOG        NaT        NaN    NaN          NaN     False
# ...           ...        ...        ...    ...          ...       ...
# 238988  PluggedOG 2016-10-01       7.25     No          Yes     False
# 239104  PluggedOG        NaT        NaN    NaN          NaN     False
# 239303  PluggedOG        NaT        NaN    NaN          NaN     False
# 240072  PluggedOG        NaT        NaN    NaN          NaN     False
# 240367  PluggedOG        NaT        NaN    NaN          NaN     False
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 287       2018.0       NaN  0403700722 1977-01-31 2016-03-01      -2.16
# 16075     2018.0       NaN  0407920819 2000-07-31 2017-01-01      -1.23
# 17207     2008.0       NaN  0402956422 1978-04-30 1988-07-31     -19.48
# 20174     2015.0       NaN  0403040327 2010-05-31 2015-03-01      -0.43
# 20239     2015.0       NaN  0403027796 2005-08-31 2014-01-31      -1.53
# ...          ...       ...         ...        ...        ...        ...
# 238988    2018.0    2016.0  0403701489 1977-01-31 2014-07-31      -3.59
# 239104    2022.0       NaN  0403721984 1979-09-30 2008-12-31     -13.30
# 239303    2012.0       NaN  0403703267 1977-01-31 2012-07-31      -0.04
# 240072    2018.0       NaN  0403704421 1977-01-31 2002-07-31     -15.96
# 240367    2017.0       NaN  0403723555 1989-04-30 2002-05-31     -15.29
#
# [291 rows x 37 columns]

# %%
# Calculate the Production Life (SPUD to CalcIdle) for the wells, if they have SPUD dates
well_list_df[well_list_df['ProdYears']<0]
# Out:
#                API                              LeaseName WellNumber  \
# 287     0403700722                                 Porter         35
# 16075   0407920819                                  Maino   17-6 SPL
# 17207   0402956422                               Shamrock         68
# 20174   0403040327                            Unspecified   530C2-35
# 20239   0403027796                            Unspecified   533A3-35
# ...            ...                                    ...        ...
# 238988  0403701489                                    NWU       72-3
# 239104  0403721984                                    NWU       79-9
# 239303  0403703267        Lease by The Port of Long Beach      E130D
# 240072  0403704421  Lease by Tidelands Oil Production Co.    UP278RA
# 240367  0403723555  Lease by Tidelands Oil Production Co.     UP905B
#
#                   WellDesign WellStatus WellType   WellTypeLa OperatorCo  \
# 287                Porter 35    Plugged       GS  Gas Storage      S4700
# 16075         Maino 17-6 SPL    Plugged       OG    Oil & Gas      S2641
# 17207            Shamrock 68    Plugged       OG    Oil & Gas      C5640
# 20174   Unspecified 530C2-35    Plugged       WF   Waterflood      A0610
# 20239   Unspecified 533A3-35    Plugged       OG    Oil & Gas      A0610
# ...                      ...        ...      ...          ...        ...
# 238988              NWU 72-3    Plugged       OG    Oil & Gas      W0325
# 239104              NWU 79-9    Plugged       OG    Oil & Gas      W0325
# 239303                 E130D    Plugged       OG    Oil & Gas      P4015
# 240072               UP278RA    Plugged       OG    Oil & Gas      T2975
# 240367                UP905B    Plugged       OG    Oil & Gas      T2975
#
#                                     OperatorNa          FieldName  \
# 287            Southern California Gas Company       Aliso Canyon
# 16075   Sentinel Peak Resources California LLC      Arroyo Grande
# 17207                      Chevron U.S.A. Inc.  Belgian Anticline
# 20174                          Aera Energy LLC    Belridge, North
# 20239                          Aera Energy LLC    Belridge, North
# ...                                        ...                ...
# 238988                        Warren E&P, Inc.         Wilmington
# 239104                        Warren E&P, Inc.         Wilmington
# 239303                  The Port of Long Beach         Wilmington
# 240072            Tidelands Oil Production Co.         Wilmington
# 240367            Tidelands Oil Production Co.         Wilmington
#
#                 AreaName                   Place  District       CountyName  \
# 287             Any Area      Los Angeles County  Northern      Los Angeles
# 16075              Tiber  San Luis Obispo County  Northern  San Luis Obispo
# 17207               Main             Kern County    Inland             Kern
# 20174           Any Area             Kern County    Inland             Kern
# 20239           Any Area             Kern County    Inland             Kern
# ...                  ...                     ...       ...              ...
# 238988    Fault Block IV              Long Beach  Southern      Los Angeles
# 239104    Fault Block IV             Los Angeles  Southern      Los Angeles
# 239303    Fault Block IV     Long Beach Offshore  Southern      Los Angeles
# 240072     Fault Block I             Los Angeles  Southern      Los Angeles
# 240367  Fault Block II-A             Los Angeles  Southern      Los Angeles
#
#         Section Township Range BaseMeridi   Latitude   Longitude  \
# 287          28      03N   16W         SB  34.311604 -118.555931
# 16075        31      31S   13E         MD  35.181938 -120.616157
# 17207        19      30S   22E         MD  35.296673 -119.647629
# 20174        35      27S   20E         MD  35.536293 -119.784561
# 20239        35      27S   20E         MD  35.533894 -119.780357
# ...         ...      ...   ...        ...        ...         ...
# 238988       35      04S   13W         SB  33.784157 -118.219673
# 239104       34      04S   13W         SB  33.787242 -118.226069
# 239303        3      05S   13W         SB  33.764351 -118.222839
# 240072        4      05S   13W         SB  33.771713 -118.247414
# 240367        4      05S   13W         SB  33.767487 -118.241661
#
#            GISSource isConfiden isDirectio   SpudDate           inHPZ  \
# 287     Well Summary          N          Y        NaT  Not Within HPZ
# 16075   Well Summary          N          N 2000-06-30    Verified HPZ
# 17207   Well Summary          N          N 1978-03-30  Not Within HPZ
# 20174   Well Summary          N          N 2010-04-30  Not Within HPZ
# 20239   Well Summary          N          Y 2005-07-31  Not Within HPZ
# ...              ...        ...        ...        ...             ...
# 238988  Well Summary          N          Y        NaT    Verified HPZ
# 239104  Well Summary          N          Y 1979-08-30    Verified HPZ
# 239303  Well Summary          N          Y        NaT  Not Within HPZ
# 240072  Well Summary          N          Y        NaT    Verified HPZ
# 240367  Well Summary          N          Y 1989-03-30    Verified HPZ
#
#        WellSymbol   IdleDate  YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 287     PluggedGS        NaT        NaN    NaN          NaN     False
# 16075   PluggedOG        NaT        NaN    NaN          NaN     False
# 17207   PluggedOG        NaT        NaN    NaN          NaN     False
# 20174   PluggedWF        NaT        NaN    NaN          NaN     False
# 20239   PluggedOG        NaT        NaN    NaN          NaN     False
# ...           ...        ...        ...    ...          ...       ...
# 238988  PluggedOG 2016-10-01       7.25     No          Yes     False
# 239104  PluggedOG        NaT        NaN    NaN          NaN     False
# 239303  PluggedOG        NaT        NaN    NaN          NaN     False
# 240072  PluggedOG        NaT        NaN    NaN          NaN     False
# 240367  PluggedOG        NaT        NaN    NaN          NaN     False
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 287       2018.0       NaN  0403700722 1977-01-31 2016-03-01      -2.16
# 16075     2018.0       NaN  0407920819 2000-07-31 2017-01-01      -1.23
# 17207     2008.0       NaN  0402956422 1978-04-30 1988-07-31     -19.48
# 20174     2015.0       NaN  0403040327 2010-05-31 2015-03-01      -0.43
# 20239     2015.0       NaN  0403027796 2005-08-31 2014-01-31      -1.53
# ...          ...       ...         ...        ...        ...        ...
# 238988    2018.0    2016.0  0403701489 1977-01-31 2014-07-31      -3.59
# 239104    2022.0       NaN  0403721984 1979-09-30 2008-12-31     -13.30
# 239303    2012.0       NaN  0403703267 1977-01-31 2012-07-31      -0.04
# 240072    2018.0       NaN  0403704421 1977-01-31 2002-07-31     -15.96
# 240367    2017.0       NaN  0403723555 1989-04-30 2002-05-31     -15.29
#
# [291 rows x 37 columns]

# %%
# Recalc SpudYear and ProdYears after all the Spud Date cleanup and make sure there aren't any negatives
well_list_df['ProdYears'] = round((well_list_df['last_date'] - well_list_df['SpudDate']).dt.days/365.25, 2)
well_list_df['SpudYear'] = well_list_df['SpudDate'].dt.year
assert(len(well_list_df[well_list_df['ProdYears']<0])==0)

# %% [markdown]
# ## Some Idle Well Date cleanup

# %%
# for long ago dates, set it to the 1/1/1977; it's irrelevant for our purposes if it's before that
well_list_df.loc[(well_list_df['last_date'].isna()) & (well_list_df['WellStatus'] == 'Idle') & (well_list_df['IdleYear'] < 1977), 'last_date'] = pd.Timestamp(1977,1,1)
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT        NaT        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT        NaT        NaN
# 241911       NaN       NaN         NaN        NaT        NaT        NaN
#
# [241912 rows x 37 columns]

# %%
# subtract 2 years from the idle date to see when last production would have been
well_list_df.loc[(well_list_df['last_date'].isna()) & (well_list_df['WellStatus'] == 'Idle' ), 'last_date'] = well_list_df['IdleDate'] - pd.DateOffset(years=2)
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT        NaT        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT        NaT        NaN
# 241911       NaN       NaN         NaN        NaT        NaT        NaN
#
# [241912 rows x 37 columns]

# %%
# finally, set any additional NULL in last_date to current for Active wells, and 1977 for Plugged wells
well_list_df.loc[(well_list_df['last_date'].isna()) & (well_list_df['WellStatus'] == 'Active' ), 'last_date'] = CURRENT_DATE
well_list_df.loc[(well_list_df['last_date'].isna()) & (well_list_df['WellStatus'] == 'Plugged' ), 'last_date'] = pd.Timestamp(1977,1,1)
well_list_df.loc[(well_list_df['last_date'].isna()), 'last_date'] = pd.Timestamp(1977,1,1)

well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241911       NaN       NaN         NaN        NaT 1977-01-01        NaN
#
# [241912 rows x 37 columns]

# %%
#well_list_df['last_date'] = well_list_df['last_date'].astype('datetime64[ns]')

# %%
well_list_df['LastProdYear'] = well_list_df['last_date'].dt.year
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears  \
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241911       NaN       NaN         NaN        NaT 1977-01-01        NaN
#
#         LastProdYear
# 0               1977
# 1               2013
# 2               2013
# 3               2009
# 4               2023
# ...              ...
# 241907          1982
# 241908          1977
# 241909          1985
# 241910          1977
# 241911          1977
#
# [241912 rows x 38 columns]

# %%
# ensure we don't have any LastProdYears prior to around 1875 which is the year of the discovery of the Pico Canyon oil field in Los Angeles
# (earliest well drilled around oil seeps in 1866, but wasn't really commercial production)
well_list_df[(~well_list_df['IdleYear'].isna()) &
    (well_list_df['WellStatus'].isin(['Plugged','PluggedOnly']))]
# Out:
#                API                  LeaseName WellNumber     WellDesign  \
# 3150    0407720601                Holly Sugar          1  Holly Sugar 1
# 4895    0411105694                      Janss          1        Janss 1
# 6249    0403706168                      Bundy          1        Bundy 1
# 8997    0403900156  Lease by F. A. Rife & Co.          1              1
# 19777   0403004712   Lease by Aera Energy LLC    32GH1-1        32GH1-1
# ...            ...                        ...        ...            ...
# 238988  0403701489                        NWU       72-3       NWU 72-3
# 239034  0403726995                        NWU      73-32      NWU 73-32
# 239097  0403721574                        NWU       79-2       NWU 79-2
# 239100  0403721592                        NWU       79-5       NWU 79-5
# 239121  0403701812                        WTU        814        WTU 814
#
#        WellStatus WellType    WellTypeLa OperatorCo  \
# 3150      Plugged       DG       Dry Gas      11930
# 4895      Plugged       DH      Dry Hole      A4500
# 6249      Plugged       OG     Oil & Gas      U0200
# 8997      Plugged       DH      Dry Hole      02810
# 19777     Plugged       OG     Oil & Gas      A0610
# ...           ...      ...           ...        ...
# 238988    Plugged       OG     Oil & Gas      W0325
# 239034    Plugged       OG     Oil & Gas      W0325
# 239097    Plugged       OG     Oil & Gas      W0325
# 239100    Plugged       OG     Oil & Gas      W0325
# 239121    Plugged       WS  Water Source      W0325
#
#                              OperatorNa        FieldName         AreaName  \
# 3150         Holly Commerce Center, LLC        Any Field         Any Area
# 4895               Arco Oil and Gas Co.        Any Field         Any Area
# 6249    Union Oil Company of California        Any Field         Any Area
# 8997                   F. A. Rife & Co.        Any Field         Any Area
# 19777                   Aera Energy LLC  Belridge, North         Any Area
# ...                                 ...              ...              ...
# 238988                 Warren E&P, Inc.       Wilmington   Fault Block IV
# 239034                 Warren E&P, Inc.       Wilmington  Fault Block III
# 239097                 Warren E&P, Inc.       Wilmington   Fault Block IV
# 239100                 Warren E&P, Inc.       Wilmington   Fault Block IV
# 239121                 Warren E&P, Inc.       Wilmington        Any Block
#
#                      Place  District   CountyName  Section Township Range  \
# 3150    San Joaquin County  Northern  San Joaquin        9      02S   05E
# 4895         Thousand Oaks  Northern      Ventura       36      02N   20W
# 6249           Los Angeles  Southern  Los Angeles       32      01S   15W
# 8997         Madera County  Northern       Madera       17      12S   20E
# 19777          Kern County    Inland         Kern        1      28S   20E
# ...                    ...       ...          ...      ...      ...   ...
# 238988          Long Beach  Southern  Los Angeles       35      04S   13W
# 239034          Long Beach  Southern  Los Angeles       35      04S   13W
# 239097         Los Angeles  Southern  Los Angeles       34      04S   13W
# 239100         Los Angeles  Southern  Los Angeles       34      04S   13W
# 239121         Los Angeles  Southern  Los Angeles       32      04S   13W
#
#        BaseMeridi   Latitude   Longitude     GISSource isConfiden isDirectio  \
# 3150           MD  37.769478 -121.420425  Well Summary          N          N
# 4895           SB  34.217500 -118.930278           hud          N          N
# 6249           SB  34.045982 -118.469810           hud          N          N
# 8997           MD  36.891130 -119.807458  Well Summary          N          N
# 19777          MD  35.526074 -119.773230  Well Summary          N          Y
# ...           ...        ...         ...           ...        ...        ...
# 238988         SB  33.784157 -118.219673  Well Summary          N          Y
# 239034         SB  33.783749 -118.221428  Well Summary          N          Y
# 239097         SB  33.787731 -118.226021  Well Summary          N          Y
# 239100         SB  33.787522 -118.226030  Well Summary          N          Y
# 239121         SB  33.781929 -118.256374  Well Summary          N          N
#
#          SpudDate                       inHPZ WellSymbol   IdleDate  \
# 3150          NaT                Verified HPZ  PluggedDG 2001-01-01
# 4895          NaT  Potentially Not Within HPZ  PluggedDH 1956-06-01
# 6249          NaT                Verified HPZ  PluggedOG 1912-04-06
# 8997          NaT             Potentially HPZ  PluggedDH 1902-02-01
# 19777  1995-11-29              Not Within HPZ  PluggedOG 1999-11-01
# ...           ...                         ...        ...        ...
# 238988        NaT                Verified HPZ  PluggedOG 2016-10-01
# 239034 2008-07-13                Verified HPZ  PluggedOG 2018-10-01
# 239097        NaT                Verified HPZ  PluggedOG 2011-01-01
# 239100 1976-02-27                Verified HPZ  PluggedOG 2009-07-01
# 239121 1949-03-04                Verified HPZ  PluggedWS 1992-07-01
#
#          YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  IdleYear  \
# 3150     23.000000    Yes           No     False       NaN    2001.0
# 4895     67.583336    Yes          Yes     False       NaN    1956.0
# 6249    111.736115    Yes           No     False       NaN    1912.0
# 8997    121.916664    Yes           No     False       NaN    1902.0
# 19777    24.166666    Yes          Yes     False    1995.0    1999.0
# ...            ...    ...          ...       ...       ...       ...
# 238988    7.250000     No          Yes     False       NaN    2016.0
# 239034    5.250000     No           No     False    2008.0    2018.0
# 239097   13.000000    Yes          Yes     False       NaN    2011.0
# 239100   14.500000    Yes          Yes     False    1976.0    2009.0
# 239121   31.500000    Yes           No     False    1949.0    1992.0
#
#             api_10 first_date  last_date  ProdYears  LastProdYear
# 3150           NaN        NaT 1977-01-01        NaN          1977
# 4895           NaN        NaT 1977-01-01        NaN          1977
# 6249           NaN        NaT 1977-01-01        NaN          1977
# 8997           NaN        NaT 1977-01-01        NaN          1977
# 19777   0403004712 1996-01-31 1997-10-31       1.92          1997
# ...            ...        ...        ...        ...           ...
# 238988  0403701489 1977-01-31 2014-07-31        NaN          2014
# 239034  0403726995 2008-09-30 2016-09-01       8.14          2016
# 239097         NaN        NaT 1977-01-01        NaN          1977
# 239100  0403721592 1977-01-31 2007-06-30      31.34          2007
# 239121  0403701812 1977-01-31 1991-11-30      42.74          1991
#
# [503 rows x 38 columns]

# %%
# So what's happening is the regulators have likely just put a date of 1900/1/1 (which is the 0 date in Excel) into some of the IdleDate fields, so subtracting Years Idle from that, gives us these wierd LastProdYears
# Let's check a calculated Idle Date with provided Idle Date... public database production records started with the state in 1977, so we'll set LastProdYear to 1977 for those just to have something a long time ago, but not pre-industrial age
# I don't know the regulators are doing any manual records searches for their listed Idle Dates, maybe this will reveal something
well_list_df['CalcIdleDate'] = None
well_list_df.loc[(~well_list_df['last_date'].isnull()) & (well_list_df['last_date'] < CURRENT_DATE) & (~well_list_df['WellStatus'].isin(['Plugged','PluggedOnly'])), 'CalcIdleDate'] =  well_list_df['last_date'] + pd.DateOffset(years=2)
well_list_df['CalcIdleDate'] = well_list_df['CalcIdleDate'].astype('datetime64[ns]')

# also derive the year for simpler comparisons
well_list_df['CalcIdleYear'] = well_list_df['CalcIdleDate'].dt.year

# This is likely useful for the model below
# some of the P&Aed wells had a recorded Idle date, and it was kept after P&A, so use that to start
well_list_df['CalcIdleYear'] = well_list_df['CalcIdleYear'].where(~(
    (~well_list_df['IdleYear'].isna()) &
    (well_list_df['WellStatus'].isin(['Plugged','PluggedOnly','Cancelled']))), well_list_df['IdleYear'])

# For P&Aed or Cancelled wells without an Idle year, if it has last production, use that date + 2 years
well_list_df['CalcIdleYear'] = well_list_df['CalcIdleYear'].where(~(
    (well_list_df['IdleYear'].isna()) &
    (well_list_df['WellStatus'].isin(['Plugged','PluggedOnly','Cancelled'])) &
    (~well_list_df['LastProdYear'].isna())), well_list_df['LastProdYear'] + 2)

# For P&Aed wells without an Idle year, if it's been P&A'ed, it's 1977, otherwise just put it in the future for now
well_list_df.loc[(well_list_df['CalcIdleYear'].isna()) & (well_list_df['WellStatus'].isin(['Plugged','PluggedOnly'])), 'CalcIdleYear'] = 1977

# remainder of None are Active wells, so just put them in 2040 for now (important for the regression model)
well_list_df['CalcIdleYear'] = well_list_df['CalcIdleYear'].fillna(2040)

# is the calculated idle year the same as the provided one?
well_list_df['IsIdleYearSame'] = well_list_df['IdleYear'].eq(well_list_df['CalcIdleYear'])
well_list_df.loc[(well_list_df['IdleYear'].isna()) & (well_list_df['CalcIdleYear']==0), 'IsIdleYearSame'] = True

# some wells will have stopped volume recordings less than 2 years ago - if that's the case, they're not technically "IDLE" yet (as far as this model goes; there is some actual nuance, but not important to start)
well_list_df['CalcYearsIdle'] = round((CURRENT_DATE - well_list_df['CalcIdleDate']).dt.days/365.25, 2)
well_list_df.loc[well_list_df['CalcYearsIdle'] <= 0, 'CalcIdleDate']  = None
well_list_df.loc[well_list_df['CalcYearsIdle'] <= 0, 'CalcYearsIdle'] = 0

well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears  \
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241911       NaN       NaN         NaN        NaT 1977-01-01        NaN
#
#         LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  CalcYearsIdle
# 0               1977   1979-01-01        1979.0           False          46.00
# 1               2013   2015-07-31        2015.0            True           9.42
# 2               2013   2015-07-31        2015.0            True           9.42
# 3               2009   2011-05-31        2011.0            True          13.59
# 4               2023          NaT        2025.0           False           0.00
# ...              ...          ...           ...             ...            ...
# 241907          1982          NaT        1984.0           False            NaN
# 241908          1977          NaT        1979.0           False            NaN
# 241909          1985          NaT        1987.0           False            NaN
# 241910          1977          NaT        1979.0           False            NaN
# 241911          1977          NaT        1979.0           False            NaN
#
# [241912 rows x 42 columns]

# %%
well_list_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241912 entries, 0 to 241911
# Data columns (total 42 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   API             241912 non-null  object
#  1   LeaseName       241912 non-null  object
#  2   WellNumber      241567 non-null  object
#  3   WellDesign      241779 non-null  object
#  4   WellStatus      241912 non-null  object
#  5   WellType        241912 non-null  object
#  6   WellTypeLa      241912 non-null  object
#  7   OperatorCo      241912 non-null  object
#  8   OperatorNa      241912 non-null  object
#  9   FieldName       241912 non-null  object
#  10  AreaName        240458 non-null  object
#  11  Place           241895 non-null  object
#  12  District        241912 non-null  object
#  13  CountyName      241912 non-null  object
#  14  Section         241912 non-null  int64
#  15  Township        241912 non-null  object
#  16  Range           241912 non-null  object
#  17  BaseMeridi      241912 non-null  object
#  18  Latitude        241912 non-null  float64
#  19  Longitude       241912 non-null  float64
#  20  GISSource       241912 non-null  object
#  21  isConfiden      241912 non-null  object
#  22  isDirectio      241912 non-null  object
#  23  SpudDate        118417 non-null  datetime64[ns]
#  24  inHPZ           241912 non-null  object
#  25  WellSymbol      241912 non-null  object
#  26  IdleDate        29910 non-null   datetime64[ns]
#  27  YearsIdle       29910 non-null   float32
#  28  IsLTIW          29910 non-null   object
#  29  UnsatAbandon    29910 non-null   object
#  30  FieldAbd        241912 non-null  bool
#  31  SpudYear        118417 non-null  float64
#  32  IdleYear        29910 non-null   float64
#  33  api_10          151584 non-null  object
#  34  first_date      151584 non-null  datetime64[ns]
#  35  last_date       241912 non-null  datetime64[ns]
#  36  ProdYears       118417 non-null  float64
#  37  LastProdYear    241912 non-null  int32
#  38  CalcIdleDate    49237 non-null   datetime64[ns]
#  39  CalcIdleYear    241912 non-null  float64
#  40  IsIdleYearSame  241912 non-null  bool
#  41  CalcYearsIdle   67084 non-null   float64
# dtypes: bool(2), datetime64[ns](5), float32(1), float64(7), int32(1), int64(1), object(25)
# memory usage: 72.4+ MB

# %%
well_list_df['IsIdleYearSame'].value_counts()
# Out:
# IsIdleYearSame
# False    222582
# True      19330
# Name: count, dtype: int64

# %%
well_list_df[well_list_df['IsIdleYearSame'] == False]
# Out:
#                API                       LeaseName WellNumber  \
# 0       0403300003             Lease by W.G. Young          1
# 4       0402120521                    Angel Slough      1-Feb
# 5       0402100240  Max Pray-Central Valley-Boyd U          1
# 6       0402120034               Afton Community 3          1
# 7       0402100017               Afton Community 2          1
# ...            ...                             ...        ...
# 241907  0411320572                  Knaggs-Wallace          5
# 241908  0411321202                  Knaggs-Wallace          6
# 241909  0411320667        Reclamation District 108          1
# 241910  0411321025                    Colusa Basin     Jan-35
# 241911  0411320692        Reclamation District 108          3
#
#                               WellDesign WellStatus WellType WellTypeLa  \
# 0                                      1       Idle       DG    Dry Gas
# 4                       Angel Slough 2-1     Active       DG    Dry Gas
# 5       Max Pray-Central Valley-Boyd U 1    Plugged       DH   Dry Hole
# 6                    Afton Community 3 1    Plugged       DH   Dry Hole
# 7                    Afton Community 2 1    Plugged       DG    Dry Gas
# ...                                  ...        ...      ...        ...
# 241907                  Knaggs-Wallace 5    Plugged       DG    Dry Gas
# 241908                  Knaggs-Wallace 6    Plugged       DH   Dry Hole
# 241909        Reclamation District 108 1    Plugged       DG    Dry Gas
# 241910                 Colusa Basin 1-35    Plugged       DH   Dry Hole
# 241911        Reclamation District 108 3    Plugged       DH   Dry Hole
#
#        OperatorCo                            OperatorNa  \
# 0           11838                            W.G. Young
# 4           C8720                  Crain Orchards, Inc.
# 5           03279               General Expl. Co. of Ca
# 6           S3280                    Shoshone Oil Corp.
# 7           V1150                           Venoco, LLC
# ...           ...                                   ...
# 241907      P0325  Pacific Inland Operating Corporation
# 241908      P4733        Production Specialties Company
# 241909      C5640                   Chevron U.S.A. Inc.
# 241910      R3755        Rosetta Resources Operating LP
# 241911      C5640                   Chevron U.S.A. Inc.
#
#                        FieldName  AreaName         Place  District CountyName  \
# 0                      Any Field       NaN   Lake County  Northern       Lake
# 4                      Afton Gas      Main  Glenn County  Northern      Glenn
# 5                      Afton Gas      Main  Glenn County  Northern      Glenn
# 6                      Afton Gas      Main  Glenn County  Northern      Glenn
# 7                      Afton Gas      Main  Glenn County  Northern      Glenn
# ...                          ...       ...           ...       ...        ...
# 241907          Zamora Gas (ABD)  Any Area   Yolo County  Northern       Yolo
# 241908          Zamora Gas (ABD)  Any Area   Yolo County  Northern       Yolo
# 241909  Zamora, North, Gas (ABD)  Any Area   Yolo County  Northern       Yolo
# 241910  Zamora, North, Gas (ABD)  Any Area   Yolo County  Northern       Yolo
# 241911  Zamora, North, Gas (ABD)  Any Area   Yolo County  Northern       Yolo
#
#         Section Township Range BaseMeridi   Latitude   Longitude  \
# 0            14      13N   09W         MD  38.976693 -122.833093
# 4             2      18N   01W         MD  39.449158 -121.946289
# 5             2      18N   01W         MD  39.438267 -121.947418
# 6            34      19N   01W         MD  39.455864 -121.949425
# 7            34      19N   01W         MD  39.460217 -121.953537
# ...         ...      ...   ...        ...        ...         ...
# 241907       12      11N   01E         MD  38.812370 -121.812614
# 241908       11      11N   01E         MD  38.815502 -121.826279
# 241909       35      12N   01E         MD  38.840790 -121.838989
# 241910       35      12N   01E         MD  38.851700 -121.837715
# 241911       35      12N   01E         MD  38.840210 -121.829697
#
#                         GISSource isConfiden isDirectio   SpudDate  \
# 0       Notice of Intent to Drill          N          N        NaT
# 4                             GPS          N          N 1988-02-17
# 5                             hud          N          N        NaT
# 6                             hud          N          N        NaT
# 7                             hud          N          N 1945-04-14
# ...                           ...        ...        ...        ...
# 241907                        hud          N          N 1979-12-12
# 241908                        GPS          N          N        NaT
# 241909                        hud          N          N 1981-09-17
# 241910                        hud          N          N        NaT
# 241911                        hud          N          N        NaT
#
#                              inHPZ WellSymbol   IdleDate  YearsIdle IsLTIW  \
# 0                     Verified HPZ     IdleDG 1901-01-01      123.0    Yes
# 4                   Not Within HPZ   ActiveDG        NaT        NaN    NaN
# 5                     Verified HPZ  PluggedDH        NaT        NaN    NaN
# 6                  Potentially HPZ  PluggedDH        NaT        NaN    NaN
# 7                  Potentially HPZ  PluggedDG        NaT        NaN    NaN
# ...                            ...        ...        ...        ...    ...
# 241907  Potentially Not Within HPZ  PluggedDG        NaT        NaN    NaN
# 241908  Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 241909  Potentially Not Within HPZ  PluggedDG        NaT        NaN    NaN
# 241910  Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 241911  Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
#
#        UnsatAbandon  FieldAbd  SpudYear  IdleYear      api_10 first_date  \
# 0                No     False       NaN    1901.0         NaN        NaT
# 4               NaN     False    1988.0       NaN  0402120521 1988-06-30
# 5               NaN     False       NaN       NaN         NaN        NaT
# 6               NaN     False       NaN       NaN         NaN        NaT
# 7               NaN     False    1945.0       NaN  0402100017 1977-09-30
# ...             ...       ...       ...       ...         ...        ...
# 241907          NaN      True    1979.0       NaN  0411320572 1981-07-31
# 241908          NaN      True       NaN       NaN         NaN        NaT
# 241909          NaN      True    1981.0       NaN  0411320667 1985-02-28
# 241910          NaN      True       NaN       NaN         NaN        NaT
# 241911          NaN      True       NaN       NaN         NaN        NaT
#
#         last_date  ProdYears  LastProdYear CalcIdleDate  CalcIdleYear  \
# 0      1977-01-01        NaN          1977   1979-01-01        1979.0
# 4      2023-08-31      35.53          2023          NaT        2025.0
# 5      1977-01-01        NaN          1977          NaT        1979.0
# 6      1977-01-01        NaN          1977          NaT        1979.0
# 7      1995-05-31      50.13          1995          NaT        1997.0
# ...           ...        ...           ...          ...           ...
# 241907 1982-02-28       2.21          1982          NaT        1984.0
# 241908 1977-01-01        NaN          1977          NaT        1979.0
# 241909 1985-10-31       4.12          1985          NaT        1987.0
# 241910 1977-01-01        NaN          1977          NaT        1979.0
# 241911 1977-01-01        NaN          1977          NaT        1979.0
#
#         IsIdleYearSame  CalcYearsIdle
# 0                False           46.0
# 4                False            0.0
# 5                False            NaN
# 6                False            NaN
# 7                False            NaN
# ...                ...            ...
# 241907           False            NaN
# 241908           False            NaN
# 241909           False            NaN
# 241910           False            NaN
# 241911           False            NaN
#
# [222582 rows x 42 columns]

# %%
well_list_df.columns
# Out:
# Index(['API', 'LeaseName', 'WellNumber', 'WellDesign', 'WellStatus',
#        'WellType', 'WellTypeLa', 'OperatorCo', 'OperatorNa', 'FieldName',
#        'AreaName', 'Place', 'District', 'CountyName', 'Section', 'Township',
#        'Range', 'BaseMeridi', 'Latitude', 'Longitude', 'GISSource',
#        'isConfiden', 'isDirectio', 'SpudDate', 'inHPZ', 'WellSymbol',
#        'IdleDate', 'YearsIdle', 'IsLTIW', 'UnsatAbandon', 'FieldAbd',
#        'SpudYear', 'IdleYear', 'api_10', 'first_date', 'last_date',
#        'ProdYears', 'LastProdYear', 'CalcIdleDate', 'CalcIdleYear',
#        'IsIdleYearSame', 'CalcYearsIdle'],
#       dtype='object')

# %%
# Investigate another individual well... for example, well 1 has a valid Spud date so subtracting it's Idle Years from Idle Date gives us a useful Last Production date
well_index = 1
print("Spud Date: ", well_list_df.loc[well_index, 'SpudYear'])
print("Idle Year: ", well_list_df.loc[well_index, 'IdleYear'])
print("Years Idle: ", well_list_df.loc[well_index, 'YearsIdle'])
print("Last Prod Calc Date: ", well_list_df.loc[well_index, 'IdleYear'] - well_list_df.loc[well_index, 'YearsIdle'])
print("Last Prod < Spud Date: ", well_list_df.loc[well_index, 'SpudYear'] < (well_list_df.loc[well_index, 'IdleYear'] - well_list_df.loc[well_index, 'YearsIdle']))
# Out:
# Spud Date:  1999.0
# Idle Year:  2015.0
# Years Idle:  8.416667
# Last Prod Calc Date:  2006.583333015442
# Last Prod < Spud Date:  True

# %%
# number of long term idles, ignores NaN
well_list_df.value_counts('IsLTIW')
# Out:
# IsLTIW
# No     15343
# Yes    14567
# Name: count, dtype: int64

# %% [markdown]
# ### Set up some 0/1 flags we can easily sum for counts later.
# One risk component can be if an Operator has badly plugged wells noted in `UnsatAbandon`.

# %%
# Create a flag so we can sum the `1` values later and get a count of unsatisfactory abandonments
well_list_df['UnsatAbandonFlag'] = 0
well_list_df.loc[well_list_df['UnsatAbandon'] == 'Yes', 'UnsatAbandonFlag'] = 1

# Create a flag for Plugged Wells
well_list_df['PluggedFlag'] = 0
well_list_df.loc[well_list_df['WellStatus'].isin(['Plugged','PluggedOnly']), 'PluggedFlag'] = 1

# Create a flag for Plugged Wells in the last 10 years
well_list_df['PluggedRecentFlag'] = 0
well_list_df.loc[(well_list_df['WellStatus'].isin(['Plugged','PluggedOnly'])) & (well_list_df['LastProdYear'] >= 2014), 'PluggedRecentFlag'] = 1

# Create a flag for Idle Wells
well_list_df['IdleFlag'] = 0
well_list_df.loc[~(well_list_df['WellStatus'].isin(['Plugged','PluggedOnly'])) & (well_list_df['CalcYearsIdle']>3), 'IdleFlag'] = 1

well_list_df.groupby('OperatorNa')['UnsatAbandon'].value_counts()
# Out:
# OperatorNa                   UnsatAbandon
# 104 Oil & Drilling Co.       No               3
# 1301 Colton LLC              No               2
# 1350 Court Partners, LP      No               2
# 25 Hill Properties, Inc.     No              35
# 260 Resource Management LLC  No              12
#                                              ..
# Yoelin Family Trust          No               2
# Young & Shaw                 No               6
# Young Petroleum Corp., Ltd.  No               1
# Yunker, Morton & Dolley      No               1
# Zynergy, LLC                 No              44
# Name: count, Length: 1271, dtype: int64

# %% [markdown]
# ## Advanced Imputation : SPUD date cleanup
# SPUD (or drilling) date is likely to be an useful feature for training the model, as age of the well is a likely factor in the risk assessment. Older wells sometimes are more complicated, or contain material that make modern abandonment practices more difficult.

# %%
total_count_with_null_spud = well_list_df['SpudDate'].isna().sum()
idle_count_with_null_spud = well_list_df[(well_list_df['WellStatus']=='Idle') & (well_list_df['SpudDate'].isna())]['API'].count()
total_idle_count = well_list_df['IdleFlag'].sum()

print(f"Total Count of NULL SPUD Date: {total_count_with_null_spud:,}")
print(f"Total Idle Count: {total_idle_count:,}")
print(f"Count of Idle Wells with NULL SPUD Date: {idle_count_with_null_spud:,} ({(idle_count_with_null_spud/total_idle_count):.0%})")
# Out:
# Total Count of NULL SPUD Date: 123,495
# Total Idle Count: 42,499
# Count of Idle Wells with NULL SPUD Date: 12,133 (29%)

# %%
# this resets the dataframe and removes any views
# well_list_df = well_list_df.copy()

# %%
# Check if there are any wells with status Idle but no Idle date, as provided by regulator
missing_reg_idle_date = well_list_df[(well_list_df['WellStatus'] == 'Idle') & (well_list_df['IdleDate'].isna())]
print(f"Count of Idle Status wells with no Idle date set: {missing_reg_idle_date['API'].count():,}")
missing_reg_idle_date
# Out:
# Count of Idle Status wells with no Idle date set: 11,261
#                API                              LeaseName WellNumber  \
# 102     0403700771                      Standard-Sesnon 1         19
# 107     0403721362                                 Porter        26A
# 112     0403721276                                 Porter        32B
# 113     0403721359                           Fernando Fee        32C
# 117     0403700785                      Standard-Sesnon 1         35
# ...            ...                                    ...        ...
# 235757  0403704489  Lease by Tidelands Oil Production Co.     UP413A
# 235775  0403723827  Lease by Tidelands Oil Production Co.      UP956
# 235779  0403702666  Lease by Tidelands Oil Production Co.      W 169
# 235784  0403702747  Lease by Tidelands Oil Production Co.       X 11
# 241656  0403068384                        Yowlumne Unit B      25-33
#
#                    WellDesign WellStatus WellType   WellTypeLa OperatorCo  \
# 102      Standard-Sesnon 1 19       Idle       OG    Oil & Gas      C9035
# 107                Porter 26A       Idle       GS  Gas Storage      S4700
# 112                Porter 32B       Idle       GS  Gas Storage      S4700
# 113          Fernando Fee 32C       Idle       GS  Gas Storage      S4700
# 117      Standard-Sesnon 1 35       Idle       OG    Oil & Gas      C9035
# ...                       ...        ...      ...          ...        ...
# 235757                 UP413A       Idle       OG    Oil & Gas      T2975
# 235775                  UP956       Idle       OG    Oil & Gas      T2975
# 235779                  W 169       Idle       OG    Oil & Gas      T2975
# 235784                   X 11       Idle       OG    Oil & Gas      T2975
# 241656  Yowlumne Unit B 25-33       Idle       OG    Oil & Gas      C0885
#
#                                          OperatorNa     FieldName  \
# 102               Crimson Resource Management Corp.  Aliso Canyon
# 107                 Southern California Gas Company  Aliso Canyon
# 112                 Southern California Gas Company  Aliso Canyon
# 113                 Southern California Gas Company  Aliso Canyon
# 117               Crimson Resource Management Corp.  Aliso Canyon
# ...                                             ...           ...
# 235757                 Tidelands Oil Production Co.    Wilmington
# 235775                 Tidelands Oil Production Co.    Wilmington
# 235779                 Tidelands Oil Production Co.    Wilmington
# 235784                 Tidelands Oil Production Co.    Wilmington
# 241656  California Resources Production Corporation      Yowlumne
#
#                 AreaName                Place  District   CountyName  Section  \
# 102             Any Area   Los Angeles County  Northern  Los Angeles       28
# 107             Any Area   Los Angeles County  Northern  Los Angeles       28
# 112             Any Area   Los Angeles County  Northern  Los Angeles       27
# 113             Any Area          Los Angeles  Northern  Los Angeles       27
# 117             Any Area   Los Angeles County  Northern  Los Angeles       28
# ...                  ...                  ...       ...          ...      ...
# 235757     Fault Block I          Los Angeles  Southern  Los Angeles        4
# 235775  Fault Block II-A  Long Beach Offshore  Southern  Los Angeles        4
# 235779    Fault Block IV  Long Beach Offshore  Southern  Los Angeles        3
# 235784    Fault Block IV           Long Beach  Southern  Los Angeles        2
# 241656          Any Area          Kern County    Inland         Kern       33
#
#        Township Range BaseMeridi   Latitude   Longitude     GISSource  \
# 102         03N   16W         SB  34.313702 -118.563377           GPS
# 107         03N   16W         SB  34.315704 -118.557350  Well Summary
# 112         03N   16W         SB  34.312504 -118.550522  Well Summary
# 113         03N   16W         SB  34.313217 -118.539986  Well Summary
# 117         03N   16W         SB  34.317844 -118.566788           GPS
# ...         ...   ...        ...        ...         ...           ...
# 235757      05S   13W         SB  33.768555 -118.241798      Operator
# 235775      05S   13W         SB  33.762705 -118.240989  Well Summary
# 235779      05S   13W         SB  33.762501 -118.221062      Operator
# 235784      05S   13W         SB  33.761707 -118.217094      Operator
# 241656      12N   22W         SB  35.084136 -119.238809  Well Summary
#
#        isConfiden isDirectio   SpudDate           inHPZ WellSymbol IdleDate  \
# 102             N          Y 1951-12-22  Not Within HPZ     IdleOG      NaT
# 107             N          Y 1973-07-17  Not Within HPZ     IdleGS      NaT
# 112             N          Y 1972-09-12  Not Within HPZ     IdleGS      NaT
# 113             N          Y 1973-05-16  Not Within HPZ     IdleGS      NaT
# 117             N          Y        NaT    Verified HPZ     IdleOG      NaT
# ...           ...        ...        ...             ...        ...      ...
# 235757          N          Y        NaT    Verified HPZ     IdleOG      NaT
# 235775          N          Y 1995-10-21    Verified HPZ     IdleOG      NaT
# 235779          N          N 2017-12-31  Not Within HPZ     IdleOG      NaT
# 235784          N          Y 2023-02-28  Not Within HPZ     IdleOG      NaT
# 241656          N          Y        NaT  Not Within HPZ     IdleOG      NaT
#
#         YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  IdleYear  \
# 102           NaN    NaN          NaN     False    1951.0       NaN
# 107           NaN    NaN          NaN     False    1973.0       NaN
# 112           NaN    NaN          NaN     False    1972.0       NaN
# 113           NaN    NaN          NaN     False    1973.0       NaN
# 117           NaN    NaN          NaN     False       NaN       NaN
# ...           ...    ...          ...       ...       ...       ...
# 235757        NaN    NaN          NaN     False       NaN       NaN
# 235775        NaN    NaN          NaN     False    1995.0       NaN
# 235779        NaN    NaN          NaN     False    2017.0       NaN
# 235784        NaN    NaN          NaN     False    2023.0       NaN
# 241656        NaN    NaN          NaN     False       NaN       NaN
#
#             api_10 first_date  last_date  ProdYears  LastProdYear  \
# 102     0403700771 1978-09-30 1978-11-30      26.94          1978
# 107     0403721362 1978-01-31 2022-09-30      49.20          2022
# 112     0403721276 1977-01-31 2022-09-30      50.05          2022
# 113     0403721359 1978-01-31 2022-09-30      49.37          2022
# 117     0403700785 1977-01-31 1986-07-31        NaN          1986
# ...            ...        ...        ...        ...           ...
# 235757  0403704489 1977-01-31 1989-08-31        NaN          1989
# 235775  0403723827 1997-01-31 2020-12-31      25.20          2020
# 235779  0403702666 2018-01-31 2024-11-30       6.92          2024
# 235784  0403702747 2023-03-31 2023-04-30       0.17          2023
# 241656         NaN        NaT 1977-01-01        NaN          1977
#
#        CalcIdleDate  CalcIdleYear  IsIdleYearSame  CalcYearsIdle  \
# 102      1980-11-30        1980.0           False          44.08
# 107      2024-09-30        2024.0           False           0.25
# 112      2024-09-30        2024.0           False           0.25
# 113      2024-09-30        2024.0           False           0.25
# 117      1988-07-31        1988.0           False          36.42
# ...             ...           ...             ...            ...
# 235757   1991-08-31        1991.0           False          33.34
# 235775   2022-12-31        2022.0           False           2.00
# 235779          NaT        2026.0           False           0.00
# 235784          NaT        2025.0           False           0.00
# 241656   1979-01-01        1979.0           False          46.00
#
#         UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  IdleFlag
# 102                    0            0                  0         1
# 107                    0            0                  0         0
# 112                    0            0                  0         0
# 113                    0            0                  0         0
# 117                    0            0                  0         1
# ...                  ...          ...                ...       ...
# 235757                 0            0                  0         1
# 235775                 0            0                  0         0
# 235779                 0            0                  0         0
# 235784                 0            0                  0         0
# 241656                 0            0                  0         1
#
# [11261 rows x 46 columns]

# %%
# Check if there are any wells with status Idle but no Idle date, as calculated
missing_calc_idle_date = well_list_df[(well_list_df['WellStatus'] == 'Idle') & (well_list_df['IdleFlag']==0)]
print(f"Count of Idle Status wells with no Idle date set: {missing_calc_idle_date['API'].count():,}")
missing_calc_idle_date
# Out:
# Count of Idle Status wells with no Idle date set: 9,337
#                API          LeaseName WellNumber              WellDesign  \
# 98      0403700036             Porter          1                Porter 1
# 101     0403700707             Porter         18               Porter 18
# 103     0403700708             Porter         19               Porter 19
# 105     0403700774  Standard-Sesnon 1         23    Standard-Sesnon 1 23
# 107     0403721362             Porter        26A              Porter 26A
# ...            ...                ...        ...                     ...
# 241666  0402975044    Yowlumne Unit B     38X-34  Yowlumne Unit B 38X-34
# 241702  0402957459    Yowlumne Unit B      67X-4   Yowlumne Unit B 67X-4
# 241704  0402957363    Yowlumne Unit B     68X-32  Yowlumne Unit B 68X-32
# 241814  0408301804              Luton        103               Luton 103
# 241828  0408301011              Quati         98                Quati 98
#
#        WellStatus WellType      WellTypeLa OperatorCo  \
# 98           Idle       OG       Oil & Gas      S4700
# 101          Idle       OG       Oil & Gas      S4700
# 103          Idle       WF      Waterflood      S4700
# 105          Idle       OG       Oil & Gas      C9035
# 107          Idle       GS     Gas Storage      S4700
# ...           ...      ...             ...        ...
# 241666       Idle       OG       Oil & Gas      C0885
# 241702       Idle       OG       Oil & Gas      C0885
# 241704       Idle       WF      Waterflood      C0885
# 241814       Idle       WD  Water Disposal      T3460
# 241828       Idle       OG       Oil & Gas      10379
#
#                                          OperatorNa     FieldName  AreaName  \
# 98                  Southern California Gas Company  Aliso Canyon  Any Area
# 101                 Southern California Gas Company  Aliso Canyon  Any Area
# 103                 Southern California Gas Company  Aliso Canyon  Any Area
# 105               Crimson Resource Management Corp.  Aliso Canyon  Any Area
# 107                 Southern California Gas Company  Aliso Canyon  Any Area
# ...                                             ...           ...       ...
# 241666  California Resources Production Corporation      Yowlumne  Any Area
# 241702  California Resources Production Corporation      Yowlumne  Any Area
# 241704  California Resources Production Corporation      Yowlumne  Any Area
# 241814                Towne Exploration Company, LP          Zaca  Any Area
# 241828                     NewBridge Resources, LLC          Zaca  Any Area
#
#                        Place  District     CountyName  Section Township Range  \
# 98        Los Angeles County  Northern    Los Angeles       27      03N   16W
# 101       Los Angeles County  Northern    Los Angeles       28      03N   16W
# 103       Los Angeles County  Northern    Los Angeles       28      03N   16W
# 105       Los Angeles County  Northern    Los Angeles       28      03N   16W
# 107       Los Angeles County  Northern    Los Angeles       28      03N   16W
# ...                      ...       ...            ...      ...      ...   ...
# 241666           Kern County    Inland           Kern       34      12N   22W
# 241702           Kern County    Inland           Kern        4      11N   22W
# 241704           Kern County    Inland           Kern       32      12N   22W
# 241814  Santa Barbara County  Northern  Santa Barbara       29      08N   31W
# 241828  Santa Barbara County  Northern  Santa Barbara        3      07N   31W
#
#        BaseMeridi   Latitude   Longitude     GISSource isConfiden isDirectio  \
# 98             SB  34.316761 -118.547584           GPS          N          N
# 101            SB  34.317791 -118.557999           GPS          N          N
# 103            SB  34.317715 -118.560219           GPS          N          N
# 105            SB  34.317600 -118.570267           GPS          N          N
# 107            SB  34.315704 -118.557350  Well Summary          N          Y
# ...           ...        ...         ...           ...        ...        ...
# 241666         SB  35.077286 -119.219978           GPS          N          Y
# 241702         SB  35.065617 -119.229195           GPS          N          N
# 241704         SB  35.077850 -119.247894  Well Summary          N          N
# 241814         SB  34.738342 -120.165787           GPS          N          N
# 241828         SB  34.720535 -120.127739           GPS          N          N
#
#          SpudDate           inHPZ WellSymbol   IdleDate  YearsIdle IsLTIW  \
# 98     1938-06-21  Not Within HPZ     IdleOG 2020-11-01   3.166667     No
# 101    1943-10-23  Not Within HPZ     IdleOG 2022-03-01   1.833333     No
# 103    1947-11-22  Not Within HPZ     IdleWF 1985-08-01  38.416668    Yes
# 105    1952-10-18    Verified HPZ     IdleOG 2022-05-01   1.666667     No
# 107    1973-07-17  Not Within HPZ     IdleGS        NaT        NaN    NaN
# ...           ...             ...        ...        ...        ...    ...
# 241666 1985-05-30  Not Within HPZ     IdleOG 2022-04-01   1.750000     No
# 241702 1979-05-30  Not Within HPZ     IdleOG 2017-05-01   6.666667     No
# 241704 1978-04-08  Not Within HPZ     IdleWF 2010-02-01  13.916667    Yes
# 241814 2012-11-30  Not Within HPZ     IdleWD 2023-05-01   0.666667     No
# 241828 2006-02-28    Verified HPZ     IdleOG 2023-02-01   0.916667     No
#
#        UnsatAbandon  FieldAbd  SpudYear  IdleYear      api_10 first_date  \
# 98               No     False    1938.0    2020.0  0403700036 1977-01-31
# 101              No     False    1943.0    2022.0  0403700707 1977-01-31
# 103              No     False    1947.0    1985.0  0403700708 1977-01-31
# 105              No     False    1952.0    2022.0  0403700774 1977-01-31
# 107             NaN     False    1973.0       NaN  0403721362 1978-01-31
# ...             ...       ...       ...       ...         ...        ...
# 241666           No     False    1985.0    2022.0  0402975044 1985-06-30
# 241702           No     False    1979.0    2017.0  0402957459 1979-06-30
# 241704           No     False    1978.0    2010.0  0402957363 1980-04-30
# 241814           No     False    2012.0    2023.0  0408301804 2012-12-31
# 241828           No     False    2006.0    2023.0  0408301011 2006-03-31
#
#         last_date  ProdYears  LastProdYear CalcIdleDate  CalcIdleYear  \
# 98     2020-05-31      81.94          2020   2022-05-31        2022.0
# 101    2020-02-29      76.35          2020   2022-02-28        2022.0
# 103    2022-09-30      74.86          2022   2024-09-30        2024.0
# 105    2020-04-30      67.53          2020   2022-04-30        2022.0
# 107    2022-09-30      49.20          2022   2024-09-30        2024.0
# ...           ...        ...           ...          ...           ...
# 241666 2020-12-31      35.59          2020   2022-12-31        2022.0
# 241702 2022-05-31      43.00          2022   2024-05-31        2024.0
# 241704 2020-12-31      42.73          2020   2022-12-31        2022.0
# 241814 2021-04-30       8.41          2021   2023-04-30        2023.0
# 241828 2024-12-31      18.84          2024          NaT        2040.0
#
#         IsIdleYearSame  CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  \
# 98               False           2.59                 0            0
# 101               True           2.84                 0            0
# 103              False           0.25                 0            0
# 105               True           2.67                 0            0
# 107              False           0.25                 0            0
# ...                ...            ...               ...          ...
# 241666            True           2.00                 0            0
# 241702           False           0.59                 0            0
# 241704           False           2.00                 0            0
# 241814            True           1.67                 0            0
# 241828           False            NaN                 0            0
#
#         PluggedRecentFlag  IdleFlag
# 98                      0         0
# 101                     0         0
# 103                     0         0
# 105                     0         0
# 107                     0         0
# ...                   ...       ...
# 241666                  0         0
# 241702                  0         0
# 241704                  0         0
# 241814                  0         0
# 241828                  0         0
#
# [9337 rows x 46 columns]

# %%
print(f"Count of Idle-status wells with no Idle date from regulators or Spud Date set: {missing_reg_idle_date['SpudDate'].count():,}")
print(f"Count of Idle-status wells with Spud Date but no Idle date set by regulators: {missing_reg_idle_date['API'].count() - missing_reg_idle_date['SpudDate'].count():,}")
print(f"Count of Idle-status wells with no Idle date from my calculation or Spud Date set: {missing_calc_idle_date['SpudDate'].count():,}")
print(f"Count of Idle-status wells with Spud Date but no Idle date set by my calc: {missing_calc_idle_date['API'].count() - missing_calc_idle_date['SpudDate'].count():,}")
# Out:
# Count of Idle-status wells with no Idle date from regulators or Spud Date set: 8,913
# Count of Idle-status wells with Spud Date but no Idle date set by regulators: 2,348
# Count of Idle-status wells with no Idle date from my calculation or Spud Date set: 7,904
# Count of Idle-status wells with Spud Date but no Idle date set by my calc: 1,433

# %% [markdown]
# ## Data Wrangling on full data set
# I think the data wrangling work will take place in 2 steps. First step is with all the data, and the second step will be specifically around the idle wells. For the first step, we can use the full dataset to help fill in gaps in the well data (i.e. potentially using location-based information to fill in missing values from nearest neighbors). The second step may take another pass on the idle well data to look for outliers or "bad" data.

# %% [markdown]
# ### Step 1 : Nearest neighbors
# As the lat/long data is the most complete feature, can I use nearest neighbors to impute some other missing values later (like SPUD date) ? This will be difficult given 61% of SPUD Dates are missing for the Idle status wells, but it's worth a look to see how big the variance is.
#
# Create the radian lat/longs for haversine formulas

# %%
well_list_df['lat_r'] = np.radians(well_list_df['Latitude'])
well_list_df['lng_r'] = np.radians(well_list_df['Longitude'])
print(f"Latitude Original: {well_list_df['Latitude'][1]} ; Converted to radians: {well_list_df['lat_r'][1]}")
print(f"Longitude Original: {well_list_df['Longitude'][1]} ; Converted to radians: {well_list_df['lng_r'][1]}")
# Out:
# Latitude Original: 39.4406395 ; Converted to radians: 0.6883690183671302
# Longitude Original: -121.951889 ; Converted to radians: -2.1284619920766548

# %%
# Investigate an individual well... for example, well 0 doesn't have a Spud date so subtracting its Idle Years from Idle Date gives us a fictitious date
# this is relevant because later I impute Spud Date various ways, and this Idle date is apparently fictitious, so I could wind up with Idle Dates before Spud Dates which is nonsensical
well_index = 0
print("Spud Date: ", well_list_df.loc[well_index, 'SpudYear'])
print("Calc Idle Year: ", well_list_df.loc[well_index, 'CalcIdleYear'])
print("Years Idle: ", well_list_df.loc[well_index, 'CalcYearsIdle'])
print("Last Prod Calc Date: ", well_list_df.loc[well_index, 'CalcIdleYear'] - well_list_df.loc[well_index, 'CalcYearsIdle'])
print("Last Prod < Spud Date: ", well_list_df.loc[well_index, 'SpudYear'] < (well_list_df.loc[well_index, 'CalcIdleYear'] - well_list_df.loc[well_index, 'CalcYearsIdle']))
# Out:
# Spud Date:  nan
# Calc Idle Year:  1979.0
# Years Idle:  46.0
# Last Prod Calc Date:  1933.0
# Last Prod < Spud Date:  False

# %%
# Construct the full tree
# some example code here for a large dataset: https://stackoverflow.com/questions/58893719/find-nearest-point-in-other-dataframe-with-a-lot-of-data
# tutorial on the problem: https://autogis-site.readthedocs.io/en/2019/notebooks/L3/nearest-neighbor-faster.html
# leaf_size impacts the size of the tree in memory and the speed of the queries. a tutorial linked above recommends 15 as a good starting point
# Note : I haven't specific the projection system, so the nearest neighbors will be correct, but probably not the distances
btree = BallTree(well_list_df[['lat_r','lng_r']], leaf_size=15)
well_list_df[['API','Latitude','Longitude','lat_r','lng_r']][:5]
# Out:
#           API   Latitude   Longitude     lat_r     lng_r
# 0  0403300003  38.976693 -122.833093  0.680272 -2.143842
# 1  0402120723  39.440640 -121.951889  0.688369 -2.128462
# 2  0402120734  39.447174 -121.961273  0.688483 -2.128626
# 3  0402120815  39.443230 -121.951042  0.688414 -2.128447
# 4  0402120521  39.449158 -121.946289  0.688518 -2.128364

# %%
# Check for one location, get the 10 nearest neighbors (excluding itself):
# this only takes 21s on my computer, so fairly fast
earth_radius_miles = 3958.8
k = 12
well_dist, well_idx = btree.query(well_list_df[['lat_r','lng_r']], k=k+1)

# this drops the first column which is the self match, and multiplies up to miles of distance
well_dist = well_dist[:,1:] * earth_radius_miles
well_dist[:5]
# Out:
# array([[ 3.76464031, 15.96980289, 19.22964628, 22.55896184, 23.12585248,
#         23.25375323, 23.73471081, 23.74452899, 29.17865084, 29.51841346,
#         29.80037237, 29.82790795],
#        [ 0.18828746,  0.34971439,  0.36794818,  0.65157559,  0.69278971,
#          0.6988316 ,  0.70434908,  0.75120863,  0.75616521,  0.79010484,
#          0.9283144 ,  0.94632129],
#        [ 0.14971877,  0.35658865,  0.52865789,  0.55485852,  0.65492492,
#          0.75761784,  0.78235095,  0.79010484,  0.79175114,  1.01523884,
#          1.02802253,  1.04434548],
#        [ 0.18828746,  0.23726257,  0.42460022,  0.50839039,  0.51943312,
#          0.52499464,  0.57306312,  0.75518273,  0.75761784,  0.78908721,
#          0.79498866,  0.88007837],
#        [ 0.28621085,  0.30480871,  0.34363565,  0.51150934,  0.52499464,
#          0.54275087,  0.58959346,  0.67392245,  0.70434908,  0.74093106,
#          0.7565342 ,  0.83098154]])

# %%
well_idx[:5]
# Out:
# array([[    0,  2680,  1481,  2682,  2681,  2684,  7323, 11742,  7295,
#          7245,  7235,  2609,  7236],
#        [    1,     3,     5,    22,    33,    40,    35,     4,    37,
#             8,     2, 10503,    50],
#        [    2,    37,    41,    35,    22,    50,     3,    40,     1,
#             8,     6,    16,     4],
#        [    3,     1,    22,     5,    40,    33,     4,     8,    37,
#             2,    50,    35,     6],
#        [    4,    33,    40,     8,     6,     3,    22,    17,    50,
#             1,    27,     5,    24]])

# %%
# checked well 0 against its nearest neighbor on google earth, and it's indeed 3.33 miles away, so the calculations look good.
well_list_df.iloc[[0,2680]]
# Out:
#              API            LeaseName WellNumber    WellDesign WellStatus  \
# 0     0403300003  Lease by W.G. Young          1             1       Idle
# 2680  0403300001           Evelyn Awe          1  Evelyn Awe 1    Plugged
#
#      WellType WellTypeLa OperatorCo           OperatorNa  FieldName  AreaName  \
# 0          DG    Dry Gas      11838           W.G. Young  Any Field       NaN
# 2680       DH   Dry Hole      09267  William T. McKenzie  Any Field  Any Area
#
#             Place  District CountyName  Section Township Range BaseMeridi  \
# 0     Lake County  Northern       Lake       14      13N   09W         MD
# 2680  Lake County  Northern       Lake       28      13N   09W         MD
#
#        Latitude   Longitude                  GISSource isConfiden isDirectio  \
# 0     38.976693 -122.833093  Notice of Intent to Drill          N          N
# 2680  38.940266 -122.873611                        hud          N          N
#
#      SpudDate            inHPZ WellSymbol   IdleDate  YearsIdle IsLTIW  \
# 0         NaT     Verified HPZ     IdleDG 1901-01-01      123.0    Yes
# 2680      NaT  Potentially HPZ  PluggedDH        NaT        NaN    NaN
#
#      UnsatAbandon  FieldAbd  SpudYear  IdleYear api_10 first_date  last_date  \
# 0              No     False       NaN    1901.0    NaN        NaT 1977-01-01
# 2680          NaN     False       NaN       NaN    NaN        NaT 1977-01-01
#
#       ProdYears  LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  \
# 0           NaN          1977   1979-01-01        1979.0           False
# 2680        NaN          1977          NaT        1979.0           False
#
#       CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  \
# 0              46.0                 0            0                  0
# 2680            NaN                 0            1                  0
#
#       IdleFlag     lat_r     lng_r
# 0            1  0.680272 -2.143842
# 2680         0  0.679636 -2.144549

# %% [markdown]
# ### Google Earth measurement between well 0 and well 2680
# <img src='source_pics\Screenshot 2025-01-08 210358.png'/>

# %%
# this pulls the list of nearest neighbors for the first well, which is missing it's SPUD date
# it appears that the neighboring wells were mainly drilled in the 1920s-1930s
well_list_df.iloc[well_idx[0,:]]
# Out:
#               API                                 LeaseName WellNumber  \
# 0      0403300003                       Lease by W.G. Young          1
# 2680   0403300001                                Evelyn Awe          1
# 1481   0403300002  Lease by Lake County Drilling & Dev. Co.          1
# 2682   0409700053         Lease by Alexander Valley Oil Co.          1
# 2681   0409700050                  Lease by Beach & Landini          1
# 2684   0409700140                                   Bidwell          1
# 7323   0409700141                                     Smith          1
# 11742  0409700051     Lease by Skaggs Springs Oil & Gas Co.          2
# 7295   0409700060     Lease by Skaggs Springs Oil & Gas Co.          1
# 7245   0401100250                    Lease by Young Oil Co.          1
# 7235   0401100251                  Lease by D. & M. Oil Co.          1
# 2609   0401100253    Lease by Amalgamated Oil Co. of Nevada          1
# 7236   0401120118                                    Terhel          1
#
#          WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                 1       Idle       DG    Dry Gas      11838
# 2680   Evelyn Awe 1    Plugged       DH   Dry Hole      09267
# 1481              1       Idle       DH   Dry Hole      05186
# 2682              1    Plugged       DH   Dry Hole      00212
# 2681              1    Plugged       DH   Dry Hole      00673
# 2684      Bidwell 1    Plugged       DH   Dry Hole      06081
# 7323        Smith 1    Plugged       DH   Dry Hole      06081
# 11742             2    Plugged       DH   Dry Hole      07888
# 7295              1    Plugged       DH   Dry Hole      07888
# 7245              1    Plugged       DH   Dry Hole      09402
# 7235              1    Plugged       DH   Dry Hole      01966
# 2609              1    Plugged       DH   Dry Hole      00280
# 7236       Terhel 1    Plugged       DH   Dry Hole      00301
#
#                             OperatorNa  FieldName  AreaName          Place  \
# 0                           W.G. Young  Any Field       NaN    Lake County
# 2680               William T. McKenzie  Any Field  Any Area    Lake County
# 1481   Lake County Drilling & Dev. Co.  Any Field  Any Area      Clearlake
# 2682          Alexander Valley Oil Co.  Any Field  Any Area  Sonoma County
# 2681                   Beach & Landini  Any Field  Any Area  Sonoma County
# 2684                   Mortara Oil Co.  Any Field  Any Area  Sonoma County
# 7323                   Mortara Oil Co.  Any Field  Any Area  Sonoma County
# 11742     Skaggs Springs Oil & Gas Co.  Any Field  Any Area  Sonoma County
# 7295      Skaggs Springs Oil & Gas Co.  Any Field  Any Area  Sonoma County
# 7245                     Young Oil Co.  Any Field  Any Area  Colusa County
# 7235                   D. & M. Oil Co.  Any Field  Any Area  Colusa County
# 2609     Amalgamated Oil Co. of Nevada  Any Field  Any Area  Colusa County
# 7236             American Energy Corp.  Any Field  Any Area  Colusa County
#
#        District CountyName  Section Township Range BaseMeridi   Latitude  \
# 0      Northern       Lake       14      13N   09W         MD  38.976693
# 2680   Northern       Lake       28      13N   09W         MD  38.940266
# 1481   Northern       Lake       35      13N   07W         MD  38.925224
# 2682   Northern     Sonoma       22      10N   09W         MD  38.698509
# 2681   Northern     Sonoma        4      09N   09W         MD  38.652409
# 2684   Northern     Sonoma        8      09N   08W         MD  38.646648
# 7323   Northern     Sonoma        8      09N   08W         MD  38.645107
# 11742  Northern     Sonoma       24      10N   11W         MD  38.692799
# 7295   Northern     Sonoma       24      10N   11W         MD  38.692699
# 7245   Northern     Colusa       21      14N   05W         MD  39.044113
# 7235   Northern     Colusa       21      14N   05W         MD  39.040974
# 2609   Northern     Colusa       27      14N   05W         MD  39.031086
# 7236   Northern     Colusa       27      14N   05W         MD  39.033302
#
#         Longitude                  GISSource isConfiden isDirectio SpudDate  \
# 0     -122.833093  Notice of Intent to Drill          N          N      NaT
# 2680  -122.873611                        hud          N          N      NaT
# 1481  -122.607765                        hud          N          N      NaT
# 2682  -122.841507                        hud          N          N      NaT
# 2681  -122.871033                        hud          N          N      NaT
# 2684  -122.777458                        hud          N          N      NaT
# 7323  -122.775490                        hud          N          N      NaT
# 11742 -123.026497                    Unknown          N          N      NaT
# 7295  -123.026604                    Unknown          N          N      NaT
# 7245  -122.416206                        hud          N          N      NaT
# 7235  -122.410736                        hud          N          N      NaT
# 2609  -122.405235                        hud          N          N      NaT
# 7236  -122.405121                        hud          N          N      NaT
#
#                             inHPZ WellSymbol   IdleDate  YearsIdle IsLTIW  \
# 0                    Verified HPZ     IdleDG 1901-01-01     123.00    Yes
# 2680              Potentially HPZ  PluggedDH        NaT        NaN    NaN
# 1481                 Verified HPZ     IdleDH 1926-04-01      97.75    Yes
# 2682              Potentially HPZ  PluggedDH        NaT        NaN    NaN
# 2681              Potentially HPZ  PluggedDH        NaT        NaN    NaN
# 2684              Potentially HPZ  PluggedDH        NaT        NaN    NaN
# 7323              Potentially HPZ  PluggedDH        NaT        NaN    NaN
# 11742  Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 7295   Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 7245   Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 7235   Potentially Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 2609               Not Within HPZ  PluggedDH        NaT        NaN    NaN
# 7236               Not Within HPZ  PluggedDH        NaT        NaN    NaN
#
#       UnsatAbandon  FieldAbd  SpudYear  IdleYear api_10 first_date  last_date  \
# 0               No     False       NaN    1901.0    NaN        NaT 1977-01-01
# 2680           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 1481            No     False       NaN    1926.0    NaN        NaT 1977-01-01
# 2682           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 2681           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 2684           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 7323           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 11742          NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 7295           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 7245           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 7235           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 2609           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
# 7236           NaN     False       NaN       NaN    NaN        NaT 1977-01-01
#
#        ProdYears  LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  \
# 0            NaN          1977   1979-01-01        1979.0           False
# 2680         NaN          1977          NaT        1979.0           False
# 1481         NaN          1977   1979-01-01        1979.0           False
# 2682         NaN          1977          NaT        1979.0           False
# 2681         NaN          1977          NaT        1979.0           False
# 2684         NaN          1977          NaT        1979.0           False
# 7323         NaN          1977          NaT        1979.0           False
# 11742        NaN          1977          NaT        1979.0           False
# 7295         NaN          1977          NaT        1979.0           False
# 7245         NaN          1977          NaT        1979.0           False
# 7235         NaN          1977          NaT        1979.0           False
# 2609         NaN          1977          NaT        1979.0           False
# 7236         NaN          1977          NaT        1979.0           False
#
#        CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  \
# 0               46.0                 0            0                  0
# 2680             NaN                 0            1                  0
# 1481            46.0                 0            0                  0
# 2682             NaN                 0            1                  0
# 2681             NaN                 0            1                  0
# 2684             NaN                 0            1                  0
# 7323             NaN                 0            1                  0
# 11742            NaN                 0            1                  0
# 7295             NaN                 0            1                  0
# 7245             NaN                 0            1                  0
# 7235             NaN                 0            1                  0
# 2609             NaN                 0            1                  0
# 7236             NaN                 0            1                  0
#
#        IdleFlag     lat_r     lng_r
# 0             1  0.680272 -2.143842
# 2680          0  0.679636 -2.144549
# 1481          1  0.679373 -2.139909
# 2682          0  0.675416 -2.143989
# 2681          0  0.674612 -2.144504
# 2684          0  0.674511 -2.142871
# 7323          0  0.674484 -2.142837
# 11742         0  0.675317 -2.147217
# 7295          0  0.675315 -2.147219
# 7245          0  0.681448 -2.136566
# 7235          0  0.681394 -2.136470
# 2609          0  0.681221 -2.136374
# 7236          0  0.681260 -2.136372

# %%
# this pulls the list of nearest neighbors for the 109 well, which is Idle and missing it's SPUD date
# it appears that the neighboring wells were mainly drilled in the 1920s-1930s
well_list_df.iloc[well_idx[109,:]]
# Out:
#             API LeaseName WellNumber  WellDesign WellStatus WellType  \
# 109  0403700715    Porter         28   Porter 28       Idle       OG
# 212  0403720642    Porter         73   Porter 73     Active       WF
# 194  0403700746    Porter         61   Porter 61     Active       OG
# 199  0403700750    Porter         69   Porter 69     Active       OG
# 268  0403700716    Porter         29   Porter 29    Plugged       OG
# 125  0403700737    Porter         52   Porter 52       Idle       WF
# 200  0403722051    Porter        69A  Porter 69A     Active       GS
# 331  0403724127    Porter        69B  Porter 69B    Plugged       GS
# 201  0403724128    Porter        69C  Porter 69C     Active       GS
# 203  0403724138    Porter        69E  Porter 69E     Active       GS
# 324  0403700742    Porter         57   Porter 57    Plugged       OG
# 184  0403700733    Porter         46   Porter 46     Active       GS
# 182  0403700731    Porter         44   Porter 44     Active       GS
#
#       WellTypeLa OperatorCo                       OperatorNa     FieldName  \
# 109    Oil & Gas      S4700  Southern California Gas Company  Aliso Canyon
# 212   Waterflood      S4700  Southern California Gas Company  Aliso Canyon
# 194    Oil & Gas      S4700  Southern California Gas Company  Aliso Canyon
# 199    Oil & Gas      S4700  Southern California Gas Company  Aliso Canyon
# 268    Oil & Gas      S4700  Southern California Gas Company  Aliso Canyon
# 125   Waterflood      S4700  Southern California Gas Company  Aliso Canyon
# 200  Gas Storage      S4700  Southern California Gas Company  Aliso Canyon
# 331  Gas Storage      S4700  Southern California Gas Company  Aliso Canyon
# 201  Gas Storage      S4700  Southern California Gas Company  Aliso Canyon
# 203  Gas Storage      S4700  Southern California Gas Company  Aliso Canyon
# 324    Oil & Gas      S4700  Southern California Gas Company  Aliso Canyon
# 184  Gas Storage      S4700  Southern California Gas Company  Aliso Canyon
# 182  Gas Storage      S4700  Southern California Gas Company  Aliso Canyon
#
#      AreaName               Place  District   CountyName  Section Township  \
# 109  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 212  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 194  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 199  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 268  Any Area  Los Angeles County  Northern  Los Angeles       27      03N
# 125  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 200  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 331  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 201  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 203  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 324  Any Area  Los Angeles County  Northern  Los Angeles       27      03N
# 184  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
# 182  Any Area  Los Angeles County  Northern  Los Angeles       28      03N
#
#     Range BaseMeridi   Latitude   Longitude     GISSource isConfiden  \
# 109   16W         SB  34.314426 -118.555145           GPS          N
# 212   16W         SB  34.314434 -118.555328  Well Summary          N
# 194   16W         SB  34.315277 -118.554108           GPS          N
# 199   16W         SB  34.314896 -118.556465           GPS          N
# 268   16W         SB  34.313969 -118.553657           hud          N
# 125   16W         SB  34.312870 -118.554398  Well Summary          N
# 200   16W         SB  34.314846 -118.556831  Well Summary          N
# 331   16W         SB  34.314968 -118.556831  Well Summary          N
# 201   16W         SB  34.314945 -118.556961  Well Summary          N
# 203   16W         SB  34.314810 -118.557072  Well Summary          N
# 324   16W         SB  34.314384 -118.553085  Well Summary          N
# 184   16W         SB  34.313419 -118.556992  Well Summary          N
# 182   16W         SB  34.312611 -118.556236  Well Summary          N
#
#     isDirectio   SpudDate           inHPZ WellSymbol   IdleDate  YearsIdle  \
# 109          Y        NaT  Not Within HPZ     IdleOG 2000-04-01      23.75
# 212          N 1968-09-26  Not Within HPZ   ActiveWF        NaT        NaN
# 194          N        NaT  Not Within HPZ   ActiveOG        NaT        NaN
# 199          Y        NaT  Not Within HPZ   ActiveOG        NaT        NaN
# 268          N        NaT  Not Within HPZ  PluggedOG        NaT        NaN
# 125          N        NaT  Not Within HPZ     IdleWF        NaT        NaN
# 200          Y 1980-01-03  Not Within HPZ   ActiveGS        NaT        NaN
# 331          Y 1992-01-28  Not Within HPZ  PluggedGS        NaT        NaN
# 201          Y 1992-03-19  Not Within HPZ   ActiveGS        NaT        NaN
# 203          Y 1993-06-23  Not Within HPZ   ActiveGS        NaT        NaN
# 324          N 1951-08-05  Not Within HPZ  PluggedOG        NaT        NaN
# 184          N 1943-11-02  Not Within HPZ   ActiveGS        NaT        NaN
# 182          Y 1955-11-11  Not Within HPZ   ActiveGS        NaT        NaN
#
#     IsLTIW UnsatAbandon  FieldAbd  SpudYear  IdleYear      api_10 first_date  \
# 109    Yes           No     False       NaN    2000.0  0403700715 1977-01-31
# 212    NaN          NaN     False    1968.0       NaN  0403720642 2010-05-31
# 194    NaN          NaN     False       NaN       NaN  0403700746 1977-01-31
# 199    NaN          NaN     False       NaN       NaN  0403700750 1977-01-31
# 268    NaN          NaN     False       NaN       NaN         NaN        NaT
# 125    NaN          NaN     False       NaN       NaN  0403700737 1977-01-31
# 200    NaN          NaN     False    1980.0       NaN  0403722051 1982-01-31
# 331    NaN          NaN     False    1992.0       NaN  0403724127 1992-12-31
# 201    NaN          NaN     False    1992.0       NaN  0403724128 1992-12-31
# 203    NaN          NaN     False    1993.0       NaN  0403724138 1994-01-31
# 324    NaN          NaN     False    1951.0       NaN  0403700742 1977-01-31
# 184    NaN          NaN     False    1943.0       NaN  0403700733 1977-08-31
# 182    NaN          NaN     False    1955.0       NaN  0403700731 1977-07-31
#
#      last_date  ProdYears  LastProdYear CalcIdleDate  CalcIdleYear  \
# 109 2007-09-30        NaN          2007   2009-09-30        2009.0
# 212 2024-12-31      56.26          2024          NaT        2040.0
# 194 2024-12-31        NaN          2024          NaT        2040.0
# 199 2024-12-31        NaN          2024          NaT        2040.0
# 268 1977-01-01        NaN          1977          NaT        1979.0
# 125 2022-06-30        NaN          2022   2024-06-30        2024.0
# 200 2024-12-31      44.99          2024          NaT        2040.0
# 331 2020-09-30      28.67          2020          NaT        2022.0
# 201 2024-12-31      32.79          2024          NaT        2040.0
# 203 2024-12-31      31.52          2024          NaT        2040.0
# 324 2005-02-28      53.57          2005          NaT        2007.0
# 184 2024-12-31      81.16          2024          NaT        2040.0
# 182 2024-12-31      69.14          2024          NaT        2040.0
#
#      IsIdleYearSame  CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  \
# 109           False          15.25                 0            0
# 212           False            NaN                 0            0
# 194           False            NaN                 0            0
# 199           False            NaN                 0            0
# 268           False            NaN                 0            1
# 125           False           0.50                 0            0
# 200           False            NaN                 0            0
# 331           False            NaN                 0            1
# 201           False            NaN                 0            0
# 203           False            NaN                 0            0
# 324           False            NaN                 0            1
# 184           False            NaN                 0            0
# 182           False            NaN                 0            0
#
#      PluggedRecentFlag  IdleFlag     lat_r     lng_r
# 109                  0         1  0.598900 -2.069178
# 212                  0         0  0.598900 -2.069181
# 194                  0         0  0.598915 -2.069160
# 199                  0         0  0.598908 -2.069201
# 268                  0         0  0.598892 -2.069152
# 125                  0         0  0.598873 -2.069165
# 200                  0         0  0.598907 -2.069207
# 331                  1         0  0.598909 -2.069207
# 201                  0         0  0.598909 -2.069209
# 203                  0         0  0.598906 -2.069211
# 324                  0         0  0.598899 -2.069142
# 184                  0         0  0.598882 -2.069210
# 182                  0         0  0.598868 -2.069197

# %%
well_dist[109,1:]
# Out:
# array([0.09270641, 0.09678181, 0.10755385, 0.11930302, 0.12005313,
#        0.12236409, 0.13048147, 0.13576691, 0.14236336, 0.14531186,
#        0.14636495])

# %%
well_list_df.iloc[well_idx[109,:]]["SpudDate"][1:]
# Out:
# 212   1968-09-26
# 194          NaT
# 199          NaT
# 268          NaT
# 125          NaT
# 200   1980-01-03
# 331   1992-01-28
# 201   1992-03-19
# 203   1993-06-23
# 324   1951-08-05
# 184   1943-11-02
# 182   1955-11-11
# Name: SpudDate, dtype: datetime64[ns]

# %%
# this takes the mid point of the non-null wells, excluding itself in position 0
print(well_list_df.iloc[well_idx[109,:]]["SpudDate"][1:].median())
print(well_list_df.iloc[well_idx[109,:]]["SpudDate"][1:].mean())
print(well_list_df.iloc[well_idx[109,:]]["SpudYear"][1:].var())
# Out:
# 1974-05-16 00:00:00
# 1972-03-22 21:00:00
# 413.07142857142856

# %% [markdown]
# ### Step 2 : Deal with missing values
#
# I'm not sure how critical SpudDate will be, but since age of the well can indicate development regimes, it is likely important for quantifying operator risk of penalties
#  - create a column `SpudDate_I` that will contain the imputed `SpudDate` based on distance; I want to keep the original data clean for various slices
#  - part 1 : wells that have blank `SpudDate` but have a set RECENT `IdleDate` (1977+) - can take nearby `SpudDate` of wells (like at least 5 nearest neighbors maybe, median based on distance less than certain number of miles.. maybe 10 miles to start)
#  - part 2 : wells that have blank `SpudDate` but have a very OLD `IdleDate` (pre-1977) - may force these to 1977 for simplicity, the original source has random dates around 1900/1/1, which is useless
#  - part 3 : Fix the part 1 wells so `SpudYear_I` is before `IdleDate` for all the wells
#   -  part 4 : Fix the part 2 wells so `SpudYear_I` and `IdleDate` make sense
#
# ### Missing Idle Dates :
# Most of the analysis in the end will be focused around `Idle` wells (or `Unknown`, which are missing data), and `Active` wells soon to become `Idle` so it will probably be beneficial to have solid Idle well data
#  - create a column `IdleDate_I` that will contain the imputed `IdleDate`; there are **11,261**; I want to keep the original data clean for various slices
#  - part 1 : wells that have `SpudDate` set and `WellStatus==Idle`, but blank `IdleDate` (based on EDA above there are **7,280** of these) - seems like it would be fairly simple to check last contiguous production
#  - part 2 : wells that have `WellStatus==Idle`, but blank `SpudDate` and `IdleDate` (based on EDA above there are **3,981** of these)

# %% [markdown]
# ### Part 1 & 2 Imputation on Spud Date based on distance for recent Idle Dates
# This is the most trivial part because the Idle dates and years are set, so we can calculate an average `SpudYear_I` and then check them individually against `IdleDate` to adjust as needed so SpudYear > IdleDate doesn't happen

# %%
 # [for x in well_list_df.index]
well_dist[369,:]
# Out:
# array([0.09524217, 0.09550236, 0.0968519 , 0.10415885, 0.11114494,
#        0.12897335, 0.15448015, 0.17337333, 0.17508915, 0.19668806,
#        0.20025603, 0.2232571 ])

# %%
# Imputes the SpudYear mean from the nearest neighbors as calculated in the BallTree above
# Used in the df.apply() method below
# it checks each row to see if SpudDate is empty, and if so, pulls the nearest neighbor indices from the well_idx list calculated above in EDA
# then if that list of neighbors' SpudDates is not empty, it returns the median
def impute_from_nn( row, well_idx_list, df, col_name):
    # in this context, row.name contains the integer row index
    if pd.isnull(row[col_name]):
        # get the indices of the nearest neighbors for this row and skip the first index (itself)
        #neighbors_idx = df.iloc[well_idx_list[row.name, 1:]]["SpudYear"].dropna()
        neighbors_idx = well_idx_list[row.name, 1:]
        neighbors = df.iloc[neighbors_idx][col_name].dropna()
        if not neighbors.empty:
            return round(neighbors.mean(), 2)
        else:
            return np.nan
    # when there is a SpudYear already, just keep it
    return row[col_name]

#well_list_df['SpudYear_I'] = [well_list_df.iloc[well_idx[x, 1:]]["SpudYear"].median() if pd.isna(well_list_df.loc[x, 'SpudDate']) else well_list_df.loc[x, 'SpudYear'] for x in well_list_df.index]

well_list_df['SpudYear_I'] = well_list_df.apply(impute_from_nn, axis=1, args=(well_idx, well_list_df, 'SpudYear'))

# Imputes the ProdYears mean from the nearest neighbors as calculated in the BallTreeabove
well_list_df['ProdYears_I'] = well_list_df.apply(impute_from_nn, axis=1, args=(well_idx, well_list_df, 'ProdYears'))

# clean the negative ProdYears_I
#well_list_df.loc[well_list_df['ProdYears_I']<0, 'ProdYears_I'] = 0

# %%
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears  \
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241911       NaN       NaN         NaN        NaT 1977-01-01        NaN
#
#         LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  \
# 0               1977   1979-01-01        1979.0           False
# 1               2013   2015-07-31        2015.0            True
# 2               2013   2015-07-31        2015.0            True
# 3               2009   2011-05-31        2011.0            True
# 4               2023          NaT        2025.0           False
# ...              ...          ...           ...             ...
# 241907          1982          NaT        1984.0           False
# 241908          1977          NaT        1979.0           False
# 241909          1985          NaT        1987.0           False
# 241910          1977          NaT        1979.0           False
# 241911          1977          NaT        1979.0           False
#
#         CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  \
# 0               46.00                 0            0                  0
# 1                9.42                 0            0                  0
# 2                9.42                 0            0                  0
# 3               13.59                 0            0                  0
# 4                0.00                 0            0                  0
# ...               ...               ...          ...                ...
# 241907            NaN                 0            1                  0
# 241908            NaN                 0            1                  0
# 241909            NaN                 0            1                  0
# 241910            NaN                 0            1                  0
# 241911            NaN                 0            1                  0
#
#         IdleFlag     lat_r     lng_r  SpudYear_I  ProdYears_I
# 0              1  0.680272 -2.143842         NaN          NaN
# 1              1  0.688369 -2.128462     1999.00        13.65
# 2              1  0.688483 -2.128626     2000.00        13.22
# 3              1  0.688414 -2.128447     2002.00         6.57
# 4              0  0.688518 -2.128364     1988.00        35.53
# ...          ...       ...       ...         ...          ...
# 241907         0  0.677404 -2.126031     1979.00         2.21
# 241908         0  0.677458 -2.126270     1978.57         6.62
# 241909         0  0.677900 -2.126492     1981.00         4.12
# 241910         0  0.678090 -2.126469     1978.33         6.08
# 241911         0  0.677890 -2.126329     1979.20         6.40
#
# [241912 rows x 50 columns]

# %%
print(f"Number of wells in active field areas missing SpudYear before imputation: {well_list_df[(well_list_df['SpudYear'].isna()) & (well_list_df['FieldAbd'] == False)]['API'].count():,}")
print(f"Number of wells in active field areas remaining without imputed SpudYear: {well_list_df[(well_list_df['SpudYear_I'].isna()) & (well_list_df['FieldAbd'] == False)]['API'].count():,}")
print(f"Number of wells in with imputed SpudYear but SpudYear >= last_prod: {well_list_df[(well_list_df['SpudYear_I'] >= (well_list_df['LastProdYear'])) & (well_list_df['FieldAbd'] == False)]['API'].count():,}")
# Out:
# Number of wells in active field areas missing SpudYear before imputation: 116,967
# Number of wells in active field areas remaining without imputed SpudYear: 25,213
# Number of wells in with imputed SpudYear but SpudYear >= last_prod: 59,000

# %%
well_list_df[(well_list_df['SpudYear_I']  >= well_list_df['LastProdYear']) & (well_list_df['FieldAbd'] == False)]
# Out:
#                API                       LeaseName WellNumber  \
# 5       0402100240  Max Pray-Central Valley-Boyd U          1
# 6       0402120034               Afton Community 3          1
# 9       0402120035                Spectrum-Pacific          1
# 10      0402100262                        Mantelli          1
# 13      0402120613                      Butte City     28-Jan
# ...            ...                             ...        ...
# 241881  0408321698                        Potreros         14
# 241882  0408304559                      Chamberlin         24
# 241885  0408322901                      Chamberlin       5-2A
# 241888  0408301012                           Quati         75
# 241889  0408301013                           Quati         77
#
#                               WellDesign WellStatus WellType      WellTypeLa  \
# 5       Max Pray-Central Valley-Boyd U 1    Plugged       DH        Dry Hole
# 6                    Afton Community 3 1    Plugged       DH        Dry Hole
# 9                     Spectrum-Pacific 1    Plugged       DH        Dry Hole
# 10                            Mantelli 1    Plugged       DH        Dry Hole
# 13                       Butte City 1-28    Plugged       DH        Dry Hole
# ...                                  ...        ...      ...             ...
# 241881                       Potreros 14    Plugged       OG       Oil & Gas
# 241882                     Chamberlin 24    Plugged       WD  Water Disposal
# 241885                   Chamberlin 5-2A    Plugged       OG       Oil & Gas
# 241888                          Quati 75    Plugged       OG       Oil & Gas
# 241889                          Quati 77    Plugged       OG       Oil & Gas
#
#        OperatorCo                      OperatorNa  FieldName         AreaName  \
# 5           03279         General Expl. Co. of Ca  Afton Gas             Main
# 6           S3280              Shoshone Oil Corp.  Afton Gas             Main
# 9           S3280              Shoshone Oil Corp.  Afton Gas             Main
# 10          02212        Donald Frankel, Operator  Afton Gas             Main
# 13          S4260  Donald C Slawson Expl Co., Inc  Afton Gas  Northwest (ABD)
# ...           ...                             ...        ...              ...
# 241881      C5640             Chevron U.S.A. Inc.       Zaca         Any Area
# 241882      C5640             Chevron U.S.A. Inc.       Zaca         Any Area
# 241885      11800            Angel Petroleum, LLC       Zaca         Any Area
# 241888      11639        Maria Joaquin Basin, LLC       Zaca         Any Area
# 241889      11639        Maria Joaquin Basin, LLC       Zaca         Any Area
#
#                        Place  District     CountyName  Section Township Range  \
# 5               Glenn County  Northern          Glenn        2      18N   01W
# 6               Glenn County  Northern          Glenn       34      19N   01W
# 9               Glenn County  Northern          Glenn       27      19N   01W
# 10              Glenn County  Northern          Glenn       26      19N   01W
# 13              Glenn County  Northern          Glenn       28      19N   01W
# ...                      ...       ...            ...      ...      ...   ...
# 241881  Santa Barbara County  Northern  Santa Barbara        2      07N   31W
# 241882  Santa Barbara County  Northern  Santa Barbara       33      08N   31W
# 241885  Santa Barbara County  Northern  Santa Barbara        2      07N   31W
# 241888  Santa Barbara County  Northern  Santa Barbara       34      08N   31W
# 241889  Santa Barbara County  Northern  Santa Barbara        3      07N   31W
#
#        BaseMeridi   Latitude   Longitude     GISSource isConfiden isDirectio  \
# 5              MD  39.438267 -121.947418           hud          N          N
# 6              MD  39.455864 -121.949425           hud          N          N
# 9              MD  39.467045 -121.962898           hud          N          N
# 10             MD  39.467525 -121.935989           hud          N          N
# 13             MD  39.466465 -121.971077           hud          N          N
# ...           ...        ...         ...           ...        ...        ...
# 241881         SB  34.717014 -120.122078           hud          N          N
# 241882         SB  34.728329 -120.151344           hud          N          N
# 241885         SB  34.718405 -120.115516  Well Summary          N          N
# 241888         SB  34.725861 -120.131943           hud          N          N
# 241889         SB  34.722115 -120.131737           hud          N          N
#
#        SpudDate            inHPZ WellSymbol IdleDate  YearsIdle IsLTIW  \
# 5           NaT     Verified HPZ  PluggedDH      NaT        NaN    NaN
# 6           NaT  Potentially HPZ  PluggedDH      NaT        NaN    NaN
# 9           NaT  Potentially HPZ  PluggedDH      NaT        NaN    NaN
# 10          NaT  Potentially HPZ  PluggedDH      NaT        NaN    NaN
# 13          NaT  Potentially HPZ  PluggedDH      NaT        NaN    NaN
# ...         ...              ...        ...      ...        ...    ...
# 241881      NaT     Verified HPZ  PluggedOG      NaT        NaN    NaN
# 241882      NaT     Verified HPZ  PluggedWD      NaT        NaN    NaN
# 241885      NaT     Verified HPZ  PluggedOG      NaT        NaN    NaN
# 241888      NaT     Verified HPZ  PluggedOG      NaT        NaN    NaN
# 241889      NaT     Verified HPZ  PluggedOG      NaT        NaN    NaN
#
#        UnsatAbandon  FieldAbd  SpudYear  IdleYear      api_10 first_date  \
# 5               NaN     False       NaN       NaN         NaN        NaT
# 6               NaN     False       NaN       NaN         NaN        NaT
# 9               NaN     False       NaN       NaN         NaN        NaT
# 10              NaN     False       NaN       NaN         NaN        NaT
# 13              NaN     False       NaN       NaN         NaN        NaT
# ...             ...       ...       ...       ...         ...        ...
# 241881          NaN     False       NaN       NaN         NaN        NaT
# 241882          NaN     False       NaN       NaN         NaN        NaT
# 241885          NaN     False       NaN       NaN         NaN        NaT
# 241888          NaN     False       NaN       NaN         NaN        NaT
# 241889          NaN     False       NaN       NaN  0408301013 1977-01-31
#
#         last_date  ProdYears  LastProdYear CalcIdleDate  CalcIdleYear  \
# 5      1977-01-01        NaN          1977          NaT        1979.0
# 6      1977-01-01        NaN          1977          NaT        1979.0
# 9      1977-01-01        NaN          1977          NaT        1979.0
# 10     1977-01-01        NaN          1977          NaT        1979.0
# 13     1977-01-01        NaN          1977          NaT        1979.0
# ...           ...        ...           ...          ...           ...
# 241881 1977-01-01        NaN          1977          NaT        1979.0
# 241882 1977-01-01        NaN          1977          NaT        1979.0
# 241885 1977-01-01        NaN          1977          NaT        1979.0
# 241888 1977-01-01        NaN          1977          NaT        1979.0
# 241889 1987-12-31        NaN          1987          NaT        1989.0
#
#         IsIdleYearSame  CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  \
# 5                False            NaN                 0            1
# 6                False            NaN                 0            1
# 9                False            NaN                 0            1
# 10               False            NaN                 0            1
# 13               False            NaN                 0            1
# ...                ...            ...               ...          ...
# 241881           False            NaN                 0            1
# 241882           False            NaN                 0            1
# 241885           False            NaN                 0            1
# 241888           False            NaN                 0            1
# 241889           False            NaN                 0            1
#
#         PluggedRecentFlag  IdleFlag     lat_r     lng_r  SpudYear_I  \
# 5                       0         0  0.688328 -2.128384     1990.12
# 6                       0         0  0.688635 -2.128419     1978.11
# 9                       0         0  0.688830 -2.128654     1981.75
# 10                      0         0  0.688838 -2.128184     1988.40
# 13                      0         0  0.688820 -2.128797     1980.83
# ...                   ...       ...       ...       ...         ...
# 241881                  0         0  0.605926 -2.096526     1995.00
# 241882                  0         0  0.606124 -2.097037     1978.00
# 241885                  0         0  0.605950 -2.096411     1991.33
# 241888                  0         0  0.606081 -2.096698     1986.75
# 241889                  0         0  0.606015 -2.096694     1987.50
#
#         ProdYears_I
# 5             15.11
# 6             17.06
# 9             12.97
# 10             6.36
# 13            12.93
# ...             ...
# 241881        24.82
# 241882        46.46
# 241885        26.82
# 241888        37.76
# 241889        37.20
#
# [59000 rows x 50 columns]

# %%
# For the wells with SpudDate_I > LastProdYear, (about 54k) subtract the imputed average production years from the last_prod to infer a SPUD Date
well_list_df['SpudYear_I2'] = well_list_df['SpudYear_I'].where(~(
            well_list_df['SpudYear_I'] >= well_list_df['LastProdYear']), well_list_df['LastProdYear'] - well_list_df['ProdYears_I'])
assert(len(well_list_df[(well_list_df['SpudYear_I2']  >= well_list_df['LastProdYear']) & (well_list_df['FieldAbd'] == False)])==0)

# %%
# First pass on adjusting Imputed SPUD that's after CalcIdleYear by subtracting avg prodyears
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears  \
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241911       NaN       NaN         NaN        NaT 1977-01-01        NaN
#
#         LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  \
# 0               1977   1979-01-01        1979.0           False
# 1               2013   2015-07-31        2015.0            True
# 2               2013   2015-07-31        2015.0            True
# 3               2009   2011-05-31        2011.0            True
# 4               2023          NaT        2025.0           False
# ...              ...          ...           ...             ...
# 241907          1982          NaT        1984.0           False
# 241908          1977          NaT        1979.0           False
# 241909          1985          NaT        1987.0           False
# 241910          1977          NaT        1979.0           False
# 241911          1977          NaT        1979.0           False
#
#         CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  \
# 0               46.00                 0            0                  0
# 1                9.42                 0            0                  0
# 2                9.42                 0            0                  0
# 3               13.59                 0            0                  0
# 4                0.00                 0            0                  0
# ...               ...               ...          ...                ...
# 241907            NaN                 0            1                  0
# 241908            NaN                 0            1                  0
# 241909            NaN                 0            1                  0
# 241910            NaN                 0            1                  0
# 241911            NaN                 0            1                  0
#
#         IdleFlag     lat_r     lng_r  SpudYear_I  ProdYears_I  SpudYear_I2
# 0              1  0.680272 -2.143842         NaN          NaN          NaN
# 1              1  0.688369 -2.128462     1999.00        13.65      1999.00
# 2              1  0.688483 -2.128626     2000.00        13.22      2000.00
# 3              1  0.688414 -2.128447     2002.00         6.57      2002.00
# 4              0  0.688518 -2.128364     1988.00        35.53      1988.00
# ...          ...       ...       ...         ...          ...          ...
# 241907         0  0.677404 -2.126031     1979.00         2.21      1979.00
# 241908         0  0.677458 -2.126270     1978.57         6.62      1970.38
# 241909         0  0.677900 -2.126492     1981.00         4.12      1981.00
# 241910         0  0.678090 -2.126469     1978.33         6.08      1970.92
# 241911         0  0.677890 -2.126329     1979.20         6.40      1970.60
#
# [241912 rows x 51 columns]

# %%
# First pass on adjusting Imputed SPUD that's after CalcIdleYear by subtracting avg prodyears
well_list_df['SpudYear_I'].value_counts(sort=True).sort_index()
# Out:
# SpudYear_I
# 1867.00      1
# 1882.00      1
# 1886.00      1
# 1887.00      1
# 1887.50      1
#           ...
# 2022.25      2
# 2022.33      3
# 2022.50      6
# 2023.00    225
# 2024.00     46
# Name: count, Length: 3111, dtype: int64

# %% [markdown]
# ### Further Impute Spud Dates for the Operator and Field and Area, we can use it for correcting the missing Spud Years where Spud > Idle date
# There are 3,022 wells that have an imputed SpudYear >= IdleYear + 2, so those need to be corrected. First I'll set them all to NaN, and then calculate a replacement.
# Starting default to 20 years from Spud to Idle if there aren't at least 2 instance of these dates already

# %%
f_spud_to_idle = lambda x : round(x.mean(),1) if x.count() >= 2 else 20

print(f"Count of NaN in imputed SpudYear: {well_list_df['SpudYear_I2'].isna().sum():,}")
print(f"Count of NaN in imputed SpudYear for unplugged wells: {len(well_list_df[(well_list_df['PluggedFlag']==0) & (well_list_df['SpudYear_I2'].isna())]):,}")

# now we have a bunch of wells with NULL SpudDate_I3 and NULL ProdYears_I, but some have Idle dates from the original set, so fill those in
well_list_df['SpudYear_I3'] = well_list_df['SpudYear_I2'].fillna(well_list_df['IdleYear'])

# Then fill the rest in as best we can
well_list_df['SpudYear_I4'] = well_list_df['SpudYear_I3'].fillna(well_list_df.groupby(['OperatorCo', 'FieldName', 'WellType', 'AreaName'])['SpudYear_I3'].transform(f_spud_to_idle))
print(f"Count of NaN in after correcting SpudYear_I2: {well_list_df['SpudYear_I3'].isna().sum():,}")
print(f"Again, number of wells in with imputed SpudYear but SpudYear_I4 >= ProdYear: {len(well_list_df[(well_list_df['SpudYear_I4'] >= (well_list_df['LastProdYear'])) & (well_list_df['FieldAbd'] == False)]):,}")
print(f"Again, number of wells in with imputed SpudYear but SpudYear_I4 >= IdleYear: {len(well_list_df[(well_list_df['SpudYear_I4'] >= (well_list_df['CalcIdleYear'])) & (well_list_df['FieldAbd'] == False)]):,}")
# Out:
# Count of NaN in imputed SpudYear: 28,428
# Count of NaN in imputed SpudYear for unplugged wells: 3,483
# Count of NaN in after correcting SpudYear_I2: 26,123
# Again, number of wells in with imputed SpudYear but SpudYear_I4 >= ProdYear: 2,771
# Again, number of wells in with imputed SpudYear but SpudYear_I4 >= IdleYear: 2,314

# %%
# Final imputation on this set is taking the CalcIdleYear if it's NULL or before SpudDate_I4
well_list_df['SpudYear_I5'] = well_list_df['SpudYear_I4'].fillna(well_list_df['CalcIdleYear'])
well_list_df['SpudYear_I5'] = well_list_df['SpudYear_I5'].where(well_list_df['SpudYear_I4'] <= well_list_df['CalcIdleYear'], well_list_df['CalcIdleYear'])

# %%
# at this point, all these SpudYears should be cleaned up
assert(len(well_list_df[(well_list_df['SpudYear_I5'] > (well_list_df['CalcIdleYear'])) & (well_list_df['FieldAbd'] == False)])==0 )
assert(well_list_df['SpudYear_I5'].isna().sum()==0 )

# %% [markdown]
# ### Imputation on SpudDate of wells based on similar attributes like Field Area and Operator; an alternative to doing it by distance above

# %%
list(well_list_df.groupby(['OperatorCo', 'FieldName', 'WellType', 'AreaName'])[['CalcIdleYear','SpudYear']])[230:250]
# Out:
# [(('00269', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   6887        1979.0       NaN),
#  (('00270', 'Long Beach', 'OG', 'Northwest Extension'),
#           CalcIdleYear  SpudYear
#   136259        1979.0       NaN),
#  (('00271', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   9121        1979.0       NaN),
#  (('00273', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   4502        1979.0       NaN),
#  (('00274', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   5547        1979.0       NaN),
#  (('00275', 'Any Field', 'DH', 'Any Area'),
#          CalcIdleYear  SpudYear
#   5397         1979.0       NaN
#   11283        1979.0       NaN),
#  (('00277', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   2875        1979.0       NaN
#   3040        1979.0       NaN),
#  (('00278', 'Richfield', 'OG', 'Any Area'),
#           CalcIdleYear  SpudYear
#   209747        1979.0       NaN),
#  (('00279', 'Any Field', 'DH', 'Any Area'),
#          CalcIdleYear  SpudYear
#   13622        1979.0       NaN
#   14002        1979.0       NaN),
#  (('00280', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   2609        1979.0       NaN),
#  (('00281', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   9647        1979.0       NaN),
#  (('00282', 'Any Field', 'DH', 'Any Area'),
#         CalcIdleYear  SpudYear
#   4293        1979.0       NaN),
#  (('00284', 'Any Field', 'DH', 'Any Area'),
#          CalcIdleYear  SpudYear
#   4973         1979.0       NaN
#   11521        1979.0       NaN),
#  (('00284', 'Del Valle', 'DH', 'Kinler (ABD)'),
#          CalcIdleYear  SpudYear
#   85978        1979.0       NaN),
#  (('00284', 'Del Valle', 'DH', 'Main'),
#          CalcIdleYear  SpudYear
#   86018        1979.0       NaN
#   86030        1979.0       NaN),
#  (('00284', 'Del Valle', 'OG', 'Kinler (ABD)'),
#          CalcIdleYear  SpudYear
#   85977        1979.0       NaN
#   86024        1979.0       NaN),
#  (('00284', 'Lawndale (ABD)', 'OG', 'Any Area'),
#           CalcIdleYear  SpudYear
#   134458        1979.0       NaN
#   134490        1979.0       NaN
#   134491        1979.0       NaN),
#  (('00285', 'Any Field', 'DH', 'Any Area'),
#          CalcIdleYear  SpudYear
#   11409        1979.0       NaN),
#  (('00285', 'Any Field', 'OG', 'Any Area'),
#         CalcIdleYear  SpudYear
#   1320        1978.0       NaN),
#  (('00286', 'Any Field', 'DH', 'Any Area'),
#          CalcIdleYear  SpudYear
#   4184         1979.0       NaN
#   5698         1979.0       NaN
#   13373        1979.0       NaN
#   13400        1979.0       NaN)]

# %%
# lambda function to be used for the imputation.
# Choosing median here because most field areas have a few years of intensive drilling by
# an operator, and may have a few outliers from very early exploration wells, or very recent
# redevelopment attempts.
# Arbitrarily choosing 5 as a start point for minimum count on the grouping
f_spud = lambda x: round(x.median(),0) if x.count() >= 5 else np.nan

print(f"original SPUD year NaN count: {well_list_df['SpudYear'].isna().sum():,}")

well_list_df['SpudYear_T'] = well_list_df['SpudYear'].fillna(well_list_df.groupby(['OperatorCo', 'FieldName', 'WellType', 'AreaName', 'CalcIdleYear'])['SpudYear'].transform(f_spud))

print(f"first pass Nearest Neighbors SpudYear_T NaN count: {well_list_df['SpudYear_T'].isna().sum():,}")

# 6,579 wells have 5 or more matches on 'OperatorCo', 'FieldName', 'WellType', 'AreaName', 'IdleYear'
# my hypothesis is that these are mainly going to be in the giant fields, and under the large operators so not very interesting
temp_df = well_list_df[well_list_df['SpudYear'].isna() & well_list_df['SpudYear_T'].notna()]
temp_df
# Out:
# original SPUD year NaN count: 123,495
# first pass Nearest Neighbors SpudYear_T NaN count: 93,595
#                API         LeaseName WellNumber          WellDesign  \
# 118     0403730471            Porter        39A          Porter 39A
# 154     0403700686      Fernando Fee         32     Fernando Fee 32
# 157     0403721360            Porter        32C          Porter 32C
# 287     0403700722            Porter         35           Porter 35
# 481     0402923914  Pickrell-Mitchel          1  Pickrell-Mitchel 1
# ...            ...               ...        ...                 ...
# 241861  0408301795             Davis         56            Davis 56
# 241863  0408321061           Davis B          6           Davis B 6
# 241864  0408301796             Davis         66            Davis 66
# 241865  0408301798             Davis         67            Davis 67
# 241872  0408301010             Quati         87            Quati 87
#
#        WellStatus WellType   WellTypeLa OperatorCo  \
# 118          Idle       GS  Gas Storage      S4700
# 154        Active       GS  Gas Storage      S4700
# 157        Active       GS  Gas Storage      S4700
# 287       Plugged       GS  Gas Storage      S4700
# 481        Active       OG    Oil & Gas      E0100
# ...           ...      ...          ...        ...
# 241861     Active       OG    Oil & Gas      10379
# 241863     Active       OG    Oil & Gas      10379
# 241864     Active       OG    Oil & Gas      10379
# 241865     Active       OG    Oil & Gas      10379
# 241872     Active       OG    Oil & Gas      10379
#
#                                             OperatorNa       FieldName  \
# 118                    Southern California Gas Company    Aliso Canyon
# 154                    Southern California Gas Company    Aliso Canyon
# 157                    Southern California Gas Company    Aliso Canyon
# 287                    Southern California Gas Company    Aliso Canyon
# 481     E & B Natural Resources Management Corporation  Antelope Hills
# ...                                                ...             ...
# 241861                        NewBridge Resources, LLC            Zaca
# 241863                        NewBridge Resources, LLC            Zaca
# 241864                        NewBridge Resources, LLC            Zaca
# 241865                        NewBridge Resources, LLC            Zaca
# 241872                        NewBridge Resources, LLC            Zaca
#
#         AreaName                 Place  District     CountyName  Section  \
# 118     Any Area    Los Angeles County  Northern    Los Angeles       28
# 154     Any Area           Los Angeles  Northern    Los Angeles       27
# 157     Any Area    Los Angeles County  Northern    Los Angeles       27
# 287     Any Area    Los Angeles County  Northern    Los Angeles       28
# 481     Williams           Kern County    Inland           Kern        7
# ...          ...                   ...       ...            ...      ...
# 241861  Any Area  Santa Barbara County  Northern  Santa Barbara       34
# 241863  Any Area  Santa Barbara County  Northern  Santa Barbara       33
# 241864  Any Area  Santa Barbara County  Northern  Santa Barbara       34
# 241865  Any Area  Santa Barbara County  Northern  Santa Barbara        3
# 241872  Any Area  Santa Barbara County  Northern  Santa Barbara        3
#
#        Township Range BaseMeridi   Latitude   Longitude     GISSource  \
# 118         03N   16W         SB  34.312569 -118.560349  Well Summary
# 154         03N   16W         SB  34.313175 -118.540100           GPS
# 157         03N   16W         SB  34.312477 -118.550453           GPS
# 287         03N   16W         SB  34.311604 -118.555931  Well Summary
# 481         28S   20E         MD  35.512726 -119.850410           GPS
# ...         ...   ...        ...        ...         ...           ...
# 241861      08N   31W         SB  34.724010 -120.136192           GPS
# 241863      08N   31W         SB  34.724453 -120.146858           GPS
# 241864      08N   31W         SB  34.723614 -120.134720           GPS
# 241865      07N   31W         SB  34.722271 -120.134537           GPS
# 241872      07N   31W         SB  34.721378 -120.129692           GPS
#
#        isConfiden isDirectio SpudDate           inHPZ WellSymbol   IdleDate  \
# 118             N          Y      NaT  Not Within HPZ     IdleGS 2018-01-01
# 154             N          N      NaT  Not Within HPZ   ActiveGS        NaT
# 157             N          N      NaT  Not Within HPZ   ActiveGS        NaT
# 287             N          Y      NaT  Not Within HPZ  PluggedGS        NaT
# 481             N          N      NaT  Not Within HPZ   ActiveOG        NaT
# ...           ...        ...      ...             ...        ...        ...
# 241861          N          N      NaT    Verified HPZ   ActiveOG 1998-12-01
# 241863          N          Y      NaT    Verified HPZ   ActiveOG        NaT
# 241864          N          N      NaT    Verified HPZ   ActiveOG        NaT
# 241865          N          N      NaT    Verified HPZ   ActiveOG 2023-02-01
# 241872          N          N      NaT    Verified HPZ   ActiveOG 2023-02-01
#
#         YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  IdleYear  \
# 118      6.000000     No           No     False       NaN    2018.0
# 154           NaN    NaN          NaN     False       NaN       NaN
# 157           NaN    NaN          NaN     False       NaN       NaN
# 287           NaN    NaN          NaN     False       NaN       NaN
# 481           NaN    NaN          NaN     False       NaN       NaN
# ...           ...    ...          ...       ...       ...       ...
# 241861  25.083334    Yes           No     False       NaN    1998.0
# 241863        NaN    NaN          NaN     False       NaN       NaN
# 241864        NaN    NaN          NaN     False       NaN       NaN
# 241865   0.916667     No           No     False       NaN    2023.0
# 241872   0.916667     No           No     False       NaN    2023.0
#
#             api_10 first_date  last_date  ProdYears  LastProdYear  \
# 118            NaN        NaT 2016-01-01        NaN          2016
# 154     0403700686 1977-01-31 2024-12-31        NaN          2024
# 157     0403721360 1977-01-31 2024-12-31        NaN          2024
# 287     0403700722 1977-01-31 2016-03-01        NaN          2016
# 481     0402923914 1977-01-31 2024-11-30        NaN          2024
# ...            ...        ...        ...        ...           ...
# 241861  0408301795 1977-01-31 2024-12-31        NaN          2024
# 241863  0408321061 1977-01-31 2024-12-31        NaN          2024
# 241864  0408301796 1977-01-31 2024-12-31        NaN          2024
# 241865  0408301798 1977-01-31 2024-12-31        NaN          2024
# 241872  0408301010 1977-01-31 2024-12-31        NaN          2024
#
#        CalcIdleDate  CalcIdleYear  IsIdleYearSame  CalcYearsIdle  \
# 118      2018-01-01        2018.0            True            7.0
# 154             NaT        2040.0           False            NaN
# 157             NaT        2040.0           False            NaN
# 287             NaT        2018.0           False            NaN
# 481             NaT        2026.0           False            0.0
# ...             ...           ...             ...            ...
# 241861          NaT        2040.0           False            NaN
# 241863          NaT        2040.0           False            NaN
# 241864          NaT        2040.0           False            NaN
# 241865          NaT        2040.0           False            NaN
# 241872          NaT        2040.0           False            NaN
#
#         UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  IdleFlag     lat_r  \
# 118                    0            0                  0         1  0.598867
# 154                    0            0                  0         0  0.598878
# 157                    0            0                  0         0  0.598866
# 287                    0            1                  1         0  0.598850
# 481                    0            0                  0         0  0.619814
# ...                  ...          ...                ...       ...       ...
# 241861                 0            0                  0         0  0.606048
# 241863                 0            0                  0         0  0.606056
# 241864                 0            0                  0         0  0.606041
# 241865                 0            0                  0         0  0.606018
# 241872                 0            0                  0         0  0.606002
#
#            lng_r  SpudYear_I  ProdYears_I  SpudYear_I2  SpudYear_I3  \
# 118    -2.069268     1948.43        60.19      1948.43      1948.43
# 154    -2.068915     1976.64        45.65      1976.64      1976.64
# 157    -2.069096     1965.44        52.00      1965.44      1965.44
# 287    -2.069191     1965.25        50.96      1965.25      1965.25
# 481    -2.091784     1981.00        35.68      1981.00      1981.00
# ...          ...         ...          ...          ...          ...
# 241861 -2.096772     1980.00        44.51      1980.00      1980.00
# 241863 -2.096958     1972.40        52.02      1972.40      1972.40
# 241864 -2.096746     1980.00        44.44      1980.00      1980.00
# 241865 -2.096743     1982.71        41.90      1982.71      1982.71
# 241872 -2.096659     1989.00        35.66      1989.00      1989.00
#
#         SpudYear_I4  SpudYear_I5  SpudYear_T
# 118         1948.43      1948.43      1950.0
# 154         1976.64      1976.64      1978.0
# 157         1965.44      1965.44      1978.0
# 287         1965.25      1965.25      1950.0
# 481         1981.00      1981.00      2006.0
# ...             ...          ...         ...
# 241861      1980.00      1980.00      1980.0
# 241863      1972.40      1972.40      1980.0
# 241864      1980.00      1980.00      1980.0
# 241865      1982.71      1982.71      1980.0
# 241872      1989.00      1989.00      1980.0
#
# [29900 rows x 55 columns]

# %%
# examine the hypothesis
temp_df.value_counts('OperatorNa')
# Out:
# OperatorNa
# Chevron U.S.A. Inc.                       12965
# Aera Energy LLC                            7924
# California Resources Elk Hills, LLC        1784
# Sentinel Peak Resources California LLC     1331
# Berry Petroleum Company, LLC                932
#                                           ...
# Macpherson Oil Company                        1
# The Termo Company                             1
# Watt Mineral Holdings LLC                     1
# West American Energy Corporation              1
# Zynergy, LLC                                  1
# Name: count, Length: 106, dtype: int64

# %%
t5_count = temp_df.value_counts('OperatorNa').head(5).sum()
print(f"Top 5 operators have {t5_count:,} of the {temp_df['OperatorNa'].count():,} wells in this group ({t5_count/temp_df['OperatorNa'].count():.0%}) - so this is a safe imputation that likely won't affect the overall analysis")
# Out:
# Top 5 operators have 24,936 of the 29,900 wells in this group (83%) - so this is a safe imputation that likely won't affect the overall analysis

# %%
# check if any of them have SpudDate_T > IdleDate - IdleYears - 2
temp_df[temp_df['SpudYear_T'] > (temp_df['CalcIdleYear'] - temp_df['CalcYearsIdle'] - 2.0)]
# Out:
#                API        LeaseName WellNumber             WellDesign  \
# 15561   0407920202            Maino         11               Maino 11
# 15659   0407900706            Adams          2                Adams 2
# 16936   0402901506            M & L     41-16Y           M & L 41-16Y
# 18167   0402929589      Unspecified       102R       Unspecified 102R
# 18201   0402929647      Unspecified      38-35      Unspecified 38-35
# ...            ...              ...        ...                    ...
# 231670  0411105010       V. L. & W.         99          V. L. & W. 99
# 235338  0403703874              NWU      24-14              NWU 24-14
# 235382  0403701856              NWU      6-Apr                NWU 4-6
# 241642  0402951871  Yowlumne Unit A     11-Dec  Yowlumne Unit A 12-11
# 241703  0402952057  Yowlumne Unit A       68-3   Yowlumne Unit A 68-3
#
#        WellStatus WellType  WellTypeLa OperatorCo  \
# 15561        Idle       OG   Oil & Gas      S2641
# 15659        Idle       OG   Oil & Gas      S2641
# 16936        Idle       OG   Oil & Gas      E0100
# 18167        Idle       OG   Oil & Gas      A0610
# 18201        Idle       OG   Oil & Gas      A0610
# ...           ...      ...         ...        ...
# 231670       Idle       OG   Oil & Gas      A0610
# 235338       Idle       OG   Oil & Gas      W0325
# 235382       Idle       OG   Oil & Gas      W0325
# 241642       Idle       WF  Waterflood      C0885
# 241703       Idle       WF  Waterflood      C0885
#
#                                             OperatorNa          FieldName  \
# 15561           Sentinel Peak Resources California LLC      Arroyo Grande
# 15659           Sentinel Peak Resources California LLC      Arroyo Grande
# 16936   E & B Natural Resources Management Corporation  Belgian Anticline
# 18167                                  Aera Energy LLC    Belridge, North
# 18201                                  Aera Energy LLC    Belridge, North
# ...                                                ...                ...
# 231670                                 Aera Energy LLC            Ventura
# 235338                                Warren E&P, Inc.         Wilmington
# 235382                                Warren E&P, Inc.         Wilmington
# 241642     California Resources Production Corporation           Yowlumne
# 241703     California Resources Production Corporation           Yowlumne
#
#               AreaName                   Place  District       CountyName  \
# 15561            Tiber  San Luis Obispo County  Northern  San Luis Obispo
# 15659            Tiber  San Luis Obispo County  Northern  San Luis Obispo
# 16936        Northwest             Kern County    Inland             Kern
# 18167         Any Area             Kern County    Inland             Kern
# 18201         Any Area             Kern County    Inland             Kern
# ...                ...                     ...       ...              ...
# 231670        Any Area          Ventura County  Northern          Ventura
# 235338  Fault Block II             Los Angeles  Southern      Los Angeles
# 235382  Fault Block II             Los Angeles  Southern      Los Angeles
# 241642        Any Area             Kern County    Inland             Kern
# 241703        Any Area             Kern County    Inland             Kern
#
#         Section Township Range BaseMeridi   Latitude   Longitude  \
# 15561        31      31S   13E         MD  35.181644 -120.617088
# 15659        31      31S   13E         MD  35.179626 -120.623642
# 16936        16      30S   21E         MD  35.319965 -119.723244
# 18167        21      27S   20E         MD  35.559582 -119.815407
# 18201        35      27S   20E         MD  35.534340 -119.791565
# ...         ...      ...   ...        ...        ...         ...
# 231670       24      03N   23W         SB  34.321808 -119.234543
# 235338       33      04S   13W         SB  33.782856 -118.241379
# 235382       34      04S   13W         SB  33.783497 -118.238472
# 241642       11      11N   22W         SB  35.059555 -119.205902
# 241703        3      11N   22W         SB  35.063160 -119.212578
#
#            GISSource isConfiden isDirectio SpudDate             inHPZ  \
# 15561            GPS          N          N      NaT      Verified HPZ
# 15659            GPS          N          N      NaT  Uncertainty Area
# 16936            GPS          N          N      NaT    Not Within HPZ
# 18167   Well Summary          N          N      NaT    Not Within HPZ
# 18201       Operator          N          N      NaT    Not Within HPZ
# ...              ...        ...        ...      ...               ...
# 231670           GPS          N          N      NaT    Not Within HPZ
# 235338           GPS          N          N      NaT      Verified HPZ
# 235382           GPS          N          N      NaT      Verified HPZ
# 241642           GPS          N          N      NaT    Not Within HPZ
# 241703           GPS          N          N      NaT    Not Within HPZ
#
#        WellSymbol   IdleDate  YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 15561      IdleOG 1999-11-01  24.166666    Yes           No     False
# 15659      IdleOG 1990-09-01  33.333332    Yes           No     False
# 16936      IdleOG 2008-09-01  15.333333    Yes           No     False
# 18167      IdleOG 2006-08-01  17.416666    Yes           No     False
# 18201      IdleOG 1982-02-01  41.916668    Yes           No     False
# ...           ...        ...        ...    ...          ...       ...
# 231670     IdleOG 2003-12-01  20.083334    Yes           No     False
# 235338     IdleOG 1991-01-01  33.000000    Yes           No     False
# 235382     IdleOG 1986-07-01  37.500000    Yes           No     False
# 241642     IdleWF 1992-11-01  31.166666    Yes           No     False
# 241703     IdleWF 2006-07-01  17.500000    Yes           No     False
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears  \
# 15561        NaN    1999.0  0407920202 1977-01-31 1997-10-31        NaN
# 15659        NaN    1990.0  0407900706 1977-01-31 1997-10-31        NaN
# 16936        NaN    2008.0  0402901506 1977-01-31 2006-08-31        NaN
# 18167        NaN    2006.0  0402929589 1977-01-31 2004-07-31        NaN
# 18201        NaN    1982.0  0402929647 1977-01-31 1983-10-31        NaN
# ...          ...       ...         ...        ...        ...        ...
# 231670       NaN    2003.0  0411105010 1977-01-31 2001-11-30        NaN
# 235338       NaN    1991.0  0403703874 1977-01-31 1997-10-31        NaN
# 235382       NaN    1986.0  0403701856 1977-01-31 1997-10-31        NaN
# 241642       NaN    1992.0  0402951871 1977-01-31 1982-08-31        NaN
# 241703       NaN    2006.0  0402952057 1977-01-31 1982-10-31        NaN
#
#         LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  \
# 15561           1997   1999-10-31        1999.0            True
# 15659           1997   1999-10-31        1999.0           False
# 16936           2006   2008-08-31        2008.0            True
# 18167           2004   2006-07-31        2006.0            True
# 18201           1983   1985-10-31        1985.0           False
# ...              ...          ...           ...             ...
# 231670          2001   2003-11-30        2003.0            True
# 235338          1997   1999-10-31        1999.0           False
# 235382          1997   1999-10-31        1999.0           False
# 241642          1982   1984-08-31        1984.0           False
# 241703          1982   1984-10-31        1984.0           False
#
#         CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  \
# 15561           25.17                 0            0                  0
# 15659           25.17                 0            0                  0
# 16936           16.33                 0            0                  0
# 18167           18.42                 0            0                  0
# 18201           39.17                 0            0                  0
# ...               ...               ...          ...                ...
# 231670          21.09                 0            0                  0
# 235338          25.17                 0            0                  0
# 235382          25.17                 0            0                  0
# 241642          40.33                 0            0                  0
# 241703          40.17                 0            0                  0
#
#         IdleFlag     lat_r     lng_r  SpudYear_I  ProdYears_I  SpudYear_I2  \
# 15561          1  0.614036 -2.105165     1996.45        25.43      1996.45
# 15659          1  0.614000 -2.105280     1994.50        20.78      1994.50
# 16936          1  0.616450 -2.089565     1969.14        33.90      1969.14
# 18167          1  0.620632 -2.091173     1973.67        23.08      1973.67
# 18201          1  0.620191 -2.090757     1975.86        37.59      1975.86
# ...          ...       ...       ...         ...          ...          ...
# 231670         1  0.599029 -2.081035     1980.33        27.11      1980.33
# 235338         1  0.589622 -2.063701     1937.00        60.52      1937.00
# 235382         1  0.589633 -2.063651     1980.00        16.83      1980.00
# 241642         1  0.611905 -2.080535     1978.83        23.17      1978.83
# 241703         1  0.611968 -2.080652     1984.60        16.42      1965.58
#
#         SpudYear_I3  SpudYear_I4  SpudYear_I5  SpudYear_T
# 15561       1996.45      1996.45      1996.45      1979.0
# 15659       1994.50      1994.50      1994.50      1979.0
# 16936       1969.14      1969.14      1969.14      1990.0
# 18167       1973.67      1973.67      1973.67      1998.0
# 18201       1975.86      1975.86      1975.86      1979.0
# ...             ...          ...          ...         ...
# 231670      1980.33      1980.33      1980.33      1984.0
# 235338      1937.00      1937.00      1937.00      1977.0
# 235382      1980.00      1980.00      1980.00      1977.0
# 241642      1978.83      1978.83      1978.83      1977.0
# 241703      1965.58      1965.58      1965.58      1977.0
#
# [1365 rows x 55 columns]

# %%
well_list_df['SpudYear_T2'] = well_list_df['SpudYear_T'].fillna(well_list_df.groupby(['OperatorCo', 'FieldName', 'CalcIdleYear'])['SpudYear_T'].transform(f_spud))

print(f"2nd pass SPUD year NaN count: {well_list_df['SpudYear_T2'].isna().sum():,}")
# Out:
# 2nd pass SPUD year NaN count: 78,090

# %%
# Swap out IdleYear with AreaName
well_list_df['SpudYear_T3'] = well_list_df['SpudYear_T2'].fillna(well_list_df.groupby(['OperatorCo', 'FieldName', 'AreaName'])['SpudYear_T2'].transform(f_spud))

print(f"3rd pass SPUD year NaN count: {well_list_df['SpudYear_T3'].isna().sum():,}")
# Out:
# 3rd pass SPUD year NaN count: 48,873

# %%
# Swap out AreaName with LeaseName
well_list_df['SpudYear_T4'] = well_list_df['SpudYear_T2'].fillna(well_list_df.groupby(['OperatorCo', 'FieldName', 'LeaseName'])['SpudYear_T3'].transform(f_spud))

print(f"4th pass SPUD year NaN count: {well_list_df['SpudYear_T4'].isna().sum():,}")
# Out:
# 4th pass SPUD year NaN count: 50,705

# %%
# Now combine all Operators, but differentiate by AreaName and IdleYear
well_list_df['SpudYear_T5'] = well_list_df['SpudYear_T4'].fillna(well_list_df.groupby(['FieldName', 'WellType', 'AreaName', 'CalcIdleYear'])['SpudYear_T4'].transform(f_spud))

print(f"5th pass SPUD year NaN count: {well_list_df['SpudYear_T5'].isna().sum():,}")
# Out:
# 5th pass SPUD year NaN count: 17,491

# %%
well_list_df['SpudYear_T5'] = well_list_df['SpudYear_T4'].fillna(well_list_df.groupby(['FieldName', 'WellType', 'AreaName'])['SpudYear_T4'].transform(f_spud))

print(f"6th pass SPUD year NaN count: {well_list_df['SpudYear_T5'].isna().sum():,}")
# Out:
# 6th pass SPUD year NaN count: 9,780

# %%
# Now combine all Operators, and AreaNames
well_list_df['SpudYear_T6'] = well_list_df['SpudYear_T5'].fillna(well_list_df.groupby(['FieldName', 'WellType'])['SpudYear_T5'].transform(f_spud))

print(f"7th pass SPUD year NaN count: {well_list_df['SpudYear_T6'].isna().sum():,}")
# Out:
# 7th pass SPUD year NaN count: 7,528

# %%
# Now combine all WellTypes but differentiate IdleYear
well_list_df['SpudYear_T7'] = well_list_df['SpudYear_T6'].fillna(well_list_df.groupby(['FieldName', 'CalcIdleYear'])['SpudYear_T6'].transform(f_spud))

print(f"7th pass SPUD year NaN count: {well_list_df['SpudYear_T7'].isna().sum():,}")
# Out:
# 7th pass SPUD year NaN count: 4,422

# %%
# Now combine all FieldNames
well_list_df['SpudYear_T8'] = well_list_df['SpudYear_T7'].fillna(well_list_df.groupby(['OperatorCo', 'CalcIdleYear'])['SpudYear_T7'].transform(f_spud))

print(f"8th pass SPUD year NaN count: {well_list_df['SpudYear_T8'].isna().sum():,}")
# Out:
# 8th pass SPUD year NaN count: 1,863

# %%
well_list_df[well_list_df['SpudYear_T8'].isna()]
# Out:
#                API                       LeaseName WellNumber  \
# 5       0402100240  Max Pray-Central Valley-Boyd U          1
# 6       0402120034               Afton Community 3          1
# 9       0402120035                Spectrum-Pacific          1
# 10      0402100262                        Mantelli          1
# 55      0408300978                       Hollister          1
# ...            ...                             ...        ...
# 240696  0402120561                     Domenighini     28-Jan
# 240706  0411320705                      Martinelli          1
# 240808  0411320243                          Venada        S-1
# 241892  0411320940                     Zamora Unit          1
# 241901  0411300288                  Knaggs-Wallace          1
#
#                               WellDesign WellStatus WellType WellTypeLa  \
# 5       Max Pray-Central Valley-Boyd U 1    Plugged       DH   Dry Hole
# 6                    Afton Community 3 1    Plugged       DH   Dry Hole
# 9                     Spectrum-Pacific 1    Plugged       DH   Dry Hole
# 10                            Mantelli 1    Plugged       DH   Dry Hole
# 55                           Hollister 1    Plugged       OG  Oil & Gas
# ...                                  ...        ...      ...        ...
# 240696                  Domenighini 1-28    Plugged       DH   Dry Hole
# 240706                      Martinelli 1    Plugged       DH   Dry Hole
# 240808                        Venada S-1    Plugged       DH   Dry Hole
# 241892                     Zamora Unit 1    Plugged       DH   Dry Hole
# 241901                  Knaggs-Wallace 1    Plugged       DH   Dry Hole
#
#        OperatorCo                            OperatorNa            FieldName  \
# 5           03279               General Expl. Co. of Ca            Afton Gas
# 6           S3280                    Shoshone Oil Corp.            Afton Gas
# 9           S3280                    Shoshone Oil Corp.            Afton Gas
# 10          02212              Donald Frankel, Operator            Afton Gas
# 55          06399             Oil & Gas Prop Mgmt. Inc.        Alegria (ABD)
# ...           ...                                   ...                  ...
# 240696      U0300                    United Energy Inc.     Wilson Creek Gas
# 240706      00796                Big Valley Expl., Inc.  Winchester Lake Gas
# 240808      08750                           Venada Res.   Woodland Gas (ABD)
# 241892      H2050  Hartley Natural Resource Development     Zamora Gas (ABD)
# 241901      06813                           Pexco, Inc.     Zamora Gas (ABD)
#
#         AreaName                 Place  District     CountyName  Section  \
# 5           Main          Glenn County  Northern          Glenn        2
# 6           Main          Glenn County  Northern          Glenn       34
# 9           Main          Glenn County  Northern          Glenn       27
# 10          Main          Glenn County  Northern          Glenn       26
# 55      Any Area  Santa Barbara County  Northern  Santa Barbara       31
# ...          ...                   ...       ...            ...      ...
# 240696  Any Area          Glenn County  Northern          Glenn       28
# 240706  Any Area           Yolo County  Northern           Yolo        9
# 240808  Any Area           Yolo County  Northern           Yolo       13
# 241892  Any Area           Yolo County  Northern           Yolo       10
# 241901  Any Area           Yolo County  Northern           Yolo       12
#
#        Township Range BaseMeridi   Latitude   Longitude GISSource isConfiden  \
# 5           18N   01W         MD  39.438267 -121.947418       hud          N
# 6           19N   01W         MD  39.455864 -121.949425       hud          N
# 9           19N   01W         MD  39.467045 -121.962898       hud          N
# 10          19N   01W         MD  39.467525 -121.935989       hud          N
# 55          05N   32W         SB  34.473499 -120.267067       hud          N
# ...         ...   ...        ...        ...         ...       ...        ...
# 240696      20N   03W         MD  39.553970 -122.204636       hud          N
# 240706      07N   04E         MD  38.470367 -121.540520       hud          N
# 240808      10N   01E         MD  38.715263 -121.815185       hud          N
# 241892      11N   01E         MD  38.809059 -121.846977       hud          N
# 241901      11N   01E         MD  38.820602 -121.805306       hud          N
#
#        isDirectio SpudDate                       inHPZ WellSymbol IdleDate  \
# 5               N      NaT                Verified HPZ  PluggedDH      NaT
# 6               N      NaT             Potentially HPZ  PluggedDH      NaT
# 9               N      NaT             Potentially HPZ  PluggedDH      NaT
# 10              N      NaT             Potentially HPZ  PluggedDH      NaT
# 55              N      NaT             Potentially HPZ  PluggedOG      NaT
# ...           ...      ...                         ...        ...      ...
# 240696          N      NaT             Potentially HPZ  PluggedDH      NaT
# 240706          N      NaT             Potentially HPZ  PluggedDH      NaT
# 240808          N      NaT             Potentially HPZ  PluggedDH      NaT
# 241892          N      NaT                Verified HPZ  PluggedDH      NaT
# 241901          N      NaT  Potentially Not Within HPZ  PluggedDH      NaT
#
#         YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  IdleYear api_10  \
# 5             NaN    NaN          NaN     False       NaN       NaN    NaN
# 6             NaN    NaN          NaN     False       NaN       NaN    NaN
# 9             NaN    NaN          NaN     False       NaN       NaN    NaN
# 10            NaN    NaN          NaN     False       NaN       NaN    NaN
# 55            NaN    NaN          NaN      True       NaN       NaN    NaN
# ...           ...    ...          ...       ...       ...       ...    ...
# 240696        NaN    NaN          NaN     False       NaN       NaN    NaN
# 240706        NaN    NaN          NaN     False       NaN       NaN    NaN
# 240808        NaN    NaN          NaN      True       NaN       NaN    NaN
# 241892        NaN    NaN          NaN      True       NaN       NaN    NaN
# 241901        NaN    NaN          NaN      True       NaN       NaN    NaN
#
#        first_date  last_date  ProdYears  LastProdYear CalcIdleDate  \
# 5             NaT 1977-01-01        NaN          1977          NaT
# 6             NaT 1977-01-01        NaN          1977          NaT
# 9             NaT 1977-01-01        NaN          1977          NaT
# 10            NaT 1977-01-01        NaN          1977          NaT
# 55            NaT 1977-01-01        NaN          1977          NaT
# ...           ...        ...        ...           ...          ...
# 240696        NaT 1977-01-01        NaN          1977          NaT
# 240706        NaT 1977-01-01        NaN          1977          NaT
# 240808        NaT 1977-01-01        NaN          1977          NaT
# 241892        NaT 1977-01-01        NaN          1977          NaT
# 241901        NaT 1977-01-01        NaN          1977          NaT
#
#         CalcIdleYear  IsIdleYearSame  CalcYearsIdle  UnsatAbandonFlag  \
# 5             1979.0           False            NaN                 0
# 6             1979.0           False            NaN                 0
# 9             1979.0           False            NaN                 0
# 10            1979.0           False            NaN                 0
# 55            1979.0           False            NaN                 0
# ...              ...             ...            ...               ...
# 240696        1979.0           False            NaN                 0
# 240706        1979.0           False            NaN                 0
# 240808        1979.0           False            NaN                 0
# 241892        1979.0           False            NaN                 0
# 241901        1979.0           False            NaN                 0
#
#         PluggedFlag  PluggedRecentFlag  IdleFlag     lat_r     lng_r  \
# 5                 1                  0         0  0.688328 -2.128384
# 6                 1                  0         0  0.688635 -2.128419
# 9                 1                  0         0  0.688830 -2.128654
# 10                1                  0         0  0.688838 -2.128184
# 55                1                  0         0  0.601676 -2.099056
# ...             ...                ...       ...       ...       ...
# 240696            1                  0         0  0.690347 -2.132873
# 240706            1                  0         0  0.671435 -2.121282
# 240808            1                  0         0  0.675709 -2.126076
# 241892            1                  0         0  0.677346 -2.126631
# 241901            1                  0         0  0.677547 -2.125904
#
#         SpudYear_I  ProdYears_I  SpudYear_I2  SpudYear_I3  SpudYear_I4  \
# 5          1990.12        15.11      1961.89      1961.89      1961.89
# 6          1978.11        17.06      1959.94      1959.94      1959.94
# 9          1981.75        12.97      1964.03      1964.03      1964.03
# 10         1988.40         6.36      1970.64      1970.64      1970.64
# 55             NaN          NaN          NaN          NaN        20.00
# ...            ...          ...          ...          ...          ...
# 240696     1988.67         6.17      1970.83      1970.83      1970.83
# 240706     1983.12         9.17      1967.83      1967.83      1967.83
# 240808     1963.00        22.05      1963.00      1963.00      1963.00
# 241892     1977.00         8.67      1968.33      1968.33      1968.33
# 241901     1984.38         4.02      1972.98      1972.98      1972.98
#
#         SpudYear_I5  SpudYear_T  SpudYear_T2  SpudYear_T3  SpudYear_T4  \
# 5           1961.89         NaN          NaN          NaN          NaN
# 6           1959.94         NaN          NaN          NaN          NaN
# 9           1964.03         NaN          NaN          NaN          NaN
# 10          1970.64         NaN          NaN          NaN          NaN
# 55            20.00         NaN          NaN          NaN          NaN
# ...             ...         ...          ...          ...          ...
# 240696      1970.83         NaN          NaN          NaN          NaN
# 240706      1967.83         NaN          NaN          NaN          NaN
# 240808      1963.00         NaN          NaN          NaN          NaN
# 241892      1968.33         NaN          NaN          NaN          NaN
# 241901      1972.98         NaN          NaN          NaN          NaN
#
#         SpudYear_T5  SpudYear_T6  SpudYear_T7  SpudYear_T8
# 5               NaN          NaN          NaN          NaN
# 6               NaN          NaN          NaN          NaN
# 9               NaN          NaN          NaN          NaN
# 10              NaN          NaN          NaN          NaN
# 55              NaN          NaN          NaN          NaN
# ...             ...          ...          ...          ...
# 240696          NaN          NaN          NaN          NaN
# 240706          NaN          NaN          NaN          NaN
# 240808          NaN          NaN          NaN          NaN
# 241892          NaN          NaN          NaN          NaN
# 241901          NaN          NaN          NaN          NaN
#
# [1863 rows x 62 columns]

# %% [markdown]
# ## Merge imputed SPUD dates
# - Average the 2 imputed dates together
# - Then if there are NULLs, grab the `SpudYear_I5`, and any NULLs remaining grab `SpudYear_T8`
# - Finally, check for `SpudYear_Model` > `CalcIdleYear` and clean up as necessary

# %%
well_list_df['SpudYear_Model'] = round((well_list_df['SpudYear_I5'] + well_list_df['SpudYear_T8'])/2.0, 1)
well_list_df['SpudYear_Model'] = well_list_df['SpudYear_Model'].fillna(well_list_df['SpudYear_I5'])
well_list_df['SpudYear_Model'] = well_list_df['SpudYear_Model'].fillna(well_list_df['SpudYear_T8'])

# I know from the earlier imputation calcs that the 'SpudYear_I5' is already corrected to be before or the same as 'CalcIdleYear'
well_list_df['SpudYear_Model'] = well_list_df['SpudYear_Model'].where(well_list_df['SpudYear_Model'] > well_list_df['CalcIdleYear'], well_list_df['SpudYear_I5'])
well_list_df
# Out:
#                API                 LeaseName WellNumber  \
# 0       0403300003       Lease by W.G. Young          1
# 1       0402120723                     Kauai      1-Mar
# 2       0402120734                     Lanai      3-Mar
# 3       0402120815                   Anacapa      4-Mar
# 4       0402120521              Angel Slough      1-Feb
# ...            ...                       ...        ...
# 241907  0411320572            Knaggs-Wallace          5
# 241908  0411321202            Knaggs-Wallace          6
# 241909  0411320667  Reclamation District 108          1
# 241910  0411321025              Colusa Basin     Jan-35
# 241911  0411320692  Reclamation District 108          3
#
#                         WellDesign WellStatus WellType WellTypeLa OperatorCo  \
# 0                                1       Idle       DG    Dry Gas      11838
# 1                        Kauai 3-1       Idle       DG    Dry Gas      R4085
# 2                        Lanai 3-3       Idle       DG    Dry Gas      R4085
# 3                      Anacapa 3-4       Idle       DG    Dry Gas      R4085
# 4                 Angel Slough 2-1     Active       DG    Dry Gas      C8720
# ...                            ...        ...      ...        ...        ...
# 241907            Knaggs-Wallace 5    Plugged       DG    Dry Gas      P0325
# 241908            Knaggs-Wallace 6    Plugged       DH   Dry Hole      P4733
# 241909  Reclamation District 108 1    Plugged       DG    Dry Gas      C5640
# 241910           Colusa Basin 1-35    Plugged       DH   Dry Hole      R3755
# 241911  Reclamation District 108 3    Plugged       DH   Dry Hole      C5640
#
#                                   OperatorNa                 FieldName  \
# 0                                 W.G. Young                 Any Field
# 1                        Royale Energy, Inc.                 Afton Gas
# 2                        Royale Energy, Inc.                 Afton Gas
# 3                        Royale Energy, Inc.                 Afton Gas
# 4                       Crain Orchards, Inc.                 Afton Gas
# ...                                      ...                       ...
# 241907  Pacific Inland Operating Corporation          Zamora Gas (ABD)
# 241908        Production Specialties Company          Zamora Gas (ABD)
# 241909                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
# 241910        Rosetta Resources Operating LP  Zamora, North, Gas (ABD)
# 241911                   Chevron U.S.A. Inc.  Zamora, North, Gas (ABD)
#
#         AreaName         Place  District CountyName  Section Township Range  \
# 0            NaN   Lake County  Northern       Lake       14      13N   09W
# 1           Main  Glenn County  Northern      Glenn        3      18N   01W
# 2           Main  Glenn County  Northern      Glenn        3      18N   01W
# 3           Main  Glenn County  Northern      Glenn        3      18N   01W
# 4           Main  Glenn County  Northern      Glenn        2      18N   01W
# ...          ...           ...       ...        ...      ...      ...   ...
# 241907  Any Area   Yolo County  Northern       Yolo       12      11N   01E
# 241908  Any Area   Yolo County  Northern       Yolo       11      11N   01E
# 241909  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241910  Any Area   Yolo County  Northern       Yolo       35      12N   01E
# 241911  Any Area   Yolo County  Northern       Yolo       35      12N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241907         MD  38.812370 -121.812614                        hud
# 241908         MD  38.815502 -121.826279                        GPS
# 241909         MD  38.840790 -121.838989                        hud
# 241910         MD  38.851700 -121.837715                        hud
# 241911         MD  38.840210 -121.829697                        hud
#
#        isConfiden isDirectio   SpudDate                       inHPZ  \
# 0               N          N        NaT                Verified HPZ
# 1               N          N 1999-12-07              Not Within HPZ
# 2               N          N 2000-05-13            Uncertainty Area
# 3               N          N 2002-11-06              Not Within HPZ
# 4               N          N 1988-02-17              Not Within HPZ
# ...           ...        ...        ...                         ...
# 241907          N          N 1979-12-12  Potentially Not Within HPZ
# 241908          N          N        NaT  Potentially Not Within HPZ
# 241909          N          N 1981-09-17  Potentially Not Within HPZ
# 241910          N          N        NaT  Potentially Not Within HPZ
# 241911          N          N        NaT  Potentially Not Within HPZ
#
#        WellSymbol   IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  \
# 0          IdleDG 1901-01-01  123.000000    Yes           No     False
# 1          IdleDG 2015-08-01    8.416667    Yes           No     False
# 2          IdleDG 2015-08-01    8.416667    Yes           No     False
# 3          IdleDG 2011-06-01   12.583333    Yes           No     False
# 4        ActiveDG        NaT         NaN    NaN          NaN     False
# ...           ...        ...         ...    ...          ...       ...
# 241907  PluggedDG        NaT         NaN    NaN          NaN      True
# 241908  PluggedDH        NaT         NaN    NaN          NaN      True
# 241909  PluggedDG        NaT         NaN    NaN          NaN      True
# 241910  PluggedDH        NaT         NaN    NaN          NaN      True
# 241911  PluggedDH        NaT         NaN    NaN          NaN      True
#
#         SpudYear  IdleYear      api_10 first_date  last_date  ProdYears  \
# 0            NaN    1901.0         NaN        NaT 1977-01-01        NaN
# 1         1999.0    2015.0  0402120723 2000-04-30 2013-07-31      13.65
# 2         2000.0    2015.0  0402120734 2000-06-30 2013-07-31      13.22
# 3         2002.0    2011.0  0402120815 2004-10-31 2009-05-31       6.57
# 4         1988.0       NaN  0402120521 1988-06-30 2023-08-31      35.53
# ...          ...       ...         ...        ...        ...        ...
# 241907    1979.0       NaN  0411320572 1981-07-31 1982-02-28       2.21
# 241908       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241909    1981.0       NaN  0411320667 1985-02-28 1985-10-31       4.12
# 241910       NaN       NaN         NaN        NaT 1977-01-01        NaN
# 241911       NaN       NaN         NaN        NaT 1977-01-01        NaN
#
#         LastProdYear CalcIdleDate  CalcIdleYear  IsIdleYearSame  \
# 0               1977   1979-01-01        1979.0           False
# 1               2013   2015-07-31        2015.0            True
# 2               2013   2015-07-31        2015.0            True
# 3               2009   2011-05-31        2011.0            True
# 4               2023          NaT        2025.0           False
# ...              ...          ...           ...             ...
# 241907          1982          NaT        1984.0           False
# 241908          1977          NaT        1979.0           False
# 241909          1985          NaT        1987.0           False
# 241910          1977          NaT        1979.0           False
# 241911          1977          NaT        1979.0           False
#
#         CalcYearsIdle  UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  \
# 0               46.00                 0            0                  0
# 1                9.42                 0            0                  0
# 2                9.42                 0            0                  0
# 3               13.59                 0            0                  0
# 4                0.00                 0            0                  0
# ...               ...               ...          ...                ...
# 241907            NaN                 0            1                  0
# 241908            NaN                 0            1                  0
# 241909            NaN                 0            1                  0
# 241910            NaN                 0            1                  0
# 241911            NaN                 0            1                  0
#
#         IdleFlag     lat_r     lng_r  SpudYear_I  ProdYears_I  SpudYear_I2  \
# 0              1  0.680272 -2.143842         NaN          NaN          NaN
# 1              1  0.688369 -2.128462     1999.00        13.65      1999.00
# 2              1  0.688483 -2.128626     2000.00        13.22      2000.00
# 3              1  0.688414 -2.128447     2002.00         6.57      2002.00
# 4              0  0.688518 -2.128364     1988.00        35.53      1988.00
# ...          ...       ...       ...         ...          ...          ...
# 241907         0  0.677404 -2.126031     1979.00         2.21      1979.00
# 241908         0  0.677458 -2.126270     1978.57         6.62      1970.38
# 241909         0  0.677900 -2.126492     1981.00         4.12      1981.00
# 241910         0  0.678090 -2.126469     1978.33         6.08      1970.92
# 241911         0  0.677890 -2.126329     1979.20         6.40      1970.60
#
#         SpudYear_I3  SpudYear_I4  SpudYear_I5  SpudYear_T  SpudYear_T2  \
# 0           1901.00      1901.00      1901.00         NaN          NaN
# 1           1999.00      1999.00      1999.00      1999.0       1999.0
# 2           2000.00      2000.00      2000.00      2000.0       2000.0
# 3           2002.00      2002.00      2002.00      2002.0       2002.0
# 4           1988.00      1988.00      1988.00      1988.0       1988.0
# ...             ...          ...          ...         ...          ...
# 241907      1979.00      1979.00      1979.00      1979.0       1979.0
# 241908      1970.38      1970.38      1970.38         NaN          NaN
# 241909      1981.00      1981.00      1981.00      1981.0       1981.0
# 241910      1970.92      1970.92      1970.92         NaN          NaN
# 241911      1970.60      1970.60      1970.60         NaN          NaN
#
#         SpudYear_T3  SpudYear_T4  SpudYear_T5  SpudYear_T6  SpudYear_T7  \
# 0               NaN          NaN          NaN       2000.0       2000.0
# 1            1999.0       1999.0       1999.0       1999.0       1999.0
# 2            2000.0       2000.0       2000.0       2000.0       2000.0
# 3            2002.0       2002.0       2002.0       2002.0       2002.0
# 4            1988.0       1988.0       1988.0       1988.0       1988.0
# ...             ...          ...          ...          ...          ...
# 241907       1979.0       1979.0       1979.0       1979.0       1979.0
# 241908          NaN          NaN          NaN          NaN          NaN
# 241909       1981.0       1981.0       1981.0       1981.0       1981.0
# 241910          NaN          NaN          NaN          NaN          NaN
# 241911          NaN          NaN          NaN          NaN          NaN
#
#         SpudYear_T8  SpudYear_Model
# 0            2000.0         1901.00
# 1            1999.0         1999.00
# 2            2000.0         2000.00
# 3            2002.0         2002.00
# 4            1988.0         1988.00
# ...             ...             ...
# 241907       1979.0         1979.00
# 241908       1992.0         1981.20
# 241909       1981.0         1981.00
# 241910       1985.0         1970.92
# 241911       1977.0         1970.60
#
# [241912 rows x 63 columns]

# %%
# Final check for invalid SPUD Years - there are a few that don't pick up a SPUD year from any of the imputation, so we'll make that 1975
well_list_df.loc[well_list_df['SpudYear_Model']<1800, 'SpudYear_Model'] = 1975

# %%
# Ensure SpudYear_Model doesn't have any NULLs since we're using it as a feature in the model
assert(well_list_df['SpudYear_Model'].isna().sum()==0)

# %% [markdown]
# ## Export the imputed data columns for deployment
# Most of this is static metadata, so it doesn't need to be updated very often... maybe annually

# %%
well_list_df[['API','LastProdYear','CalcIdleYear','CalcYearsIdle','UnsatAbandonFlag','IdleFlag','SpudYear_Model']].to_pickle('imputed_features.pkl', protocol=4)

# %% [markdown]
# # Target creation

# %% [markdown]
# ## Set up  `op_pivot`
# this will be used to calculate the `AtRisk` flag, which I'll use later for the model target. once the `AtRisk` flag is set, I can merge it back to all the wells.

# %%
op_pivot_aggfunc = {'API':'count','UnsatAbandonFlag':'sum', 'PluggedFlag':'sum', 'PluggedRecentFlag':'sum', 'IdleFlag':'sum'}
op_pivot = well_list_df.pivot_table(index=['OperatorNa'], columns=[], values=['API','IdleFlag','UnsatAbandonFlag', 'PluggedFlag', 'PluggedRecentFlag'], aggfunc=op_pivot_aggfunc).copy()
op_pivot
# Out:
#                                      API  IdleFlag  PluggedFlag  \
# OperatorNa
# 104 Oil & Drilling Co.                 3         3            0
# 1062 McGaw APG LLC                     1         0            1
# 10622 Court Ave LLC                    2         0            2
# 120 7th St. LLC                        1         0            1
# 1211 S. Olive Street Development LP    3         0            3
# ...                                  ...       ...          ...
# Zoraida B. Travis                      4         0            4
# Zuni Oil Co.                           3         0            3
# Zurich Oil Co.                         1         0            1
# Zynergy, LLC                          47        39            1
# dba Calgren Renewable Fuels            1         1            0
#
#                                      PluggedRecentFlag  UnsatAbandonFlag
# OperatorNa
# 104 Oil & Drilling Co.                               0                 0
# 1062 McGaw APG LLC                                   0                 0
# 10622 Court Ave LLC                                  0                 0
# 120 7th St. LLC                                      0                 0
# 1211 S. Olive Street Development LP                  0                 0
# ...                                                ...               ...
# Zoraida B. Travis                                    0                 0
# Zuni Oil Co.                                         0                 0
# Zurich Oil Co.                                       0                 0
# Zynergy, LLC                                         0                 0
# dba Calgren Renewable Fuels                          0                 0
#
# [8634 rows x 5 columns]

# %%
# a number of operators have already plugged all their wells, so lets focus on operators with unplugged wells
op_pivot = op_pivot[op_pivot['API'] != op_pivot['PluggedFlag']].copy()

# %%
# Now we can see a list of operators that potentially haven't caught up with their plugging requirements
# For example "260 Resource Management LLC" has 14 wells, 11 are idle, and none are plugged - this looks like an operator at risk of fines
# Because the operators have to have plugged a certain number of wells over the last 5 years to keep up with the requirement (even small operators it's a minimum of 1 a year)
# There's some logic to consider here:
#       If it's a small operator (<250 wells) they have to abandon at least 1 well per year (so minimum 5), so conversely, if the Idle well count > 5, and Plugged < 5, then at-risk
#       If the number of Idle Wells > Plugged, we can say they are probably also 'at-risk'
#       For larger operators, it's a bit more complicated. But we can probably say if Plugged Recent * 8 >= Idle Flag, that could be a good start
# A caveat is that if they have unsatisfactory abandonments, they are also 'at-risk' because they'll likely have to redo them

op_pivot['AtRisk'] = 0
op_pivot.loc[(op_pivot['API'] - op_pivot['PluggedFlag'] < 250 ) & (op_pivot['IdleFlag'] > 5 ) & (op_pivot['PluggedRecentFlag'] < 5), 'AtRisk'] = 1
op_pivot.loc[(op_pivot['API'] - op_pivot['PluggedFlag'] < 1250 ) & (op_pivot['IdleFlag'] > op_pivot['PluggedFlag']), 'AtRisk'] = 1
op_pivot.loc[(op_pivot['API'] - op_pivot['PluggedFlag'] < 1250 ) & (op_pivot['UnsatAbandonFlag'] > 0 ), 'AtRisk'] = 1

# write out the operator table for use in the deployment later
op_pivot.to_pickle('operator_data.pkl', protocol=4)

op_pivot
# Out:
#                              API  IdleFlag  PluggedFlag  PluggedRecentFlag  \
# OperatorNa
# 104 Oil & Drilling Co.         3         3            0                  0
# 1301 Colton LLC                4         2            2                  0
# 1350 Court Partners, LP        4         2            2                  0
# 25 Hill Properties, Inc.      97        12           45                  0
# 260 Resource Management LLC   14        11            0                  0
# ...                          ...       ...          ...                ...
# Young Petroleum Corp., Ltd.    1         1            0                  0
# Yunker, Morton & Dolley       23         1           22                  0
# Zodiac Energy LLC              3         3            0                  0
# Zynergy, LLC                  47        39            1                  0
# dba Calgren Renewable Fuels    1         1            0                  0
#
#                              UnsatAbandonFlag  AtRisk
# OperatorNa
# 104 Oil & Drilling Co.                      0       1
# 1301 Colton LLC                             0       0
# 1350 Court Partners, LP                     0       0
# 25 Hill Properties, Inc.                    0       1
# 260 Resource Management LLC                 0       1
# ...                                       ...     ...
# Young Petroleum Corp., Ltd.                 0       1
# Yunker, Morton & Dolley                     0       0
# Zodiac Energy LLC                           0       1
# Zynergy, LLC                                0       1
# dba Calgren Renewable Fuels                 0       1
#
# [1646 rows x 6 columns]

# %% [markdown]
# ## Add an Operator Size bucket.
# Buckets are defined by the State as well counts of 0-250, 251-1250, 1251+
# https://www.conservation.ca.gov/calgem/idle_well/Pages/idle-well-operators.aspx
#
# I'll group the Operators further into with more well counts (excluding Plugged) of
# - more than 1250
# - 251 to 1250
# - 101 to 250
# - 11 to 100
# - less than 10

# %%
# Create a copy with only the unplugged wells in it
unplugged_df = well_list_df[~well_list_df['WellStatus'].isin(['Plugged','PluggedOnly'])].copy()

# %%
# Add an Operator Size bucket
# the big publicly traded companies are > 1000 wells, and have incentives to decrease their idle count
well_list_df['OperatorNa'].value_counts(sort=True, ascending=False)
# Out:
# OperatorNa
# Chevron U.S.A. Inc.                            58393
# Aera Energy LLC                                57665
# California Resources Production Corporation    11497
# Sentinel Peak Resources California LLC         10888
# California Resources Elk Hills, LLC            10476
#                                                ...
# Central Valley Petro Co.                           1
# Priest Valley Petro Co.                            1
# Cyrus Peirce, Agent                                1
# R. A. Rowan, E. Armstrong & J. Babcock             1
# Community Oil                                      1
# Name: count, Length: 8634, dtype: int64

# %%
op_bins = [0, 10, 100, 250, 1250, np.inf]
op_bin_labels = ['0-10', '11-100', '101-250', '251-1250','1251+']

unplugged_df['OperatorWellCount'] = unplugged_df.groupby('OperatorNa')['OperatorNa'].transform('size')
unplugged_df['OperatorBin'] = pd.cut(unplugged_df['OperatorWellCount'], bins=op_bins, labels=op_bin_labels)
unplugged_df
# Out:
#                API            LeaseName WellNumber            WellDesign  \
# 0       0403300003  Lease by W.G. Young          1                     1
# 1       0402120723                Kauai      1-Mar             Kauai 3-1
# 2       0402120734                Lanai      3-Mar             Lanai 3-3
# 3       0402120815              Anacapa      4-Mar           Anacapa 3-4
# 4       0402120521         Angel Slough      1-Feb      Angel Slough 2-1
# ...            ...                  ...        ...                   ...
# 241872  0408301010                Quati         87              Quati 87
# 241873  0408301802                Luton         92              Luton 92
# 241874  0408301803                Luton         93              Luton 93
# 241875  0408322941                Luton       NW-1            Luton NW-1
# 241890  0411321280      Roosevelt Ranch      1-Oct  Roosevelt Ranch 10-1
#
#        WellStatus WellType WellTypeLa OperatorCo  \
# 0            Idle       DG    Dry Gas      11838
# 1            Idle       DG    Dry Gas      R4085
# 2            Idle       DG    Dry Gas      R4085
# 3            Idle       DG    Dry Gas      R4085
# 4          Active       DG    Dry Gas      C8720
# ...           ...      ...        ...        ...
# 241872     Active       OG  Oil & Gas      10379
# 241873     Active       OG  Oil & Gas      T3460
# 241874     Active       OG  Oil & Gas      T3460
# 241875     Active       OG  Oil & Gas      T3460
# 241890   Canceled      GAS        Gas      P0300
#
#                               OperatorNa         FieldName  AreaName  \
# 0                             W.G. Young         Any Field       NaN
# 1                    Royale Energy, Inc.         Afton Gas      Main
# 2                    Royale Energy, Inc.         Afton Gas      Main
# 3                    Royale Energy, Inc.         Afton Gas      Main
# 4                   Crain Orchards, Inc.         Afton Gas      Main
# ...                                  ...               ...       ...
# 241872          NewBridge Resources, LLC              Zaca  Any Area
# 241873     Towne Exploration Company, LP              Zaca  Any Area
# 241874     Towne Exploration Company, LP              Zaca  Any Area
# 241875     Towne Exploration Company, LP              Zaca  Any Area
# 241890  Pacific Gas and Electric Company  Zamora Gas (ABD)  Any Area
#
#                        Place  District     CountyName  Section Township Range  \
# 0                Lake County  Northern           Lake       14      13N   09W
# 1               Glenn County  Northern          Glenn        3      18N   01W
# 2               Glenn County  Northern          Glenn        3      18N   01W
# 3               Glenn County  Northern          Glenn        3      18N   01W
# 4               Glenn County  Northern          Glenn        2      18N   01W
# ...                      ...       ...            ...      ...      ...   ...
# 241872  Santa Barbara County  Northern  Santa Barbara        3      07N   31W
# 241873  Santa Barbara County  Northern  Santa Barbara       32      08N   31W
# 241874  Santa Barbara County  Northern  Santa Barbara       29      08N   31W
# 241875  Santa Barbara County  Northern  Santa Barbara       30      08N   31W
# 241890           Yolo County  Northern           Yolo       10      11N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241872         SB  34.721378 -120.129692                        GPS
# 241873         SB  34.736721 -120.163727                        GPS
# 241874         SB  34.738331 -120.163513                        GPS
# 241875         SB  34.746796 -120.180992  Notice of Intent to Drill
# 241890         MD  38.809052 -121.845451  Notice of Intent to Drill
#
#        isConfiden isDirectio   SpudDate             inHPZ   WellSymbol  \
# 0               N          N        NaT      Verified HPZ       IdleDG
# 1               N          N 1999-12-07    Not Within HPZ       IdleDG
# 2               N          N 2000-05-13  Uncertainty Area       IdleDG
# 3               N          N 2002-11-06    Not Within HPZ       IdleDG
# 4               N          N 1988-02-17    Not Within HPZ     ActiveDG
# ...           ...        ...        ...               ...          ...
# 241872          N          N        NaT      Verified HPZ     ActiveOG
# 241873          N          N        NaT    Not Within HPZ     ActiveOG
# 241874          N          N        NaT    Not Within HPZ     ActiveOG
# 241875          N          N 2017-12-31      Verified HPZ     ActiveOG
# 241890          N          N        NaT      Verified HPZ  CanceledGAS
#
#          IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  \
# 0      1901-01-01  123.000000    Yes           No     False       NaN
# 1      2015-08-01    8.416667    Yes           No     False    1999.0
# 2      2015-08-01    8.416667    Yes           No     False    2000.0
# 3      2011-06-01   12.583333    Yes           No     False    2002.0
# 4             NaT         NaN    NaN          NaN     False    1988.0
# ...           ...         ...    ...          ...       ...       ...
# 241872 2023-02-01    0.916667     No           No     False       NaN
# 241873        NaT         NaN    NaN          NaN     False       NaN
# 241874        NaT         NaN    NaN          NaN     False       NaN
# 241875        NaT         NaN    NaN          NaN     False    2017.0
# 241890        NaT         NaN    NaN          NaN      True       NaN
#
#         IdleYear      api_10 first_date  last_date  ProdYears  LastProdYear  \
# 0         1901.0         NaN        NaT 1977-01-01        NaN          1977
# 1         2015.0  0402120723 2000-04-30 2013-07-31      13.65          2013
# 2         2015.0  0402120734 2000-06-30 2013-07-31      13.22          2013
# 3         2011.0  0402120815 2004-10-31 2009-05-31       6.57          2009
# 4            NaN  0402120521 1988-06-30 2023-08-31      35.53          2023
# ...          ...         ...        ...        ...        ...           ...
# 241872    2023.0  0408301010 1977-01-31 2024-12-31        NaN          2024
# 241873       NaN  0408301802 1977-01-31 2024-11-30        NaN          2024
# 241874       NaN  0408301803 1977-01-31 2024-11-30        NaN          2024
# 241875       NaN  0408322941 2018-01-31 2024-11-30       6.92          2024
# 241890       NaN         NaN        NaT 1977-01-01        NaN          1977
#
#        CalcIdleDate  CalcIdleYear  IsIdleYearSame  CalcYearsIdle  \
# 0        1979-01-01        1979.0           False          46.00
# 1        2015-07-31        2015.0            True           9.42
# 2        2015-07-31        2015.0            True           9.42
# 3        2011-05-31        2011.0            True          13.59
# 4               NaT        2025.0           False           0.00
# ...             ...           ...             ...            ...
# 241872          NaT        2040.0           False            NaN
# 241873          NaT        2026.0           False           0.00
# 241874          NaT        2026.0           False           0.00
# 241875          NaT        2026.0           False           0.00
# 241890   1979-01-01        1979.0           False          46.00
#
#         UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  IdleFlag     lat_r  \
# 0                      0            0                  0         1  0.680272
# 1                      0            0                  0         1  0.688369
# 2                      0            0                  0         1  0.688483
# 3                      0            0                  0         1  0.688414
# 4                      0            0                  0         0  0.688518
# ...                  ...          ...                ...       ...       ...
# 241872                 0            0                  0         0  0.606002
# 241873                 0            0                  0         0  0.606270
# 241874                 0            0                  0         0  0.606298
# 241875                 0            0                  0         0  0.606446
# 241890                 0            0                  0         1  0.677346
#
#            lng_r  SpudYear_I  ProdYears_I  SpudYear_I2  SpudYear_I3  \
# 0      -2.143842         NaN          NaN          NaN      1901.00
# 1      -2.128462     1999.00        13.65      1999.00      1999.00
# 2      -2.128626     2000.00        13.22      2000.00      2000.00
# 3      -2.128447     2002.00         6.57      2002.00      2002.00
# 4      -2.128364     1988.00        35.53      1988.00      1988.00
# ...          ...         ...          ...          ...          ...
# 241872 -2.096659     1989.00        35.66      1989.00      1989.00
# 241873 -2.097253     1991.00        32.07      1991.00      1991.00
# 241874 -2.097249     2012.00        10.32      2012.00      2012.00
# 241875 -2.097554     2017.00         6.92      2017.00      2017.00
# 241890 -2.126604     1979.33         8.68      1968.32      1968.32
#
#         SpudYear_I4  SpudYear_I5  SpudYear_T  SpudYear_T2  SpudYear_T3  \
# 0           1901.00      1901.00         NaN          NaN          NaN
# 1           1999.00      1999.00      1999.0       1999.0       1999.0
# 2           2000.00      2000.00      2000.0       2000.0       2000.0
# 3           2002.00      2002.00      2002.0       2002.0       2002.0
# 4           1988.00      1988.00      1988.0       1988.0       1988.0
# ...             ...          ...         ...          ...          ...
# 241872      1989.00      1989.00      1980.0       1980.0       1980.0
# 241873      1991.00      1991.00         NaN          NaN       2015.0
# 241874      2012.00      2012.00         NaN          NaN       2015.0
# 241875      2017.00      2017.00      2017.0       2017.0       2017.0
# 241890      1968.32      1968.32         NaN          NaN          NaN
#
#         SpudYear_T4  SpudYear_T5  SpudYear_T6  SpudYear_T7  SpudYear_T8  \
# 0               NaN          NaN       2000.0       2000.0       2000.0
# 1            1999.0       1999.0       1999.0       1999.0       1999.0
# 2            2000.0       2000.0       2000.0       2000.0       2000.0
# 3            2002.0       2002.0       2002.0       2002.0       2002.0
# 4            1988.0       1988.0       1988.0       1988.0       1988.0
# ...             ...          ...          ...          ...          ...
# 241872       1980.0       1980.0       1980.0       1980.0       1980.0
# 241873       2015.0       2015.0       2015.0       2015.0       2015.0
# 241874       2015.0       2015.0       2015.0       2015.0       2015.0
# 241875       2017.0       2017.0       2017.0       2017.0       2017.0
# 241890          NaN          NaN          NaN          NaN       1985.0
#
#         SpudYear_Model  OperatorWellCount OperatorBin
# 0              1901.00                  1        0-10
# 1              1999.00                 47      11-100
# 2              2000.00                 47      11-100
# 3              2002.00                 47      11-100
# 4              1988.00                  1        0-10
# ...                ...                ...         ...
# 241872         1989.00                488    251-1250
# 241873         1991.00                 26      11-100
# 241874         2012.00                 26      11-100
# 241875         2017.00                 26      11-100
# 241890         1968.32                114     101-250
#
# [110040 rows x 65 columns]

# %% [markdown]
# ## Idle well fee calculations
# If a well is Idle, this would be the annual fee for the well until it is placed on an P&A Plan (aka Testing Waiver Plan). The State just posts if they are on an IWMP, not if they are in compliance or not.
# From https://www.conservation.ca.gov/calgem/idle_well/Pages/idle-well-operators.aspx

# %%
### Add an operator fee bucket
unplugged_df['IdleFees'] = 0
unplugged_df.loc[(unplugged_df['CalcYearsIdle'] >= 3.0 ) & (unplugged_df['CalcYearsIdle'] < 8.0), 'IdleFees'] = 150
unplugged_df.loc[(unplugged_df['CalcYearsIdle'] >= 8.0 ) & (unplugged_df['CalcYearsIdle'] < 15.0), 'IdleFees'] = 300
unplugged_df.loc[(unplugged_df['CalcYearsIdle'] >= 15.0) & (unplugged_df['CalcYearsIdle'] < 20.0), 'IdleFees'] = 750
unplugged_df.loc[unplugged_df['CalcYearsIdle'] >= 20.0, 'IdleFees'] = 1500
unplugged_df
# Out:
#                API            LeaseName WellNumber            WellDesign  \
# 0       0403300003  Lease by W.G. Young          1                     1
# 1       0402120723                Kauai      1-Mar             Kauai 3-1
# 2       0402120734                Lanai      3-Mar             Lanai 3-3
# 3       0402120815              Anacapa      4-Mar           Anacapa 3-4
# 4       0402120521         Angel Slough      1-Feb      Angel Slough 2-1
# ...            ...                  ...        ...                   ...
# 241872  0408301010                Quati         87              Quati 87
# 241873  0408301802                Luton         92              Luton 92
# 241874  0408301803                Luton         93              Luton 93
# 241875  0408322941                Luton       NW-1            Luton NW-1
# 241890  0411321280      Roosevelt Ranch      1-Oct  Roosevelt Ranch 10-1
#
#        WellStatus WellType WellTypeLa OperatorCo  \
# 0            Idle       DG    Dry Gas      11838
# 1            Idle       DG    Dry Gas      R4085
# 2            Idle       DG    Dry Gas      R4085
# 3            Idle       DG    Dry Gas      R4085
# 4          Active       DG    Dry Gas      C8720
# ...           ...      ...        ...        ...
# 241872     Active       OG  Oil & Gas      10379
# 241873     Active       OG  Oil & Gas      T3460
# 241874     Active       OG  Oil & Gas      T3460
# 241875     Active       OG  Oil & Gas      T3460
# 241890   Canceled      GAS        Gas      P0300
#
#                               OperatorNa         FieldName  AreaName  \
# 0                             W.G. Young         Any Field       NaN
# 1                    Royale Energy, Inc.         Afton Gas      Main
# 2                    Royale Energy, Inc.         Afton Gas      Main
# 3                    Royale Energy, Inc.         Afton Gas      Main
# 4                   Crain Orchards, Inc.         Afton Gas      Main
# ...                                  ...               ...       ...
# 241872          NewBridge Resources, LLC              Zaca  Any Area
# 241873     Towne Exploration Company, LP              Zaca  Any Area
# 241874     Towne Exploration Company, LP              Zaca  Any Area
# 241875     Towne Exploration Company, LP              Zaca  Any Area
# 241890  Pacific Gas and Electric Company  Zamora Gas (ABD)  Any Area
#
#                        Place  District     CountyName  Section Township Range  \
# 0                Lake County  Northern           Lake       14      13N   09W
# 1               Glenn County  Northern          Glenn        3      18N   01W
# 2               Glenn County  Northern          Glenn        3      18N   01W
# 3               Glenn County  Northern          Glenn        3      18N   01W
# 4               Glenn County  Northern          Glenn        2      18N   01W
# ...                      ...       ...            ...      ...      ...   ...
# 241872  Santa Barbara County  Northern  Santa Barbara        3      07N   31W
# 241873  Santa Barbara County  Northern  Santa Barbara       32      08N   31W
# 241874  Santa Barbara County  Northern  Santa Barbara       29      08N   31W
# 241875  Santa Barbara County  Northern  Santa Barbara       30      08N   31W
# 241890           Yolo County  Northern           Yolo       10      11N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241872         SB  34.721378 -120.129692                        GPS
# 241873         SB  34.736721 -120.163727                        GPS
# 241874         SB  34.738331 -120.163513                        GPS
# 241875         SB  34.746796 -120.180992  Notice of Intent to Drill
# 241890         MD  38.809052 -121.845451  Notice of Intent to Drill
#
#        isConfiden isDirectio   SpudDate             inHPZ   WellSymbol  \
# 0               N          N        NaT      Verified HPZ       IdleDG
# 1               N          N 1999-12-07    Not Within HPZ       IdleDG
# 2               N          N 2000-05-13  Uncertainty Area       IdleDG
# 3               N          N 2002-11-06    Not Within HPZ       IdleDG
# 4               N          N 1988-02-17    Not Within HPZ     ActiveDG
# ...           ...        ...        ...               ...          ...
# 241872          N          N        NaT      Verified HPZ     ActiveOG
# 241873          N          N        NaT    Not Within HPZ     ActiveOG
# 241874          N          N        NaT    Not Within HPZ     ActiveOG
# 241875          N          N 2017-12-31      Verified HPZ     ActiveOG
# 241890          N          N        NaT      Verified HPZ  CanceledGAS
#
#          IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  \
# 0      1901-01-01  123.000000    Yes           No     False       NaN
# 1      2015-08-01    8.416667    Yes           No     False    1999.0
# 2      2015-08-01    8.416667    Yes           No     False    2000.0
# 3      2011-06-01   12.583333    Yes           No     False    2002.0
# 4             NaT         NaN    NaN          NaN     False    1988.0
# ...           ...         ...    ...          ...       ...       ...
# 241872 2023-02-01    0.916667     No           No     False       NaN
# 241873        NaT         NaN    NaN          NaN     False       NaN
# 241874        NaT         NaN    NaN          NaN     False       NaN
# 241875        NaT         NaN    NaN          NaN     False    2017.0
# 241890        NaT         NaN    NaN          NaN      True       NaN
#
#         IdleYear      api_10 first_date  last_date  ProdYears  LastProdYear  \
# 0         1901.0         NaN        NaT 1977-01-01        NaN          1977
# 1         2015.0  0402120723 2000-04-30 2013-07-31      13.65          2013
# 2         2015.0  0402120734 2000-06-30 2013-07-31      13.22          2013
# 3         2011.0  0402120815 2004-10-31 2009-05-31       6.57          2009
# 4            NaN  0402120521 1988-06-30 2023-08-31      35.53          2023
# ...          ...         ...        ...        ...        ...           ...
# 241872    2023.0  0408301010 1977-01-31 2024-12-31        NaN          2024
# 241873       NaN  0408301802 1977-01-31 2024-11-30        NaN          2024
# 241874       NaN  0408301803 1977-01-31 2024-11-30        NaN          2024
# 241875       NaN  0408322941 2018-01-31 2024-11-30       6.92          2024
# 241890       NaN         NaN        NaT 1977-01-01        NaN          1977
#
#        CalcIdleDate  CalcIdleYear  IsIdleYearSame  CalcYearsIdle  \
# 0        1979-01-01        1979.0           False          46.00
# 1        2015-07-31        2015.0            True           9.42
# 2        2015-07-31        2015.0            True           9.42
# 3        2011-05-31        2011.0            True          13.59
# 4               NaT        2025.0           False           0.00
# ...             ...           ...             ...            ...
# 241872          NaT        2040.0           False            NaN
# 241873          NaT        2026.0           False           0.00
# 241874          NaT        2026.0           False           0.00
# 241875          NaT        2026.0           False           0.00
# 241890   1979-01-01        1979.0           False          46.00
#
#         UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  IdleFlag     lat_r  \
# 0                      0            0                  0         1  0.680272
# 1                      0            0                  0         1  0.688369
# 2                      0            0                  0         1  0.688483
# 3                      0            0                  0         1  0.688414
# 4                      0            0                  0         0  0.688518
# ...                  ...          ...                ...       ...       ...
# 241872                 0            0                  0         0  0.606002
# 241873                 0            0                  0         0  0.606270
# 241874                 0            0                  0         0  0.606298
# 241875                 0            0                  0         0  0.606446
# 241890                 0            0                  0         1  0.677346
#
#            lng_r  SpudYear_I  ProdYears_I  SpudYear_I2  SpudYear_I3  \
# 0      -2.143842         NaN          NaN          NaN      1901.00
# 1      -2.128462     1999.00        13.65      1999.00      1999.00
# 2      -2.128626     2000.00        13.22      2000.00      2000.00
# 3      -2.128447     2002.00         6.57      2002.00      2002.00
# 4      -2.128364     1988.00        35.53      1988.00      1988.00
# ...          ...         ...          ...          ...          ...
# 241872 -2.096659     1989.00        35.66      1989.00      1989.00
# 241873 -2.097253     1991.00        32.07      1991.00      1991.00
# 241874 -2.097249     2012.00        10.32      2012.00      2012.00
# 241875 -2.097554     2017.00         6.92      2017.00      2017.00
# 241890 -2.126604     1979.33         8.68      1968.32      1968.32
#
#         SpudYear_I4  SpudYear_I5  SpudYear_T  SpudYear_T2  SpudYear_T3  \
# 0           1901.00      1901.00         NaN          NaN          NaN
# 1           1999.00      1999.00      1999.0       1999.0       1999.0
# 2           2000.00      2000.00      2000.0       2000.0       2000.0
# 3           2002.00      2002.00      2002.0       2002.0       2002.0
# 4           1988.00      1988.00      1988.0       1988.0       1988.0
# ...             ...          ...         ...          ...          ...
# 241872      1989.00      1989.00      1980.0       1980.0       1980.0
# 241873      1991.00      1991.00         NaN          NaN       2015.0
# 241874      2012.00      2012.00         NaN          NaN       2015.0
# 241875      2017.00      2017.00      2017.0       2017.0       2017.0
# 241890      1968.32      1968.32         NaN          NaN          NaN
#
#         SpudYear_T4  SpudYear_T5  SpudYear_T6  SpudYear_T7  SpudYear_T8  \
# 0               NaN          NaN       2000.0       2000.0       2000.0
# 1            1999.0       1999.0       1999.0       1999.0       1999.0
# 2            2000.0       2000.0       2000.0       2000.0       2000.0
# 3            2002.0       2002.0       2002.0       2002.0       2002.0
# 4            1988.0       1988.0       1988.0       1988.0       1988.0
# ...             ...          ...          ...          ...          ...
# 241872       1980.0       1980.0       1980.0       1980.0       1980.0
# 241873       2015.0       2015.0       2015.0       2015.0       2015.0
# 241874       2015.0       2015.0       2015.0       2015.0       2015.0
# 241875       2017.0       2017.0       2017.0       2017.0       2017.0
# 241890          NaN          NaN          NaN          NaN       1985.0
#
#         SpudYear_Model  OperatorWellCount OperatorBin  IdleFees
# 0              1901.00                  1        0-10      1500
# 1              1999.00                 47      11-100       300
# 2              2000.00                 47      11-100       300
# 3              2002.00                 47      11-100       300
# 4              1988.00                  1        0-10         0
# ...                ...                ...         ...       ...
# 241872         1989.00                488    251-1250         0
# 241873         1991.00                 26      11-100         0
# 241874         2012.00                 26      11-100         0
# 241875         2017.00                 26      11-100         0
# 241890         1968.32                114     101-250      1500
#
# [110040 rows x 66 columns]

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Iterating, looking at various pivots and charts to see how the data falls

# %%
# Some pivots to see what's in the dataset, start with well status
well_list_df.pivot_table(values='API', columns='WellStatus', fill_value=0, aggfunc='count')
# Out:
# WellStatus  Active  Canceled   Idle   New  Plugged  PluggedOnly  Unknown
# API          58683      9685  39786  1854   131802           70       32

# %%
sns.histplot(well_list_df['WellStatus'], kde=False)
plt.ylabel('Well Count')
plt.xlabel('Current Well Status')
# Out:
# Text(0.5, 0, 'Current Well Status')

# %%
sns.histplot(well_list_df[~well_list_df['WellStatus'].isin(['Plugged','PluggedOnly'])]['WellStatus'], kde=False)
plt.ylabel('Unplugged Well Count')
plt.xlabel('Current Well Status')
# Out:
# Text(0.5, 0, 'Current Well Status')

# %%
# Separate out the idle wells
idle_df = well_list_df[well_list_df['WellStatus'] == 'Idle']

# %%
sns.histplot(idle_df['CalcIdleYear'], kde=False)
plt.ylabel('Count of Idle Wells')
plt.xlabel('Last Volume Year')
# Out:
# Text(0.5, 0, 'Last Volume Year')

# %%
sns.histplot(idle_df['CalcYearsIdle'], kde=False)
plt.ylabel('Count of Idle Wells')
plt.xlabel('Years Idle')
# Out:
# Text(0.5, 0, 'Years Idle')

# %% [markdown]
# ## Idle well analysis by other attributes

# %%
sns.histplot(idle_df['WellType'], kde=False)
plt.ylabel('Count of Idle Wells')
plt.xlabel('Well Type')
# Out:
# Text(0.5, 0, 'Well Type')

# %% [markdown]
# Idle well population is overwhelmingly `OG` which means Oil/Gas. Next runners up are `SF` and `SC` which is Steamflood and Cyclic Steam, respectively

# %%
sns.histplot(idle_df[idle_df['WellType']=='OG']['CalcYearsIdle'], kde=False)
plt.ylabel('Count of Idle Oil/Gas Wells')
plt.xlabel('Years Idle')
# Out:
# Text(0.5, 0, 'Years Idle')

# %%
sns.histplot(unplugged_df['OperatorBin'], kde=False)
plt.ylabel('Count of Unplugged Wells')
plt.xlabel('Operator Size')
# Out:
# Text(0.5, 0, 'Operator Size')

# %%
sns.histplot(unplugged_df[unplugged_df['WellStatus'] =='Idle']['OperatorBin'], kde=False)
plt.ylabel('Count of Idle Wells')
plt.xlabel('Operator Size')
# Out:
# Text(0.5, 0, 'Operator Size')

# %%
op_df = pd.DataFrame(unplugged_df[unplugged_df['WellStatus'] =='Idle'].groupby('OperatorNa')['OperatorNa'].value_counts().copy())
op_df['OpSize'] = pd.cut(op_df['count'], bins=op_bins, labels=op_bin_labels)
op_df
# Out:
#                              count  OpSize
# OperatorNa
# 104 Oil & Drilling Co.           3    0-10
# 1301 Colton LLC                  2    0-10
# 1350 Court Partners, LP          2    0-10
# 25 Hill Properties, Inc.        36  11-100
# 260 Resource Management LLC     12  11-100
# ...                            ...     ...
# Yoelin Family Trust              2    0-10
# Young & Shaw                     6    0-10
# Young Petroleum Corp., Ltd.      1    0-10
# Yunker, Morton & Dolley          1    0-10
# Zynergy, LLC                    42  11-100
#
# [1243 rows x 2 columns]

# %%
sns.histplot(op_df['OpSize'], kde=False)
plt.ylabel('Number of Operators with Idle Wells')
plt.xlabel('Operator Size')
# Out:
# Text(0.5, 0, 'Operator Size')

# %%
sns.histplot(unplugged_df[unplugged_df['WellStatus'] =='Idle']['OperatorBin'], kde=False)
plt.ylabel('Count of Idle Wells')
plt.xlabel('Operator Size')
# Out:
# Text(0.5, 0, 'Operator Size')

# %% [markdown]
# ## Correlations between features
# - First I'll do some correlation mapping between different features. There will be another correlation section below against the target
# - df.corr() uses Pearson correlation coefficient, which is a linear measure. +1 is strong positive correlation, -1 is strong inverse correlation
# - **note** use scatterplots to find non-linear correlations that can also exist

# %%
# First between all features
#unplugged_df.corr()

# %%
sns.pairplot(unplugged_df, vars=['WellStatus','WellType','isDirectio','CalcIdleYear','OperatorBin','IdleFlag','IdleFees','SpudYear_Model'])

# %%
sns.pairplot(unplugged_df, vars=['CalcIdleYear','SpudYear_Model'])

# %% [markdown]
# ## Assign the `op_df['at-risk']` back to the `unplugged_df` by operator

# %%
unplugged_df = pd.merge(unplugged_df, op_pivot[['AtRisk']], how='left', left_on='OperatorNa', right_index=True)
unplugged_df
# Out:
#                API            LeaseName WellNumber            WellDesign  \
# 0       0403300003  Lease by W.G. Young          1                     1
# 1       0402120723                Kauai      1-Mar             Kauai 3-1
# 2       0402120734                Lanai      3-Mar             Lanai 3-3
# 3       0402120815              Anacapa      4-Mar           Anacapa 3-4
# 4       0402120521         Angel Slough      1-Feb      Angel Slough 2-1
# ...            ...                  ...        ...                   ...
# 241872  0408301010                Quati         87              Quati 87
# 241873  0408301802                Luton         92              Luton 92
# 241874  0408301803                Luton         93              Luton 93
# 241875  0408322941                Luton       NW-1            Luton NW-1
# 241890  0411321280      Roosevelt Ranch      1-Oct  Roosevelt Ranch 10-1
#
#        WellStatus WellType WellTypeLa OperatorCo  \
# 0            Idle       DG    Dry Gas      11838
# 1            Idle       DG    Dry Gas      R4085
# 2            Idle       DG    Dry Gas      R4085
# 3            Idle       DG    Dry Gas      R4085
# 4          Active       DG    Dry Gas      C8720
# ...           ...      ...        ...        ...
# 241872     Active       OG  Oil & Gas      10379
# 241873     Active       OG  Oil & Gas      T3460
# 241874     Active       OG  Oil & Gas      T3460
# 241875     Active       OG  Oil & Gas      T3460
# 241890   Canceled      GAS        Gas      P0300
#
#                               OperatorNa         FieldName  AreaName  \
# 0                             W.G. Young         Any Field       NaN
# 1                    Royale Energy, Inc.         Afton Gas      Main
# 2                    Royale Energy, Inc.         Afton Gas      Main
# 3                    Royale Energy, Inc.         Afton Gas      Main
# 4                   Crain Orchards, Inc.         Afton Gas      Main
# ...                                  ...               ...       ...
# 241872          NewBridge Resources, LLC              Zaca  Any Area
# 241873     Towne Exploration Company, LP              Zaca  Any Area
# 241874     Towne Exploration Company, LP              Zaca  Any Area
# 241875     Towne Exploration Company, LP              Zaca  Any Area
# 241890  Pacific Gas and Electric Company  Zamora Gas (ABD)  Any Area
#
#                        Place  District     CountyName  Section Township Range  \
# 0                Lake County  Northern           Lake       14      13N   09W
# 1               Glenn County  Northern          Glenn        3      18N   01W
# 2               Glenn County  Northern          Glenn        3      18N   01W
# 3               Glenn County  Northern          Glenn        3      18N   01W
# 4               Glenn County  Northern          Glenn        2      18N   01W
# ...                      ...       ...            ...      ...      ...   ...
# 241872  Santa Barbara County  Northern  Santa Barbara        3      07N   31W
# 241873  Santa Barbara County  Northern  Santa Barbara       32      08N   31W
# 241874  Santa Barbara County  Northern  Santa Barbara       29      08N   31W
# 241875  Santa Barbara County  Northern  Santa Barbara       30      08N   31W
# 241890           Yolo County  Northern           Yolo       10      11N   01E
#
#        BaseMeridi   Latitude   Longitude                  GISSource  \
# 0              MD  38.976693 -122.833093  Notice of Intent to Drill
# 1              MD  39.440640 -121.951889                        GPS
# 2              MD  39.447174 -121.961273                        GPS
# 3              MD  39.443230 -121.951042                        GPS
# 4              MD  39.449158 -121.946289                        GPS
# ...           ...        ...         ...                        ...
# 241872         SB  34.721378 -120.129692                        GPS
# 241873         SB  34.736721 -120.163727                        GPS
# 241874         SB  34.738331 -120.163513                        GPS
# 241875         SB  34.746796 -120.180992  Notice of Intent to Drill
# 241890         MD  38.809052 -121.845451  Notice of Intent to Drill
#
#        isConfiden isDirectio   SpudDate             inHPZ   WellSymbol  \
# 0               N          N        NaT      Verified HPZ       IdleDG
# 1               N          N 1999-12-07    Not Within HPZ       IdleDG
# 2               N          N 2000-05-13  Uncertainty Area       IdleDG
# 3               N          N 2002-11-06    Not Within HPZ       IdleDG
# 4               N          N 1988-02-17    Not Within HPZ     ActiveDG
# ...           ...        ...        ...               ...          ...
# 241872          N          N        NaT      Verified HPZ     ActiveOG
# 241873          N          N        NaT    Not Within HPZ     ActiveOG
# 241874          N          N        NaT    Not Within HPZ     ActiveOG
# 241875          N          N 2017-12-31      Verified HPZ     ActiveOG
# 241890          N          N        NaT      Verified HPZ  CanceledGAS
#
#          IdleDate   YearsIdle IsLTIW UnsatAbandon  FieldAbd  SpudYear  \
# 0      1901-01-01  123.000000    Yes           No     False       NaN
# 1      2015-08-01    8.416667    Yes           No     False    1999.0
# 2      2015-08-01    8.416667    Yes           No     False    2000.0
# 3      2011-06-01   12.583333    Yes           No     False    2002.0
# 4             NaT         NaN    NaN          NaN     False    1988.0
# ...           ...         ...    ...          ...       ...       ...
# 241872 2023-02-01    0.916667     No           No     False       NaN
# 241873        NaT         NaN    NaN          NaN     False       NaN
# 241874        NaT         NaN    NaN          NaN     False       NaN
# 241875        NaT         NaN    NaN          NaN     False    2017.0
# 241890        NaT         NaN    NaN          NaN      True       NaN
#
#         IdleYear      api_10 first_date  last_date  ProdYears  LastProdYear  \
# 0         1901.0         NaN        NaT 1977-01-01        NaN          1977
# 1         2015.0  0402120723 2000-04-30 2013-07-31      13.65          2013
# 2         2015.0  0402120734 2000-06-30 2013-07-31      13.22          2013
# 3         2011.0  0402120815 2004-10-31 2009-05-31       6.57          2009
# 4            NaN  0402120521 1988-06-30 2023-08-31      35.53          2023
# ...          ...         ...        ...        ...        ...           ...
# 241872    2023.0  0408301010 1977-01-31 2024-12-31        NaN          2024
# 241873       NaN  0408301802 1977-01-31 2024-11-30        NaN          2024
# 241874       NaN  0408301803 1977-01-31 2024-11-30        NaN          2024
# 241875       NaN  0408322941 2018-01-31 2024-11-30       6.92          2024
# 241890       NaN         NaN        NaT 1977-01-01        NaN          1977
#
#        CalcIdleDate  CalcIdleYear  IsIdleYearSame  CalcYearsIdle  \
# 0        1979-01-01        1979.0           False          46.00
# 1        2015-07-31        2015.0            True           9.42
# 2        2015-07-31        2015.0            True           9.42
# 3        2011-05-31        2011.0            True          13.59
# 4               NaT        2025.0           False           0.00
# ...             ...           ...             ...            ...
# 241872          NaT        2040.0           False            NaN
# 241873          NaT        2026.0           False           0.00
# 241874          NaT        2026.0           False           0.00
# 241875          NaT        2026.0           False           0.00
# 241890   1979-01-01        1979.0           False          46.00
#
#         UnsatAbandonFlag  PluggedFlag  PluggedRecentFlag  IdleFlag     lat_r  \
# 0                      0            0                  0         1  0.680272
# 1                      0            0                  0         1  0.688369
# 2                      0            0                  0         1  0.688483
# 3                      0            0                  0         1  0.688414
# 4                      0            0                  0         0  0.688518
# ...                  ...          ...                ...       ...       ...
# 241872                 0            0                  0         0  0.606002
# 241873                 0            0                  0         0  0.606270
# 241874                 0            0                  0         0  0.606298
# 241875                 0            0                  0         0  0.606446
# 241890                 0            0                  0         1  0.677346
#
#            lng_r  SpudYear_I  ProdYears_I  SpudYear_I2  SpudYear_I3  \
# 0      -2.143842         NaN          NaN          NaN      1901.00
# 1      -2.128462     1999.00        13.65      1999.00      1999.00
# 2      -2.128626     2000.00        13.22      2000.00      2000.00
# 3      -2.128447     2002.00         6.57      2002.00      2002.00
# 4      -2.128364     1988.00        35.53      1988.00      1988.00
# ...          ...         ...          ...          ...          ...
# 241872 -2.096659     1989.00        35.66      1989.00      1989.00
# 241873 -2.097253     1991.00        32.07      1991.00      1991.00
# 241874 -2.097249     2012.00        10.32      2012.00      2012.00
# 241875 -2.097554     2017.00         6.92      2017.00      2017.00
# 241890 -2.126604     1979.33         8.68      1968.32      1968.32
#
#         SpudYear_I4  SpudYear_I5  SpudYear_T  SpudYear_T2  SpudYear_T3  \
# 0           1901.00      1901.00         NaN          NaN          NaN
# 1           1999.00      1999.00      1999.0       1999.0       1999.0
# 2           2000.00      2000.00      2000.0       2000.0       2000.0
# 3           2002.00      2002.00      2002.0       2002.0       2002.0
# 4           1988.00      1988.00      1988.0       1988.0       1988.0
# ...             ...          ...         ...          ...          ...
# 241872      1989.00      1989.00      1980.0       1980.0       1980.0
# 241873      1991.00      1991.00         NaN          NaN       2015.0
# 241874      2012.00      2012.00         NaN          NaN       2015.0
# 241875      2017.00      2017.00      2017.0       2017.0       2017.0
# 241890      1968.32      1968.32         NaN          NaN          NaN
#
#         SpudYear_T4  SpudYear_T5  SpudYear_T6  SpudYear_T7  SpudYear_T8  \
# 0               NaN          NaN       2000.0       2000.0       2000.0
# 1            1999.0       1999.0       1999.0       1999.0       1999.0
# 2            2000.0       2000.0       2000.0       2000.0       2000.0
# 3            2002.0       2002.0       2002.0       2002.0       2002.0
# 4            1988.0       1988.0       1988.0       1988.0       1988.0
# ...             ...          ...          ...          ...          ...
# 241872       1980.0       1980.0       1980.0       1980.0       1980.0
# 241873       2015.0       2015.0       2015.0       2015.0       2015.0
# 241874       2015.0       2015.0       2015.0       2015.0       2015.0
# 241875       2017.0       2017.0       2017.0       2017.0       2017.0
# 241890          NaN          NaN          NaN          NaN       1985.0
#
#         SpudYear_Model  OperatorWellCount OperatorBin  IdleFees  AtRisk
# 0              1901.00                  1        0-10      1500       1
# 1              1999.00                 47      11-100       300       1
# 2              2000.00                 47      11-100       300       1
# 3              2002.00                 47      11-100       300       1
# 4              1988.00                  1        0-10         0       0
# ...                ...                ...         ...       ...     ...
# 241872         1989.00                488    251-1250         0       1
# 241873         1991.00                 26      11-100         0       1
# 241874         2012.00                 26      11-100         0       1
# 241875         2017.00                 26      11-100         0       1
# 241890         1968.32                114     101-250      1500       0
#
# [110040 rows x 67 columns]

# %%
# map the smaller operators, and how many unplugged wells might be at-risk
sns.histplot(unplugged_df[unplugged_df['OperatorWellCount'] < 1250 ], x='OperatorBin',  kde=False, multiple='stack', hue='AtRisk')
plt.ylabel('Count of Idle Wells')
plt.xlabel('Operator Size')
# Out:
# Text(0.5, 0, 'Operator Size')

# %% [markdown]
# # Baseline Model Building
# - This may be too high-level, we may need Field level or some other subdivision on the `AtRisk` flag
# - set up the train-test split datasets

# %% [markdown]
# ## Model input prep

# %%
# Select the variables that seem to be of interest
X = unplugged_df[['API','WellStatus','WellType','CountyName','isDirectio','CalcIdleYear','OperatorBin','IdleFlag','IdleFees','SpudYear_Model']].copy()
y = unplugged_df['AtRisk']

# Trying to set the API as the index, which will simplify deployment later
X.set_index('API', inplace=True)

numeric_cols = ['CalcIdleYear','IdleFees','SpudYear_Model']
categorical_cols = ['WellStatus','WellType','CountyName','isDirectio','OperatorBin','IdleFlag']

# %% [markdown]
# ['API',## Set up the Pipeline, we'll save this for deployment

# %%
# OneHotEncoder needs to be passed 'sparse_output=False' or it will cause errors with downstream steps in certain model training and deployment

preproc = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), categorical_cols)
    ]
)

pipeline = Pipeline([
    ('preproc', preproc),
    ('classifier', LogisticRegression(random_state=452))
])

# %% [markdown]
# ### Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# ## Baseline Model Training / Logistic Regression

# %%
pipeline.fit(X_train, y_train)
# Out:
# C:\Users\dan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Pipeline(steps=[('preproc',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['CalcIdleYear', 'IdleFees',
#                                                    'SpudYear_Model']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['WellStatus', 'WellType',
#                                                    'CountyName', 'isDirectio',
#                                                    'OperatorBin',
#                                                    'IdleFlag'])])),
#                 ('classifier', LogisticRegression(random_state=452))])

# %%
y_pred = pipeline.predict(X_test)

# %% [markdown]
# ### Baseline Model Results

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
conf_matrix
# Out:
# array([[28415,   696],
#        [  872,  3029]])

# %%
def show_confusion_plot(conf_matrix):
    class_names=['Safe','At Risk'] # name  of classes
    fig, ax = plt.subplots()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names)
    plt.yticks(tick_marks, class_names)
    # create heatmap
    sns.heatmap(pd.DataFrame(conf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
    ax.xaxis.set_label_position("top")
    plt.tight_layout()
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

show_confusion_plot(conf_matrix)

# %%
# add hyperparameter tuning
# print the classificaiton report and feature importance
report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     29111
#            1       0.81      0.78      0.79      3901
#
#     accuracy                           0.95     33012
#    macro avg       0.89      0.88      0.88     33012
# weighted avg       0.95      0.95      0.95     33012

# %% [raw]
# With these results, Accuracy and Precision are fairly high.
#
# False Negatives and False Positives are about equally weighted, but large in proportion to True Positives, which is what I'm most interested in. I'll look to improve the True Positive count in future versions of the model.

# %% [markdown]
# ### Some hyperparameter tuning on the Baseline Log Reg model

# %%
param_grid = {
    'classifier__C' : uniform(loc=0, scale=4),  # C is regularization strength
    'classifier__penalty' : ['l2', 'l1'],       # penalty is regulatization type
    'classifier__solver' : ['saga', 'liblinear'],
    'classifier__max_iter' : [100,150,200,300,400,500]
}

clf = RandomizedSearchCV( estimator=pipeline, param_distributions=param_grid, cv=4, n_jobs=-1, n_iter=50)

search = clf.fit(X_train, y_train)
print(search.best_params_)
print(search.best_score_)
print(search.best_estimator_)
# Out:
# C:\Users\dan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# {'classifier__C': np.float64(3.4802309300814342), 'classifier__max_iter': 100, 'classifier__penalty': 'l1', 'classifier__solver': 'liblinear'}
# 0.9538868982707587
# Pipeline(steps=[('preproc',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['CalcIdleYear', 'IdleFees',
#                                                    'SpudYear_Model']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['WellStatus', 'WellType',
#                                                    'CountyName', 'isDirectio',
#                                                    'OperatorBin',
#                                                    'IdleFlag'])])),
#                 ('classifier',
#                  LogisticRegression(C=np.float64(3.4802309300814342),
#                                     penalty='l1', random_state=452,
#                                     solver='liblinear'))])

# %%
best_pipe = search.best_estimator_

# %%
y_pred_tuned = best_pipe.predict(X_test)

conf_matrix = confusion_matrix(y_test, y_pred_tuned)
show_confusion_plot(conf_matrix)

# %%
report = classification_report(y_test, y_pred_tuned)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97     29111
#            1       0.81      0.78      0.79      3901
#
#     accuracy                           0.95     33012
#    macro avg       0.89      0.88      0.88     33012
# weighted avg       0.95      0.95      0.95     33012

# %% [markdown]
# ## Export
# So after hyperparameter tuning and 50 iterations, the best fit model only moved 5 wells in the True Positive category, which is not a very significant improvement with this model. The classification report is basically the same as well. In the next exercise, I will use several other types of models to see if there is a better fit. It would also be beneficial to review the output of the False Pos/Neg and see if that information can improve the target construction.

# %%
X
# Out:
#            WellStatus WellType     CountyName isDirectio  CalcIdleYear  \
# API
# 0403300003       Idle       DG           Lake          N        1979.0
# 0402120723       Idle       DG          Glenn          N        2015.0
# 0402120734       Idle       DG          Glenn          N        2015.0
# 0402120815       Idle       DG          Glenn          N        2011.0
# 0402120521     Active       DG          Glenn          N        2025.0
# ...               ...      ...            ...        ...           ...
# 0408301010     Active       OG  Santa Barbara          N        2040.0
# 0408301802     Active       OG  Santa Barbara          N        2026.0
# 0408301803     Active       OG  Santa Barbara          N        2026.0
# 0408322941     Active       OG  Santa Barbara          N        2026.0
# 0411321280   Canceled      GAS           Yolo          N        1979.0
#
#            OperatorBin  IdleFlag  IdleFees  SpudYear_Model
# API
# 0403300003        0-10         1      1500         1901.00
# 0402120723      11-100         1       300         1999.00
# 0402120734      11-100         1       300         2000.00
# 0402120815      11-100         1       300         2002.00
# 0402120521        0-10         0         0         1988.00
# ...                ...       ...       ...             ...
# 0408301010    251-1250         0         0         1989.00
# 0408301802      11-100         0         0         1991.00
# 0408301803      11-100         0         0         2012.00
# 0408322941      11-100         0         0         2017.00
# 0411321280     101-250         1      1500         1968.32
#
# [110040 rows x 9 columns]

# %%
# Exporting the datasets for the next sequence of exercises
# using pickle format preserves the datatypes and format, and the binary method is more compact
X.to_pickle("capstone_x.pkl")
y.to_pickle("capstone_y.pkl")

# export the optimized pipeline for deployment
joblib.dump(best_pipe, "baseline_pipeline_logreg.pkl")
# Out:
# ['baseline_pipeline_logreg.pkl']

# %% [markdown]
# # Appendix - Metadata & Data Dictionary

# %% [markdown]
# ## Main categories:  Status and Type
#
# **Well Status** single code identifying current status of well. Single code stands for:
# - A = Active (well has been drilled and completed and in-use)
# - B = Buried (well is buried and idle)
# - C = Cancelled (well permit has been cancelled prior to drilling)
# - I = Idle (well is idle, not produced or injected for 6 consecutive months for two years)
# - N = New (recently permitted well; planned or in the process of being drilled)
# - P = Plugged & Abandoned (well has been plugged and abandoned to current standards)
# - U = Unknown (well status not known; mostly older wells dated on pre-1976)
#
# **Well Type Codes**
# AI = Air Injector
# CH = Core Hole
# DG = Dry Gas
# DH = Dry Hole
# GAS = Gas
# GD = Gas Disposal
# GI = Gas Injection
# GS = Gas Storage
# INJ = Injection
# LG = Liquid Petroleum Gas
# Multi = Multiple Types
# OB = Observation
# OG = Oil & Gas
# PM = Pressure Maintenance
# SC = Cyclic Steam
# SF = Steam Flood
# UNK = Unknown well type; often a historic or legacy (pre-1976) well
# WD = Water Disposal
# WF = Water Flood
# WS = Water Source

# %% [markdown]
# ## Features names and descriptions
# This is my current understanding of the CSV data file description of the fields
#
# |Field Name| Data type | Width | description of record                                                                                                                                                                                |
# |---|-----------|-------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# |OID| 	Integer  | 	4    | 	Internal feature number OBJECTID: Sequential unique whole numbers that are automatically generated.                                                                                                 |
# |API| 	String   | 	10   | 	API Number. Unique and permanent identifier assigned to each well as standardized by the American Petroleum Institute                                                                               |
# |LeaseName| 	String   | 	109  | 	Lease name of oil and gas wells. At situation when lease name of that well is unknown, the location in which well is located (i.e. section, township, range, longitude, latitude) is then recorded. |
# |WellNumber| 	String   | 	50   | 	Operator-assigned alpha numeric designation for well.                                                                                                                                               |
# |WellDesign| 	String   | 	     | 	???                                                                                                                                                                                                 |
# |WellStatus| 	String   | 	     | 	Well Status - single code identifying current status of well  (see below)                                                                                                                           |
# |WellType| 	String   | 	     | 	Codes indicating well type  (see below)                                                                                                                                                             |
# |WellTypeLa| 	String   | 	     | 	Likely well type label                                                                                                                                                                              |
# |OperatorCo| 	String   | 	12   | 	Operator code. Unique identifier number assigned to each operator                                                                                                                                   |
# |OperatorNa| 	String   | 	100  | 	Operator Name. Name of individual or company or organization responsible for managment and operations of wells.                                                                                     |
# |FieldName| 	String   | 	255  | 	Name of the oil and gas field in which the well is located                                                                                                                                          |
# |AreaName| 	String   | 	255  | 	Name of area in which well is located                                                                                                                                                               |
# |Place| 	String   | 	     | 	Keyword                                                                                                                                                                                             |
# |District| 	String   | 	255  | 	DOGGR district with jurisdiction over the location in which well is located                                                                                                                         |
# |CountyName| 	String   | 	50   | 	County with jurisdiction over the location in which well is located                                                                                                                                 |
# |Section| 	Integer  | 	50   | 	Public Land Survey System section number in which well is located                                                                                                                                   |
# |Township| 	String   | 	100  | 	Public Land Survey System township in which well is located                                                                                                                                         |
# |Range| 	String   | 	100  | 	Public Land Survey System range in which well is located                                                                                                                                            |
# |BaseMeridi| 	String   | 	50   | 	Base Meridian. Principle meridians required for all California surveys; defines PLSS base; H = Humboldt; MD = Mount Diablo; SB = San Bernardino                                                     |
# |Latitude| 	Double   | 	8    | 	Latitude of well in the NAD83 coordinate system; decimal degree format                                                                                                                              |
# |Longitude| 	Double   | 	8    | 	Longitude of well in the NAD83 coordinate system; decimal degree format                                                                                                                             |
# |GISSource| 	String   | 	3    | 	3-character code describing the method by which the well location was established (see below)                                                                                                       |
# |isConfiden| 	String   | 	1    | 	Confidential Well. Subsurface information for well is held confidential for a period of two years pursuant to Public Resources Code section 3234                                                    |
# |isDirectio| 	String   | 	1    | 	Directionally Drilled. Indicator of whether well was directionally drilled; NULL for confidential wells                                                                                             |
# |SpudDate| 	String   | 	8    | 	Date on which well drilling commenced                                                                                                                                                               |
# |inHPZ| 	String   | 	26   | 	Well Intersection with Health Protection Zone (HPZ) (see below)                                                                                                                                     |
# |WellSymbol| 	String   | 	15   | 	Code for GIS symbology (see below)|
#
# ## Additional Codes:
#
#
# **Pre-2021 Well Production Type Codes**
# - 1 - Non-Associated Gas Withdrawal (aka Dry Gas)
# - 2 - Oil and Associated Gas Withdrawal
# - 3 - Gas Storage Withdrawal
# - 5 - Liquified Petroleum Gas Storage Withdrawal
# - 9 - Water Source
#
# **Pre-2021 Well Injection Type Codes**
# - 3 - Gas Storage Injection
# - 4 - Pressure Maintenance (Gas Injection)
# - 5 - Liquified Petroleum | Gas Injection (Propane, Butane, Olefin, etc.)
# - 6 - Water Disposal
# - 7 - Water Flood
# - 8 - Steam Flood
# - 0 - Air Injection
# - A - Cyclic Steam Injection
#
# **Pre-2021 Method of Operation (MO)**
# - 0 - Not Applicable
# - 1 - Flowing
# - 2 - Jack Line
# - 3 - Beam Rod Pump
# - 4 - Hydraulic Rod Pump
# - 5 - Bottom-Hole Hydraulic Rod Pump
# - 6 - Bottom-Hole Electric Pump (ESP)
# - 7 - Gas Lift
# - 8 - Other
#
# **Pre-2021 Water Disposition (Disp)**
# - 0 - Not Applicable
# - 1 - Evaporation-Percolation
# - 2 - Evaporation (lined sump)
# - 3 - Surface Water Body
# - 4 - Sewer System
# - 5 - Subsurface Injection
# - 6 - Other (i.e. turned over to commercial water disposal)
#
# **Pre-2021 Reason Well Not In Production**
# - 0 - Well on production
# - 1 - Standing (incapable of production in present condition)
# - 4 - Uncompleted
# - 5 - Abandoned or converted to another well type (DOGGR Approved)
# - 6 - Shut-In (capable of production in its present condition)
# - 8 - Other (i.e., observation well)
# - 9 - Operator Change (well transferred)
#
# **Pre-2021 Source of Water**
# - 0 - Not Applicable
# - 1 - Oil or Gas Well
# - 2 - Water Source System
# - 3 - Domestic Water System
# - 4 - Ocean
# - 5 - Industrial Waste
# - 6 - Domestic Waste
# - 7 - Other
#
# **Pre-2021 Kind of Water**
# - 0 - Not Applicable
# - 1 - Saline
# - 2 - Fresh
# - 3 - Chemical Mixture
# - 4 - Other
#
# **Pre-2021 Reason Well Not Injecting (equivalent to Not Producing list)**
# - 0 - Well injecting
# - 1 - Standing (incapable of production in present condition)
# - 4 - Uncompleted
# - 5 - Abandoned or converted to another well type (DOGGR Approved)
# - 6 - Shut-Down (capable of production in its present condition)
# - 8 - Other (i.e., observation well)
# - 9 - Operator Change (well transferred)
#
#
# **GIS Source**: 3-character code describing the method by which the well location was established
# (Ranked from most accurate to least accurate)
# GPS = Global Positioning System (Coordinates derived from Division staff and Trimble GPS unit)
# OPR = Operator (Coordinates provided by Operator via electronic format; ex. Excel, db, etc.)
# SUM = Well Summary Report (Coordinates provided by Operator, post-drilling, on SUM)
# NOI = Notice of Intent to Drill (Coordinates provided by Operator, pre-drilling, on NOI)
# DOQ = Digital Ortho Quad (Coordinates derived from aerial imagery)
# MIP = MapInfo Plotted (Coordinates generated from tool in MapInfo using corner call locations)
# HUD = Heads Up Digitized (Coordinates derived from scanned, georeferenced Mylar maps)
#
# **InHPZ**
# Potentially HPZ = well intersects with HPZs created algorithmically from source inputs representing sensitive receptors.
# Verified HPZ = well intersects with HPZs created from verified sensitive receptors that have been quality checked by CalGEM.
# Uncertainty Area = well falls within 32ft outside or inside a potential HPZ or verified HPZ.
# Not Within HPZ = well intersects with areas quality checked to be outside known HPZ areas.
# Potentially Not Within HPZ = well is outside Potential HPZ, Verified HPZ, Not Within HPZ, and Uncertainty Area.
#
# Another source for data glossary and dictionary: https://www.conservation.ca.gov/calgem/Documents/Glossary%20UA.pdf

# %% [markdown]
# ## GIS Symbols Definition
# Pulled from XML document here: https://gis.conservation.ca.gov/server/rest/services/WellSTAR/Wells/MapServer/0
# Total Count = 241,912 wells
#
# |Code|	Count|	Desc|
# |---|---|---|
# |ActiveCH|	0|	Active Core Hole|
# |ActiveDG|	887|	Active Gas: Dry Gas; Liquid Gas|
# |ActiveDH|	0|	Active Dry Hole|
# |ActiveGD|	60|	Active Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |ActiveGS|	255|	Active Gas Storage|
# |ActiveINJ|	3|	Active Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |ActiveMulti|	45|	Active Multipurpose|
# |ActiveOB|	3127|	Active Observation|
# |ActiveOG|	37998|	Active Oil and Gas|
# |ActivePM|	96|	Active Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |ActiveSC|	7674|	Active Cyclic Steam|
# |ActiveSF|	3757|	Active Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |ActiveSTR|	1|	???|
# |ActiveUNK|	2|	Active well of Unknown type|
# |ActiveWD|	776|	Active Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |ActiveWF|	3986|	Active Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |ActiveWS|	16|	Active Water Source|
# |CanceledCH|	12|	Canceled Core Hole|
# |CanceledDG|	97|	Canceled Gas: Dry Gas; Liquid Gas|
# |CanceledDH|	6|	Canceled Dry Hole|
# |CanceledGAS|	143|	Canceled Gas: Dry Gas; Liquid Gas|
# |CanceledGS|	5|	Canceled Gas Storage|
# |CanceledINJ|	669|	Canceled Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |CanceledMulti|	96|	Canceled Multipurpose|
# |CanceledOB|	123|	Canceled Observation|
# |CanceledOG|	7786|	Canceled Oil and Gas|
# |CanceledSC|	306|	Canceled Cyclic Steam|
# |CanceledSF|	186|	Canceled Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |CanceledUNK|	58|	Canceled well of Unknown type|
# |CanceledWD|	23|	Canceled Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |CanceledWF|	165|	Canceled Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |CanceledWS|	10|	Canceled Water Source|
# |IdleAI|	8|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleCH|	127|	Idle Core Hole|
# |IdleDG|	1320|	Idle Gas: Dry Gas; Liquid Gas|
# |IdleDH|	173|	Idle Dry Hole|
# |IdleGAS|	5|	Idle Gas: Dry Gas; Liquid Gas|
# |IdleGD|	37|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleGS|	27|	Idle Gas Storage|
# |IdleINJ|	35|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleLG|	1|	Idle Gas: Dry Gas; Liquid Gas|
# |IdleMulti|	109|	Idle Multipurpose|
# |IdleOB|	676|	Idle Observation|
# |IdleOG|	28372|	Idle Oil and Gas|
# |IdlePM|	28|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleSC|	1854|	Idle Cyclic Steam|
# |IdleSF|	3836|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleUNK|	56|	Idle well of Unknown type|
# |IdleWD|	848|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleWF|	2169|	Idle Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |IdleWS|	105|	Idle Water Source|
# |NewCH|	109|	Permitted Core Hole|
# |NewDG|	1|	Permitted Gas: Dry Gas; Liquid Gas|
# |NewDH|	6|	Permitted Dry Hole|
# |NewGS|	12|	Permitted Gas Storage|
# |NewINJ|	7|	Permitted Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |NewOB|	347|	Permitted Observation|
# |NewOG|	1011|	Permitted Oil and Gas|
# |NewSC|	227|	Permitted Cyclic Steam|
# |NewSF|	108|	Permitted Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |NewSTR|	1|	???|
# |NewWD|	17|	Permitted Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |NewWF|	8|	Permitted Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedAI|	83|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedCH|	1319|	Plugged Core Hole|
# |PluggedDG|	2809|	Plugged Gas: Dry Gas; Liquid Gas|
# |PluggedDH|	16587|	Plugged Dry Hole|
# |PluggedGAS|	1268|	Plugged Gas: Dry Gas; Liquid Gas|
# |PluggedGD|	21|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedGS|	168|	Plugged Gas Storage|
# |PluggedINJ|	868|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedLG|	5|	Plugged Gas: Dry Gas; Liquid Gas|
# |PluggedMulti|	2302|	Plugged Multipurpose|
# |PluggedOB|	728|	Plugged Observation|
# |PluggedOG|	91850|	Plugged Oil and Gas|
# |PluggedOnlyOB|	1|	Plugged Observation|
# |PluggedOnlyOG|	48|	Plugged Oil and Gas|
# |PluggedOnlySC|	1|	Plugged Cyclic Steam|
# |PluggedOnlySF|	3|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedOnlyWF|	17|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedPM|	18|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedSC|	2127|	Plugged Cyclic Steam|
# |PluggedSF|	5056|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedUNK|	672|	Plugged well of Unknown type|
# |PluggedWD|	790|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedWF|	5006|	Plugged Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |PluggedWS|	125|	Plugged Water Source|
# |UnknownDH|	1|	Unknown status Dry Hole|
# |UnknownINJ|	9|	Unknown status Injectors: Air Injector; Gas Disposal; Pressure Maintenance; Steam Flood; Water Disposal; Water Flood|
# |UnknownOG|	20|	Unknown status Oil and Gas|
# |UnknownUNK|	2|	Unknown status well of Unknown type|
