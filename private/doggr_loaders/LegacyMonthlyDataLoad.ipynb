# %% [markdown]
# # Export/Import script for SQL Server to MySQL
# From 2018-current, CalGEM has changed the database structure, reporting style and some of the nomenclature. This script is attempting to convert the well and monthly data into a composite format that can be used with historical data

# %%
# import os.path

import pyodbc
#import mysql.connector
from sqlalchemy import create_engine, text
import pandas as pd
import numpy as np
import os
from tqdm.auto import tqdm # as of 2/1/2022
from ipywidgets import FloatProgress
from IPython.display import display

pd.options.display.max_columns = 999

# %%
# Progress bar
progress = FloatProgress(min=0.0, max=100.0)
display(progress)
# Out:
# FloatProgress(value=0.0)

# %%
# Pandas functions progress bar
tqdm.pandas()

# %% [markdown]
# ## Loading the Data
# There are 2 data tables provided by the regulatory body of interest to me
# The Wells table, which now has API12 (so wellbore) and all the pertinent annual codes and attributes.
# Then the monthly volumes tables (actually 2, one for production and one for injection, but I've already joined them in a query)

# %%
load_year = 2017

# these are a different set up than the 2018-current databases, which are SQL Server BAK files.
# The 2015-2017 data came as Access files, and I linked them to a SQL Server db so easier access
# under the 'WellProductionInjectionLegacy' database. They also contain a PWT__ID index which greatly
# simplifies the linking of well records to monthly volumes.
sql_query_filename = f"C:/Stuff/doggr_2024/SQLQuery_{load_year}_Legacy_Prod_Inj.sql"
mssql_db_name = f"WellProductionInjectionLegacy"
mssql_tbl_name = f"{load_year}CaliforniaOilAndGasWells"

# %%
# check if the pickle data file exists
# it can take minutes to read the SQL data into a dataframe, so pickling it will save a lot time on a restart of the notebook
# note the pickle file is saved in the current working directory, not the sql directory mentioned below (obv)
pickle_file_name = f"{load_year}_prod_inj_data.pkl"
if os.path.exists(pickle_file_name) :
    print("Reading existing mv pickle...")
    df = pd.read_pickle(pickle_file_name)
else:
    # Connect to the SQL Server to read the data tables
    # Starting in v18, they default encryption, which we definately don't need for this and locally
    # ;Database=WellProductionInjection2019
    conn_str = "Driver={ODBC Driver 18 for Sql Server};Server=WhiteFractal-i7\\SQLEXPRESS;Trusted_Connection=yes;Encrypt=no;"
    conn = pyodbc.connect(conn_str)

    print("Reading SQL monthly volume data...")
    with open(sql_query_filename) as sqlfile:
        query_result = sqlfile.read()

    df = pd.read_sql_query(query_result, conn)

    # Some of the INT types in the query return here as Float b/c the Pandas default NULL is a float type.
    # So I'll convert those columns back to Int64 (which also includes a NULL option)
    df['casing_psi'] = df['casing_psi'].astype('Int64')
    df['tubing_psi'] = df['tubing_psi'].astype('Int64')
    df['gas_btu']    = df['gas_btu'].astype('Int64')
    df['well_mo']    = df['well_mo'].astype('Int64')
    df['surf_inj_press_psi'] = df['surf_inj_press_psi'].astype('Int64')
    df['water_disposition'] = df['water_disposition'].astype('Int64')
    df['water_source'] = df['water_source'].astype('Int64')
    df['water_kind'] = df['water_kind'].astype('Int64')

    # broken API number
    df['api_no'].replace('04053-223300', '040532233800', inplace=True)

    df.to_pickle(pickle_file_name)

progress.value += 5
# print out the loaded dataframe
df
# Out:
# Reading SQL monthly volume data...
# C:\Users\dan\AppData\Local\Temp\ipykernel_52708\1570805987.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query_result, conn)
# C:\Users\dan\AppData\Local\Temp\ipykernel_52708\1570805987.py:33: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['api_no'].replace('04053-223300', '040532233800', inplace=True)
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 0        040010000100  40010000100    2017-01-01          1      2017
# 1        040010000100  40010000100    2017-02-01          2      2017
# 2        040010000100  40010000100    2017-03-01          3      2017
# 3        040010000100  40010000100    2017-04-01          4      2017
# 4        040010000100  40010000100    2017-05-01          5      2017
# ...               ...          ...           ...        ...       ...
# 1270377  042832029000  42832029000    2017-05-01          5      2017
# 1270378  042832029000  42832029000    2017-06-01          6      2017
# 1270379  042832029000  42832029000    2017-07-01          7      2017
# 1270380  042832029000  42832029000    2017-08-01          8      2017
# 1270381  042832029000  42832029000    2017-09-01          9      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 0                   00      Active            0           OG              A
# 1                   00      Active            0           OG              A
# 2                   00      Active            0           OG              A
# 3                   00      Active            0           OG              A
# 4                   00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 1270377             06        Idle            0           OG              A
# 1270378             06        Idle            0           OG              A
# 1270379             06        Idle            0           OG              A
# 1270380             06        Idle            0           OG              A
# 1270381             06        Idle            0           OG              A
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 0                10          50        1        4           0.0
# 1                10          50        0        4           0.0
# 2                10          50        0        4           0.0
# 3                10          50        0        4           0.0
# 4                10          50        2        4           0.0
# ...             ...         ...      ...      ...           ...
# 1270377          10          14        0        6           0.0
# 1270378           0          14        0        6           0.0
# 1270379           0          18        0        6           0.0
# 1270380           0          18        0        6           0.0
# 1270381           0          17        0        6           0.0
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 0                        5               9.0       31.0               1.0
# 1                        5               9.0       28.0               0.0
# 2                        5               3.0        7.0               0.0
# 3                        5               2.0       20.0               0.0
# 4                        5               0.0       31.0               2.0
# ...                    ...               ...        ...               ...
# 1270377               <NA>               0.0        0.0               0.0
# 1270378               <NA>               0.0        0.0               0.0
# 1270379               <NA>               0.0        0.0               0.0
# 1270380               <NA>               0.0        0.0               0.0
# 1270381               <NA>               0.0        0.0               0.0
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 0                       0.0              NaN                NaN       NaN
# 1                       0.0              NaN                NaN       NaN
# 2                       0.0              NaN                NaN       NaN
# 3                       0.0              NaN                NaN       NaN
# 4                       0.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 1270377                 0.0              NaN                NaN       NaN
# 1270378                 0.0              NaN                NaN       NaN
# 1270379                 0.0              NaN                NaN       NaN
# 1270380                 0.0              NaN                NaN       NaN
# 1270381                 0.0              NaN                NaN       NaN
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 0                      <NA>          <NA>        <NA>        404        00
# 1                      <NA>          <NA>        <NA>        404        00
# 2                      <NA>          <NA>        <NA>        404        00
# 3                      <NA>          <NA>        <NA>        404        00
# 4                      <NA>          <NA>        <NA>        404        00
# ...                     ...           ...         ...        ...       ...
# 1270377                <NA>          <NA>        <NA>        236        06
# 1270378                <NA>          <NA>        <NA>        236        06
# 1270379                <NA>          <NA>        <NA>        236        06
# 1270380                <NA>          <NA>        <NA>        236        06
# 1270381                <NA>          <NA>        <NA>        236        06
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID
# 0              00   Reported              1  100097216
# 1              00   Reported              1  100097216
# 2              00   Reported              1  100097216
# 3              00   Reported              1  100097216
# 4              00   Reported              1  100097216
# ...           ...        ...            ...        ...
# 1270377        03   Reported              1  100017895
# 1270378        03   Reported              1  100017895
# 1270379        03   Reported              1  100017895
# 1270380        03   Reported              1  100017895
# 1270381        03   Reported              1  100017895
#
# [1270382 rows x 32 columns]

# %%
pickle_file_name = f"{load_year}_well_records.pkl"
if os.path.exists(pickle_file_name) :
    print("Reading existing wells pickle...")
    df_wells = pd.read_pickle(pickle_file_name)
else:
    # Connect to the SQL Server to read the data tables
    # Starting in v18, they default encryption, which we definately don't need for this and locally
    conn_str = f"Driver={{ODBC Driver 18 for Sql Server}};Server=WhiteFractal-i7\\SQLEXPRESS;Database={mssql_db_name};Trusted_Connection=yes;Encrypt=no;"
    conn = pyodbc.connect(conn_str)

    print(f"Reading SQL well data... {mssql_db_name}.dbo.{mssql_tbl_name}")

    # This query composites the well tables together to remove duplicate rows by SystemEntryDate
    sql_str = f"SELECT * FROM [{mssql_db_name}].[dbo].[{mssql_tbl_name}]"

    col_rename = {
        'APINumber':'api_no',
        'FieldCode':'field_code',
        'AreaCode':'area_code',
        'PoolCode':'pool_code',
        'WellTypeCode':'well_type_cd',
        'Section':'loc_section',
        'Subsection':'loc_subsection',
        'Range':'loc_range',
        'BaseMeridian':'loc_bm',
        'Township':'loc_township',
        'CountyName':'county',
        'LeaseName':'lease_name',
        'FieldName':'field_name',
        'AreaName':'area_name',
        'PoolName':'pool_name',
        'OperatorName':'operator_name',
        'OperatorStatus':'operator_status',
        'OperatorReportingMethod':'report_type',
        'WellNumber':'well_number',
        'WellStatus':'well_status',
        'DistrictNumber':'district',
        'OperatorCode':'operator_cd' }

    df_wells = pd.read_sql_query(sql_str, conn)

    # cleanup the column names from the SQL Server db - getting them into mysql format right off the bat
    df_wells.rename(columns=col_rename, inplace=True)

    # convert the section to string and drop the <NA> strings
    df_wells['loc_section'] = df_wells['loc_section'].astype('Int64').astype(str)
    df_wells.replace({'loc_section':'<NA>'}, None, inplace=True)

    # set up the 12 digit API number
    df_wells['api_no'] = "04" + df_wells['api_no'] + "00"

    # broken API number
    df_wells.replace({'api_no':'04053-223300'}, '040532233800', inplace=True)

    # save the pickle for the next run
    df_wells.to_pickle(pickle_file_name)

progress.value += 5
# print out the loaded dataframe
df_wells
# Out:
# Reading SQL well data... WellProductionInjectionLegacy.dbo.2017CaliforniaOilAndGasWells
# C:\Users\dan\AppData\Local\Temp\ipykernel_52708\3528343423.py:40: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_wells = pd.read_sql_query(sql_str, conn)
#        district field_code area_code        api_no well_status loc_section  \
# 0             1        000        00  040370049400           I           4
# 1             1        000        00  040370116700           B           4
# 2             1        000        00  040712006500           P          29
# 3             1        000        00  040712006000           A          26
# 4             1        000        00  040712006100           P          28
# ...         ...        ...       ...           ...         ...         ...
# 277292        4        340        00  040306375500           N           5
# 277293        4        340        00  040306375500           N           5
# 277294        4        464        00  040296988200           A          24
# 277295        4        464        00  040296696000           A          24
# 277296        4        464        00  040295768000           P          24
#
#        loc_subsection loc_township loc_range loc_bm operator_cd  \
# 0                               1N       17W     SB       K2100
# 1                               1N       17W     SB       L2150
# 2                              30S       41E     MD       K1855
# 3                               3N        6W     SB       U0515
# 4                              31S       41E     SB       U0515
# ...               ...          ...       ...    ...         ...
# 277292           None          29S       28E     MD       C5640
# 277293           None          29S       28E     MD       C5640
# 277294                         11N       23W     SB       A0610
# 277295                         11N       23W     SB       A0610
# 277296                         11N       23W     SB       A0610
#
#                 lease_name well_number     field_name area_name  \
# 0                    Knapp           3      Any Field  Any Area
# 1               Lucky Star           1      Any Field  Any Area
# 2       Kitchens Oil Baron           1      Any Field  Any Area
# 3                  Federal        2-26      Any Field  Any Area
# 4                Kitchen's         101      Any Field  Any Area
# ...                    ...         ...            ...       ...
# 277292         San Joaquin        216R     Kern River  Any Area
# 277293         San Joaquin        216R     Kern River  Any Area
# 277294              Metson    SWD 4-24  Midway-Sunset  Any Area
# 277295              Metson    SWD 3-24  Midway-Sunset  Any Area
# 277296              Metson      C24-24  Midway-Sunset  Any Area
#
#                   operator_name operator_status report_type          county  \
# 0                   Frank Knapp               I          50     Los Angeles
# 1             Liu Cheng and Lin               I          50     Los Angeles
# 2           Charles L. Kitchens               I          50  San Bernardino
# 3       U. S. Geological Survey               I          50  San Bernardino
# 4       U. S. Geological Survey               I          50  San Bernardino
# ...                         ...             ...         ...             ...
# 277292      Chevron U.S.A. Inc.               A          99            Kern
# 277293      Chevron U.S.A. Inc.               A          99            Kern
# 277294          Aera Energy LLC               A          99            Kern
# 277295          Aera Energy LLC               A          99            Kern
# 277296          Aera Energy LLC               A          99            Kern
#
#        pool_code well_type_cd PoolWellTypeStatus SystemEntryDate  \
# 0             00           OG                  I      1987-09-01
# 1             00           OG                  B      1976-04-01
# 2             00           OG                  P      1993-04-01
# 3             00           OG                  I      1986-07-01
# 4             00           OG                  P      1986-07-01
# ...          ...          ...                ...             ...
# 277292        05           OG                  N      2018-04-05
# 277293        05           SC                  N      2018-04-05
# 277294        23           WD                  A      1983-10-01
# 277295        23           WD                  A      1982-05-01
# 277296        23           WD                  P      1978-11-01
#
#                  pool_name    PWT__ID
# 0        No Pool Breakdown  100000001
# 1        No Pool Breakdown  100000002
# 2        No Pool Breakdown  100000003
# 3        No Pool Breakdown  100000004
# 4        No Pool Breakdown  100000005
# ...                    ...        ...
# 277292          Kern River  100320508
# 277293          Kern River  100320509
# 277294  Tulare-San Joaquin  100320510
# 277295  Tulare-San Joaquin  100320511
# 277296  Tulare-San Joaquin  100320512
#
# [277297 rows x 25 columns]

# %%
df_wells['loc_section'].value_counts()
# Out:
# loc_section
# 29    13227
# 2     12989
# 33    11887
# 34    10767
# 31    10674
# 3     10582
# 36     9830
# 4      9263
# 19     8979
# 1      8760
# 22     8632
# 35     8528
# 32     8284
# 26     7855
# 28     7558
# 6      7442
# 11     7281
# 30     7085
# 21     7044
# 14     6945
# 18     6600
# 12     6566
# 5      6523
# 27     6519
# 13     6366
# 15     6343
# 20     6234
# 8      6219
# 25     6196
# 16     6156
# 24     6140
# 17     5081
# 23     4877
# 7      4850
# 9      4850
# 10     4064
# Name: count, dtype: int64

# %%
original_cols = df.columns
original_cols
# Out:
# Index(['api_no', 'api_no_int', 'prod_inj_date', 'vol_month', 'vol_year',
#        'well_status_no', 'well_status', 'prod_or_inj', 'well_type_cd',
#        'well_status_cd', 'casing_psi', 'tubing_psi', 'gas_btu', 'well_mo',
#        'oil_api_grav', 'water_disposition', 'oil_prod_vol_bbl', 'prod_days',
#        'gas_prod_vol_mcf', 'water_prod_vol_bbl', 'gas_inj_vol_mcf',
#        'water_inj_vol_bbl', 'inj_days', 'surf_inj_press_psi', 'water_source',
#        'water_kind', 'field_code', 'area_code', 'pool_code', 'rep_or_est',
#        'rep_or_est_cd', 'PWT__ID'],
#       dtype='object')

# %%
# setting a column type as category can allow us to organize/sort the categories manually
# i.e. df["Status"].cat.set_categories(["won","pending","presented","declined"],inplace=True)
# I'm adding a new category 'Inactive' later in my calculations, so would need to add it to the category set here
# df['well_status'] = df['well_status'].astype('category')

# Set the index of the df_wells to the API number - actually doing this towards the end, just before the merge call
# Turns out the unique index is API / field_code / area_code / pool_code...
#    they didn't bother suffixing the API for a different pool for many of the old wells
#df_wells.set_index(['API','field_code','pool_code','well_type_cd'], drop=True, inplace=True, verify_integrity=True)
#print(f"Index of df_wells_from_mv: {df_wells.index}")

# %%
# df['prod_inj_date'] = df['prod_inj_date'].astype('date') # python dataframe calls this an object, but it seems to be correctly assinging Date datatype under the hood
print(f"datatype of {type(df['prod_inj_date'][0])}")
# Out:
# datatype of <class 'datetime.date'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1270382 entries, 0 to 1270381
# Data columns (total 32 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   api_no              1270382 non-null  object
#  1   api_no_int          1270382 non-null  int64
#  2   prod_inj_date       1270382 non-null  object
#  3   vol_month           1270382 non-null  int64
#  4   vol_year            1270382 non-null  int64
#  5   well_status_no      1270382 non-null  object
#  6   well_status         1270382 non-null  object
#  7   prod_or_inj         1270382 non-null  int64
#  8   well_type_cd        1270382 non-null  object
#  9   well_status_cd      1270382 non-null  object
#  10  casing_psi          1024107 non-null  Int64
#  11  tubing_psi          1023947 non-null  Int64
#  12  gas_btu             1026596 non-null  Int64
#  13  well_mo             949034 non-null   Int64
#  14  oil_api_grav        1021856 non-null  float64
#  15  water_disposition   824496 non-null   Int64
#  16  oil_prod_vol_bbl    1029963 non-null  float64
#  17  prod_days           1029092 non-null  float64
#  18  gas_prod_vol_mcf    1026596 non-null  float64
#  19  water_prod_vol_bbl  1029482 non-null  float64
#  20  gas_inj_vol_mcf     290317 non-null   float64
#  21  water_inj_vol_bbl   287801 non-null   float64
#  22  inj_days            292806 non-null   float64
#  23  surf_inj_press_psi  292324 non-null   Int64
#  24  water_source        242743 non-null   Int64
#  25  water_kind          224837 non-null   Int64
#  26  field_code          1270382 non-null  object
#  27  area_code           1270382 non-null  object
#  28  pool_code           1270382 non-null  object
#  29  rep_or_est          1270382 non-null  object
#  30  rep_or_est_cd       1270382 non-null  int64
#  31  PWT__ID             1270382 non-null  int64
# dtypes: Int64(8), float64(8), int64(6), object(10)
# memory usage: 319.8+ MB

# %%
df_wells.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277297 entries, 0 to 277296
# Data columns (total 25 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   district            277297 non-null  object
#  1   field_code          277297 non-null  object
#  2   area_code           277297 non-null  object
#  3   api_no              277297 non-null  object
#  4   well_status         277297 non-null  object
#  5   loc_section         277196 non-null  object
#  6   loc_subsection      193829 non-null  object
#  7   loc_township        277196 non-null  object
#  8   loc_range           277196 non-null  object
#  9   loc_bm              277195 non-null  object
#  10  operator_cd         277297 non-null  object
#  11  lease_name          228409 non-null  object
#  12  well_number         277297 non-null  object
#  13  field_name          277297 non-null  object
#  14  area_name           277297 non-null  object
#  15  operator_name       277297 non-null  object
#  16  operator_status     277297 non-null  object
#  17  report_type         277297 non-null  object
#  18  county              277297 non-null  object
#  19  pool_code           277297 non-null  object
#  20  well_type_cd        277297 non-null  object
#  21  PoolWellTypeStatus  277297 non-null  object
#  22  SystemEntryDate     277297 non-null  datetime64[ns]
#  23  pool_name           277297 non-null  object
#  24  PWT__ID             277297 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(23)
# memory usage: 52.9+ MB

# %% [markdown]
# ## Examine the categorical fields - these have discrete codes or strings
#
# ### investigate categoricals from the monthly volumes table

# %%
# Examine the report type category
aggfunc = {
    'api_no'                : pd.Series.nunique,
    'prod_days'             :'sum',
    'inj_days'              :'sum',
    'oil_prod_vol_bbl'      :'sum',
    'gas_prod_vol_mcf'      :'sum',
    'gas_inj_vol_mcf'       :'sum',
    'water_inj_vol_bbl'     :'sum'
}

df.pivot_table(index=['rep_or_est'], values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#             api_no  gas_inj_vol_mcf  gas_prod_vol_mcf   inj_days  \
# rep_or_est
# Reported     99853     1.859618e+09      2.020869e+09  3810208.0
#
#             oil_prod_vol_bbl   prod_days  water_inj_vol_bbl
# rep_or_est
# Reported         173948017.0  16594158.0       2.822416e+09

# %%
# Examine the well status category
df.pivot_table(index='well_status', values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#              api_no  gas_inj_vol_mcf  gas_prod_vol_mcf   inj_days  \
# well_status
# Active        62424     1.628976e+09      2.013686e+09  3761986.0
# Idle          41772     2.172848e+08      7.183102e+06    46220.0
# New             252     0.000000e+00      0.000000e+00        0.0
# Observ         9660     1.335662e+07      0.000000e+00     2002.0
# Plugged         119     0.000000e+00      0.000000e+00        0.0
#
#              oil_prod_vol_bbl   prod_days  water_inj_vol_bbl
# well_status
# Active            173945363.0  16588910.0       2.821904e+09
# Idle                   2653.0      5177.0       4.823520e+05
# New                       0.0         7.0       0.000000e+00
# Observ                    0.0        28.0       2.947600e+04
# Plugged                   1.0        36.0       0.000000e+00

# %%
# Examine the well type category
df.pivot_table(index='well_type_cd', values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#               api_no  gas_inj_vol_mcf  gas_prod_vol_mcf   inj_days  \
# well_type_cd
# AI                 8     0.000000e+00      0.000000e+00        0.0
# DG              2240     0.000000e+00      2.019038e+07        0.0
# GD                96     3.532029e+06      0.000000e+00    19751.0
# GS               382     1.816170e+09      1.818788e+09   371724.0
# OB              3721     0.000000e+00      0.000000e+00        0.0
# OG             76888     0.000000e+00      1.818914e+08        0.0
# PM               131     3.988536e+07      0.000000e+00    35347.0
# SC             12297     4.040000e+03      0.000000e+00   208630.0
# SF              8455     0.000000e+00      0.000000e+00  1366238.0
# WD              1592     2.111100e+04      0.000000e+00   252810.0
# WF              6861     5.431000e+03      0.000000e+00  1555708.0
# WS               128     0.000000e+00      0.000000e+00        0.0
#
#               oil_prod_vol_bbl   prod_days  water_inj_vol_bbl
# well_type_cd
# AI                         0.0         0.0       0.000000e+00
# DG                     36842.0    357264.0       0.000000e+00
# GD                         0.0         0.0       2.511200e+04
# GS                    195999.0    254524.0       0.000000e+00
# OB                       557.0       608.0       0.000000e+00
# OG                 173714619.0  15975475.0       0.000000e+00
# PM                         0.0         0.0       3.673000e+03
# SC                         0.0         0.0       1.331614e+08
# SF                         0.0         0.0       3.941578e+08
# WD                         0.0         0.0       6.870352e+08
# WF                         0.0         0.0       1.608033e+09
# WS                         0.0      6287.0       0.000000e+00

# %%
df[df['well_type_cd'] == 'INJ']
# Out:
# Empty DataFrame
# Columns: [api_no, api_no_int, prod_inj_date, vol_month, vol_year, well_status_no, well_status, prod_or_inj, well_type_cd, well_status_cd, casing_psi, tubing_psi, gas_btu, well_mo, oil_api_grav, water_disposition, oil_prod_vol_bbl, prod_days, gas_prod_vol_mcf, water_prod_vol_bbl, gas_inj_vol_mcf, water_inj_vol_bbl, inj_days, surf_inj_press_psi, water_source, water_kind, field_code, area_code, pool_code, rep_or_est, rep_or_est_cd, PWT__ID]
# Index: []

# %% [markdown]
# ### Well Type Conversion Code cleanup
#
# <a id='well_type_cleanup'></a>
#
# <a href='#well_type_codes'>Link to Well Type Codes</a>
#
# | No. | Well Type | Definition                             |
# |:---:|:---------:|:---------------------------------------|
# |  0  |    AI     | Air Injector                           |
# |  1  |    DG     | Dry Gas Production                     |
# |  C  |    GD     | Gas Disposal Injector                  |
# |  3  |    GS     | Gas Storage Injector/Producer          |
# |  5  |    LG     | Liquid Petroleum Gas Injector/Producer |
# |  B  |    OB     | Observation Well                       |
# |  2  |    OG     | Oil & Gas Production                   |
# |  4  |    PM     | Pressure Maintenance Injector          |
# |  A  |    SC     | Steam Flood Cyclic(?)                  |
# |  8  |    SF     | Steam Flood Injector                   |
# |  6  |    WD     | Water Disposal Injector                |
# |  7  |    WF     | Water Flood Injector                   |
# |  9  |    WS     | Water Source Injector                  |

# %%
# Destination table has well type code of 2 chars, so fix the "Multi" ones
df.loc[df['well_type_cd'] == 'Multi', 'well_type_cd'] = 'ML'
df.loc[df['well_type_cd'] == 'GAS', 'well_type_cd'] = 'DG'

# For well types Unknown, try to set it by imputation later
df.loc[df['well_type_cd'] == 'UNK', 'well_type_cd'] = None

# I'm going to call all the INJ well types Cyclic Steam for now, they were corrected in later years (ex. 040192614700 has INJ in 2019, then SF in 2024)
df.loc[df['well_type_cd'] == 'INJ', 'well_type_cd'] = 'SC'
df.pivot_table(index='well_type_cd', values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#               api_no  gas_inj_vol_mcf  gas_prod_vol_mcf   inj_days  \
# well_type_cd
# AI                 8     0.000000e+00      0.000000e+00        0.0
# DG              2240     0.000000e+00      2.019038e+07        0.0
# GD                96     3.532029e+06      0.000000e+00    19751.0
# GS               382     1.816170e+09      1.818788e+09   371724.0
# OB              3721     0.000000e+00      0.000000e+00        0.0
# OG             76888     0.000000e+00      1.818914e+08        0.0
# PM               131     3.988536e+07      0.000000e+00    35347.0
# SC             12297     4.040000e+03      0.000000e+00   208630.0
# SF              8455     0.000000e+00      0.000000e+00  1366238.0
# WD              1592     2.111100e+04      0.000000e+00   252810.0
# WF              6861     5.431000e+03      0.000000e+00  1555708.0
# WS               128     0.000000e+00      0.000000e+00        0.0
#
#               oil_prod_vol_bbl   prod_days  water_inj_vol_bbl
# well_type_cd
# AI                         0.0         0.0       0.000000e+00
# DG                     36842.0    357264.0       0.000000e+00
# GD                         0.0         0.0       2.511200e+04
# GS                    195999.0    254524.0       0.000000e+00
# OB                       557.0       608.0       0.000000e+00
# OG                 173714619.0  15975475.0       0.000000e+00
# PM                         0.0         0.0       3.673000e+03
# SC                         0.0         0.0       1.331614e+08
# SF                         0.0         0.0       3.941578e+08
# WD                         0.0         0.0       6.870352e+08
# WF                         0.0         0.0       1.608033e+09
# WS                         0.0      6287.0       0.000000e+00

# %%
# Examine the well method of operation category
df.pivot_table(index='well_mo', values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#          api_no  gas_inj_vol_mcf  gas_prod_vol_mcf  inj_days  \
# well_mo
# 0          6668      240028647.0      1.296428e+07   44820.0
# 1          4778      928179093.0      1.106318e+09  131868.0
# 2            14              0.0      0.000000e+00       0.0
# 3         61994              0.0      1.392056e+08       0.0
# 4           606              0.0      3.996500e+05       0.0
# 5           523              0.0      1.553398e+06       0.0
# 6          2273              0.0      1.386898e+07       0.0
# 7           177              0.0      1.192985e+06       0.0
# 8          3850              0.0      2.045472e+06       0.0
#
#          oil_prod_vol_bbl   prod_days  water_inj_vol_bbl
# well_mo
# 0                251945.0     33474.0                0.0
# 1              12491438.0   1064591.0                0.0
# 2                  3727.0       757.0                0.0
# 3             134245607.0  13750743.0                0.0
# 4               1048502.0    139103.0                0.0
# 5               2435226.0    121429.0                0.0
# 6              15635552.0    653933.0                0.0
# 7                163214.0     16297.0                0.0
# 8               6312819.0    611251.0                0.0

# %%
# Examine the water disposal category
df.pivot_table(index='water_disposition', values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#                    api_no  gas_inj_vol_mcf  gas_prod_vol_mcf  inj_days  \
# water_disposition
# 0                    5324      628798791.0       351223425.0   95621.0
# 1                    1912       32917577.0         7327006.0    1753.0
# 2                      96              0.0               0.0       0.0
# 3                    2412              0.0          541428.0       0.0
# 4                     635        5841173.0         5881179.0    7783.0
# 5                   52974      334649587.0       571469661.0   45634.0
# 6                    7941      174166040.0       352019010.0   27128.0
# 8                      13              0.0               0.0       0.0
#
#                    oil_prod_vol_bbl   prod_days  water_inj_vol_bbl
# water_disposition
# 0                         1339310.0    127594.0                0.0
# 1                         3519289.0    359134.0                0.0
# 2                          141952.0     25512.0                0.0
# 3                         5053990.0    694611.0                0.0
# 4                          924969.0    121147.0                0.0
# 5                       138398401.0  12832238.0                0.0
# 6                        16799509.0   1711116.0                0.0
# 8                               0.0         0.0                0.0

# %%
# Examine the water kind category
df.pivot_table(index='water_kind', values=['api_no','prod_days','inj_days','oil_prod_vol_bbl','gas_prod_vol_mcf','gas_inj_vol_mcf','water_inj_vol_bbl'], aggfunc=aggfunc,  observed=False)
# Out:
#             api_no  gas_inj_vol_mcf  gas_prod_vol_mcf   inj_days  \
# water_kind
# 0              919      946517116.0       814127013.0   165085.0
# 1            12816       39669732.0               0.0  2265598.0
# 2             2318           4040.0               0.0   299678.0
# 3             9477              0.0               0.0   627634.0
# 4             1046         430873.0               0.0   113181.0
#
#             oil_prod_vol_bbl  prod_days  water_inj_vol_bbl
# water_kind
# 0                   195980.0    74711.0       2.367776e+06
# 1                        0.0        0.0       2.100605e+09
# 2                        0.0        0.0       2.450701e+08
# 3                        0.0        0.0       3.338289e+08
# 4                        0.0        0.0       3.389120e+07

# %%
progress.value += 1

# %% [markdown]
# ### investigate categoricals in the wells table

# %%
aggfunc = {'api_no':pd.Series.nunique}
df_wells.pivot_table(index='well_type_cd', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#               api_no
# well_type_cd
# AI               201
# DG              6025
# GD               165
# GS               561
# LG                 7
# OB              5722
# OG            156574
# PM               353
# SC             62727
# SF             18441
# WD              3316
# WF             15465
# WS               331

# %%
# Same fix for wells as the MV data above, Destination table has well type code of 2 chars, so fix the "Multi" ones
df_wells.loc[df_wells['well_type_cd'] == 'Multi', 'well_type_cd'] = 'ML'
df_wells.loc[df_wells['well_type_cd'] == 'GAS', 'well_type_cd'] = 'DG'

# I'm going to call all the INJ well types Cyclic Steam for now, they were corrected in later years (ex. 040192614700 has INJ in 2019, then SF in 2024)
df_wells.loc[df_wells['well_type_cd'] == 'INJ', 'well_type_cd'] = 'SC'
df_wells.loc[df_wells['well_type_cd'] == 'UNK', 'well_type_cd'] = None
df_wells.pivot_table(index='well_type_cd', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#               api_no
# well_type_cd
# AI               201
# DG              6025
# GD               165
# GS               561
# LG                 7
# OB              5722
# OG            156574
# PM               353
# SC             62727
# SF             18441
# WD              3316
# WF             15465
# WS               331

# %%
df_wells.pivot_table(index='PoolWellTypeStatus', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#                     api_no
# PoolWellTypeStatus
# A                    85339
# B                      166
# C                     9405
# I                    13954
# N                     4443
# O                     2313
# P                    90515

# %%
df_wells.pivot_table(index='well_status', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#              api_no
# well_status
# A             84219
# B               163
# C              8077
# I             14395
# N              3232
# P             78794

# %%
df_wells.pivot_table(index='district', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#           api_no
# district
# 1          19400
# 2          10426
# 3           8981
# 4         134163
# 5          10573
# 6           5336

# %%
df_wells.pivot_table(index='loc_bm', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#         api_no
# loc_bm
# H           69
# MD      145150
# SB       43622

# %%
df_wells.pivot_table(index='operator_status', values=['api_no'], aggfunc=aggfunc,  observed=False)
# Out:
#                  api_no
# operator_status
# A                161440
# I                 27439

# %%
progress.value += 1

# %% [markdown]
# ## Add helper columns
#
# ### First up is the calculated `IsActive` column which is going to be based on volumes
# Note that Estimated volumes ar ealso valid, particularly on injectors
#
# **TODO**: the wells can have  production volumes across multiple api_key values, and the record type 'Estimated', so it would not be correct to have multiple well completions all reporting production days - that should really stay at the well head, aka the top level API. So need a check at the end for active_days > dats in the record month and set them to the record month day count

# %%
# Creating our own Active flag based on Reported volumes and activity
df['IsActive'] = (df['water_disposition']>0) | (df['oil_prod_vol_bbl']>0) | (df['gas_prod_vol_mcf']>0) | (df['water_inj_vol_bbl']>0) | (df['gas_inj_vol_mcf']>0) | (df['water_inj_vol_bbl']>0) | (df['water_source']>0)
df
# Out:
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 0        040010000100  40010000100    2017-01-01          1      2017
# 1        040010000100  40010000100    2017-02-01          2      2017
# 2        040010000100  40010000100    2017-03-01          3      2017
# 3        040010000100  40010000100    2017-04-01          4      2017
# 4        040010000100  40010000100    2017-05-01          5      2017
# ...               ...          ...           ...        ...       ...
# 1270377  042832029000  42832029000    2017-05-01          5      2017
# 1270378  042832029000  42832029000    2017-06-01          6      2017
# 1270379  042832029000  42832029000    2017-07-01          7      2017
# 1270380  042832029000  42832029000    2017-08-01          8      2017
# 1270381  042832029000  42832029000    2017-09-01          9      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 0                   00      Active            0           OG              A
# 1                   00      Active            0           OG              A
# 2                   00      Active            0           OG              A
# 3                   00      Active            0           OG              A
# 4                   00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 1270377             06        Idle            0           OG              A
# 1270378             06        Idle            0           OG              A
# 1270379             06        Idle            0           OG              A
# 1270380             06        Idle            0           OG              A
# 1270381             06        Idle            0           OG              A
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 0                10          50        1        4           0.0
# 1                10          50        0        4           0.0
# 2                10          50        0        4           0.0
# 3                10          50        0        4           0.0
# 4                10          50        2        4           0.0
# ...             ...         ...      ...      ...           ...
# 1270377          10          14        0        6           0.0
# 1270378           0          14        0        6           0.0
# 1270379           0          18        0        6           0.0
# 1270380           0          18        0        6           0.0
# 1270381           0          17        0        6           0.0
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 0                        5               9.0       31.0               1.0
# 1                        5               9.0       28.0               0.0
# 2                        5               3.0        7.0               0.0
# 3                        5               2.0       20.0               0.0
# 4                        5               0.0       31.0               2.0
# ...                    ...               ...        ...               ...
# 1270377               <NA>               0.0        0.0               0.0
# 1270378               <NA>               0.0        0.0               0.0
# 1270379               <NA>               0.0        0.0               0.0
# 1270380               <NA>               0.0        0.0               0.0
# 1270381               <NA>               0.0        0.0               0.0
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 0                       0.0              NaN                NaN       NaN
# 1                       0.0              NaN                NaN       NaN
# 2                       0.0              NaN                NaN       NaN
# 3                       0.0              NaN                NaN       NaN
# 4                       0.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 1270377                 0.0              NaN                NaN       NaN
# 1270378                 0.0              NaN                NaN       NaN
# 1270379                 0.0              NaN                NaN       NaN
# 1270380                 0.0              NaN                NaN       NaN
# 1270381                 0.0              NaN                NaN       NaN
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 0                      <NA>          <NA>        <NA>        404        00
# 1                      <NA>          <NA>        <NA>        404        00
# 2                      <NA>          <NA>        <NA>        404        00
# 3                      <NA>          <NA>        <NA>        404        00
# 4                      <NA>          <NA>        <NA>        404        00
# ...                     ...           ...         ...        ...       ...
# 1270377                <NA>          <NA>        <NA>        236        06
# 1270378                <NA>          <NA>        <NA>        236        06
# 1270379                <NA>          <NA>        <NA>        236        06
# 1270380                <NA>          <NA>        <NA>        236        06
# 1270381                <NA>          <NA>        <NA>        236        06
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID  IsActive
# 0              00   Reported              1  100097216      True
# 1              00   Reported              1  100097216      True
# 2              00   Reported              1  100097216      True
# 3              00   Reported              1  100097216      True
# 4              00   Reported              1  100097216      True
# ...           ...        ...            ...        ...       ...
# 1270377        03   Reported              1  100017895      <NA>
# 1270378        03   Reported              1  100017895      <NA>
# 1270379        03   Reported              1  100017895      <NA>
# 1270380        03   Reported              1  100017895      <NA>
# 1270381        03   Reported              1  100017895      <NA>
#
# [1270382 rows x 33 columns]

# %% [markdown]
# ### Then add the actual `active_days` field, which is a corrected Production + Injection prod_days field

# %%
df['active_days'] = df['prod_days'].where(df['IsActive'] == True, 0).fillna(0) + df['inj_days'].where(df['IsActive'] == True, 0).fillna(0)
df
# Out:
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 0        040010000100  40010000100    2017-01-01          1      2017
# 1        040010000100  40010000100    2017-02-01          2      2017
# 2        040010000100  40010000100    2017-03-01          3      2017
# 3        040010000100  40010000100    2017-04-01          4      2017
# 4        040010000100  40010000100    2017-05-01          5      2017
# ...               ...          ...           ...        ...       ...
# 1270377  042832029000  42832029000    2017-05-01          5      2017
# 1270378  042832029000  42832029000    2017-06-01          6      2017
# 1270379  042832029000  42832029000    2017-07-01          7      2017
# 1270380  042832029000  42832029000    2017-08-01          8      2017
# 1270381  042832029000  42832029000    2017-09-01          9      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 0                   00      Active            0           OG              A
# 1                   00      Active            0           OG              A
# 2                   00      Active            0           OG              A
# 3                   00      Active            0           OG              A
# 4                   00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 1270377             06        Idle            0           OG              A
# 1270378             06        Idle            0           OG              A
# 1270379             06        Idle            0           OG              A
# 1270380             06        Idle            0           OG              A
# 1270381             06        Idle            0           OG              A
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 0                10          50        1        4           0.0
# 1                10          50        0        4           0.0
# 2                10          50        0        4           0.0
# 3                10          50        0        4           0.0
# 4                10          50        2        4           0.0
# ...             ...         ...      ...      ...           ...
# 1270377          10          14        0        6           0.0
# 1270378           0          14        0        6           0.0
# 1270379           0          18        0        6           0.0
# 1270380           0          18        0        6           0.0
# 1270381           0          17        0        6           0.0
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 0                        5               9.0       31.0               1.0
# 1                        5               9.0       28.0               0.0
# 2                        5               3.0        7.0               0.0
# 3                        5               2.0       20.0               0.0
# 4                        5               0.0       31.0               2.0
# ...                    ...               ...        ...               ...
# 1270377               <NA>               0.0        0.0               0.0
# 1270378               <NA>               0.0        0.0               0.0
# 1270379               <NA>               0.0        0.0               0.0
# 1270380               <NA>               0.0        0.0               0.0
# 1270381               <NA>               0.0        0.0               0.0
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 0                       0.0              NaN                NaN       NaN
# 1                       0.0              NaN                NaN       NaN
# 2                       0.0              NaN                NaN       NaN
# 3                       0.0              NaN                NaN       NaN
# 4                       0.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 1270377                 0.0              NaN                NaN       NaN
# 1270378                 0.0              NaN                NaN       NaN
# 1270379                 0.0              NaN                NaN       NaN
# 1270380                 0.0              NaN                NaN       NaN
# 1270381                 0.0              NaN                NaN       NaN
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 0                      <NA>          <NA>        <NA>        404        00
# 1                      <NA>          <NA>        <NA>        404        00
# 2                      <NA>          <NA>        <NA>        404        00
# 3                      <NA>          <NA>        <NA>        404        00
# 4                      <NA>          <NA>        <NA>        404        00
# ...                     ...           ...         ...        ...       ...
# 1270377                <NA>          <NA>        <NA>        236        06
# 1270378                <NA>          <NA>        <NA>        236        06
# 1270379                <NA>          <NA>        <NA>        236        06
# 1270380                <NA>          <NA>        <NA>        236        06
# 1270381                <NA>          <NA>        <NA>        236        06
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID  IsActive  active_days
# 0              00   Reported              1  100097216      True         31.0
# 1              00   Reported              1  100097216      True         28.0
# 2              00   Reported              1  100097216      True          7.0
# 3              00   Reported              1  100097216      True         20.0
# 4              00   Reported              1  100097216      True         31.0
# ...           ...        ...            ...        ...       ...          ...
# 1270377        03   Reported              1  100017895      <NA>          0.0
# 1270378        03   Reported              1  100017895      <NA>          0.0
# 1270379        03   Reported              1  100017895      <NA>          0.0
# 1270380        03   Reported              1  100017895      <NA>          0.0
# 1270381        03   Reported              1  100017895      <NA>          0.0
#
# [1270382 rows x 34 columns]

# %% [markdown]
# ### Create new status field that will be used going forward since the provided one is frequently inaccurate

# %%
# There are some wells that have an incorrect Idle status set while they are still injecting so overwrite that with the correct status of 'Active'
df['well_status2'] = df['well_status']
df.loc[df['IsActive'], 'well_status2'] = 'Active'
df.loc[df['IsActive']==False, 'well_status2'] = 'Inactive'
df
# Out:
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 0        040010000100  40010000100    2017-01-01          1      2017
# 1        040010000100  40010000100    2017-02-01          2      2017
# 2        040010000100  40010000100    2017-03-01          3      2017
# 3        040010000100  40010000100    2017-04-01          4      2017
# 4        040010000100  40010000100    2017-05-01          5      2017
# ...               ...          ...           ...        ...       ...
# 1270377  042832029000  42832029000    2017-05-01          5      2017
# 1270378  042832029000  42832029000    2017-06-01          6      2017
# 1270379  042832029000  42832029000    2017-07-01          7      2017
# 1270380  042832029000  42832029000    2017-08-01          8      2017
# 1270381  042832029000  42832029000    2017-09-01          9      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 0                   00      Active            0           OG              A
# 1                   00      Active            0           OG              A
# 2                   00      Active            0           OG              A
# 3                   00      Active            0           OG              A
# 4                   00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 1270377             06        Idle            0           OG              A
# 1270378             06        Idle            0           OG              A
# 1270379             06        Idle            0           OG              A
# 1270380             06        Idle            0           OG              A
# 1270381             06        Idle            0           OG              A
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 0                10          50        1        4           0.0
# 1                10          50        0        4           0.0
# 2                10          50        0        4           0.0
# 3                10          50        0        4           0.0
# 4                10          50        2        4           0.0
# ...             ...         ...      ...      ...           ...
# 1270377          10          14        0        6           0.0
# 1270378           0          14        0        6           0.0
# 1270379           0          18        0        6           0.0
# 1270380           0          18        0        6           0.0
# 1270381           0          17        0        6           0.0
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 0                        5               9.0       31.0               1.0
# 1                        5               9.0       28.0               0.0
# 2                        5               3.0        7.0               0.0
# 3                        5               2.0       20.0               0.0
# 4                        5               0.0       31.0               2.0
# ...                    ...               ...        ...               ...
# 1270377               <NA>               0.0        0.0               0.0
# 1270378               <NA>               0.0        0.0               0.0
# 1270379               <NA>               0.0        0.0               0.0
# 1270380               <NA>               0.0        0.0               0.0
# 1270381               <NA>               0.0        0.0               0.0
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 0                       0.0              NaN                NaN       NaN
# 1                       0.0              NaN                NaN       NaN
# 2                       0.0              NaN                NaN       NaN
# 3                       0.0              NaN                NaN       NaN
# 4                       0.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 1270377                 0.0              NaN                NaN       NaN
# 1270378                 0.0              NaN                NaN       NaN
# 1270379                 0.0              NaN                NaN       NaN
# 1270380                 0.0              NaN                NaN       NaN
# 1270381                 0.0              NaN                NaN       NaN
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 0                      <NA>          <NA>        <NA>        404        00
# 1                      <NA>          <NA>        <NA>        404        00
# 2                      <NA>          <NA>        <NA>        404        00
# 3                      <NA>          <NA>        <NA>        404        00
# 4                      <NA>          <NA>        <NA>        404        00
# ...                     ...           ...         ...        ...       ...
# 1270377                <NA>          <NA>        <NA>        236        06
# 1270378                <NA>          <NA>        <NA>        236        06
# 1270379                <NA>          <NA>        <NA>        236        06
# 1270380                <NA>          <NA>        <NA>        236        06
# 1270381                <NA>          <NA>        <NA>        236        06
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID  IsActive  active_days  \
# 0              00   Reported              1  100097216      True         31.0
# 1              00   Reported              1  100097216      True         28.0
# 2              00   Reported              1  100097216      True          7.0
# 3              00   Reported              1  100097216      True         20.0
# 4              00   Reported              1  100097216      True         31.0
# ...           ...        ...            ...        ...       ...          ...
# 1270377        03   Reported              1  100017895      <NA>          0.0
# 1270378        03   Reported              1  100017895      <NA>          0.0
# 1270379        03   Reported              1  100017895      <NA>          0.0
# 1270380        03   Reported              1  100017895      <NA>          0.0
# 1270381        03   Reported              1  100017895      <NA>          0.0
#
#         well_status2
# 0             Active
# 1             Active
# 2             Active
# 3             Active
# 4             Active
# ...              ...
# 1270377         Idle
# 1270378         Idle
# 1270379         Idle
# 1270380         Idle
# 1270381         Idle
#
# [1270382 rows x 35 columns]

# %%
progress.value += 1

# %% [markdown]
# # Wells table: Resolve some of the NULL values
# ## Use imputation if there are multiple entries for an api_no, otherwise set it to '00'

# %%
well_row_count = len(df_wells)
print(f"well_type_cd NULL row count {sum(df_wells['well_type_cd'].isna()):,} ({sum(df_wells['well_type_cd'].isna())/well_row_count:.0%})")

fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# First imputation, we can skip 'well_status' as a groupby since they appear to have the same NULL occurances
if sum(df_wells['well_type_cd'].isna()) > 0:
    df_wells['well_type_cd'] = df_wells['well_type_cd'].fillna(df_wells.groupby(['api_no','field_code','area_code'])['well_type_cd'].transform(fn_well_type))
    print(f"well_type_cd NULL row count {sum(df_wells['well_type_cd'].isna()):,} ({sum(df_wells['well_type_cd'].isna())/well_row_count:.1%})")
progress.value += 1
# Out:
# well_type_cd NULL row count 0 (0%)

# %%
if sum(df_wells['well_type_cd'].isna()) > 0:
    df_wells['well_type_cd'] = df_wells['well_type_cd'].fillna(df_wells.groupby(['api_no','field_code'])['well_type_cd'].transform(fn_well_type))
    print(f"well_type_cd NULL row count {sum(df_wells['well_type_cd'].isna()):,} ({sum(df_wells['well_type_cd'].isna())/well_row_count:.1%})")
progress.value += 1

# %%
if sum(df_wells['well_type_cd'].isna()) > 0:
    df_wells['well_type_cd'] = df_wells['well_type_cd'].fillna(df_wells.groupby(['api_no'])['well_type_cd'].transform(fn_well_type))
    print(f"well_type_cd NULL row count {sum(df_wells['well_type_cd'].isna()):,} ({sum(df_wells['well_type_cd'].isna())/well_row_count:.1%})")
progress.value += 1

# %%
# Fill any remaining NULLs with '00'
if sum(df_wells['well_type_cd'].isna()) > 0:
    df_wells['well_type_cd'] = df_wells['well_type_cd'].fillna('00')
    print(f"well_type_cd NULL row count {sum(df_wells['well_type_cd'].isna()):,} ({sum(df_wells['well_type_cd'].isna())/well_row_count:.1%})")
progress.value += 1

# %%
# Finally, make sure everything is a 2 letter code, or it will fail later b/c destination table has CHAR(2)
assert(len(df_wells[df_wells['well_type_cd'].str.len() > 2]) == 0)

# %% [markdown]
# # Monthly Values:  Resolve some of the NULL values by imputation

# %%
# There are some records that go null in the middle of the year, not sure why - going to fill NAs with the most common value for the well table
mv_row_count = len(df['api_no'])
print(f"monthly volume total row count {mv_row_count:,}")
print(f"well_type_cd NULL row count {sum(df['well_type_cd'].isna()):,} ({sum(df['well_type_cd'].isna())/mv_row_count:.0%})")
print(f"well_status NULL count {sum(df['well_status'].isna()):,} ({sum(df['well_status'].isna())/mv_row_count:.0%})")
print(f"water_disposition NULL count {sum(df['water_disposition'].isna()):,} ({sum(df['water_disposition'].isna())/mv_row_count:.0%})")
print(f"MO NULL count {sum(df['well_mo'].isna()):,} ({sum(df['well_mo'].isna())/mv_row_count:.0%})")
print(f"water_kind NULL count {sum(df['water_kind'].isna()):,} ({sum(df['water_kind'].isna())/mv_row_count:.0%})")
print(f"water_source NULL count {sum(df['water_source'].isna()):,} ({sum(df['water_source'].isna())/mv_row_count:.0%})")
# Out:
# monthly volume total row count 1,270,382
# well_type_cd NULL row count 0 (0%)
# well_status NULL count 0 (0%)
# water_disposition NULL count 445,886 (35%)
# MO NULL count 321,348 (25%)
# water_kind NULL count 1,045,545 (82%)
# water_source NULL count 1,027,639 (81%)

# %% [markdown]
# ### Monthly Values: Impute with well_type_cd : group by api_no/field_code/area_code/pool_code
# While looking through the data (when trying to see if I could do a set_index on the DataFrame),
# I found that this grouping mainly identified common well data, though not 100% it reduces a lot of the monthly data noise

# %%
fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# First imputation, we can skip 'well_status' as a groupby since they appear to have the same NULL occurances
if df['well_type_cd'].isna().sum() > 0:
    df['well_type_cd'] = df['well_type_cd'].fillna(df.groupby(['api_no','field_code','area_code','pool_code'])['well_type_cd'].transform(fn_well_type))
    print(f"well_type_cd NULL row count {sum(df['well_type_cd'].isna()):,} ({sum(df['well_type_cd'].isna())/mv_row_count:.0%})")

progress.value += 1

# %%
# This is the best it gets with this grouping by api_no and attributes, going all the way down to api_no only gives the same result
if df['well_type_cd'].isna().sum() > 0:
    df['well_type_cd'] = df['well_type_cd'].fillna(df.groupby(['api_no','field_code','area_code'])['well_type_cd'].transform(fn_well_type))
    print(f"well_type_cd NULL row count {sum(df['well_type_cd'].isna()):,} ({sum(df['well_type_cd'].isna())/mv_row_count:.0%})")

progress.value += 1

# %%
# Finally, make sure everything is a 2 letter code, or it will fail later b/c destination table has CHAR(2)
assert(len(df[df['well_type_cd'].str.len() > 2]) == 0)

# %% [markdown]
# ### Monthly Values: Impute with well_status : group by api_no/field_code/area_code/pool_code

# %%
print(f"Current well status NULL counts: {df['well_status'].isna().sum()}")
print(f"Current well status 2 NULL counts: {df['well_status2'].isna().sum()}")
df['well_status'].value_counts()
# Out:
# Current well status NULL counts: 0
# Current well status 2 NULL counts: 0
# well_status
# Active     744723
# Idle       418765
# Observ     104572
# New          2021
# Plugged       301
# Name: count, dtype: int64

# %%
fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# I don't want to impute well_status from other records like I did for well_type, since this is really just an indicator of whether the well is active or not
# First imputation
if df['well_status'].isna().sum() > 0:
    df['well_status'] = df['well_status'].fillna(np.where(df['IsActive'] == True, 'Active', None))
    print(f"well_status NULL row count {sum(df['well_status'].isna()):,} ({sum(df['well_status'].isna())/mv_row_count:.0%})")

progress.value += 1

# %% [markdown]
# ### Monthly Values: Impute with water_disposition : group by api_no/field_code/area_code/pool_code

# %%
fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# First imputation
df['water_disposition'] = df['water_disposition'].fillna(df.groupby(['api_no','field_code','area_code','pool_code'])['water_disposition'].transform(fn_well_type))
print(f"water_disposition NULL row count {sum(df['water_disposition'].isna()):,} ({sum(df['water_disposition'].isna())/mv_row_count:.0%})")

progress.value += 1
# Out:
# water_disposition NULL row count 380,848 (30%)

# %%
# this is as good as it gets
df['water_disposition'] = df['water_disposition'].fillna(df.groupby(['api_no','field_code','area_code'])['water_disposition'].transform(fn_well_type))
print(f"water_disposition NULL row count {sum(df['water_disposition'].isna()):,} ({sum(df['water_disposition'].isna())/mv_row_count:.0%})")
progress.value += 1
# Out:
# water_disposition NULL row count 380,085 (30%)

# %% [markdown]
# ### Monthly Values: Impute with MO : group by api_no/field_code/area_code/pool_code

# %%
fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# imputation
df['well_mo'] = df['well_mo'].fillna(df.groupby(['PWT__ID'])['well_mo'].transform(fn_well_type))
print(f"MO NULL row count {sum(df['PWT__ID'].isna()):,} ({sum(df['well_mo'].isna())/mv_row_count:.0%})")
progress.value += 1
# Out:
# MO NULL row count 0 (24%)

# %% [markdown]
# ### Monthly Values: Impute with WATKIND : group by api_no/field_code/area_code/pool_code

# %%
fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# imputation
df['water_kind'] = df['water_kind'].fillna(df.groupby(['PWT__ID'])['water_kind'].transform(fn_well_type))
print(f"water_kind NULL row count {sum(df['water_kind'].isna()):,} ({sum(df['water_kind'].isna())/mv_row_count:.0%})")
progress.value += 1
# Out:
# water_kind NULL row count 1,040,844 (82%)

# %% [markdown]
# ### Monthly Values: Impute with water_source : group by api_no/field_code/area_code/pool_code

# %%
fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# imputation
df['water_source'] = df['water_source'].fillna(df.groupby(['PWT__ID'])['water_source'].transform(fn_well_type))
print(f"water_source NULL row count {sum(df['water_source'].isna()):,} ({sum(df['water_source'].isna())/mv_row_count:.0%})")
progress.value += 1
# Out:
# water_source NULL row count 1,025,884 (81%)

# %%
# This idea fell by the wayside since CalGEM actually just aggregates all the api_no data together for their charts etc.
# I thought I could add an api_key helper column to the wells table, to use this as a DataFrame index later but there's too much noise
# Note that the monthly vol table already has this created from the SQL
# the api_key is api_no+field_code+area_code+pool_code
#df_wells['api_key'] = df_wells['api_no'] + "-" + df_wells['field_code'] +"-" + df_wells['area_code'] + "-" + df_wells['pool_code'] + "-" + df_wells['well_type_cd']
#df_wells

# %%
# after we've filled in the blanks at the well level, some categorical fields with NaN can be set to zero, which means "Not Applicable"
# I need all the categoricals to not have NULLs before I do the CHANGED column calculations below, NaN throws off the CHANGED calc
df['well_status']       = df['well_status'].fillna("00")
df['well_type_cd']      = df['well_type_cd'].fillna("00") # this needs to be a string to match the rest of the
df['water_disposition'] = df['water_disposition'].fillna(0)
df['well_mo']           = df['well_mo'].fillna(0)
df['water_source']      = df['water_source'].fillna(0)
df['water_kind']        = df['water_kind'].fillna(0)

# This field will always either be Reported or Estimated. If it's empty, then Estimated.
df['rep_or_est'] = df['rep_or_est'].fillna('Estimated')

# All the categoricals should be non-null at this point, which is import for checking for changes in the next section
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1270382 entries, 0 to 1270381
# Data columns (total 35 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   api_no              1270382 non-null  object
#  1   api_no_int          1270382 non-null  int64
#  2   prod_inj_date       1270382 non-null  object
#  3   vol_month           1270382 non-null  int64
#  4   vol_year            1270382 non-null  int64
#  5   well_status_no      1270382 non-null  object
#  6   well_status         1270382 non-null  object
#  7   prod_or_inj         1270382 non-null  int64
#  8   well_type_cd        1270382 non-null  object
#  9   well_status_cd      1270382 non-null  object
#  10  casing_psi          1024107 non-null  Int64
#  11  tubing_psi          1023947 non-null  Int64
#  12  gas_btu             1026596 non-null  Int64
#  13  well_mo             1270382 non-null  Int64
#  14  oil_api_grav        1021856 non-null  float64
#  15  water_disposition   1270382 non-null  Int64
#  16  oil_prod_vol_bbl    1029963 non-null  float64
#  17  prod_days           1029092 non-null  float64
#  18  gas_prod_vol_mcf    1026596 non-null  float64
#  19  water_prod_vol_bbl  1029482 non-null  float64
#  20  gas_inj_vol_mcf     290317 non-null   float64
#  21  water_inj_vol_bbl   287801 non-null   float64
#  22  inj_days            292806 non-null   float64
#  23  surf_inj_press_psi  292324 non-null   Int64
#  24  water_source        1270382 non-null  Int64
#  25  water_kind          1270382 non-null  Int64
#  26  field_code          1270382 non-null  object
#  27  area_code           1270382 non-null  object
#  28  pool_code           1270382 non-null  object
#  29  rep_or_est          1270382 non-null  object
#  30  rep_or_est_cd       1270382 non-null  int64
#  31  PWT__ID             1270382 non-null  int64
#  32  IsActive            1022203 non-null  boolean
#  33  active_days         1270382 non-null  float64
#  34  well_status2        1270382 non-null  object
# dtypes: Int64(8), boolean(1), float64(9), int64(6), object(11)
# memory usage: 341.7+ MB

# %%
# Add some helper columns, these will calculate when the monthly attributes change during the year
# note - first the data needs to be sorted by well ID and then date, and then we're effectively doing a Partition style calculation using python
df.sort_values(by=['PWT__ID','prod_inj_date'], inplace=True)

# a_itr should be a groupby iterator for a specific col to pivot and a col to iterate over
# a_col_name should be an existing column in the original pre-groupby DataFrame to populate, similar to what a Transform method would do
# a_df is the dataframe to make the changes into
# also everything should be sorted in the order it's going to be grouped and checked for changes; in this case, api_no and prod_inj_date
# NOTE: this methodology is obsolete
#   this takes about 20 minutes to run all the changed categories with a full year's data - using vectorized transforms takes about 4 min
def flag_changes( a_itr, a_col_name, a_df):
    idx = 0
    for i in a_itr:
        last_x = None
        s = f"{i[0]}: "
        n = 0
        for x in i[1]:
            s = f"{s} {x}"

            if n == 0:
                # first row of the group is always False
                a_df.loc[idx, a_col_name] = False
            else:
                # now do the change test
                a_df.loc[idx, a_col_name] = (x != last_x)

            # save this one for the next loop
            last_x = x
            n = n + 1
            idx = idx + 1

        if idx < 10: print(s)


df['well_status_CHANGED']   = None
df['well_type_cd_CHANGED']  = None
df['rep_or_est_CHANGED']    = None

# it's worth noting that if any of these are numeric data types, I can do the following to more quickly process:
# test_df['measure_change'] = test_df.groupby('item')['measure'].diff().fillna(0) != 0

#df['report_type_CHANGED']    = None
#it = df.groupby('api_no')['report_type']
#FlagChanges( it, 'report_type_CHANGED', df)
#df['report_type_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))

#df['pool_code_CHANGED']      = None
#it = df.groupby('api_no')['pool_code']
#FlagChanges( it, 'pool_code_CHANGED', df)
#df['pool_code_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))

it = df.groupby('PWT__ID')['well_status2'] # use the imputed/updated well_status2
#FlagChanges( it, 'well_status_CHANGED', df)
df['well_status_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))
progress.value += 2

it = df.groupby('PWT__ID')['well_type_cd']
#FlagChanges( it, 'well_type_cd_CHANGED', df)
df['well_type_cd_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))
progress.value += 2

#df['water_disposition_CHANGED']       = None
#it = df.groupby('api_no')['water_disposition']
#FlagChanges( it, 'water_disposition_CHANGED', df)
#df['water_disposition_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))

#df['well_mo_CHANGED']            = None
#it = df.groupby('api_no')['well_mo']
#FlagChanges( it, 'well_mo_CHANGED', df)
#df['well_mo_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))

#df['water_source_CHANGED']        = None
#it = df.groupby('api_no')['water_source']
#FlagChanges( it, 'water_source_CHANGED', df)
#df['water_source_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))

#df['water_kind_CHANGED']       = None
#it = df.groupby('api_no')['water_kind']
#FlagChanges( it, 'water_kind_CHANGED', df)
#df['water_kind_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))

it = df.groupby('PWT__ID')['rep_or_est']
#FlagChanges( it, 'rep_or_est_CHANGED', df)
df['rep_or_est_CHANGED'] = it.transform(lambda x: (x != x.shift()) & (x.shift().notna()))
progress.value += 2

df
# Out:
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 1011366  040370080500  40370080500    2017-01-01          1      2017
# 1011367  040370080500  40370080500    2017-02-01          2      2017
# 1011368  040370080500  40370080500    2017-03-01          3      2017
# 1011369  040370080500  40370080500    2017-05-01          5      2017
# 1011370  040370080500  40370080500    2017-06-01          6      2017
# ...               ...          ...           ...        ...       ...
# 319027   040296696000  40296696000    2017-08-01          8      2017
# 319028   040296696000  40296696000    2017-09-01          9      2017
# 319029   040296696000  40296696000    2017-10-01         10      2017
# 319030   040296696000  40296696000    2017-11-01         11      2017
# 319031   040296696000  40296696000    2017-12-01         12      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 1011366             00      Active            0           OG              A
# 1011367             00      Active            0           OG              A
# 1011368             00      Active            0           OG              A
# 1011369             00      Active            0           OG              A
# 1011370             00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 319027              06        Idle            1           WD              A
# 319028              06        Idle            1           WD              A
# 319029              06        Idle            1           WD              A
# 319030              06        Idle            1           WD              A
# 319031              06        Idle            1           WD              A
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 1011366          22          20        0        3          39.0
# 1011367          22          20     <NA>        3          39.0
# 1011368          20          18     <NA>        3          39.0
# 1011369          20          18     <NA>        3          39.0
# 1011370          20          18     <NA>        3          39.0
# ...             ...         ...      ...      ...           ...
# 319027         <NA>        <NA>     <NA>        0           NaN
# 319028         <NA>        <NA>     <NA>        0           NaN
# 319029         <NA>        <NA>     <NA>        0           NaN
# 319030         <NA>        <NA>     <NA>        0           NaN
# 319031         <NA>        <NA>     <NA>        0           NaN
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 1011366                  4             157.0       31.0               0.0
# 1011367                  4             142.0       28.0               NaN
# 1011368                  4             159.0       31.0               NaN
# 1011369                  4             159.0       31.0               NaN
# 1011370                  4             155.0       30.0               NaN
# ...                    ...               ...        ...               ...
# 319027                   0               NaN        NaN               NaN
# 319028                   0               NaN        NaN               NaN
# 319029                   0               NaN        NaN               NaN
# 319030                   0               NaN        NaN               NaN
# 319031                   0               NaN        NaN               NaN
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 1011366               170.0              NaN                NaN       NaN
# 1011367               153.0              NaN                NaN       NaN
# 1011368               170.0              NaN                NaN       NaN
# 1011369               170.0              NaN                NaN       NaN
# 1011370               164.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 319027                  NaN              0.0                0.0       0.0
# 319028                  NaN              0.0                0.0       0.0
# 319029                  NaN              0.0                0.0       0.0
# 319030                  NaN              0.0                0.0       0.0
# 319031                  NaN              0.0                0.0       0.0
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 1011366                <NA>             0           0        034        00
# 1011367                <NA>             0           0        034        00
# 1011368                <NA>             0           0        034        00
# 1011369                <NA>             0           0        034        00
# 1011370                <NA>             0           0        034        00
# ...                     ...           ...         ...        ...       ...
# 319027                    0             7           1        464        00
# 319028                    0             7           1        464        00
# 319029                    0             7           1        464        00
# 319030                    0             7           1        464        00
# 319031                    0             7           1        464        00
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID  IsActive  active_days  \
# 1011366        05   Reported              1  100000007      True         31.0
# 1011367        05   Reported              1  100000007      True         28.0
# 1011368        05   Reported              1  100000007      True         31.0
# 1011369        05   Reported              1  100000007      True         31.0
# 1011370        05   Reported              1  100000007      True         30.0
# ...           ...        ...            ...        ...       ...          ...
# 319027         23   Reported              1  100320511      True          0.0
# 319028         23   Reported              1  100320511      True          0.0
# 319029         23   Reported              1  100320511      True          0.0
# 319030         23   Reported              1  100320511      True          0.0
# 319031         23   Reported              1  100320511      True          0.0
#
#         well_status2  well_status_CHANGED  well_type_cd_CHANGED  \
# 1011366       Active                False                 False
# 1011367       Active                False                 False
# 1011368       Active                False                 False
# 1011369       Active                False                 False
# 1011370       Active                False                 False
# ...              ...                  ...                   ...
# 319027        Active                False                 False
# 319028        Active                False                 False
# 319029        Active                False                 False
# 319030        Active                False                 False
# 319031        Active                False                 False
#
#          rep_or_est_CHANGED
# 1011366               False
# 1011367               False
# 1011368               False
# 1011369               False
# 1011370               False
# ...                     ...
# 319027                False
# 319028                False
# 319029                False
# 319030                False
# 319031                False
#
# [1270382 rows x 38 columns]

# %%
df['well_type_cd_CHANGED'].value_counts()
# Out:
# well_type_cd_CHANGED
# False    1270382
# Name: count, dtype: int64

# %%
# remember this is well_status2
df['well_status_CHANGED'].value_counts()
# Out:
# well_status_CHANGED
# False    1249788
# True       20594
# Name: count, dtype: int64

# %%
df['rep_or_est_CHANGED'].value_counts()
# Out:
# rep_or_est_CHANGED
# False    1270382
# Name: count, dtype: int64

# %% [markdown]
# ### Original DOGRR data was either 0 for prod or 1 for inj record
# Current data doesn't have this field, but the records are either from the Production table or the Injection table
#
# | Code | Desc    | Explanation         |
# |------|---------|---------------------|
# | 0    | PROD    | Production record   |
# | 1    | INJ     | Injection record    |
# | 2    | Unknown | Unknown record type |

# %%
## Report Type Code conversion
# 0 = Production record
# 1 = Injection record
# 2 = unknown (maybe shut-in)
df['prod_inj_cd'] = "2"
df.loc[((df['water_disposition']>0) | (df['gas_inj_vol_mcf']>0) | (df['water_inj_vol_bbl']>0)) & (df['rep_or_est'] == 'Reported'), 'prod_inj_cd'] = "1"
df.loc[((df['oil_prod_vol_bbl']>0) | (df['gas_prod_vol_mcf']>0) | (df['water_inj_vol_bbl']>0) | (df['water_source']>0)) & (df['rep_or_est'] == 'Reported'), 'prod_inj_cd'] = "0"
df
# Out:
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 1011366  040370080500  40370080500    2017-01-01          1      2017
# 1011367  040370080500  40370080500    2017-02-01          2      2017
# 1011368  040370080500  40370080500    2017-03-01          3      2017
# 1011369  040370080500  40370080500    2017-05-01          5      2017
# 1011370  040370080500  40370080500    2017-06-01          6      2017
# ...               ...          ...           ...        ...       ...
# 319027   040296696000  40296696000    2017-08-01          8      2017
# 319028   040296696000  40296696000    2017-09-01          9      2017
# 319029   040296696000  40296696000    2017-10-01         10      2017
# 319030   040296696000  40296696000    2017-11-01         11      2017
# 319031   040296696000  40296696000    2017-12-01         12      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 1011366             00      Active            0           OG              A
# 1011367             00      Active            0           OG              A
# 1011368             00      Active            0           OG              A
# 1011369             00      Active            0           OG              A
# 1011370             00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 319027              06        Idle            1           WD              A
# 319028              06        Idle            1           WD              A
# 319029              06        Idle            1           WD              A
# 319030              06        Idle            1           WD              A
# 319031              06        Idle            1           WD              A
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 1011366          22          20        0        3          39.0
# 1011367          22          20     <NA>        3          39.0
# 1011368          20          18     <NA>        3          39.0
# 1011369          20          18     <NA>        3          39.0
# 1011370          20          18     <NA>        3          39.0
# ...             ...         ...      ...      ...           ...
# 319027         <NA>        <NA>     <NA>        0           NaN
# 319028         <NA>        <NA>     <NA>        0           NaN
# 319029         <NA>        <NA>     <NA>        0           NaN
# 319030         <NA>        <NA>     <NA>        0           NaN
# 319031         <NA>        <NA>     <NA>        0           NaN
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 1011366                  4             157.0       31.0               0.0
# 1011367                  4             142.0       28.0               NaN
# 1011368                  4             159.0       31.0               NaN
# 1011369                  4             159.0       31.0               NaN
# 1011370                  4             155.0       30.0               NaN
# ...                    ...               ...        ...               ...
# 319027                   0               NaN        NaN               NaN
# 319028                   0               NaN        NaN               NaN
# 319029                   0               NaN        NaN               NaN
# 319030                   0               NaN        NaN               NaN
# 319031                   0               NaN        NaN               NaN
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 1011366               170.0              NaN                NaN       NaN
# 1011367               153.0              NaN                NaN       NaN
# 1011368               170.0              NaN                NaN       NaN
# 1011369               170.0              NaN                NaN       NaN
# 1011370               164.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 319027                  NaN              0.0                0.0       0.0
# 319028                  NaN              0.0                0.0       0.0
# 319029                  NaN              0.0                0.0       0.0
# 319030                  NaN              0.0                0.0       0.0
# 319031                  NaN              0.0                0.0       0.0
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 1011366                <NA>             0           0        034        00
# 1011367                <NA>             0           0        034        00
# 1011368                <NA>             0           0        034        00
# 1011369                <NA>             0           0        034        00
# 1011370                <NA>             0           0        034        00
# ...                     ...           ...         ...        ...       ...
# 319027                    0             7           1        464        00
# 319028                    0             7           1        464        00
# 319029                    0             7           1        464        00
# 319030                    0             7           1        464        00
# 319031                    0             7           1        464        00
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID  IsActive  active_days  \
# 1011366        05   Reported              1  100000007      True         31.0
# 1011367        05   Reported              1  100000007      True         28.0
# 1011368        05   Reported              1  100000007      True         31.0
# 1011369        05   Reported              1  100000007      True         31.0
# 1011370        05   Reported              1  100000007      True         30.0
# ...           ...        ...            ...        ...       ...          ...
# 319027         23   Reported              1  100320511      True          0.0
# 319028         23   Reported              1  100320511      True          0.0
# 319029         23   Reported              1  100320511      True          0.0
# 319030         23   Reported              1  100320511      True          0.0
# 319031         23   Reported              1  100320511      True          0.0
#
#         well_status2  well_status_CHANGED  well_type_cd_CHANGED  \
# 1011366       Active                False                 False
# 1011367       Active                False                 False
# 1011368       Active                False                 False
# 1011369       Active                False                 False
# 1011370       Active                False                 False
# ...              ...                  ...                   ...
# 319027        Active                False                 False
# 319028        Active                False                 False
# 319029        Active                False                 False
# 319030        Active                False                 False
# 319031        Active                False                 False
#
#          rep_or_est_CHANGED prod_inj_cd
# 1011366               False           0
# 1011367               False           0
# 1011368               False           0
# 1011369               False           0
# 1011370               False           0
# ...                     ...         ...
# 319027                False           0
# 319028                False           0
# 319029                False           0
# 319030                False           0
# 319031                False           0
#
# [1270382 rows x 39 columns]

# %% [markdown]
# ### WELL STATUS CODE conversion
# in the new format, they use a whole word like "IDLE" where the older format used a single char like "I"
#
# This is saved in `doggr.wells.well_status`
#
# There is another field `doggr.wells.operator_status_cd` with codes `A`, `I`, `O` of which `O` only has 2 wells. Will have to come back to this but, that could be Active and Idle/Inactive also. I'm not sure why there are 2 fields in the original table.
#
# | Well Status | Definition | Explanation                                                                                |
# |-------------|------------|--------------------------------------------------------------------------------------------|
# | N           | New        | Recently permitted, the well has not been drilled or completed.                            |
# | B           | Buried     | Older Well, not abandoned to today’s standards, location of well may be approximate.       |
# | U           | Unknown    | Status not yet entered from hard copy file. Wells are mostly older, pre-1976.              |
# | A           | Active     | Well has been drilled and completed                                                        |
# | C           | Cancelled  | Well permit was cancelled prior to drilling                                                |
# | P           | Plugged    | Well gas been plugged and abandoned                                                        |
# | I           | Idle       | Idle Well. An idle well has not produced or injected for 6 consecutive months for 2 years. |

# %%
# unknown status types found in the data:
# Abeyance
# PluggedOnly
# also they misspelled Cancelled...

# Create an overall Well Status single character code for the 'wells' table, which is one of the codes above
# there may be a faster way to do this, but this is easy to read
df_wells['well_status_cd'] = 'U' # start with default of Unknown
df_wells.loc[df_wells['well_status'] == 'Plugged',  'well_status_cd'] = 'P'
df_wells.loc[df_wells['well_status'] == 'Idle',     'well_status_cd'] = 'I'
df_wells.loc[df_wells['well_status'] == 'Buried',   'well_status_cd'] = 'B'
df_wells.loc[df_wells['well_status'] == 'Active',   'well_status_cd'] = 'A'
df_wells.loc[df_wells['well_status'] == 'Canceled', 'well_status_cd'] = 'C'
df_wells.loc[df_wells['well_status'] == 'New',      'well_status_cd'] = 'N'
df_wells
# Out:
#        district field_code area_code        api_no well_status loc_section  \
# 0             1        000        00  040370049400           I           4
# 1             1        000        00  040370116700           B           4
# 2             1        000        00  040712006500           P          29
# 3             1        000        00  040712006000           A          26
# 4             1        000        00  040712006100           P          28
# ...         ...        ...       ...           ...         ...         ...
# 277292        4        340        00  040306375500           N           5
# 277293        4        340        00  040306375500           N           5
# 277294        4        464        00  040296988200           A          24
# 277295        4        464        00  040296696000           A          24
# 277296        4        464        00  040295768000           P          24
#
#        loc_subsection loc_township loc_range loc_bm operator_cd  \
# 0                               1N       17W     SB       K2100
# 1                               1N       17W     SB       L2150
# 2                              30S       41E     MD       K1855
# 3                               3N        6W     SB       U0515
# 4                              31S       41E     SB       U0515
# ...               ...          ...       ...    ...         ...
# 277292           None          29S       28E     MD       C5640
# 277293           None          29S       28E     MD       C5640
# 277294                         11N       23W     SB       A0610
# 277295                         11N       23W     SB       A0610
# 277296                         11N       23W     SB       A0610
#
#                 lease_name well_number     field_name area_name  \
# 0                    Knapp           3      Any Field  Any Area
# 1               Lucky Star           1      Any Field  Any Area
# 2       Kitchens Oil Baron           1      Any Field  Any Area
# 3                  Federal        2-26      Any Field  Any Area
# 4                Kitchen's         101      Any Field  Any Area
# ...                    ...         ...            ...       ...
# 277292         San Joaquin        216R     Kern River  Any Area
# 277293         San Joaquin        216R     Kern River  Any Area
# 277294              Metson    SWD 4-24  Midway-Sunset  Any Area
# 277295              Metson    SWD 3-24  Midway-Sunset  Any Area
# 277296              Metson      C24-24  Midway-Sunset  Any Area
#
#                   operator_name operator_status report_type          county  \
# 0                   Frank Knapp               I          50     Los Angeles
# 1             Liu Cheng and Lin               I          50     Los Angeles
# 2           Charles L. Kitchens               I          50  San Bernardino
# 3       U. S. Geological Survey               I          50  San Bernardino
# 4       U. S. Geological Survey               I          50  San Bernardino
# ...                         ...             ...         ...             ...
# 277292      Chevron U.S.A. Inc.               A          99            Kern
# 277293      Chevron U.S.A. Inc.               A          99            Kern
# 277294          Aera Energy LLC               A          99            Kern
# 277295          Aera Energy LLC               A          99            Kern
# 277296          Aera Energy LLC               A          99            Kern
#
#        pool_code well_type_cd PoolWellTypeStatus SystemEntryDate  \
# 0             00           OG                  I      1987-09-01
# 1             00           OG                  B      1976-04-01
# 2             00           OG                  P      1993-04-01
# 3             00           OG                  I      1986-07-01
# 4             00           OG                  P      1986-07-01
# ...          ...          ...                ...             ...
# 277292        05           OG                  N      2018-04-05
# 277293        05           SC                  N      2018-04-05
# 277294        23           WD                  A      1983-10-01
# 277295        23           WD                  A      1982-05-01
# 277296        23           WD                  P      1978-11-01
#
#                  pool_name    PWT__ID well_status_cd
# 0        No Pool Breakdown  100000001              U
# 1        No Pool Breakdown  100000002              U
# 2        No Pool Breakdown  100000003              U
# 3        No Pool Breakdown  100000004              U
# 4        No Pool Breakdown  100000005              U
# ...                    ...        ...            ...
# 277292          Kern River  100320508              U
# 277293          Kern River  100320509              U
# 277294  Tulare-San Joaquin  100320510              U
# 277295  Tulare-San Joaquin  100320511              U
# 277296  Tulare-San Joaquin  100320512              U
#
# [277297 rows x 26 columns]

# %%
# Create an overall Well Status single character code for the 'monthly volumes' table, which is one of the codes above
# there may be a faster way to do this, but this is easy to read
df['well_status_cd'] = 'U' # start with default of Unknown
df.loc[df['well_status'] == 'Plugged',  'well_status_cd'] = 'P'
df.loc[df['well_status'] == 'Idle',     'well_status_cd'] = 'I'
df.loc[df['well_status'] == 'Buried',   'well_status_cd'] = 'B'
df.loc[df['well_status'] == 'Active',   'well_status_cd'] = 'A'
df.loc[df['well_status'] == 'Canceled', 'well_status_cd'] = 'C'
df.loc[df['well_status'] == 'New',      'well_status_cd'] = 'N'
df
# Out:
#                api_no   api_no_int prod_inj_date  vol_month  vol_year  \
# 1011366  040370080500  40370080500    2017-01-01          1      2017
# 1011367  040370080500  40370080500    2017-02-01          2      2017
# 1011368  040370080500  40370080500    2017-03-01          3      2017
# 1011369  040370080500  40370080500    2017-05-01          5      2017
# 1011370  040370080500  40370080500    2017-06-01          6      2017
# ...               ...          ...           ...        ...       ...
# 319027   040296696000  40296696000    2017-08-01          8      2017
# 319028   040296696000  40296696000    2017-09-01          9      2017
# 319029   040296696000  40296696000    2017-10-01         10      2017
# 319030   040296696000  40296696000    2017-11-01         11      2017
# 319031   040296696000  40296696000    2017-12-01         12      2017
#
#         well_status_no well_status  prod_or_inj well_type_cd well_status_cd  \
# 1011366             00      Active            0           OG              A
# 1011367             00      Active            0           OG              A
# 1011368             00      Active            0           OG              A
# 1011369             00      Active            0           OG              A
# 1011370             00      Active            0           OG              A
# ...                ...         ...          ...          ...            ...
# 319027              06        Idle            1           WD              I
# 319028              06        Idle            1           WD              I
# 319029              06        Idle            1           WD              I
# 319030              06        Idle            1           WD              I
# 319031              06        Idle            1           WD              I
#
#          casing_psi  tubing_psi  gas_btu  well_mo  oil_api_grav  \
# 1011366          22          20        0        3          39.0
# 1011367          22          20     <NA>        3          39.0
# 1011368          20          18     <NA>        3          39.0
# 1011369          20          18     <NA>        3          39.0
# 1011370          20          18     <NA>        3          39.0
# ...             ...         ...      ...      ...           ...
# 319027         <NA>        <NA>     <NA>        0           NaN
# 319028         <NA>        <NA>     <NA>        0           NaN
# 319029         <NA>        <NA>     <NA>        0           NaN
# 319030         <NA>        <NA>     <NA>        0           NaN
# 319031         <NA>        <NA>     <NA>        0           NaN
#
#          water_disposition  oil_prod_vol_bbl  prod_days  gas_prod_vol_mcf  \
# 1011366                  4             157.0       31.0               0.0
# 1011367                  4             142.0       28.0               NaN
# 1011368                  4             159.0       31.0               NaN
# 1011369                  4             159.0       31.0               NaN
# 1011370                  4             155.0       30.0               NaN
# ...                    ...               ...        ...               ...
# 319027                   0               NaN        NaN               NaN
# 319028                   0               NaN        NaN               NaN
# 319029                   0               NaN        NaN               NaN
# 319030                   0               NaN        NaN               NaN
# 319031                   0               NaN        NaN               NaN
#
#          water_prod_vol_bbl  gas_inj_vol_mcf  water_inj_vol_bbl  inj_days  \
# 1011366               170.0              NaN                NaN       NaN
# 1011367               153.0              NaN                NaN       NaN
# 1011368               170.0              NaN                NaN       NaN
# 1011369               170.0              NaN                NaN       NaN
# 1011370               164.0              NaN                NaN       NaN
# ...                     ...              ...                ...       ...
# 319027                  NaN              0.0                0.0       0.0
# 319028                  NaN              0.0                0.0       0.0
# 319029                  NaN              0.0                0.0       0.0
# 319030                  NaN              0.0                0.0       0.0
# 319031                  NaN              0.0                0.0       0.0
#
#          surf_inj_press_psi  water_source  water_kind field_code area_code  \
# 1011366                <NA>             0           0        034        00
# 1011367                <NA>             0           0        034        00
# 1011368                <NA>             0           0        034        00
# 1011369                <NA>             0           0        034        00
# 1011370                <NA>             0           0        034        00
# ...                     ...           ...         ...        ...       ...
# 319027                    0             7           1        464        00
# 319028                    0             7           1        464        00
# 319029                    0             7           1        464        00
# 319030                    0             7           1        464        00
# 319031                    0             7           1        464        00
#
#         pool_code rep_or_est  rep_or_est_cd    PWT__ID  IsActive  active_days  \
# 1011366        05   Reported              1  100000007      True         31.0
# 1011367        05   Reported              1  100000007      True         28.0
# 1011368        05   Reported              1  100000007      True         31.0
# 1011369        05   Reported              1  100000007      True         31.0
# 1011370        05   Reported              1  100000007      True         30.0
# ...           ...        ...            ...        ...       ...          ...
# 319027         23   Reported              1  100320511      True          0.0
# 319028         23   Reported              1  100320511      True          0.0
# 319029         23   Reported              1  100320511      True          0.0
# 319030         23   Reported              1  100320511      True          0.0
# 319031         23   Reported              1  100320511      True          0.0
#
#         well_status2  well_status_CHANGED  well_type_cd_CHANGED  \
# 1011366       Active                False                 False
# 1011367       Active                False                 False
# 1011368       Active                False                 False
# 1011369       Active                False                 False
# 1011370       Active                False                 False
# ...              ...                  ...                   ...
# 319027        Active                False                 False
# 319028        Active                False                 False
# 319029        Active                False                 False
# 319030        Active                False                 False
# 319031        Active                False                 False
#
#          rep_or_est_CHANGED prod_inj_cd
# 1011366               False           0
# 1011367               False           0
# 1011368               False           0
# 1011369               False           0
# 1011370               False           0
# ...                     ...         ...
# 319027                False           0
# 319028                False           0
# 319029                False           0
# 319030                False           0
# 319031                False           0
#
# [1270382 rows x 39 columns]

# %% [markdown]
# ### WELL TYPE Conversion Codes
#
# | No. | Well Type | Definition                             |
# |:---:|:---------:|:---------------------------------------|
# |  0  |    AI     | Air Injector                           |
# |  1  |    DG     | Dry Gas Production                     |
# |  C  |    GD     | Gas Disposal Injector                  |
# |  3  |    GS     | Gas Storage Injector/Producer          |
# |  5  |    LG     | Liquid Petroleum Gas Injector/Producer |
# |  B  |    OB     | Observation Well                       |
# |  2  |    OG     | Oil & Gas Production                   |
# |  4  |    PM     | Pressure Maintenance Injector          |
# |  A  |    SC     | Steam Flood Cyclic(?)                  |
# |  8  |    SF     | Steam Flood Injector                   |
# |  6  |    WD     | Water Disposal Injector                |
# |  7  |    WF     | Water Flood Injector                   |
# |  9  |    WS     | Water Source Injector                  |

# %%
# Unknown codes
#  DH - could be Dry Hole?
#  Multi - ???
#  UNK - literally...
#  GAS - really?
#  INJ - really?

# Type Code conversions
df_wells['well_type_no'] = 'X'  # start with default of unknown
df_wells.loc[df_wells['well_type_cd'] == 'AI', 'well_type_no'] = '0'
df_wells.loc[df_wells['well_type_cd'] == 'DG', 'well_type_no'] = '1'
df_wells.loc[df_wells['well_type_cd'] == 'GD', 'well_type_no'] = 'C'
df_wells.loc[df_wells['well_type_cd'] == 'GS', 'well_type_no'] = '3'
df_wells.loc[df_wells['well_type_cd'] == 'LG', 'well_type_no'] = '5'
df_wells.loc[df_wells['well_type_cd'] == 'OB', 'well_type_no'] = 'B'
df_wells.loc[df_wells['well_type_cd'] == 'OG', 'well_type_no'] = '2'
df_wells.loc[df_wells['well_type_cd'] == 'PM', 'well_type_no'] = '4'
df_wells.loc[df_wells['well_type_cd'] == 'SC', 'well_type_no'] = 'A'
df_wells.loc[df_wells['well_type_cd'] == 'SF', 'well_type_no'] = '8'
df_wells.loc[df_wells['well_type_cd'] == 'WD', 'well_type_no'] = '6'
df_wells.loc[df_wells['well_type_cd'] == 'WF', 'well_type_no'] = '7'
df_wells.loc[df_wells['well_type_cd'] == 'WS', 'well_type_no'] = '9'
df_wells
# Out:
#        district field_code area_code        api_no well_status loc_section  \
# 0             1        000        00  040370049400           I           4
# 1             1        000        00  040370116700           B           4
# 2             1        000        00  040712006500           P          29
# 3             1        000        00  040712006000           A          26
# 4             1        000        00  040712006100           P          28
# ...         ...        ...       ...           ...         ...         ...
# 277292        4        340        00  040306375500           N           5
# 277293        4        340        00  040306375500           N           5
# 277294        4        464        00  040296988200           A          24
# 277295        4        464        00  040296696000           A          24
# 277296        4        464        00  040295768000           P          24
#
#        loc_subsection loc_township loc_range loc_bm operator_cd  \
# 0                               1N       17W     SB       K2100
# 1                               1N       17W     SB       L2150
# 2                              30S       41E     MD       K1855
# 3                               3N        6W     SB       U0515
# 4                              31S       41E     SB       U0515
# ...               ...          ...       ...    ...         ...
# 277292           None          29S       28E     MD       C5640
# 277293           None          29S       28E     MD       C5640
# 277294                         11N       23W     SB       A0610
# 277295                         11N       23W     SB       A0610
# 277296                         11N       23W     SB       A0610
#
#                 lease_name well_number     field_name area_name  \
# 0                    Knapp           3      Any Field  Any Area
# 1               Lucky Star           1      Any Field  Any Area
# 2       Kitchens Oil Baron           1      Any Field  Any Area
# 3                  Federal        2-26      Any Field  Any Area
# 4                Kitchen's         101      Any Field  Any Area
# ...                    ...         ...            ...       ...
# 277292         San Joaquin        216R     Kern River  Any Area
# 277293         San Joaquin        216R     Kern River  Any Area
# 277294              Metson    SWD 4-24  Midway-Sunset  Any Area
# 277295              Metson    SWD 3-24  Midway-Sunset  Any Area
# 277296              Metson      C24-24  Midway-Sunset  Any Area
#
#                   operator_name operator_status report_type          county  \
# 0                   Frank Knapp               I          50     Los Angeles
# 1             Liu Cheng and Lin               I          50     Los Angeles
# 2           Charles L. Kitchens               I          50  San Bernardino
# 3       U. S. Geological Survey               I          50  San Bernardino
# 4       U. S. Geological Survey               I          50  San Bernardino
# ...                         ...             ...         ...             ...
# 277292      Chevron U.S.A. Inc.               A          99            Kern
# 277293      Chevron U.S.A. Inc.               A          99            Kern
# 277294          Aera Energy LLC               A          99            Kern
# 277295          Aera Energy LLC               A          99            Kern
# 277296          Aera Energy LLC               A          99            Kern
#
#        pool_code well_type_cd PoolWellTypeStatus SystemEntryDate  \
# 0             00           OG                  I      1987-09-01
# 1             00           OG                  B      1976-04-01
# 2             00           OG                  P      1993-04-01
# 3             00           OG                  I      1986-07-01
# 4             00           OG                  P      1986-07-01
# ...          ...          ...                ...             ...
# 277292        05           OG                  N      2018-04-05
# 277293        05           SC                  N      2018-04-05
# 277294        23           WD                  A      1983-10-01
# 277295        23           WD                  A      1982-05-01
# 277296        23           WD                  P      1978-11-01
#
#                  pool_name    PWT__ID well_status_cd well_type_no
# 0        No Pool Breakdown  100000001              U            2
# 1        No Pool Breakdown  100000002              U            2
# 2        No Pool Breakdown  100000003              U            2
# 3        No Pool Breakdown  100000004              U            2
# 4        No Pool Breakdown  100000005              U            2
# ...                    ...        ...            ...          ...
# 277292          Kern River  100320508              U            2
# 277293          Kern River  100320509              U            A
# 277294  Tulare-San Joaquin  100320510              U            6
# 277295  Tulare-San Joaquin  100320511              U            6
# 277296  Tulare-San Joaquin  100320512              U            6
#
# [277297 rows x 27 columns]

# %%
# post-2018 operator status codes, translating them to single char for wells table
# Active
# Bankruptcy/Receivership
# Inactive
# Unknown

df_wells['operator_status_cd'] = None
df_wells.loc[df_wells['operator_status'] == 'Active', 'operator_status_cd'] = 'A'
df_wells.loc[df_wells['operator_status'] == 'Bankruptcy/Receivership', 'operator_status_cd'] = 'B'
df_wells.loc[df_wells['operator_status'] == 'Inactive', 'operator_status_cd'] = 'I'
df_wells.loc[df_wells['operator_status'] == 'Unknown', 'operator_status_cd'] = 'U'
df_wells
# Out:
#        district field_code area_code        api_no well_status loc_section  \
# 0             1        000        00  040370049400           I           4
# 1             1        000        00  040370116700           B           4
# 2             1        000        00  040712006500           P          29
# 3             1        000        00  040712006000           A          26
# 4             1        000        00  040712006100           P          28
# ...         ...        ...       ...           ...         ...         ...
# 277292        4        340        00  040306375500           N           5
# 277293        4        340        00  040306375500           N           5
# 277294        4        464        00  040296988200           A          24
# 277295        4        464        00  040296696000           A          24
# 277296        4        464        00  040295768000           P          24
#
#        loc_subsection loc_township loc_range loc_bm operator_cd  \
# 0                               1N       17W     SB       K2100
# 1                               1N       17W     SB       L2150
# 2                              30S       41E     MD       K1855
# 3                               3N        6W     SB       U0515
# 4                              31S       41E     SB       U0515
# ...               ...          ...       ...    ...         ...
# 277292           None          29S       28E     MD       C5640
# 277293           None          29S       28E     MD       C5640
# 277294                         11N       23W     SB       A0610
# 277295                         11N       23W     SB       A0610
# 277296                         11N       23W     SB       A0610
#
#                 lease_name well_number     field_name area_name  \
# 0                    Knapp           3      Any Field  Any Area
# 1               Lucky Star           1      Any Field  Any Area
# 2       Kitchens Oil Baron           1      Any Field  Any Area
# 3                  Federal        2-26      Any Field  Any Area
# 4                Kitchen's         101      Any Field  Any Area
# ...                    ...         ...            ...       ...
# 277292         San Joaquin        216R     Kern River  Any Area
# 277293         San Joaquin        216R     Kern River  Any Area
# 277294              Metson    SWD 4-24  Midway-Sunset  Any Area
# 277295              Metson    SWD 3-24  Midway-Sunset  Any Area
# 277296              Metson      C24-24  Midway-Sunset  Any Area
#
#                   operator_name operator_status report_type          county  \
# 0                   Frank Knapp               I          50     Los Angeles
# 1             Liu Cheng and Lin               I          50     Los Angeles
# 2           Charles L. Kitchens               I          50  San Bernardino
# 3       U. S. Geological Survey               I          50  San Bernardino
# 4       U. S. Geological Survey               I          50  San Bernardino
# ...                         ...             ...         ...             ...
# 277292      Chevron U.S.A. Inc.               A          99            Kern
# 277293      Chevron U.S.A. Inc.               A          99            Kern
# 277294          Aera Energy LLC               A          99            Kern
# 277295          Aera Energy LLC               A          99            Kern
# 277296          Aera Energy LLC               A          99            Kern
#
#        pool_code well_type_cd PoolWellTypeStatus SystemEntryDate  \
# 0             00           OG                  I      1987-09-01
# 1             00           OG                  B      1976-04-01
# 2             00           OG                  P      1993-04-01
# 3             00           OG                  I      1986-07-01
# 4             00           OG                  P      1986-07-01
# ...          ...          ...                ...             ...
# 277292        05           OG                  N      2018-04-05
# 277293        05           SC                  N      2018-04-05
# 277294        23           WD                  A      1983-10-01
# 277295        23           WD                  A      1982-05-01
# 277296        23           WD                  P      1978-11-01
#
#                  pool_name    PWT__ID well_status_cd well_type_no  \
# 0        No Pool Breakdown  100000001              U            2
# 1        No Pool Breakdown  100000002              U            2
# 2        No Pool Breakdown  100000003              U            2
# 3        No Pool Breakdown  100000004              U            2
# 4        No Pool Breakdown  100000005              U            2
# ...                    ...        ...            ...          ...
# 277292          Kern River  100320508              U            2
# 277293          Kern River  100320509              U            A
# 277294  Tulare-San Joaquin  100320510              U            6
# 277295  Tulare-San Joaquin  100320511              U            6
# 277296  Tulare-San Joaquin  100320512              U            6
#
#        operator_status_cd
# 0                    None
# 1                    None
# 2                    None
# 3                    None
# 4                    None
# ...                   ...
# 277292               None
# 277293               None
# 277294               None
# 277295               None
# 277296               None
#
# [277297 rows x 28 columns]

# %%
# district codes - CalGEM redid the districts into 4, where DOGGR used to have 6
df_wells['dist_no'] = 0
df_wells.loc[df_wells['district'] == 'Coastal', 'dist_no'] = 3
df_wells.loc[df_wells['district'] == 'Inland', 'dist_no'] = 4
df_wells.loc[df_wells['district'] == 'Northern', 'dist_no'] = 6
df_wells.loc[df_wells['district'] == 'Southern', 'dist_no'] = 1
df_wells
# Out:
#        district field_code area_code        api_no well_status loc_section  \
# 0             1        000        00  040370049400           I           4
# 1             1        000        00  040370116700           B           4
# 2             1        000        00  040712006500           P          29
# 3             1        000        00  040712006000           A          26
# 4             1        000        00  040712006100           P          28
# ...         ...        ...       ...           ...         ...         ...
# 277292        4        340        00  040306375500           N           5
# 277293        4        340        00  040306375500           N           5
# 277294        4        464        00  040296988200           A          24
# 277295        4        464        00  040296696000           A          24
# 277296        4        464        00  040295768000           P          24
#
#        loc_subsection loc_township loc_range loc_bm operator_cd  \
# 0                               1N       17W     SB       K2100
# 1                               1N       17W     SB       L2150
# 2                              30S       41E     MD       K1855
# 3                               3N        6W     SB       U0515
# 4                              31S       41E     SB       U0515
# ...               ...          ...       ...    ...         ...
# 277292           None          29S       28E     MD       C5640
# 277293           None          29S       28E     MD       C5640
# 277294                         11N       23W     SB       A0610
# 277295                         11N       23W     SB       A0610
# 277296                         11N       23W     SB       A0610
#
#                 lease_name well_number     field_name area_name  \
# 0                    Knapp           3      Any Field  Any Area
# 1               Lucky Star           1      Any Field  Any Area
# 2       Kitchens Oil Baron           1      Any Field  Any Area
# 3                  Federal        2-26      Any Field  Any Area
# 4                Kitchen's         101      Any Field  Any Area
# ...                    ...         ...            ...       ...
# 277292         San Joaquin        216R     Kern River  Any Area
# 277293         San Joaquin        216R     Kern River  Any Area
# 277294              Metson    SWD 4-24  Midway-Sunset  Any Area
# 277295              Metson    SWD 3-24  Midway-Sunset  Any Area
# 277296              Metson      C24-24  Midway-Sunset  Any Area
#
#                   operator_name operator_status report_type          county  \
# 0                   Frank Knapp               I          50     Los Angeles
# 1             Liu Cheng and Lin               I          50     Los Angeles
# 2           Charles L. Kitchens               I          50  San Bernardino
# 3       U. S. Geological Survey               I          50  San Bernardino
# 4       U. S. Geological Survey               I          50  San Bernardino
# ...                         ...             ...         ...             ...
# 277292      Chevron U.S.A. Inc.               A          99            Kern
# 277293      Chevron U.S.A. Inc.               A          99            Kern
# 277294          Aera Energy LLC               A          99            Kern
# 277295          Aera Energy LLC               A          99            Kern
# 277296          Aera Energy LLC               A          99            Kern
#
#        pool_code well_type_cd PoolWellTypeStatus SystemEntryDate  \
# 0             00           OG                  I      1987-09-01
# 1             00           OG                  B      1976-04-01
# 2             00           OG                  P      1993-04-01
# 3             00           OG                  I      1986-07-01
# 4             00           OG                  P      1986-07-01
# ...          ...          ...                ...             ...
# 277292        05           OG                  N      2018-04-05
# 277293        05           SC                  N      2018-04-05
# 277294        23           WD                  A      1983-10-01
# 277295        23           WD                  A      1982-05-01
# 277296        23           WD                  P      1978-11-01
#
#                  pool_name    PWT__ID well_status_cd well_type_no  \
# 0        No Pool Breakdown  100000001              U            2
# 1        No Pool Breakdown  100000002              U            2
# 2        No Pool Breakdown  100000003              U            2
# 3        No Pool Breakdown  100000004              U            2
# 4        No Pool Breakdown  100000005              U            2
# ...                    ...        ...            ...          ...
# 277292          Kern River  100320508              U            2
# 277293          Kern River  100320509              U            A
# 277294  Tulare-San Joaquin  100320510              U            6
# 277295  Tulare-San Joaquin  100320511              U            6
# 277296  Tulare-San Joaquin  100320512              U            6
#
#        operator_status_cd  dist_no
# 0                    None        0
# 1                    None        0
# 2                    None        0
# 3                    None        0
# 4                    None        0
# ...                   ...      ...
# 277292               None        0
# 277293               None        0
# 277294               None        0
# 277295               None        0
# 277296               None        0
#
# [277297 rows x 29 columns]

# %%
progress.value += 2

# %%
df_wells.columns
# Out:
# Index(['district', 'field_code', 'area_code', 'api_no', 'well_status',
#        'loc_section', 'loc_subsection', 'loc_township', 'loc_range', 'loc_bm',
#        'operator_cd', 'lease_name', 'well_number', 'field_name', 'area_name',
#        'operator_name', 'operator_status', 'report_type', 'county',
#        'pool_code', 'well_type_cd', 'PoolWellTypeStatus', 'SystemEntryDate',
#        'pool_name', 'PWT__ID', 'well_status_cd', 'well_type_no',
#        'operator_status_cd', 'dist_no'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['api_no', 'api_no_int', 'prod_inj_date', 'vol_month', 'vol_year',
#        'well_status_no', 'well_status', 'prod_or_inj', 'well_type_cd',
#        'well_status_cd', 'casing_psi', 'tubing_psi', 'gas_btu', 'well_mo',
#        'oil_api_grav', 'water_disposition', 'oil_prod_vol_bbl', 'prod_days',
#        'gas_prod_vol_mcf', 'water_prod_vol_bbl', 'gas_inj_vol_mcf',
#        'water_inj_vol_bbl', 'inj_days', 'surf_inj_press_psi', 'water_source',
#        'water_kind', 'field_code', 'area_code', 'pool_code', 'rep_or_est',
#        'rep_or_est_cd', 'PWT__ID', 'IsActive', 'active_days', 'well_status2',
#        'well_status_CHANGED', 'well_type_cd_CHANGED', 'rep_or_est_CHANGED',
#        'prod_inj_cd'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1270382 entries, 1011366 to 319031
# Data columns (total 39 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   api_no                1270382 non-null  object
#  1   api_no_int            1270382 non-null  int64
#  2   prod_inj_date         1270382 non-null  object
#  3   vol_month             1270382 non-null  int64
#  4   vol_year              1270382 non-null  int64
#  5   well_status_no        1270382 non-null  object
#  6   well_status           1270382 non-null  object
#  7   prod_or_inj           1270382 non-null  int64
#  8   well_type_cd          1270382 non-null  object
#  9   well_status_cd        1270382 non-null  object
#  10  casing_psi            1024107 non-null  Int64
#  11  tubing_psi            1023947 non-null  Int64
#  12  gas_btu               1026596 non-null  Int64
#  13  well_mo               1270382 non-null  Int64
#  14  oil_api_grav          1021856 non-null  float64
#  15  water_disposition     1270382 non-null  Int64
#  16  oil_prod_vol_bbl      1029963 non-null  float64
#  17  prod_days             1029092 non-null  float64
#  18  gas_prod_vol_mcf      1026596 non-null  float64
#  19  water_prod_vol_bbl    1029482 non-null  float64
#  20  gas_inj_vol_mcf       290317 non-null   float64
#  21  water_inj_vol_bbl     287801 non-null   float64
#  22  inj_days              292806 non-null   float64
#  23  surf_inj_press_psi    292324 non-null   Int64
#  24  water_source          1270382 non-null  Int64
#  25  water_kind            1270382 non-null  Int64
#  26  field_code            1270382 non-null  object
#  27  area_code             1270382 non-null  object
#  28  pool_code             1270382 non-null  object
#  29  rep_or_est            1270382 non-null  object
#  30  rep_or_est_cd         1270382 non-null  int64
#  31  PWT__ID               1270382 non-null  int64
#  32  IsActive              1022203 non-null  boolean
#  33  active_days           1270382 non-null  float64
#  34  well_status2          1270382 non-null  object
#  35  well_status_CHANGED   1270382 non-null  bool
#  36  well_type_cd_CHANGED  1270382 non-null  bool
#  37  rep_or_est_CHANGED    1270382 non-null  bool
#  38  prod_inj_cd           1270382 non-null  object
# dtypes: Int64(8), bool(3), boolean(1), float64(9), int64(6), object(12)
# memory usage: 364.7+ MB

# %%
print(f"NULL count for df_wells['well_type_cd']: {df_wells['well_type_cd'].isna().sum():,}")
# Out:
# NULL count for df_wells['well_type_cd']: 0

# %%
# At this point, there shouldn't be any NULLs in these features
print(f"NULL PWT__ID: {df_wells['PWT__ID'].isna().sum():,}")
print(f"NULL api_no: {df_wells['api_no'].isna().sum():,}")
print(f"NULL field_code: {df_wells['field_code'].isna().sum():,}")
print(f"NULL area_code: {df_wells['area_code'].isna().sum():,}")
print(f"NULL pool_code: {df_wells['pool_code'].isna().sum():,}")
print(f"NULL well_type_cd: {df_wells['well_type_cd'].isna().sum():,}")
print(f"NULL well_status_cd: {df_wells['well_status_cd'].isna().sum():,}")
# Out:
# NULL PWT__ID: 0
# NULL api_no: 0
# NULL field_code: 0
# NULL area_code: 0
# NULL pool_code: 0
# NULL well_type_cd: 0
# NULL well_status_cd: 0

# %%
# At this point, there shouldn't be any NULLs in these features
print(f"NULL PWT__ID: {df['PWT__ID'].isna().sum():,}")
print(f"NULL api_no: {df['api_no'].isna().sum():,}")
print(f"NULL field_code: {df['field_code'].isna().sum():,}")
print(f"NULL area_code: {df['area_code'].isna().sum():,}")
print(f"NULL pool_code: {df['pool_code'].isna().sum():,}")
print(f"NULL well_type_cd: {df['well_type_cd'].isna().sum():,}")
print(f"NULL well_status_cd: {df['well_status'].isna().sum():,}")
# Out:
# NULL PWT__ID: 0
# NULL api_no: 0
# NULL field_code: 0
# NULL area_code: 0
# NULL pool_code: 0
# NULL well_type_cd: 0
# NULL well_status_cd: 0

# %% [markdown]
# ## Imputation & NULL checks finished, now create the indexes

# %%
# Figure out what combination of attributes identifies a well uniquely between the 2 tables
# I'm not convinced this is necessary, I may be trying to preserve too much information

# NOTE to future self - there are well table entries that have duplicate 'SystemEntryDate' at different times. so the partition query in the original load removes those
# Otherwise, for 2019 data at least, this gives a unique set of well rows for inserting, and combining with the monthly data
df_wells['APIKey1'] = df_wells['api_no']  + "-" + df_wells['field_code']  + "-" + df_wells['area_code']  + "-" + df_wells['pool_code']  + "-" + df_wells['well_type_cd']
#df_wells['APIKey2'] = df_wells['APIKey1'] + "-" + df_wells['well_status_cd']

# Same for the monthly values, although these won't be unique row indices because of the dates
# This will be used to pivot and then join some data together later, as well as receive the UNIQUE ID/PRIMARY KEY from MySQL on insert of the well
df['APIKey1'] = df['api_no']  + "-" + df['field_code']  + "-" + df['area_code']  + "-" + df['pool_code']  + "-" + df['well_type_cd']

progress.value += 2

# %%
# Confirm we don't have any NULL keys/indexes
print(f"Count of NULL df['PWT__ID'] values: {df['PWT__ID'].isna().sum():,}")
assert(df['PWT__ID'].isna().sum() == 0)
# Out:
# Count of NULL df['PWT__ID'] values: 0

# %%
# Show the rows where APIKey1 != APIKey2, I can probably consolidate these somehow
assert(df_wells['PWT__ID'].isna().sum() == 0)
df_wells.set_index('PWT__ID', verify_integrity=True, inplace=True)

# %%
# Set this index, this confirms that we have a unique set of wells
df_wells
# Out:
#           district field_code area_code        api_no well_status loc_section  \
# PWT__ID
# 100000001        1        000        00  040370049400           I           4
# 100000002        1        000        00  040370116700           B           4
# 100000003        1        000        00  040712006500           P          29
# 100000004        1        000        00  040712006000           A          26
# 100000005        1        000        00  040712006100           P          28
# ...            ...        ...       ...           ...         ...         ...
# 100320508        4        340        00  040306375500           N           5
# 100320509        4        340        00  040306375500           N           5
# 100320510        4        464        00  040296988200           A          24
# 100320511        4        464        00  040296696000           A          24
# 100320512        4        464        00  040295768000           P          24
#
#           loc_subsection loc_township loc_range loc_bm operator_cd  \
# PWT__ID
# 100000001                          1N       17W     SB       K2100
# 100000002                          1N       17W     SB       L2150
# 100000003                         30S       41E     MD       K1855
# 100000004                          3N        6W     SB       U0515
# 100000005                         31S       41E     SB       U0515
# ...                  ...          ...       ...    ...         ...
# 100320508           None          29S       28E     MD       C5640
# 100320509           None          29S       28E     MD       C5640
# 100320510                         11N       23W     SB       A0610
# 100320511                         11N       23W     SB       A0610
# 100320512                         11N       23W     SB       A0610
#
#                    lease_name well_number     field_name area_name  \
# PWT__ID
# 100000001               Knapp           3      Any Field  Any Area
# 100000002          Lucky Star           1      Any Field  Any Area
# 100000003  Kitchens Oil Baron           1      Any Field  Any Area
# 100000004             Federal        2-26      Any Field  Any Area
# 100000005           Kitchen's         101      Any Field  Any Area
# ...                       ...         ...            ...       ...
# 100320508         San Joaquin        216R     Kern River  Any Area
# 100320509         San Joaquin        216R     Kern River  Any Area
# 100320510              Metson    SWD 4-24  Midway-Sunset  Any Area
# 100320511              Metson    SWD 3-24  Midway-Sunset  Any Area
# 100320512              Metson      C24-24  Midway-Sunset  Any Area
#
#                      operator_name operator_status report_type  \
# PWT__ID
# 100000001              Frank Knapp               I          50
# 100000002        Liu Cheng and Lin               I          50
# 100000003      Charles L. Kitchens               I          50
# 100000004  U. S. Geological Survey               I          50
# 100000005  U. S. Geological Survey               I          50
# ...                            ...             ...         ...
# 100320508      Chevron U.S.A. Inc.               A          99
# 100320509      Chevron U.S.A. Inc.               A          99
# 100320510          Aera Energy LLC               A          99
# 100320511          Aera Energy LLC               A          99
# 100320512          Aera Energy LLC               A          99
#
#                    county pool_code well_type_cd PoolWellTypeStatus  \
# PWT__ID
# 100000001     Los Angeles        00           OG                  I
# 100000002     Los Angeles        00           OG                  B
# 100000003  San Bernardino        00           OG                  P
# 100000004  San Bernardino        00           OG                  I
# 100000005  San Bernardino        00           OG                  P
# ...                   ...       ...          ...                ...
# 100320508            Kern        05           OG                  N
# 100320509            Kern        05           SC                  N
# 100320510            Kern        23           WD                  A
# 100320511            Kern        23           WD                  A
# 100320512            Kern        23           WD                  P
#
#           SystemEntryDate           pool_name well_status_cd well_type_no  \
# PWT__ID
# 100000001      1987-09-01   No Pool Breakdown              U            2
# 100000002      1976-04-01   No Pool Breakdown              U            2
# 100000003      1993-04-01   No Pool Breakdown              U            2
# 100000004      1986-07-01   No Pool Breakdown              U            2
# 100000005      1986-07-01   No Pool Breakdown              U            2
# ...                   ...                 ...            ...          ...
# 100320508      2018-04-05          Kern River              U            2
# 100320509      2018-04-05          Kern River              U            A
# 100320510      1983-10-01  Tulare-San Joaquin              U            6
# 100320511      1982-05-01  Tulare-San Joaquin              U            6
# 100320512      1978-11-01  Tulare-San Joaquin              U            6
#
#           operator_status_cd  dist_no                    APIKey1
# PWT__ID
# 100000001               None        0  040370049400-000-00-00-OG
# 100000002               None        0  040370116700-000-00-00-OG
# 100000003               None        0  040712006500-000-00-00-OG
# 100000004               None        0  040712006000-000-00-00-OG
# 100000005               None        0  040712006100-000-00-00-OG
# ...                      ...      ...                        ...
# 100320508               None        0  040306375500-340-00-05-OG
# 100320509               None        0  040306375500-340-00-05-SC
# 100320510               None        0  040296988200-464-00-23-WD
# 100320511               None        0  040296696000-464-00-23-WD
# 100320512               None        0  040295768000-464-00-23-WD
#
# [277297 rows x 29 columns]

# %%
df[df['PWT__ID'] == 100000006]
# Out:
# Empty DataFrame
# Columns: [api_no, api_no_int, prod_inj_date, vol_month, vol_year, well_status_no, well_status, prod_or_inj, well_type_cd, well_status_cd, casing_psi, tubing_psi, gas_btu, well_mo, oil_api_grav, water_disposition, oil_prod_vol_bbl, prod_days, gas_prod_vol_mcf, water_prod_vol_bbl, gas_inj_vol_mcf, water_inj_vol_bbl, inj_days, surf_inj_press_psi, water_source, water_kind, field_code, area_code, pool_code, rep_or_est, rep_or_est_cd, PWT__ID, IsActive, active_days, well_status2, well_status_CHANGED, well_type_cd_CHANGED, rep_or_est_CHANGED, prod_inj_cd, APIKey1]
# Index: []

# %%
df_wells.loc[100000006]
# Out:
# district                                      1
# field_code                                  012
# area_code                                    00
# api_no                             040370080000
# well_status                                   P
# loc_section                                  22
# loc_subsection
# loc_township                                 3S
# loc_range                                   14W
# loc_bm                                       SB
# operator_cd                               G2810
# lease_name                          Park Bodger
# well_number                                   1
# field_name                        Alondra (ABD)
# area_name                              Any Area
# operator_name             Grayson Service, Inc.
# operator_status                               A
# report_type                                  50
# county                              Los Angeles
# pool_code                                    00
# well_type_cd                                 OG
# PoolWellTypeStatus                            P
# SystemEntryDate             1976-04-01 00:00:00
# pool_name                     No Pool Breakdown
# well_status_cd                                U
# well_type_no                                  2
# operator_status_cd                         None
# dist_no                                       0
# APIKey1               040370080000-012-00-00-OG
# Name: 100000006, dtype: object

# %%
df['PWT__ID'].nunique()
# Out:
# 113468

# %%
df_wells.index.nunique()
# Out:
# 277297

# %%
progress.value += 1

# %% [markdown]
# # Do 2 Joins, one left to df_wells with pivotted df, and one left to df from df_wells.
# The `df_wells_from_mv` will be the used one, and combines monthly total data from `df` and then is added to `df_wells` for inserting into the db. The other join `df_from_wells` is a test join to see if any monthly records don't have an equivalent `df_wells` entry, so those would be orphaned monthly records.

# %%
# Original code for 2018-current datasets uses a homebrew api_key which I went to a lot of trouble to make unique.
# since we have PWT__ID already as a unique ID for 2015-2017, this is a lot simpler
#df_from_wells = pd.merge(df, df_wells, how='left', left_on='PWT__ID', right_index=True)
progress.value += 1
#df_from_wells

# %%
#start_null_key_count = df_from_wells['PWT__ID'].isnull().sum()

# %%
#print(f"Missing rows of monthly data from wells join: {start_null_key_count:,} ({start_null_key_count/len(df_from_wells):.1%})")

# %% [markdown]
# ## Solved some of the missing data in the SQL query, but the rest needs to be imputed
# Going to set `PWT__ID` to NULL for rows missing joined `df_wells` data and then impute the correct `PWT__ID`
# Note: Since this behavior was set up originally for the APIKey, it shouldn't apply for `PWT__ID` since there are no NULLs there

# %%
#missing_pwtid_list = list(df_from_wells[df_from_wells['PWT__ID'].isnull()]['PWT__ID'].unique())
progress.value += 1
#print(f"Missing unique keys: {len(missing_pwtid_list):,}")

# %%
# set those missing APIKey1 to NULL in df so we can easily impute the correct APIKey1:
#if len(missing_pwtid_list) > 0 :
#    df['PWT__ID'] = df['PWT__ID'].replace(missing_pwtid_list, pd.NA)
#    impute_null_key_count = df['PWT__ID'].isnull().sum()
#    print(f"NULL Count of PWT__ID, should be the same number of rows above: {impute_null_key_count:,}")
#    assert(impute_null_key_count == start_null_key_count)
progress.value += 3

# %%
# The simplest way to do an Excel style XLOOKUP is with a pd.merge() join call
#df = pd.merge(df, df_wells.reset_index()[['api_no','field_code','area_code','pool_code','APIKey1']],
#         how='left',
#         left_on=['api_no','field_code','area_code','pool_code'],
#         right_on=['api_no','field_code','area_code','pool_code'])
#
#df

# %% [markdown]
# ### `df` is now ready for imputing `PWT__ID` to achieve full match to df_wells
# Note that here I'm imputing the missing `PWT__ID` values in `df` directly from `df_wells`

# %%
#fn_well_type = lambda x: x.mode()[0] if not x.mode().empty else np.nan # This is a lambda function to be used with the transform method on the pandas dataframe

# First imputation the usuall way, this will fill in api_key values where there was a change in the monthly data
#df['PWT__ID2'] = df['PWT__ID'].fillna(df.groupby(['api_no','field_code','area_code','pool_code'])['PWT__ID'].transform(fn_well_type))
#print(f"PWT__ID2 NULL row count {sum(df['PWT__ID2'].isna()):,}")
progress.value += 5

# %%
# Then second imputation looking up api_key from df_wells, using where() method
# The simplest way to do an Excel style XLOOKUP is with a pd.merge() join call
#df = pd.merge(df, df_wells.reset_index()[['api_no','field_code','area_code','pool_code','APIKey1']],
#         how='left',
#         left_on=['api_no','field_code','area_code','pool_code'],
#         right_on=['api_no','field_code','area_code','pool_code'])
#
#assert(df['APIKey1_y'].isna().sum() == 0)
progress.value += 1

# %%
# now we can cleanup the APIKey1
#df['APIKey1'] = np.where(df['APIKey2'].isnull(), df['APIKey1_y'], df['APIKey2'])

# %%
#df.columns

# %%
#assert(df['APIKey1'].isna().sum()==0)

# if we've cleaned up all the NULL keys, then drop the helper columns
#df.drop(columns=['APIKey1_x', 'APIKey2', 'APIKey1_y'], inplace=True)
progress.value += 1

# %%
# Create the final loadable "wells" dataset - a wells set with 1 row per well and the monthly dataset, which is basically "df" without the helper columns
# recreate the df_wells dataframe for this purpose
# in the situation of categoricals, I'm going to take the last one ordered by date (so typically whatever was in Dec of the year)

# Create the aggregate data from the monthly volumes table for adding to the wells table
# The api_key created and aligned earlier will now be the index for joining
df_wells_from_mv = (df.groupby(['PWT__ID'], dropna=False, observed=True).agg(
    oil_prod_vol_bbl=('oil_prod_vol_bbl','sum'),
    gas_prod_vol_mcf=('gas_prod_vol_mcf','sum'),
    gas_inj_vol_mcf=('gas_inj_vol_mcf','sum'),
    water_inj_vol_bbl=('water_inj_vol_bbl','sum'),
    active_days=('active_days','sum'),
    last_well_mo=('well_mo','last'),
    prod_inj_cd=('prod_inj_cd', 'last'),
    well_status_cng=('well_status_CHANGED','max'),  # max here will return True if any value is True, otherwise False if all False
    well_type_cng=('well_type_cd_CHANGED','max'))      # max here will return True if any value is True, otherwise False if all False
)

# Since there is one file/database per year, we can just take the vol_year and set it for all the records
df_wells_from_mv['YEAR_INT'] = df['vol_year'].max()
progress.value += 1

df_wells_from_mv
# Out:
#            oil_prod_vol_bbl  gas_prod_vol_mcf  gas_inj_vol_mcf  \
# PWT__ID
# 100000007            1718.0               0.0              0.0
# 100000008             159.0               0.0              0.0
# 100000009            1877.0               0.0              0.0
# 100000010             201.0               0.0              0.0
# 100000011            1564.0               0.0              0.0
# ...                     ...               ...              ...
# 100320442               0.0               0.0              0.0
# 100320446               0.0               0.0              0.0
# 100320447               0.0               0.0              0.0
# 100320510               0.0               0.0              0.0
# 100320511               0.0               0.0              0.0
#
#            water_inj_vol_bbl  active_days  last_well_mo prod_inj_cd  \
# PWT__ID
# 100000007                0.0        335.0             3           0
# 100000008                0.0        111.0             4           0
# 100000009                0.0        334.0             3           0
# 100000010                0.0        120.0             4           1
# 100000011                0.0        335.0             3           0
# ...                      ...          ...           ...         ...
# 100320442                0.0          0.0             0           0
# 100320446                0.0          0.0             0           0
# 100320447                0.0          0.0             0           0
# 100320510           570700.0        364.0             0           0
# 100320511                0.0          0.0             0           0
#
#            well_status_cng  well_type_cng  YEAR_INT
# PWT__ID
# 100000007            False          False      2017
# 100000008            False          False      2017
# 100000009            False          False      2017
# 100000010             True          False      2017
# 100000011            False          False      2017
# ...                    ...            ...       ...
# 100320442            False          False      2017
# 100320446            False          False      2017
# 100320447            False          False      2017
# 100320510            False          False      2017
# 100320511            False          False      2017
#
# [113468 rows x 10 columns]

# %%
print(f"Index of df_wells_from_mv: {df_wells_from_mv.index.names}")
list(df_wells_from_mv.columns)
# Out:
# Index of df_wells_from_mv: ['PWT__ID']
# ['oil_prod_vol_bbl',
#  'gas_prod_vol_mcf',
#  'gas_inj_vol_mcf',
#  'water_inj_vol_bbl',
#  'active_days',
#  'last_well_mo',
#  'prod_inj_cd',
#  'well_status_cng',
#  'well_type_cng',
#  'YEAR_INT']

# %%
# Confirm that the pivot table now has unique rows per APIKey1 (which is now the index)
print(f"Number of non-unique APIs : {len(df_wells_from_mv) - df_wells_from_mv.index.nunique():,}")
assert(len(df_wells_from_mv) == df_wells_from_mv.index.nunique())
# Out:
# Number of non-unique APIs : 0

# %%
# now join the summary stats from the mv table for insert into the wells table
df_wells_sql = pd.merge(df_wells, df_wells_from_mv, how='left', left_on='PWT__ID', right_index=True)
df_wells_sql
# Out:
#           district field_code area_code        api_no well_status loc_section  \
# PWT__ID
# 100000001        1        000        00  040370049400           I           4
# 100000002        1        000        00  040370116700           B           4
# 100000003        1        000        00  040712006500           P          29
# 100000004        1        000        00  040712006000           A          26
# 100000005        1        000        00  040712006100           P          28
# ...            ...        ...       ...           ...         ...         ...
# 100320508        4        340        00  040306375500           N           5
# 100320509        4        340        00  040306375500           N           5
# 100320510        4        464        00  040296988200           A          24
# 100320511        4        464        00  040296696000           A          24
# 100320512        4        464        00  040295768000           P          24
#
#           loc_subsection loc_township loc_range loc_bm operator_cd  \
# PWT__ID
# 100000001                          1N       17W     SB       K2100
# 100000002                          1N       17W     SB       L2150
# 100000003                         30S       41E     MD       K1855
# 100000004                          3N        6W     SB       U0515
# 100000005                         31S       41E     SB       U0515
# ...                  ...          ...       ...    ...         ...
# 100320508           None          29S       28E     MD       C5640
# 100320509           None          29S       28E     MD       C5640
# 100320510                         11N       23W     SB       A0610
# 100320511                         11N       23W     SB       A0610
# 100320512                         11N       23W     SB       A0610
#
#                    lease_name well_number     field_name area_name  \
# PWT__ID
# 100000001               Knapp           3      Any Field  Any Area
# 100000002          Lucky Star           1      Any Field  Any Area
# 100000003  Kitchens Oil Baron           1      Any Field  Any Area
# 100000004             Federal        2-26      Any Field  Any Area
# 100000005           Kitchen's         101      Any Field  Any Area
# ...                       ...         ...            ...       ...
# 100320508         San Joaquin        216R     Kern River  Any Area
# 100320509         San Joaquin        216R     Kern River  Any Area
# 100320510              Metson    SWD 4-24  Midway-Sunset  Any Area
# 100320511              Metson    SWD 3-24  Midway-Sunset  Any Area
# 100320512              Metson      C24-24  Midway-Sunset  Any Area
#
#                      operator_name operator_status report_type  \
# PWT__ID
# 100000001              Frank Knapp               I          50
# 100000002        Liu Cheng and Lin               I          50
# 100000003      Charles L. Kitchens               I          50
# 100000004  U. S. Geological Survey               I          50
# 100000005  U. S. Geological Survey               I          50
# ...                            ...             ...         ...
# 100320508      Chevron U.S.A. Inc.               A          99
# 100320509      Chevron U.S.A. Inc.               A          99
# 100320510          Aera Energy LLC               A          99
# 100320511          Aera Energy LLC               A          99
# 100320512          Aera Energy LLC               A          99
#
#                    county pool_code well_type_cd PoolWellTypeStatus  \
# PWT__ID
# 100000001     Los Angeles        00           OG                  I
# 100000002     Los Angeles        00           OG                  B
# 100000003  San Bernardino        00           OG                  P
# 100000004  San Bernardino        00           OG                  I
# 100000005  San Bernardino        00           OG                  P
# ...                   ...       ...          ...                ...
# 100320508            Kern        05           OG                  N
# 100320509            Kern        05           SC                  N
# 100320510            Kern        23           WD                  A
# 100320511            Kern        23           WD                  A
# 100320512            Kern        23           WD                  P
#
#           SystemEntryDate           pool_name well_status_cd well_type_no  \
# PWT__ID
# 100000001      1987-09-01   No Pool Breakdown              U            2
# 100000002      1976-04-01   No Pool Breakdown              U            2
# 100000003      1993-04-01   No Pool Breakdown              U            2
# 100000004      1986-07-01   No Pool Breakdown              U            2
# 100000005      1986-07-01   No Pool Breakdown              U            2
# ...                   ...                 ...            ...          ...
# 100320508      2018-04-05          Kern River              U            2
# 100320509      2018-04-05          Kern River              U            A
# 100320510      1983-10-01  Tulare-San Joaquin              U            6
# 100320511      1982-05-01  Tulare-San Joaquin              U            6
# 100320512      1978-11-01  Tulare-San Joaquin              U            6
#
#           operator_status_cd  dist_no                    APIKey1  \
# PWT__ID
# 100000001               None        0  040370049400-000-00-00-OG
# 100000002               None        0  040370116700-000-00-00-OG
# 100000003               None        0  040712006500-000-00-00-OG
# 100000004               None        0  040712006000-000-00-00-OG
# 100000005               None        0  040712006100-000-00-00-OG
# ...                      ...      ...                        ...
# 100320508               None        0  040306375500-340-00-05-OG
# 100320509               None        0  040306375500-340-00-05-SC
# 100320510               None        0  040296988200-464-00-23-WD
# 100320511               None        0  040296696000-464-00-23-WD
# 100320512               None        0  040295768000-464-00-23-WD
#
#            oil_prod_vol_bbl  gas_prod_vol_mcf  gas_inj_vol_mcf  \
# PWT__ID
# 100000001               NaN               NaN              NaN
# 100000002               NaN               NaN              NaN
# 100000003               NaN               NaN              NaN
# 100000004               NaN               NaN              NaN
# 100000005               NaN               NaN              NaN
# ...                     ...               ...              ...
# 100320508               NaN               NaN              NaN
# 100320509               NaN               NaN              NaN
# 100320510               0.0               0.0              0.0
# 100320511               0.0               0.0              0.0
# 100320512               NaN               NaN              NaN
#
#            water_inj_vol_bbl  active_days  last_well_mo prod_inj_cd  \
# PWT__ID
# 100000001                NaN          NaN          <NA>         NaN
# 100000002                NaN          NaN          <NA>         NaN
# 100000003                NaN          NaN          <NA>         NaN
# 100000004                NaN          NaN          <NA>         NaN
# 100000005                NaN          NaN          <NA>         NaN
# ...                      ...          ...           ...         ...
# 100320508                NaN          NaN          <NA>         NaN
# 100320509                NaN          NaN          <NA>         NaN
# 100320510           570700.0        364.0             0           0
# 100320511                0.0          0.0             0           0
# 100320512                NaN          NaN          <NA>         NaN
#
#           well_status_cng well_type_cng  YEAR_INT
# PWT__ID
# 100000001             NaN           NaN       NaN
# 100000002             NaN           NaN       NaN
# 100000003             NaN           NaN       NaN
# 100000004             NaN           NaN       NaN
# 100000005             NaN           NaN       NaN
# ...                   ...           ...       ...
# 100320508             NaN           NaN       NaN
# 100320509             NaN           NaN       NaN
# 100320510           False         False    2017.0
# 100320511           False         False    2017.0
# 100320512             NaN           NaN       NaN
#
# [277297 rows x 39 columns]

# %%
# The non-nonunique should now be zero
print(f"Number of non-unique APIs : {len(df_wells_sql) - df_wells_sql.index.nunique():,}")
assert(len(df_wells_sql) == df_wells_sql.index.nunique())
# Out:
# Number of non-unique APIs : 0

# %%
# Purging unnecessary columns from the wells table
# district: We don't need a string version of
# SubSection : is NaN for all the original data anyway
# operator_status : Don't need full text, will rename operator_status_cd to 'operator_status' next
# well_status : We don't need a string version of
# PoolWellTypeStatus : We don't need pool status... where it's populated, it's basically meaningless
# SystemEntryDate : probably when the operator uploaded to CalGEM, don't care
# row_num : is an artefact from the SQL query
df_wells_sql.reset_index(inplace=True)
df_wells_sql.drop(columns=['district','operator_status','loc_subsection','well_status', 'PoolWellTypeStatus','SystemEntryDate'], inplace=True)
progress.value += 1

# %%
list(df_wells_sql.columns)
# Out:
# ['PWT__ID',
#  'field_code',
#  'area_code',
#  'api_no',
#  'loc_section',
#  'loc_township',
#  'loc_range',
#  'loc_bm',
#  'operator_cd',
#  'lease_name',
#  'well_number',
#  'field_name',
#  'area_name',
#  'operator_name',
#  'report_type',
#  'county',
#  'pool_code',
#  'well_type_cd',
#  'pool_name',
#  'well_status_cd',
#  'well_type_no',
#  'operator_status_cd',
#  'dist_no',
#  'APIKey1',
#  'oil_prod_vol_bbl',
#  'gas_prod_vol_mcf',
#  'gas_inj_vol_mcf',
#  'water_inj_vol_bbl',
#  'active_days',
#  'last_well_mo',
#  'prod_inj_cd',
#  'well_status_cng',
#  'well_type_cng',
#  'YEAR_INT']

# %%
# set up the monthly volumes tables as well. lots of helper columns we don't need to INSERT
df_sql = df.drop(columns=['prod_or_inj','prod_inj_cd','area_code','field_code','pool_code','IsActive','well_status_CHANGED','well_type_cd_CHANGED','rep_or_est_CHANGED','well_status2'])

df_sql = df_sql.rename(columns={
    'APIKey1':'api_key'
})

progress.value += 1
list(df_sql.columns)
# Out:
# ['api_no',
#  'api_no_int',
#  'prod_inj_date',
#  'vol_month',
#  'vol_year',
#  'well_status_no',
#  'well_status',
#  'well_type_cd',
#  'well_status_cd',
#  'casing_psi',
#  'tubing_psi',
#  'gas_btu',
#  'well_mo',
#  'oil_api_grav',
#  'water_disposition',
#  'oil_prod_vol_bbl',
#  'prod_days',
#  'gas_prod_vol_mcf',
#  'water_prod_vol_bbl',
#  'gas_inj_vol_mcf',
#  'water_inj_vol_bbl',
#  'inj_days',
#  'surf_inj_press_psi',
#  'water_source',
#  'water_kind',
#  'rep_or_est',
#  'rep_or_est_cd',
#  'PWT__ID',
#  'active_days',
#  'api_key']

# %%
#df_sql.drop(columns=['well_id_x','well_id_y'], inplace=True)

# %% [markdown]
# # Finished building `df_wells` table, SQL time
# Now I'll do a few checks to make sure there aren't duplicate rows, and then it can inserted into the `wells` table (or `wells_test` if it's a test run)

# %%
# Check the df_wells dataframe for unique row count on the API number
print(f"Number of unique APIs from wells table: {len(df_wells_sql):,}")
assert(len(df_wells_sql) == df_wells.index.nunique())
# Out:
# Number of unique APIs from wells table: 277,297

# %%
# rename some of the CalGEM fields to the original well table field names
# these mainly come from the SELECT * in the beginning, updated some names for consistency
# first we'll put the api_key index back to a column so it gets picked up in the SQL insert later
df_wells_sql.rename(columns={
    'APIKey1':'api_key',
    'Section':'loc_section',
#    'loc_subsection':'loc_subsec',
    'Range':'loc_range',
    'field_code':'field_cd',
    'area_code':'area_cd',
    'pool_code':'pool_cd'
}, inplace=True)

progress.value += 1
list(df_wells_sql.columns)
# Out:
# ['PWT__ID',
#  'field_cd',
#  'area_cd',
#  'api_no',
#  'loc_section',
#  'loc_township',
#  'loc_range',
#  'loc_bm',
#  'operator_cd',
#  'lease_name',
#  'well_number',
#  'field_name',
#  'area_name',
#  'operator_name',
#  'report_type',
#  'county',
#  'pool_cd',
#  'well_type_cd',
#  'pool_name',
#  'well_status_cd',
#  'well_type_no',
#  'operator_status_cd',
#  'dist_no',
#  'api_key',
#  'oil_prod_vol_bbl',
#  'gas_prod_vol_mcf',
#  'gas_inj_vol_mcf',
#  'water_inj_vol_bbl',
#  'active_days',
#  'last_well_mo',
#  'prod_inj_cd',
#  'well_status_cng',
#  'well_type_cng',
#  'YEAR_INT']

# %%
print(f"Number of unique APIs from monthly volumes: {df_wells_from_mv.index.nunique():,}")
# Out:
# Number of unique APIs from monthly volumes: 113,468

# %%
# api_no is now the 1st index of the multi-index created above
# checking number of rows equals number of unique wells, so we don't have any double entries
assert(len(df_wells_from_mv) == df_wells_from_mv.index.nunique())

# %%
df_wells_sql
# Out:
#           PWT__ID field_cd area_cd        api_no loc_section loc_township  \
# 0       100000001      000      00  040370049400           4           1N
# 1       100000002      000      00  040370116700           4           1N
# 2       100000003      000      00  040712006500          29          30S
# 3       100000004      000      00  040712006000          26           3N
# 4       100000005      000      00  040712006100          28          31S
# ...           ...      ...     ...           ...         ...          ...
# 277292  100320508      340      00  040306375500           5          29S
# 277293  100320509      340      00  040306375500           5          29S
# 277294  100320510      464      00  040296988200          24          11N
# 277295  100320511      464      00  040296696000          24          11N
# 277296  100320512      464      00  040295768000          24          11N
#
#        loc_range loc_bm operator_cd          lease_name well_number  \
# 0            17W     SB       K2100               Knapp           3
# 1            17W     SB       L2150          Lucky Star           1
# 2            41E     MD       K1855  Kitchens Oil Baron           1
# 3             6W     SB       U0515             Federal        2-26
# 4            41E     SB       U0515           Kitchen's         101
# ...          ...    ...         ...                 ...         ...
# 277292       28E     MD       C5640         San Joaquin        216R
# 277293       28E     MD       C5640         San Joaquin        216R
# 277294       23W     SB       A0610              Metson    SWD 4-24
# 277295       23W     SB       A0610              Metson    SWD 3-24
# 277296       23W     SB       A0610              Metson      C24-24
#
#            field_name area_name            operator_name report_type  \
# 0           Any Field  Any Area              Frank Knapp          50
# 1           Any Field  Any Area        Liu Cheng and Lin          50
# 2           Any Field  Any Area      Charles L. Kitchens          50
# 3           Any Field  Any Area  U. S. Geological Survey          50
# 4           Any Field  Any Area  U. S. Geological Survey          50
# ...               ...       ...                      ...         ...
# 277292     Kern River  Any Area      Chevron U.S.A. Inc.          99
# 277293     Kern River  Any Area      Chevron U.S.A. Inc.          99
# 277294  Midway-Sunset  Any Area          Aera Energy LLC          99
# 277295  Midway-Sunset  Any Area          Aera Energy LLC          99
# 277296  Midway-Sunset  Any Area          Aera Energy LLC          99
#
#                 county pool_cd well_type_cd           pool_name  \
# 0          Los Angeles      00           OG   No Pool Breakdown
# 1          Los Angeles      00           OG   No Pool Breakdown
# 2       San Bernardino      00           OG   No Pool Breakdown
# 3       San Bernardino      00           OG   No Pool Breakdown
# 4       San Bernardino      00           OG   No Pool Breakdown
# ...                ...     ...          ...                 ...
# 277292            Kern      05           OG          Kern River
# 277293            Kern      05           SC          Kern River
# 277294            Kern      23           WD  Tulare-San Joaquin
# 277295            Kern      23           WD  Tulare-San Joaquin
# 277296            Kern      23           WD  Tulare-San Joaquin
#
#        well_status_cd well_type_no operator_status_cd  dist_no  \
# 0                   U            2               None        0
# 1                   U            2               None        0
# 2                   U            2               None        0
# 3                   U            2               None        0
# 4                   U            2               None        0
# ...               ...          ...                ...      ...
# 277292              U            2               None        0
# 277293              U            A               None        0
# 277294              U            6               None        0
# 277295              U            6               None        0
# 277296              U            6               None        0
#
#                           api_key  oil_prod_vol_bbl  gas_prod_vol_mcf  \
# 0       040370049400-000-00-00-OG               NaN               NaN
# 1       040370116700-000-00-00-OG               NaN               NaN
# 2       040712006500-000-00-00-OG               NaN               NaN
# 3       040712006000-000-00-00-OG               NaN               NaN
# 4       040712006100-000-00-00-OG               NaN               NaN
# ...                           ...               ...               ...
# 277292  040306375500-340-00-05-OG               NaN               NaN
# 277293  040306375500-340-00-05-SC               NaN               NaN
# 277294  040296988200-464-00-23-WD               0.0               0.0
# 277295  040296696000-464-00-23-WD               0.0               0.0
# 277296  040295768000-464-00-23-WD               NaN               NaN
#
#         gas_inj_vol_mcf  water_inj_vol_bbl  active_days  last_well_mo  \
# 0                   NaN                NaN          NaN          <NA>
# 1                   NaN                NaN          NaN          <NA>
# 2                   NaN                NaN          NaN          <NA>
# 3                   NaN                NaN          NaN          <NA>
# 4                   NaN                NaN          NaN          <NA>
# ...                 ...                ...          ...           ...
# 277292              NaN                NaN          NaN          <NA>
# 277293              NaN                NaN          NaN          <NA>
# 277294              0.0           570700.0        364.0             0
# 277295              0.0                0.0          0.0             0
# 277296              NaN                NaN          NaN          <NA>
#
#        prod_inj_cd well_status_cng well_type_cng  YEAR_INT
# 0              NaN             NaN           NaN       NaN
# 1              NaN             NaN           NaN       NaN
# 2              NaN             NaN           NaN       NaN
# 3              NaN             NaN           NaN       NaN
# 4              NaN             NaN           NaN       NaN
# ...            ...             ...           ...       ...
# 277292         NaN             NaN           NaN       NaN
# 277293         NaN             NaN           NaN       NaN
# 277294           0           False         False    2017.0
# 277295           0           False         False    2017.0
# 277296         NaN             NaN           NaN       NaN
#
# [277297 rows x 34 columns]

# %% [markdown]
# ### Add some extra information to the query - this is data that's the same for all wells
# in the original data set `REPORT_MO` was used for the Reporting method (50 series = hard copy, 90 series = computerized) - so this will all be 99 now to represent the WellStar data submissions

# %%
# add the extra helper columns the destination is expecting
# Add the year of the dataset to all the columns
# This is also used later to pull all the new WELL_ID records
# the item() call converts the pandas or numpy int64 type to basic python int which is needed for MySQL later
#   (MySQL connector doesn't understand pandas or numpy datatypes)
query_year = df['vol_year'].max().item()
df_wells_sql['YEAR_INT'] = query_year
print(f"Query year dataset={query_year}; type={type(query_year)}")

df_wells_sql['report_mo'] = 99
df_wells_sql['api_no_int'] = df_wells_sql['api_no'].astype(int)
progress.value += 1
# Out:
# Query year dataset=2017; type=<class 'int'>

# %%
# this is the list of columns to insert into the wells table
wells_cols = list(df_wells_sql.columns)
wells_cols
# Out:
# ['PWT__ID',
#  'field_cd',
#  'area_cd',
#  'api_no',
#  'loc_section',
#  'loc_township',
#  'loc_range',
#  'loc_bm',
#  'operator_cd',
#  'lease_name',
#  'well_number',
#  'field_name',
#  'area_name',
#  'operator_name',
#  'report_type',
#  'county',
#  'pool_cd',
#  'well_type_cd',
#  'pool_name',
#  'well_status_cd',
#  'well_type_no',
#  'operator_status_cd',
#  'dist_no',
#  'api_key',
#  'oil_prod_vol_bbl',
#  'gas_prod_vol_mcf',
#  'gas_inj_vol_mcf',
#  'water_inj_vol_bbl',
#  'active_days',
#  'last_well_mo',
#  'prod_inj_cd',
#  'well_status_cng',
#  'well_type_cng',
#  'YEAR_INT',
#  'report_mo',
#  'api_no_int']

# %%
mv_cols = list(df_sql.columns)
mv_cols
# Out:
# ['api_no',
#  'api_no_int',
#  'prod_inj_date',
#  'vol_month',
#  'vol_year',
#  'well_status_no',
#  'well_status',
#  'well_type_cd',
#  'well_status_cd',
#  'casing_psi',
#  'tubing_psi',
#  'gas_btu',
#  'well_mo',
#  'oil_api_grav',
#  'water_disposition',
#  'oil_prod_vol_bbl',
#  'prod_days',
#  'gas_prod_vol_mcf',
#  'water_prod_vol_bbl',
#  'gas_inj_vol_mcf',
#  'water_inj_vol_bbl',
#  'inj_days',
#  'surf_inj_press_psi',
#  'water_source',
#  'water_kind',
#  'rep_or_est',
#  'rep_or_est_cd',
#  'PWT__ID',
#  'active_days',
#  'api_key']

# %%
# After inserting a new well/year row into "wells". use "mycursor.lastrowid" or "connection.insert_id()" to get the Last inserted ID for the monthly_well_volumes table
mysql_dbname = "doggr"
mysql_well_tablename ='wells'
mysql_mv_tablename = 'monthly_well_volume'

# Connect to the mysql server to add the data
# SQLAlchemy uses a database driver to connect, in this case I'll use mysql-connector-python
conn_str = f"mysql+mysqlconnector://pythonuser:pythonuser@localhost/{mysql_dbname}"
engine = create_engine(conn_str, echo=True)
progress.value += 1

# %% [markdown]
# ### Add the master record to `doggr_file` table
# ### Run the MYSQL Insert queries for the well records in `df_wells`
# This helps track which original data sources each set originated from

# %%
query_year
# Out:
# 2017

# %%
sql = f"INSERT INTO doggr_file (file_name, well_count) VALUES('{mssql_db_name}','{df_wells['api_no'].nunique()}')"

# use `begin()` to start a transaction, which is then used in all the chained queries below.
with engine.begin() as conn:

    try:
        # insert the source file record
        doggr_file_id = conn.execute(text(sql)).lastrowid
        df_wells_sql['doggr_file_id'] = doggr_file_id
        progress.value += 2

        # insert all the well records
        df_wells_sql.to_sql(name=mysql_well_tablename, if_exists='append', index=False, index_label='WELL_ID', chunksize=10000, con=conn )
        progress.value += 5

        result = conn.execute(
            text(f"SELECT well_id, PWT__ID FROM {mysql_well_tablename} WHERE year_int=:year_int"), {"year_int":query_year})

        # Get the well_id list by api_key
        wellid_pwtid_df = pd.DataFrame(result.fetchall(), columns=result.keys())
        progress.value += 5

        # attach the well_id to the monthly volumes
        df_sql = pd.merge( df_sql, wellid_pwtid_df, how='left', on='PWT__ID')

        # insert all the monthly volume data
        df_sql.to_sql(name=mysql_mv_tablename, if_exists='append', index=False, index_label='well_id', chunksize=10000, con=conn )

        conn.commit()
        progress.value += 5

    except Exception as e:
        conn.rollback()
        print(f"SQL error: {e}")
        raise
# Out:
# 2025-02-05 12:17:06,833 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-02-05 12:17:06,833 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-05 12:17:06,835 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-02-05 12:17:06,835 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-05 12:17:06,836 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-02-05 12:17:06,837 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-05 12:17:06,838 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-05 12:17:06,840 INFO sqlalchemy.engine.Engine INSERT INTO doggr_file (file_name, well_count) VALUES('WellProductionInjectionLegacy','188879')
# 2025-02-05 12:17:06,840 INFO sqlalchemy.engine.Engine [generated in 0.00095s] {}
# 2025-02-05 12:17:07,069 INFO sqlalchemy.engine.Engine DESCRIBE `doggr`.`wells`
# 2025-02-05 12:17:07,070 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-02-05 12:17:07,889 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:07,890 INFO sqlalchemy.engine.Engine [generated in 0.17318s] [{'PWT__ID': 100000001, 'field_cd': '000', 'area_cd': '00', 'api_no': '040370049400', 'loc_section': '4', 'loc_township': ' 1N', 'loc_range': '17W', 'loc_bm': 'SB', 'operator_cd': 'K2100', 'lease_name': 'Knapp', 'well_number': '3', 'field_name': 'Any Field', 'area_name': 'Any Area', 'operator_name': 'Frank Knapp', 'report_type': '50', 'county': 'Los Angeles', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040370049400-000-00-00-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40370049400, 'doggr_file_id': 117}, {'PWT__ID': 100000002, 'field_cd': '000', 'area_cd': '00', 'api_no': '040370116700', 'loc_section': '4', 'loc_township': ' 1N', 'loc_range': '17W', 'loc_bm': 'SB', 'operator_cd': 'L2150', 'lease_name': 'Lucky Star', 'well_number': '1', 'field_name': 'Any Field', 'area_name': 'Any Area', 'operator_name': 'Liu Cheng and Lin', 'report_type': '50', 'county': 'Los Angeles', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040370116700-000-00-00-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40370116700, 'doggr_file_id': 117}, {'PWT__ID': 100000003, 'field_cd': '000', 'area_cd': '00', 'api_no': '040712006500', 'loc_section': '29', 'loc_township': '30S', 'loc_range': '41E', 'loc_bm': 'MD', 'operator_cd': 'K1855', 'lease_name': 'Kitchens Oil Baron', 'well_number': '1', 'field_name': 'Any Field', 'area_name': 'Any Area', 'operator_name': 'Charles L. Kitchens', 'report_type': '50', 'county': 'San Bernardino', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040712006500-000-00-00-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40712006500, 'doggr_file_id': 117}, {'PWT__ID': 100000004, 'field_cd': '000', 'area_cd': '00', 'api_no': '040712006000', 'loc_section': '26', 'loc_township': ' 3N', 'loc_range': ' 6W', 'loc_bm': 'SB', 'operator_cd': 'U0515', 'lease_name': 'Federal', 'well_number': '2-26', 'field_name': 'Any Field', 'area_name': 'Any Area', 'operator_name': 'U. S. Geological Survey', 'report_type': '50', 'county': 'San Bernardino', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040712006000-000-00-00-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40712006000, 'doggr_file_id': 117}, {'PWT__ID': 100000005, 'field_cd': '000', 'area_cd': '00', 'api_no': '040712006100', 'loc_section': '28', 'loc_township': '31S', 'loc_range': '41E', 'loc_bm': 'SB', 'operator_cd': 'U0515', 'lease_name': "Kitchen's", 'well_number': '101', 'field_name': 'Any Field', 'area_name': 'Any Area', 'operator_name': 'U. S. Geological Survey', 'report_type': '50', 'county': 'San Bernardino', 'pool_cd': '00', 'well_type_cd': 'OG' ...
# 2025-02-05 12:17:09,240 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:09,240 INFO sqlalchemy.engine.Engine [cached since 1.523s ago] [{'PWT__ID': 100010143, 'field_cd': '010', 'area_cd': '00', 'api_no': '040372131900', 'loc_section': '28', 'loc_township': ' 3N', 'loc_range': '16W', 'loc_bm': 'SB', 'operator_cd': 'S4700', 'lease_name': 'Porter', 'well_number': '26E', 'field_name': 'Aliso Canyon', 'area_name': 'Any Area', 'operator_name': 'Southern Calif. Gas Co.', 'report_type': '99', 'county': 'Los Angeles', 'pool_cd': '30', 'well_type_cd': 'GS', 'pool_name': 'Sesnon-Frew', 'well_status_cd': 'U', 'well_type_no': '3', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040372131900-010-00-30-GS', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 0, 'prod_inj_cd': '2', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40372131900, 'doggr_file_id': 117}, {'PWT__ID': 100010144, 'field_cd': '010', 'area_cd': '00', 'api_no': '040372131900', 'loc_section': '28', 'loc_township': ' 3N', 'loc_range': '16W', 'loc_bm': 'SB', 'operator_cd': 'S4700', 'lease_name': 'Porter', 'well_number': '26E', 'field_name': 'Aliso Canyon', 'area_name': 'Any Area', 'operator_name': 'Southern Calif. Gas Co.', 'report_type': '99', 'county': 'Los Angeles', 'pool_cd': '30', 'well_type_cd': 'OG', 'pool_name': 'Sesnon-Frew', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040372131900-010-00-30-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40372131900, 'doggr_file_id': 117}, {'PWT__ID': 100010145, 'field_cd': '010', 'area_cd': '00', 'api_no': '040372127700', 'loc_section': '27', 'loc_township': ' 3N', 'loc_range': '16W', 'loc_bm': 'SB', 'operator_cd': 'S4700', 'lease_name': 'Porter', 'well_number': '32A', 'field_name': 'Aliso Canyon', 'area_name': 'Any Area', 'operator_name': 'Southern Calif. Gas Co.', 'report_type': '99', 'county': 'Los Angeles', 'pool_cd': '30', 'well_type_cd': 'GS', 'pool_name': 'Sesnon-Frew', 'well_status_cd': 'U', 'well_type_no': '3', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040372127700-010-00-30-GS', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 0, 'prod_inj_cd': '2', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40372127700, 'doggr_file_id': 117}, {'PWT__ID': 100010146, 'field_cd': '010', 'area_cd': '00', 'api_no': '040372127700', 'loc_section': '27', 'loc_township': ' 3N', 'loc_range': '16W', 'loc_bm': 'SB', 'operator_cd': 'S4700', 'lease_name': 'Porter', 'well_number': '32A', 'field_name': 'Aliso Canyon', 'area_name': 'Any Area', 'operator_name': 'Southern Calif. Gas Co.', 'report_type': '99', 'county': 'Los Angeles', 'pool_cd': '30', 'well_type_cd': 'OG', 'pool_name': 'Sesnon-Frew', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040372127700-010-00-30-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40372127700, 'doggr_file_id': 117}, {'PWT__ID': 100010147, 'field_cd': '010', 'area_cd': '00', 'api_no': '040372127600', 'loc_section': '27', 'loc_township': ' 3N', 'loc_range': '16W', 'loc_bm': 'SB', 'operator_cd': 'S4700', 'lease_name': 'Porter', 'well_number': '32B', 'field_name': 'Aliso Canyon', 'area_name': 'Any Area', 'operator_name': 'Southern Calif. Gas Co.', 'report_type': '99', 'county': 'Los Angeles', 'pool_cd': '30', 'well_type_cd': 'GS', 'pool_name': 'Sesnon-Frew', 'well_ ...
# 2025-02-05 12:17:10,671 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:10,672 INFO sqlalchemy.engine.Engine [cached since 2.955s ago] [{'PWT__ID': 100020783, 'field_cd': '020', 'area_cd': '06', 'api_no': '040297370700', 'loc_section': '6', 'loc_township': '28S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'E0100', 'lease_name': 'Williams', 'well_number': '165E-6', 'field_name': 'Antelope Hills', 'area_name': 'Williams Area', 'operator_name': 'E & B Nat. Res. Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Upper', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040297370700-020-06-05-OG', 'oil_prod_vol_bbl': 891.0, 'gas_prod_vol_mcf': 11.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 4, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40297370700, 'doggr_file_id': 117}, {'PWT__ID': 100020784, 'field_cd': '020', 'area_cd': '06', 'api_no': '040297370800', 'loc_section': '6', 'loc_township': '28S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'E0100', 'lease_name': 'Williams', 'well_number': '405E-6', 'field_name': 'Antelope Hills', 'area_name': 'Williams Area', 'operator_name': 'E & B Nat. Res. Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '20', 'well_type_cd': 'OG', 'pool_name': 'West Block-Button Bed & Agua', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040297370800-020-06-20-OG', 'oil_prod_vol_bbl': 1133.0, 'gas_prod_vol_mcf': 27.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 4, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40297370800, 'doggr_file_id': 117}, {'PWT__ID': 100020785, 'field_cd': '020', 'area_cd': '06', 'api_no': '040297370900', 'loc_section': '6', 'loc_township': '28S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'E0100', 'lease_name': 'Williams', 'well_number': '545E-6', 'field_name': 'Antelope Hills', 'area_name': 'Williams Area', 'operator_name': 'E & B Nat. Res. Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Upper', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040297370900-020-06-05-OG', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 0, 'prod_inj_cd': '2', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40297370900, 'doggr_file_id': 117}, {'PWT__ID': 100020786, 'field_cd': '020', 'area_cd': '06', 'api_no': '040297371000', 'loc_section': '6', 'loc_township': '28S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'E0100', 'lease_name': 'Williams', 'well_number': '706E-6', 'field_name': 'Antelope Hills', 'area_name': 'Williams Area', 'operator_name': 'E & B Nat. Res. Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Upper', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040297371000-020-06-05-OG', 'oil_prod_vol_bbl': 925.0, 'gas_prod_vol_mcf': 21.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 4, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40297371000, 'doggr_file_id': 117}, {'PWT__ID': 100020787, 'field_cd': '020', 'area_cd': '06', 'api_no': '040292391400', 'loc_section': '7', 'loc_township': '28S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'E0100', 'lease_name': 'Pickrell-Mitchel', 'well_number': '1', 'field_name': 'Antelope Hills', 'area_name': 'Williams Area', 'operator_name': 'E & B Nat. Res. Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '15', 'well_type_cd': 'OG', 'pool_ ...
# 2025-02-05 12:17:12,013 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:12,013 INFO sqlalchemy.engine.Engine [cached since 4.296s ago] [{'PWT__ID': 100031628, 'field_cd': '052', 'area_cd': '00', 'api_no': '040300814900', 'loc_section': '3', 'loc_township': '29S', 'loc_range': '21E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'Belridge III', 'well_number': '8052A-3', 'field_name': 'Belridge, South', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '20', 'well_type_cd': 'OG', 'pool_name': 'Diatomite', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300814900-052-00-20-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300814900, 'doggr_file_id': 117}, {'PWT__ID': 100031629, 'field_cd': '052', 'area_cd': '00', 'api_no': '040301045500', 'loc_section': '3', 'loc_township': '29S', 'loc_range': '21E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'Belridge III', 'well_number': '8057B-3', 'field_name': 'Belridge, South', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '20', 'well_type_cd': 'OG', 'pool_name': 'Diatomite', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301045500-052-00-20-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301045500, 'doggr_file_id': 117}, {'PWT__ID': 100031630, 'field_cd': '052', 'area_cd': '00', 'api_no': '040300815000', 'loc_section': '3', 'loc_township': '29S', 'loc_range': '21E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'Belridge III', 'well_number': '8076A-3', 'field_name': 'Belridge, South', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '20', 'well_type_cd': 'WF', 'pool_name': 'Diatomite', 'well_status_cd': 'U', 'well_type_no': '7', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300815000-052-00-20-WF', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300815000, 'doggr_file_id': 117}, {'PWT__ID': 100031631, 'field_cd': '052', 'area_cd': '00', 'api_no': '040300815000', 'loc_section': '3', 'loc_township': '29S', 'loc_range': '21E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'Belridge III', 'well_number': '8076A-3', 'field_name': 'Belridge, South', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '20', 'well_type_cd': 'OG', 'pool_name': 'Diatomite', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300815000-052-00-20-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300815000, 'doggr_file_id': 117}, {'PWT__ID': 100031632, 'field_cd': '052', 'area_cd': '00', 'api_no': '040300479800', 'loc_section': '3', 'loc_township': '29S', 'loc_range': '21E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'Belridge III', 'well_number': '8079S-3', 'field_name': 'Belridge, South', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '20', 'well_type_cd': 'OG', 'pool_name': 'Diatomite', ' ...
# 2025-02-05 12:17:13,403 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:13,404 INFO sqlalchemy.engine.Engine [cached since 5.687s ago] [{'PWT__ID': 100042156, 'field_cd': '228', 'area_cd': '00', 'api_no': '040300363800', 'loc_section': '19', 'loc_township': '30S', 'loc_range': '23E', 'loc_bm': 'MD', 'operator_cd': 'C0880', 'lease_name': '-19R', 'well_number': '315X', 'field_name': 'Elk Hills', 'area_name': 'Any Area', 'operator_name': 'California Resources Elk Hills, LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '22', 'well_type_cd': 'OG', 'pool_name': 'Stevens (29R)', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300363800-228-00-22-OG', 'oil_prod_vol_bbl': 466.0, 'gas_prod_vol_mcf': 25524.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300363800, 'doggr_file_id': 117}, {'PWT__ID': 100042157, 'field_cd': '228', 'area_cd': '00', 'api_no': '040301187000', 'loc_section': '2', 'loc_township': '31S', 'loc_range': '24E', 'loc_bm': 'MD', 'operator_cd': 'C0880', 'lease_name': '-2G', 'well_number': '27', 'field_name': 'Elk Hills', 'area_name': 'Any Area', 'operator_name': 'California Resources Elk Hills, LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '15', 'well_type_cd': 'OG', 'pool_name': 'Upper (Undifferentiated)', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301187000-228-00-15-OG', 'oil_prod_vol_bbl': 33.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 91.0, 'last_well_mo': 3, 'prod_inj_cd': '1', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301187000, 'doggr_file_id': 117}, {'PWT__ID': 100042158, 'field_cd': '228', 'area_cd': '00', 'api_no': '040301123200', 'loc_section': '2', 'loc_township': '31S', 'loc_range': '24E', 'loc_bm': 'MD', 'operator_cd': 'C0880', 'lease_name': '-2G', 'well_number': '72', 'field_name': 'Elk Hills', 'area_name': 'Any Area', 'operator_name': 'California Resources Elk Hills, LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '15', 'well_type_cd': 'OG', 'pool_name': 'Upper (Undifferentiated)', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301123200-228-00-15-OG', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 3, 'prod_inj_cd': '1', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301123200, 'doggr_file_id': 117}, {'PWT__ID': 100042159, 'field_cd': '228', 'area_cd': '00', 'api_no': '040301131100', 'loc_section': '2', 'loc_township': '31S', 'loc_range': '24E', 'loc_bm': 'MD', 'operator_cd': 'C0880', 'lease_name': '-2G', 'well_number': '26E', 'field_name': 'Elk Hills', 'area_name': 'Any Area', 'operator_name': 'California Resources Elk Hills, LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '15', 'well_type_cd': 'OG', 'pool_name': 'Upper (Undifferentiated)', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301131100-228-00-15-OG', 'oil_prod_vol_bbl': 3416.0, 'gas_prod_vol_mcf': 174651.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301131100, 'doggr_file_id': 117}, {'PWT__ID': 100042160, 'field_cd': '228', 'area_cd': '00', 'api_no': '040301186800', 'loc_section': '2', 'loc_township': '31S', 'loc_range': '24E', 'loc_bm': 'MD', 'operator_cd': 'C0880', 'lease_name': '-2G', 'well_number': '67N', 'field_name': 'Elk Hills', 'area_name': 'Any Area', 'operator_name': 'California Resources Elk Hills, LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '15', 'well_type_cd': 'OG', 'pool_name': ...
# 2025-02-05 12:17:15,994 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:15,994 INFO sqlalchemy.engine.Engine [cached since 8.277s ago] [{'PWT__ID': 100052582, 'field_cd': '340', 'area_cd': '00', 'api_no': '040295712700', 'loc_section': '19', 'loc_township': '28S', 'loc_range': '28E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': 'D & D A', 'well_number': '511', 'field_name': 'Kern River', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'SF', 'pool_name': 'Kern River', 'well_status_cd': 'U', 'well_type_no': '8', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040295712700-340-00-05-SF', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40295712700, 'doggr_file_id': 117}, {'PWT__ID': 100052584, 'field_cd': '340', 'area_cd': '00', 'api_no': '040292251200', 'loc_section': '19', 'loc_township': '28S', 'loc_range': '28E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': 'D & D B', 'well_number': '24', 'field_name': 'Kern River', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Kern River', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040292251200-340-00-05-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40292251200, 'doggr_file_id': 117}, {'PWT__ID': 100052585, 'field_cd': '340', 'area_cd': '00', 'api_no': '040294081700', 'loc_section': '19', 'loc_township': '28S', 'loc_range': '28E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': 'D & D B', 'well_number': '26', 'field_name': 'Kern River', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Kern River', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040294081700-340-00-05-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40294081700, 'doggr_file_id': 117}, {'PWT__ID': 100052586, 'field_cd': '340', 'area_cd': '00', 'api_no': '040295698100', 'loc_section': '19', 'loc_township': '28S', 'loc_range': '28E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': 'D & D B', 'well_number': '27', 'field_name': 'Kern River', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Kern River', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040295698100-340-00-05-OG', 'oil_prod_vol_bbl': 2949.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 361.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40295698100, 'doggr_file_id': 117}, {'PWT__ID': 100052587, 'field_cd': '340', 'area_cd': '00', 'api_no': '040295773400', 'loc_section': '19', 'loc_township': '28S', 'loc_range': '28E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': 'D & D B', 'well_number': '28', 'field_name': 'Kern River', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '05', 'well_type_cd': 'OG', 'pool_name': 'Kern River', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_s ...
# 2025-02-05 12:17:17,335 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:17,335 INFO sqlalchemy.engine.Engine [cached since 9.618s ago] [{'PWT__ID': 100063171, 'field_cd': '432', 'area_cd': '00', 'api_no': '040300336400', 'loc_section': '12', 'loc_township': '26S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'United', 'well_number': '8008', 'field_name': 'Lost Hills', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '10', 'well_type_cd': 'OG', 'pool_name': 'Tulare-Etchegoin', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300336400-432-00-10-OG', 'oil_prod_vol_bbl': 2093.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300336400, 'doggr_file_id': 117}, {'PWT__ID': 100063172, 'field_cd': '432', 'area_cd': '00', 'api_no': '040300336500', 'loc_section': '12', 'loc_township': '26S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'United', 'well_number': '8009', 'field_name': 'Lost Hills', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '10', 'well_type_cd': 'OG', 'pool_name': 'Tulare-Etchegoin', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300336500-432-00-10-OG', 'oil_prod_vol_bbl': 5169.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300336500, 'doggr_file_id': 117}, {'PWT__ID': 100063173, 'field_cd': '432', 'area_cd': '00', 'api_no': '040300336700', 'loc_section': '12', 'loc_township': '26S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'United', 'well_number': '8011', 'field_name': 'Lost Hills', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '10', 'well_type_cd': 'OG', 'pool_name': 'Tulare-Etchegoin', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300336700-432-00-10-OG', 'oil_prod_vol_bbl': 134.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 8, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300336700, 'doggr_file_id': 117}, {'PWT__ID': 100063174, 'field_cd': '432', 'area_cd': '00', 'api_no': '040300336800', 'loc_section': '12', 'loc_township': '26S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'United', 'well_number': '8012', 'field_name': 'Lost Hills', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '10', 'well_type_cd': 'OG', 'pool_name': 'Tulare-Etchegoin', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300336800-432-00-10-OG', 'oil_prod_vol_bbl': 828.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 362.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300336800, 'doggr_file_id': 117}, {'PWT__ID': 100063175, 'field_cd': '432', 'area_cd': '00', 'api_no': '040300336900', 'loc_section': '12', 'loc_township': '26S', 'loc_range': '20E', 'loc_bm': 'MD', 'operator_cd': 'A0610', 'lease_name': 'United', 'well_number': '8013', 'field_name': 'Lost Hills', 'area_name': 'Any Area', 'operator_name': 'Aera Energy LLC', 'report_type': '99', 'county': 'Kern', 'pool_cd': '10', 'well_type_cd': 'OG', 'pool_name': 'Tulare-Etchegoin', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, ' ...
# 2025-02-05 12:17:18,901 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:18,904 INFO sqlalchemy.engine.Engine [cached since 11.19s ago] [{'PWT__ID': 100073584, 'field_cd': '464', 'area_cd': '00', 'api_no': '040293896300', 'loc_section': '25', 'loc_township': '32S', 'loc_range': '23E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': None, 'well_number': '5P', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040293896300-464-00-00-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40293896300, 'doggr_file_id': 117}, {'PWT__ID': 100073585, 'field_cd': '464', 'area_cd': '00', 'api_no': '040292160200', 'loc_section': '25', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'C9035', 'lease_name': '<BLANK>', 'well_number': '6', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Crimson Resource Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040292160200-464-00-00-OG', 'oil_prod_vol_bbl': 338.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 365.0, 'last_well_mo': 3, 'prod_inj_cd': '0', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40292160200, 'doggr_file_id': 117}, {'PWT__ID': 100073586, 'field_cd': '464', 'area_cd': '00', 'api_no': '040293896400', 'loc_section': '25', 'loc_township': '32S', 'loc_range': '23E', 'loc_bm': 'MD', 'operator_cd': 'C5640', 'lease_name': None, 'well_number': '6P', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Chevron U.S.A. Inc.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040293896400-464-00-00-OG', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40293896400, 'doggr_file_id': 117}, {'PWT__ID': 100073587, 'field_cd': '464', 'area_cd': '00', 'api_no': '040290548600', 'loc_section': '23', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'C9035', 'lease_name': '<BLANK>', 'well_number': '7', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Crimson Resource Mgmt. Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd': 'U', 'well_type_no': '2', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040290548600-464-00-00-OG', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 0, 'prod_inj_cd': '2', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40290548600, 'doggr_file_id': 117}, {'PWT__ID': 100073588, 'field_cd': '464', 'area_cd': '00', 'api_no': '040290779400', 'loc_section': '9', 'loc_township': '11N', 'loc_range': '23W', 'loc_bm': 'SB', 'operator_cd': 'H5200', 'lease_name': None, 'well_number': '7', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Holmes Western Oil Corp.', 'report_type': '99', 'county': 'Kern', 'pool_cd': '00', 'well_type_cd': 'OG', 'pool_name': 'No Pool Breakdown', 'well_status_cd':  ...
# 2025-02-05 12:17:20,301 INFO sqlalchemy.engine.Engine INSERT INTO wells (`PWT__ID`, field_cd, area_cd, api_no, loc_section, loc_township, loc_range, loc_bm, operator_cd, lease_name, well_number, field_name, area_name, operator_name, report_type, county, pool_cd, well_type_cd, pool_name, well_status_cd, well_type_no, operator_status_cd, dist_no, api_key, oil_prod_vol_bbl, gas_prod_vol_mcf, gas_inj_vol_mcf, water_inj_vol_bbl, active_days, last_well_mo, prod_inj_cd, well_status_cng, well_type_cng, `YEAR_INT`, report_mo, api_no_int, doggr_file_id) VALUES (%(PWT__ID)s, %(field_cd)s, %(area_cd)s, %(api_no)s, %(loc_section)s, %(loc_township)s, %(loc_range)s, %(loc_bm)s, %(operator_cd)s, %(lease_name)s, %(well_number)s, %(field_name)s, %(area_name)s, %(operator_name)s, %(report_type)s, %(county)s, %(pool_cd)s, %(well_type_cd)s, %(pool_name)s, %(well_status_cd)s, %(well_type_no)s, %(operator_status_cd)s, %(dist_no)s, %(api_key)s, %(oil_prod_vol_bbl)s, %(gas_prod_vol_mcf)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(active_days)s, %(last_well_mo)s, %(prod_inj_cd)s, %(well_status_cng)s, %(well_type_cng)s, %(YEAR_INT)s, %(report_mo)s, %(api_no_int)s, %(doggr_file_id)s)
# 2025-02-05 12:17:20,304 INFO sqlalchemy.engine.Engine [cached since 12.59s ago] [{'PWT__ID': 100083943, 'field_cd': '464', 'area_cd': '00', 'api_no': '040300182700', 'loc_section': '16', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'S2641', 'lease_name': 'Bremer', 'well_number': 'I-58-16', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Sentinel Peak Resources CA, LLC', 'report_type': '95', 'county': 'Kern', 'pool_cd': '50', 'well_type_cd': 'SF', 'pool_name': 'Potter', 'well_status_cd': 'U', 'well_type_no': '8', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040300182700-464-00-50-SF', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 0, 'prod_inj_cd': '2', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40300182700, 'doggr_file_id': 117}, {'PWT__ID': 100083944, 'field_cd': '464', 'area_cd': '00', 'api_no': '040301044300', 'loc_section': '16', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'S2641', 'lease_name': 'Bremer', 'well_number': 'I-60-16', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Sentinel Peak Resources CA, LLC', 'report_type': '95', 'county': 'Kern', 'pool_cd': '50', 'well_type_cd': 'SF', 'pool_name': 'Potter', 'well_status_cd': 'U', 'well_type_no': '8', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301044300-464-00-50-SF', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301044300, 'doggr_file_id': 117}, {'PWT__ID': 100083945, 'field_cd': '464', 'area_cd': '00', 'api_no': '040301044400', 'loc_section': '16', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'S2641', 'lease_name': 'Bremer', 'well_number': 'I-61-16', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Sentinel Peak Resources CA, LLC', 'report_type': '95', 'county': 'Kern', 'pool_cd': '50', 'well_type_cd': 'SF', 'pool_name': 'Potter', 'well_status_cd': 'U', 'well_type_no': '8', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301044400-464-00-50-SF', 'oil_prod_vol_bbl': None, 'gas_prod_vol_mcf': None, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'active_days': None, 'last_well_mo': None, 'prod_inj_cd': None, 'well_status_cng': None, 'well_type_cng': None, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301044400, 'doggr_file_id': 117}, {'PWT__ID': 100083946, 'field_cd': '464', 'area_cd': '00', 'api_no': '040301044500', 'loc_section': '16', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'S2641', 'lease_name': 'Bremer', 'well_number': 'I-62-16', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Sentinel Peak Resources CA, LLC', 'report_type': '95', 'county': 'Kern', 'pool_cd': '50', 'well_type_cd': 'SF', 'pool_name': 'Potter', 'well_status_cd': 'U', 'well_type_no': '8', 'operator_status_cd': None, 'dist_no': 0, 'api_key': '040301044500-464-00-50-SF', 'oil_prod_vol_bbl': 0.0, 'gas_prod_vol_mcf': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'active_days': 0.0, 'last_well_mo': 0, 'prod_inj_cd': '2', 'well_status_cng': 0, 'well_type_cng': 0, 'YEAR_INT': 2017, 'report_mo': 99, 'api_no_int': 40301044500, 'doggr_file_id': 117}, {'PWT__ID': 100083947, 'field_cd': '464', 'area_cd': '00', 'api_no': '040301044600', 'loc_section': '16', 'loc_township': '31S', 'loc_range': '22E', 'loc_bm': 'MD', 'operator_cd': 'S2641', 'lease_name': 'Bremer', 'well_number': 'I-63-16', 'field_name': 'Midway-Sunset', 'area_name': 'Any Area', 'operator_name': 'Sentinel Peak Resources CA, LLC', 'report_type': '95', 'county': 'Kern', 'pool_cd': '50', 'well_type_cd': 'SF', 'pool_name': 'Potter', ' ...
# ...
# 2025-02-05 12:20:53,248 INFO sqlalchemy.engine.Engine INSERT INTO monthly_well_volume (api_no, api_no_int, prod_inj_date, vol_month, vol_year, well_status_no, well_status, well_type_cd, well_status_cd, casing_psi, tubing_psi, gas_btu, well_mo, oil_api_grav, water_disposition, oil_prod_vol_bbl, prod_days, gas_prod_vol_mcf, water_prod_vol_bbl, gas_inj_vol_mcf, water_inj_vol_bbl, inj_days, surf_inj_press_psi, water_source, water_kind, rep_or_est, rep_or_est_cd, `PWT__ID`, active_days, api_key, well_id) VALUES (%(api_no)s, %(api_no_int)s, %(prod_inj_date)s, %(vol_month)s, %(vol_year)s, %(well_status_no)s, %(well_status)s, %(well_type_cd)s, %(well_status_cd)s, %(casing_psi)s, %(tubing_psi)s, %(gas_btu)s, %(well_mo)s, %(oil_api_grav)s, %(water_disposition)s, %(oil_prod_vol_bbl)s, %(prod_days)s, %(gas_prod_vol_mcf)s, %(water_prod_vol_bbl)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(inj_days)s, %(surf_inj_press_psi)s, %(water_source)s, %(water_kind)s, %(rep_or_est)s, %(rep_or_est_cd)s, %(PWT__ID)s, %(active_days)s, %(api_key)s, %(well_id)s)
# 2025-02-05 12:20:53,249 INFO sqlalchemy.engine.Engine [cached since 160.9s ago] [{'api_no': '040373047100', 'api_no_int': 40373047100, 'prod_inj_date': datetime.date(2017, 2, 1), 'vol_month': 2, 'vol_year': 2017, 'well_status_no': '06', 'well_status': 'Idle', 'well_type_cd': 'GS', 'well_status_cd': 'I', 'casing_psi': 0, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 0, 'oil_api_grav': 23.2, 'water_disposition': 0, 'oil_prod_vol_bbl': 0.0, 'prod_days': 0.0, 'gas_prod_vol_mcf': 0.0, 'water_prod_vol_bbl': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'inj_days': 0.0, 'surf_inj_press_psi': 0, 'water_source': 0, 'water_kind': 0, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100313266, 'active_days': 0.0, 'api_key': '040373047100-010-00-30-GS', 'well_id': 13825579}, {'api_no': '040373047100', 'api_no_int': 40373047100, 'prod_inj_date': datetime.date(2017, 2, 1), 'vol_month': 2, 'vol_year': 2017, 'well_status_no': '06', 'well_status': 'Idle', 'well_type_cd': 'GS', 'well_status_cd': 'I', 'casing_psi': 0, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 0, 'oil_api_grav': 23.2, 'water_disposition': 0, 'oil_prod_vol_bbl': 0.0, 'prod_days': 0.0, 'gas_prod_vol_mcf': 0.0, 'water_prod_vol_bbl': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'inj_days': 0.0, 'surf_inj_press_psi': 0, 'water_source': 0, 'water_kind': 0, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100313266, 'active_days': 0.0, 'api_key': '040373047100-010-00-30-GS', 'well_id': 13825579}, {'api_no': '040373047100', 'api_no_int': 40373047100, 'prod_inj_date': datetime.date(2017, 2, 1), 'vol_month': 2, 'vol_year': 2017, 'well_status_no': '06', 'well_status': 'Idle', 'well_type_cd': 'GS', 'well_status_cd': 'I', 'casing_psi': 0, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 0, 'oil_api_grav': 23.2, 'water_disposition': 0, 'oil_prod_vol_bbl': 0.0, 'prod_days': 0.0, 'gas_prod_vol_mcf': 0.0, 'water_prod_vol_bbl': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'inj_days': 0.0, 'surf_inj_press_psi': 0, 'water_source': 0, 'water_kind': 0, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100313266, 'active_days': 0.0, 'api_key': '040373047100-010-00-30-GS', 'well_id': 13825579}, {'api_no': '040373047100', 'api_no_int': 40373047100, 'prod_inj_date': datetime.date(2017, 2, 1), 'vol_month': 2, 'vol_year': 2017, 'well_status_no': '06', 'well_status': 'Idle', 'well_type_cd': 'GS', 'well_status_cd': 'I', 'casing_psi': 0, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 0, 'oil_api_grav': 23.2, 'water_disposition': 0, 'oil_prod_vol_bbl': 0.0, 'prod_days': 0.0, 'gas_prod_vol_mcf': 0.0, 'water_prod_vol_bbl': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'inj_days': 0.0, 'surf_inj_press_psi': 0, 'water_source': 0, 'water_kind': 0, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100313266, 'active_days': 0.0, 'api_key': '040373047100-010-00-30-GS', 'well_id': 13825579}, {'api_no': '040373047100', 'api_no_int': 40373047100, 'prod_inj_date': datetime.date(2017, 2, 1), 'vol_month': 2, 'vol_year': 2017, 'well_status_no': '06', 'well_status': 'Idle', 'well_type_cd': 'GS', 'well_status_cd': 'I', 'casing_psi': 0, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 0, 'oil_api_grav': 23.2, 'water_disposition': 0, 'oil_prod_vol_bbl': 0.0, 'prod_days': 0.0, 'gas_prod_vol_mcf': 0.0, 'water_prod_vol_bbl': 0.0, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 0.0, 'inj_days': 0.0, 'surf_inj_press_psi': 0, 'water_source': 0, 'water_kind': 0, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100313266, 'active_days': 0.0, 'api_key': '040373047100-010-00-30-GS', 'well_id': 13825579}, {'api_no': '040373047100', 'api_no_int': 40373047100, 'prod_inj_date': datetime.date(2017, 2, 1), 'vol_month': 2, 'vol_year': 2017, 'well_status_no': '06', 'well_status': 'Idle', 'well_type_cd': 'GS', 'well_status_cd': 'I', 'casing_psi': 0, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 0, 'oil_api_grav': 23.2, 'water_disposition': 0, 'oil_prod_vol_bbl': 0.0, 'prod_days': 0.0, 'gas_prod_vol_mcf': ...
# 2025-02-05 12:20:54,580 INFO sqlalchemy.engine.Engine INSERT INTO monthly_well_volume (api_no, api_no_int, prod_inj_date, vol_month, vol_year, well_status_no, well_status, well_type_cd, well_status_cd, casing_psi, tubing_psi, gas_btu, well_mo, oil_api_grav, water_disposition, oil_prod_vol_bbl, prod_days, gas_prod_vol_mcf, water_prod_vol_bbl, gas_inj_vol_mcf, water_inj_vol_bbl, inj_days, surf_inj_press_psi, water_source, water_kind, rep_or_est, rep_or_est_cd, `PWT__ID`, active_days, api_key, well_id) VALUES (%(api_no)s, %(api_no_int)s, %(prod_inj_date)s, %(vol_month)s, %(vol_year)s, %(well_status_no)s, %(well_status)s, %(well_type_cd)s, %(well_status_cd)s, %(casing_psi)s, %(tubing_psi)s, %(gas_btu)s, %(well_mo)s, %(oil_api_grav)s, %(water_disposition)s, %(oil_prod_vol_bbl)s, %(prod_days)s, %(gas_prod_vol_mcf)s, %(water_prod_vol_bbl)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(inj_days)s, %(surf_inj_press_psi)s, %(water_source)s, %(water_kind)s, %(rep_or_est)s, %(rep_or_est_cd)s, %(PWT__ID)s, %(active_days)s, %(api_key)s, %(well_id)s)
# 2025-02-05 12:20:54,580 INFO sqlalchemy.engine.Engine [cached since 162.3s ago] [{'api_no': '040306054600', 'api_no_int': 40306054600, 'prod_inj_date': datetime.date(2017, 3, 1), 'vol_month': 3, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 167.0, 'inj_days': 1.0, 'surf_inj_press_psi': 50, 'water_source': 1, 'water_kind': 3, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100316469, 'active_days': 1.0, 'api_key': '040306054600-340-00-05-SC', 'well_id': 13828732}, {'api_no': '040306054600', 'api_no_int': 40306054600, 'prod_inj_date': datetime.date(2017, 4, 1), 'vol_month': 4, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 158.0, 'inj_days': 1.0, 'surf_inj_press_psi': 25, 'water_source': 1, 'water_kind': 3, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100316469, 'active_days': 1.0, 'api_key': '040306054600-340-00-05-SC', 'well_id': 13828732}, {'api_no': '040306054600', 'api_no_int': 40306054600, 'prod_inj_date': datetime.date(2017, 6, 1), 'vol_month': 6, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 485.0, 'inj_days': 1.0, 'surf_inj_press_psi': 42, 'water_source': 1, 'water_kind': 3, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100316469, 'active_days': 1.0, 'api_key': '040306054600-340-00-05-SC', 'well_id': 13828732}, {'api_no': '040306054600', 'api_no_int': 40306054600, 'prod_inj_date': datetime.date(2017, 7, 1), 'vol_month': 7, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 175.0, 'inj_days': 1.0, 'surf_inj_press_psi': 45, 'water_source': 1, 'water_kind': 3, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100316469, 'active_days': 1.0, 'api_key': '040306054600-340-00-05-SC', 'well_id': 13828732}, {'api_no': '040306054600', 'api_no_int': 40306054600, 'prod_inj_date': datetime.date(2017, 8, 1), 'vol_month': 8, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 179.0, 'inj_days': 1.0, 'surf_inj_press_psi': 45, 'water_source': 1, 'water_kind': 3, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100316469, 'active_days': 1.0, 'api_key': '040306054600-340-00-05-SC', 'well_id': 13828732}, {'api_no': '040306131000', 'api_no_int': 40306131000, 'prod_inj_date': datetime.date(2017, 1, 1), 'vol_month': 1, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_ap ...
# 2025-02-05 12:20:55,858 INFO sqlalchemy.engine.Engine INSERT INTO monthly_well_volume (api_no, api_no_int, prod_inj_date, vol_month, vol_year, well_status_no, well_status, well_type_cd, well_status_cd, casing_psi, tubing_psi, gas_btu, well_mo, oil_api_grav, water_disposition, oil_prod_vol_bbl, prod_days, gas_prod_vol_mcf, water_prod_vol_bbl, gas_inj_vol_mcf, water_inj_vol_bbl, inj_days, surf_inj_press_psi, water_source, water_kind, rep_or_est, rep_or_est_cd, `PWT__ID`, active_days, api_key, well_id) VALUES (%(api_no)s, %(api_no_int)s, %(prod_inj_date)s, %(vol_month)s, %(vol_year)s, %(well_status_no)s, %(well_status)s, %(well_type_cd)s, %(well_status_cd)s, %(casing_psi)s, %(tubing_psi)s, %(gas_btu)s, %(well_mo)s, %(oil_api_grav)s, %(water_disposition)s, %(oil_prod_vol_bbl)s, %(prod_days)s, %(gas_prod_vol_mcf)s, %(water_prod_vol_bbl)s, %(gas_inj_vol_mcf)s, %(water_inj_vol_bbl)s, %(inj_days)s, %(surf_inj_press_psi)s, %(water_source)s, %(water_kind)s, %(rep_or_est)s, %(rep_or_est_cd)s, %(PWT__ID)s, %(active_days)s, %(api_key)s, %(well_id)s)
# 2025-02-05 12:20:55,858 INFO sqlalchemy.engine.Engine [cached since 163.5s ago] [{'api_no': '040305503000', 'api_no_int': 40305503000, 'prod_inj_date': datetime.date(2017, 10, 1), 'vol_month': 10, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 3364.0, 'inj_days': 22.0, 'surf_inj_press_psi': 249, 'water_source': 1, 'water_kind': 2, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100319890, 'active_days': 22.0, 'api_key': '040305503000-338-00-00-SC', 'well_id': 13832076}, {'api_no': '040306284100', 'api_no_int': 40306284100, 'prod_inj_date': datetime.date(2017, 12, 1), 'vol_month': 12, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'OG', 'well_status_cd': 'A', 'casing_psi': 8, 'tubing_psi': 0, 'gas_btu': 0, 'well_mo': 3, 'oil_api_grav': 12.7, 'water_disposition': 5, 'oil_prod_vol_bbl': 352.0, 'prod_days': 23.0, 'gas_prod_vol_mcf': 0.0, 'water_prod_vol_bbl': 5177.0, 'gas_inj_vol_mcf': None, 'water_inj_vol_bbl': None, 'inj_days': None, 'surf_inj_press_psi': None, 'water_source': 0, 'water_kind': 0, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100319891, 'active_days': 23.0, 'api_key': '040306284100-464-00-00-OG', 'well_id': 13832077}, {'api_no': '040306284100', 'api_no_int': 40306284100, 'prod_inj_date': datetime.date(2017, 12, 1), 'vol_month': 12, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 5, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 3060.0, 'inj_days': 2.0, 'surf_inj_press_psi': 0, 'water_source': 3, 'water_kind': 2, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100319892, 'active_days': 2.0, 'api_key': '040306284100-464-00-00-SC', 'well_id': 13832078}, {'api_no': '040290497000', 'api_no_int': 40290497000, 'prod_inj_date': datetime.date(2017, 10, 1), 'vol_month': 10, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 6, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 11963.0, 'inj_days': 12.0, 'surf_inj_press_psi': 480, 'water_source': 1, 'water_kind': 1, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100319893, 'active_days': 12.0, 'api_key': '040290497000-222-09-00-SC', 'well_id': 13832079}, {'api_no': '040306252500', 'api_no_int': 40306252500, 'prod_inj_date': datetime.date(2017, 12, 1), 'vol_month': 12, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, 'well_mo': 0, 'oil_api_grav': None, 'water_disposition': 0, 'oil_prod_vol_bbl': None, 'prod_days': None, 'gas_prod_vol_mcf': None, 'water_prod_vol_bbl': None, 'gas_inj_vol_mcf': 0.0, 'water_inj_vol_bbl': 6538.0, 'inj_days': 26.0, 'surf_inj_press_psi': 222, 'water_source': 1, 'water_kind': 1, 'rep_or_est': 'Reported', 'rep_or_est_cd': 1, 'PWT__ID': 100319895, 'active_days': 26.0, 'api_key': '040306252500-338-00-06-SC', 'well_id': 13832081}, {'api_no': '040306254200', 'api_no_int': 40306254200, 'prod_inj_date': datetime.date(2017, 11, 1), 'vol_month': 11, 'vol_year': 2017, 'well_status_no': '00', 'well_status': 'Active', 'well_type_cd': 'SC', 'well_status_cd': 'A', 'casing_psi': None, 'tubing_psi': None, 'gas_btu': None, ...
# 2025-02-05 12:20:56,224 INFO sqlalchemy.engine.Engine COMMIT

# %%
progress.value = 100.0

# %%
wellid_pwtid_df
# Out:
#          well_id    PWT__ID
# 0       13555180  100000001
# 1       13555181  100000002
# 2       13555182  100000003
# 3       13555183  100000004
# 4       13555184  100000005
# ...          ...        ...
# 277292  13832686  100320508
# 277293  13832687  100320509
# 277294  13832688  100320510
# 277295  13832689  100320511
# 277296  13832690  100320512
#
# [277297 rows x 2 columns]
